# %%
import numpy as np
import pandas as pd
import re
import bs4
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
from scrapy import Selector
from nltk import word_tokenize
import nltk
nltk.download('punkt') #winlocker
pd.set_option("display.max_rows", 100)
pd.set_option('display.max_colwidth', -1)
from datetime import datetime, time, date
import scrapy
from scrapy.selector import Selector
import requests
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nikzo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# ДЛЯ КОЛИ!!!!!!!!!!!!!!!!!!!!!
import requests
#ssylka = 'https://lizaalert.org/forum/viewforum.php?f=184'
ssylka = 'https://lizaalert.org/forum/viewforum.php?f=180'
html1 = requests.get(ssylka).content #url='google.com'
sel1 = Selector(text=html1)
course_as11 = sel1.xpath('//a[contains(@class,"forumtitle")]')
hrefs11_from_css = course_as11.css('::attr(href)')


hrefz = list()
for i in range(len(hrefs11_from_css.extract())):
    clean_link1 = "https://lizaalert.org/forum" + str(hrefs11_from_css.extract()[i])[1:]
    hrefz.append(clean_link1)

# %%
# Import requests
import requests

list_of_all_pages = list()
# Create the string html containing the HTML source
for i in range(len(hrefz)):
    html = requests.get(hrefz[i]).content #url='google.com'
    sel = Selector(text=html)


    uClient = uReq(hrefz[i])
    page_html = uClient.read()
    uClient.close()
    page_soup = soup(page_html, "html.parser")
    containers2 = page_soup.findAll("div", {"class":"pagination"})
    containers22 = str(containers2)
    #print(containers22)

    def page12(containers22):
        page1 = list()
        c = containers22.find("из ")
        page1.append(containers22[c+11])
        page1.append(containers22[c+12])
        if containers22[c+12] == "<":
            page1.pop()
        return page1

    print('ALOOOOOOOOOOOO', page12(containers22))
    if len(page12(containers22)) == 2:
        page_real = int(page12(containers22)[0] + page12(containers22)[1])
    else:
        page_real = int(page12(containers22)[0])
    print(page_real)

    # Парсим
    course_as = sel.xpath('//a[contains(@class,"right-box right")]')
    print(course_as)
    hrefs_from_css = course_as.css('::attr(href)')
    print(len(str(hrefs_from_css.extract())[1:]))
    #next1 = "https://lizaalert.org/forum" + str(hrefs_from_css.extract()[0])[1:]
    #print("ссылка=", next1)
    if len(str(hrefs_from_css.extract())[1:]) == 1:
        links_to_follow = ssylka
        clean_link = ssylka
    else:
        links_to_follow = "\"https://lizaalert.org/forum" + str(hrefs_from_css.extract()[0])[1:] + "\""
        clean_link = str(hrefs_from_css.extract()[0])[1:len(hrefs_from_css.extract()[0])-2]
    print(clean_link)
    list_links = list()
    for i in range((page_real)-1):
        list_links.append(clean_link)
    print(list_links)

    #За 500 надо пояснить! Но это вроде несложно
    i=0
    list1 = list()
    for i in range(0,(page_real-1)*25, 25):
        i = i + 25
        list1.append(i)
    print(list1)

    result = [str(item) for item in list1]

    #print(type(result[2]))

    for i in range(len(list1)):
        list_links[i] += result[i]
    #print(list_links)

    for i in range(len(list_links)):
        list_links[i] = "https://lizaalert.org/forum" + list_links[i]
    list_of_all_pages.append(list_links)
    print(list_of_all_pages)
    print(list_links)
    
print(list_of_all_pages, "ГДЕ Я БЛЯТЬ")
# Out:
# ALOOOOOOOOOOOO ['3']
# 3
# [<Selector xpath='//a[contains(@class,"right-box right")]' data='<a href="./viewforum.php?f=131&amp;sid=d'>]
# 70
# /viewforum.php?f=131&sid=d946d8d8950b4a4969f000a393922276&start=
# ['/viewforum.php?f=131&sid=d946d8d8950b4a4969f000a393922276&start=', '/viewforum.php?f=131&sid=d946d8d8950b4a4969f000a393922276&start=']
# [25, 50]
# [['https://lizaalert.org/forum/viewforum.php?f=131&sid=d946d8d8950b4a4969f000a393922276&start=25', 'https://lizaalert.org/forum/viewforum.php?f=131&sid=d946d8d8950b4a4969f000a393922276&start=50']]
# ['https://lizaalert.org/forum/viewforum.php?f=131&sid=d946d8d8950b4a4969f000a393922276&start=25', 'https://lizaalert.org/forum/viewforum.php?f=131&sid=d946d8d8950b4a4969f000a393922276&start=50']
# ALOOOOOOOOOOOO ['8']
# 8
# [<Selector xpath='//a[contains(@class,"right-box right")]' data='<a href="./viewforum.php?f=162&amp;sid=1'>]
# 70
# /viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=
# ['/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=', '/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=', '/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=', '/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=', '/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=', '/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=', '/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=']
# [25, 50, 75, 100, 125, 150, 175]
# [['https://lizaalert.org/forum/viewforum.php?f=131&sid=d946d8d8950b4a4969f000a393922276&start=25', 'https://lizaalert.org/forum/viewforum.php?f=131&sid=d946d8d8950b4a4969f000a393922276&start=50'], ['https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=25', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=50', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=75', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=100', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=125', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=150', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=175']]
# ['https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=25', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=50', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=75', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=100', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=125', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=150', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=175']
# ALOOOOOOOOOOOO ['2']
# 2
# [<Selector xpath='//a[contains(@class,"right-box right")]' data='<a href="./viewforum.php?f=293&amp;sid=3'>]
# 70
# /viewforum.php?f=293&sid=3d0cac573dcb492f1e8f26350384bce0&start=
# ['/viewforum.php?f=293&sid=3d0cac573dcb492f1e8f26350384bce0&start=']
# [25]
# [['https://lizaalert.org/forum/viewforum.php?f=131&sid=d946d8d8950b4a4969f000a393922276&start=25', 'https://lizaalert.org/forum/viewforum.php?f=131&sid=d946d8d8950b4a4969f000a393922276&start=50'], ['https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=25', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=50', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=75', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=100', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=125', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=150', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=175'], ['https://lizaalert.org/forum/viewforum.php?f=293&sid=3d0cac573dcb492f1e8f26350384bce0&start=25']]
# ['https://lizaalert.org/forum/viewforum.php?f=293&sid=3d0cac573dcb492f1e8f26350384bce0&start=25']
# ALOOOOOOOOOOOO ['4']
# 4
# [<Selector xpath='//a[contains(@class,"right-box right")]' data='<a href="./viewforum.php?f=157&amp;sid=7'>]
# 70
# /viewforum.php?f=157&sid=724c04b3bbbc56b8654692ebe12bc40a&start=
# ['/viewforum.php?f=157&sid=724c04b3bbbc56b8654692ebe12bc40a&start=', '/viewforum.php?f=157&sid=724c04b3bbbc56b8654692ebe12bc40a&start=', '/viewforum.php?f=157&sid=724c04b3bbbc56b8654692ebe12bc40a&start=']
# [25, 50, 75]
# [['https://lizaalert.org/forum/viewforum.php?f=131&sid=d946d8d8950b4a4969f000a393922276&start=25', 'https://lizaalert.org/forum/viewforum.php?f=131&sid=d946d8d8950b4a4969f000a393922276&start=50'], ['https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=25', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=50', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=75', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=100', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=125', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=150', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=175'], ['https://lizaalert.org/forum/viewforum.php?f=293&sid=3d0cac573dcb492f1e8f26350384bce0&start=25'], ['https://lizaalert.org/forum/viewforum.php?f=157&sid=724c04b3bbbc56b8654692ebe12bc40a&start=25', 'https://lizaalert.org/forum/viewforum.php?f=157&sid=724c04b3bbbc56b8654692ebe12bc40a&start=50', 'https://lizaalert.org/forum/viewforum.php?f=157&sid=724c04b3bbbc56b8654692ebe12bc40a&start=75']]
# ['https://lizaalert.org/forum/viewforum.php?f=157&sid=724c04b3bbbc56b8654692ebe12bc40a&start=25', 'https://lizaalert.org/forum/viewforum.php?f=157&sid=724c04b3bbbc56b8654692ebe12bc40a&start=50', 'https://lizaalert.org/forum/viewforum.php?f=157&sid=724c04b3bbbc56b8654692ebe12bc40a&start=75']
# [['https://lizaalert.org/forum/viewforum.php?f=131&sid=d946d8d8950b4a4969f000a393922276&start=25', 'https://lizaalert.org/forum/viewforum.php?f=131&sid=d946d8d8950b4a4969f000a393922276&start=50'], ['https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=25', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=50', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=75', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=100', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=125', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=150', 'https://lizaalert.org/forum/viewforum.php?f=162&sid=1c791758b2451628e7d197bd6a10511f&start=175'], ['https://lizaalert.org/forum/viewforum.php?f=293&sid=3d0cac573dcb492f1e8f26350384bce0&start=25'], ['https://lizaalert.org/forum/viewforum.php?f=157&sid=724c04b3bbbc56b8654692ebe12bc40a&start=25', 'https://lizaalert.org/forum/viewforum.php?f=157&sid=724c04b3bbbc56b8654692ebe12bc40a&start=50', 'https://lizaalert.org/forum/viewforum.php?f=157&sid=724c04b3bbbc56b8654692ebe12bc40a&start=75']] ГДЕ Я БЛЯТЬ

# %%
print(len(list_of_all_pages))
listSYKA = list()
for i in range(len(list_of_all_pages)):
    for j in range(len(list_of_all_pages[i])):
        listSYKA.append(list_of_all_pages[i][j])

for j in range(len(hrefz)):
    listSYKA.append(hrefz[j])
listSYKA.append(ssylka)
# Out:
# 4

# %%
list_full = list()
for i in range(len(listSYKA)):
    #html = requests.get(list_links[i]).content #url='google.com'
    html = requests.get(listSYKA[i]).content #url='google.com'
    sel = Selector(text=html)

    course_as1 = sel.css('a.topictitle')
    hrefs1_from_css = course_as1.css('::attr(href)')

    list0 = list()
    for i in range(0, len(hrefs1_from_css.extract())):
        list0.append("https://lizaalert.org/forum" + str(hrefs1_from_css.extract()[i])[1:])
        list_full.append(list0[i])
#print(list_full)
print(len(list_full))
# Out:
# 398

# %%
my_list = list_full

# %%
my_list[0]
print(len(list_full))
# Out:
# 398

# %% [markdown]
# # Здесь соберем все вспомогательные перменные

# %%
list_searchers = []
list_photo = []
list_state1 = []
list_sex1 = []
list_age11 = []
list_posts = []
list_height = []
list_help1 = []
list_hair_color = []
list_bodytype = []
list_eye = []
list_of_lists = []  ## Здесь нужно додумать
list_place = []
list_color_of_clothes = []# Бабкен Вставил
list_of_lists = []  ## Здесь нужно додумать
list_podrobnost = []
list_primeti = []
list_search_time =[]
list_lost_time = []
list_find_time = []
list_of_coor = []

# %%
english_stops = ['.', ',', ':', ';', "!", "?", '-', ')', '(']
months_num = {"янв": 1, "фев": 2, "мар": 3,"апр": 4,"мая": 5, "май": 5,"июн": 6,"июл": 7,"авг": 8,"сен": 9,"окт": 10,"ноя": 11,"дек": 12}

# %% [markdown]
# # Напишем все функции, которые нам понадобятся в сборе признаков

# %%
def searchers(containers228):
    if containers228 == 'ebanyi obychenie':
        searchers = 0
    else:
        kerka = containers228.findAll(text=re.compile(r'\w+'))
        kerka1 = containers228.findAll(text=re.compile(r'На месте|НА МЕСТЕ|Дом|ДОМ|Экипаж|ЭКИПАЖ'))
        searchers = (len(kerka) - len(kerka1))
    return searchers

# %%
def photo1(containers11):
    if containers11.find("Изображение") != -1:
        photo =  'присутствует'
    else:
        photo = 'отсутствует'
    return photo

# %%
def state1(title1):
    if title1.find("Жив") != -1 or title1.find("ЖИВ") != -1 or title1.find("Найден") != -1 or title1.find("НАЙДЕН") != -1:
        state = "живой"
    elif title1.find("Пропал") != -1 or title1.find("ПРОПАЛ") != -1:
        state = 'ищется'
    elif title1.find("Погиб") != -1 or title1.find("ПОГИБ") != -1 or title1.find("Мертв") != -1 or title1.find("МЕРТВ") != -1:
        state = 'мертвый'
    else:
        state = "Не указано"
    return state

# %%
def sex1(title1): # Слава вставил 8 мая 
    sex = re.search(r'[Пп]ропала|[Вв]ышла|[Уу]шла|[Нн]айдена|[Жж]ива|[Ее]ё|[Ее]е|[Ее]го|[Уу]ехала|[Пп]огибла|[Вв]ернулась|не [Вв]ернулась|[Вв]ышел|[Уу]шёл|[Уу]шел|[Пп]ропал|[Нн]айден|[Жж]ив|[Ее]го|[Уу]ехал|[Пп]огиб|[Вв]ернулся|не [Вв]ернулся', title1)
    if sex is None:
        return "Er"
    sex = str(sex.group(0))
    if sex == "вышел" or sex == "Вышел" or sex == "ушел" or sex == "Ушел" or sex == 'ушёл' or sex == 'пропал' or sex == 'Пропал' or sex == 'Найден' or sex == 'найден' or sex == 'ушел'or sex == 'ушёл'or sex == 'пропал'or sex == 'найден'or sex == 'Найден'or sex == 'вышел' or sex == 'Жив'or sex == 'жив' or sex == 'уехал'or sex == 'Погиб'or sex == 'погиб'or sex == 'вернулся':
        sex = "Мужчина"
    else:
        sex = "Женщина"
    return sex

# %%
def age11(title1):
    preage = re.search(r'\d+', str(title1))
    if preage is None:
        return "Коля объебался"
    else:
        age = preage.group()
        if len(age) == 4:
            age = 2019 - int(age)
    return age

# %%
def posts1(containers2):
    posts = re.search(r'\d+', str(containers2)).group()
    return posts

# %%
def data1(containers88):
    d = containers88.find("Инфорг")
    if d == -1:
        data1, data2 = 'не','редактировали'
    else:
        data1 = containers88[d+11] + containers88[d+12] + containers88[d+13] + containers88[d+14] + containers88[d+15] + containers88[d+16] + containers88[d+17] + containers88[d+18] + containers88[d+19] + containers88[d+20] + containers88[d+21]
        data2 = containers88[d+24] + containers88[d+25] + containers88[d+26] + containers88[d+27] + containers88[d+28]
        data = data1 + ' ' + data2
    return data

# %%
def height(containers11): # Вставил Слава 8.05.2019
    high = re.search(r'[Рр]ост \d{3}|[Рр]оста \d{3}|[Рр]оста\d{3}|[Рр]ост: \d{3}|[Рр]ост - \d{3}|рост\d{3}-|Рост:\d{3}| росто \d{3}', containers11 )
    if high is None:
        return "Er"
    high = str(high.group(0))

    height = re.findall(r'\d+',high)
    height = int(" ".join(height))
    return height

# %%
def help1(containers11):
    if containers11.find("В МЕДИЦИНСКОЙ ПОМОЩИ") == -1 and containers11.find("в медицинской помощи") == -1:
        help1 = 'здоров'
    else:
        help1 = 'требуется мед. помощь'
    return help1

# %%
def hair_color(contents):
    hc = 'Не указано'
    for string in contents:
        if "олосы" in string:
            no_stops_string_1 = ''.join([t for t in string if t not in english_stops])
            tokens_1 = word_tokenize(no_stops_string_1)
            for i in range(len(tokens_1)):
                if "олосы" in tokens_1[i]:
                    if i < (len(tokens_1) - 1):
                        hc = tokens_1[i + 1]
                    else:
                        hc = tokens_1[i-1]
    return hc

# %%
## Нужно доработать код! Или сделать заново
def body_type(contents):
    body = "Не указано"
    for string in contents:
        if "елосложени" in string:
            no_stops_string = ''.join([t for t in string if t not in english_stops])
            tokens = word_tokenize(no_stops_string)
            tokens.append("Ты объебался")
            for i in range(len(tokens)):
                if "елосложени" in tokens[i]:
                    if tokens[i][-1] == "я":
                        body = tokens[i - 1]
                        break
                    else:
                        body = tokens[i + 1]
                        break
    return body

# %%
## Нужно доработать код! Или сделать заново
def eyes_color(contents):
    ec = "Не указано"
    for string in contents:
        if "лаз" in string:
            no_stops_string = ''.join([t for t in string if t not in english_stops])
            tokens = word_tokenize(no_stops_string)
            tokens.append("Кто-то объебался")
            for i in range(len(tokens)):
                if "лаз" in tokens[i]:
                    ec = tokens[i + 1]
                if ec == "Кто-то объебался":
                    ec = tokens[i-1]
                    break
    return ec

# %%
def yebanskii(sel):
    p = sel.css("div.content").xpath('./span[@style="font-size: 140%; line-height: 116%;"]/span[@style="font-weight: bold"]/text()').extract()
    a = str(p)
    b = re.split('\s+', a)
    b1 = b[5:]
    t = str(b1)
    p = t.replace("\'", "")
    p1 = p.replace(']', '')
    p2 = p1.replace('[', '')
    p3 = p2.replace('"', '')
    p4 = p3.replace(', ', " ")
    p5 = p4.replace('- ','-')
    return p5

# %%
def color_cloth(containers11):
    containers1 = re.split('<span style="font-weight: bold">', containers11)
    if len(containers1) < 4:
        return "Не указано"
    else:
        containers_new = containers1[3]
        black = len(re.findall(r'черн', containers_new))
        white = len(re.findall(r'бел', containers_new))
        yellow = len(re.findall(r'желт', containers_new))
        orange = len(re.findall(r'оранж', containers_new))
        br_grey = len(re.findall(r'тло-сер', containers_new))
        grey = len(re.findall(r'сер', containers_new))
        beg = len(re.findall(r'бежев', containers_new))
        br_blue = len(re.findall(r'тло-син', containers_new))
        blue = len(re.findall(r'син', containers_new))
        green = len(re.findall(r'зелен', containers_new))
        violent = len(re.findall(r'фиол', containers_new))
        black1 = len(re.findall(r'чёрн', containers_new))
        brown = len(re.findall(r'коричн', containers_new))
        al_colors = black + yellow + orange + grey + beg + blue + green + violent + black1
        br_colors1 = white + yellow + orange + br_grey + beg + br_blue + green + violent
        br_colors2 = white + yellow + orange + beg + br_blue + green + violent
        br_colors3 = white + yellow + orange + br_grey + beg + green + violent
        br_colors4 = white + yellow + orange + beg + green + violent
        dk_colors1 = black + black1 + brown
        dk_colors2 = black + grey + black1 + brown
        dk_colors3 = black + blue + black1 + brown
        dk_colors4 = black + blue + grey + black1 + brown
        if al_colors == 0:
            return "Не указано" 
        elif (br_grey == 0 and br_blue == 0) and br_colors4 >= dk_colors4:
            return "Яркая"
        elif (br_grey == 0 and br_blue == 0) and br_colors4 < dk_colors4:
            return "Темная"
        elif ((br_grey != 0 and grey != 0) or (br_blue != 0 and blue != 0 )) and br_colors1 >= dk_colors4:
            return "Яркая"
        elif ((br_grey != 0 and grey != 0) or (br_blue != 0 and blue != 0 )) and br_colors1 < dk_colors4:
            return "Темная"
        elif (br_grey == 0) and br_colors2 >= dk_colors2:
            return "Яркая" 
        elif (br_grey == 0) and br_colors2 < dk_colors2:
            return "Темная" 
        elif (br_blue == 0) and br_colors3 >= dk_colors3:
            return "Яркая"

# %%
def podrobnost(containers11):
    containers1 = re.split('<span style="font-weight: bold">', containers11)
    if len(containers1) < 4:
        return("Не указано")
    else:
        containers_new = containers1[3]
        containers_new_sep = containers_new.split(',')
        l = len(containers_new_sep)
        if l > 3:
            return 4
        elif 2 <= l < 3:
            return 3
        else:
            return 0

# %%
def primeti(containers11):
    containers1 = re.split('<span style="font-weight: bold">', containers11)
    if len(containers1) < 5:
        return("Не указано")
    else:
        containers_new = containers1[4]
        containers_new_sep = containers_new.split(',')
        l = len(containers_new_sep)
        if l > 3:
            return 4
        elif 2 <= l < 3:
            return 2
        else:
            return 0

# %%
def lost_timing(x):
    if re.search(r'\d+ \w+ \d{4}|\d{2}.\d{2}.\d{4}', x) == None:
        return "Сбой"
    else:
        lost_time = re.search(r'\d+ \w+ \d{4}|\d{2}.\d{2}.\d{4}', x).group()
        print(lost_time)
        if "я" in lost_time or "т" in lost_time:
            lts = lost_time.split()
            print(lts)
            lts[1] = months_num[lts[1][:3]]
            lts = list(map(int, lts))
            lost_time = date(lts[-1], lts[-2], lts[-3])
            return lost_time
            #lost_time = date(lts[-1], [-2], [-3])
        else:
            lts = lost_time.split('.')
            lts = list(map(int, lts))
            lost_time = date(lts[-1], lts[-2], lts[-3])
            return lost_time

# %%
def find_timing(x):
    if re.search(r'\d+ \w+ \d{4}|\d{2}.\d{2}.\d{4}', x) == None:
        return "Сбой"
    else:
        find_time = re.search(r'\d+ \w+ \d{4}|\d{2}.\d{2}.\d{4}', x).group()
        print(find_time)
        fts = find_time.split()
        print(fts)
        fts[1] = months_num[fts[1]]
        fts = list(map(int, fts))
        find_time = date(fts[-1], fts[-2], fts[-3])
        return find_time

# %%
def search_timing(x, y):
    return (find_timing(y) - lost_timing(x)).days

# %%
def super_format(function, x):
    if len(str(function(x).day)) == 1:
        day = "0" + str(function(x).day)
    else:
        day = str(function(x).day)
    if len(str(function(x).month)) == 1:
        month = "0" + str(function(x).month)
    else:
        month = str(function(x).month)
    return day + "." + month + "." + str(function(x).year)

# %%
def find_cor(comp):
    for i in range (len(comp)):
        contents = page_soup.findAll("div", {"class":"content"})[i].contents
        kavka = re.search(r'\d+.\d+, \d+.\d+|\d+.\d+,\d+.\d+|\d+.\d+ \d+.\d+', str(contents))
        if kavka is not None:
            kavkaz = kavka.group()
            break
        else:
            kavkaz = 'no cord'
    return kavkaz

# %% [markdown]
# # Перейдем к сбору признаков

# %%
for i in my_list:
    my_url = i
    uClient = uReq(my_url)
    page_html = uClient.read()
    uClient.close()
    page_soup = soup(page_html, "html.parser")
    title = page_soup.title
    title1 = str(title)

    comp = page_soup.findAll("div", {"class":"content"})
    containers = page_soup.findAll("div", {"class":"content"})
    contents = page_soup.findAll("div", {"class":"content"})[0].contents
    containers11 = str(containers)
    containers2 = page_soup.findAll("div", {"class":"pagination"})
    containers22 = str(containers2)
    containers8 = page_soup.findAll("div", {"class":"notice"})
    containers88 = str(containers8) 
    containers1 = re.split('<span style="font-weight: bold">', containers11)
    #containers1
    if len(page_soup.findAll("div", {"class":"content"})) > 1:
        containers228 = page_soup.findAll("div", {"class":"content"})[1]
    else:
        containers228 = 'ebanyi obychenie'
    
    list_searchers.append(searchers(containers228))
    list_photo.append(photo1(containers11))
    list_state1.append(state1(title1))
    list_sex1.append(sex1(title1))
    list_age11.append(age11(title1))
    list_posts.append(posts1(containers22))
    list_hair_color.append(hair_color(contents))
    list_bodytype.append(body_type(contents))
    list_eye.append(eyes_color(contents))
    containers = page_soup.findAll("div", {"class":"content"})
    containers11 = str(containers)
    list_height.append(height(containers11))
    list_help1.append(help1(containers11))
    list_place.append(yebanskii(sel))
    list_color_of_clothes.append(color_cloth(containers11)) # Бабкен вставил
    list_podrobnost.append(podrobnost(containers11)) # Бабкен вставил еще раз, но уже Ване
    list_primeti.append(primeti(containers11))
    if page_soup.find('div', {'class':'content'}) != None and page_soup.find('div', {'class':'notice'}) != None:
        main = page_soup.find('div', {'class':'content'}).text
        notmain = page_soup.find('div', {'class':'notice'}).text
        #if lost_timing(main) != "Сбой" and find_timing(notmain) != "Сбой":
        #    list_search_time.append(search_timing(main, notmain))
        #    list_lost_time.append(super_format(lost_timing, main))
        #    list_find_time.append(super_format(find_timing,notmain))
        #else:
        #    list_search_time.append("Ошибка")
        #    list_lost_time.append("Ошибка")
        #    list_find_time.append("Ошибка")
    #else:
        #list_search_time.append("Ошибка")
        #list_lost_time.append("Ошибка")
        #list_find_time.append("Ошибка")
    list_of_coor.append(find_cor(comp))

# %%
list_of_coor
# Out:
# ['no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '303-9011, 8-964',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '44.798627, 38.637727',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '303-9011, 8-964',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '44.798627, 38.637727',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '303-9011, 8-964',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '44.798627, 38.637727',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '45.024527, 38.974713',
#  '46,185300, 39,436079',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '44.731529, 37.741134',
#  'no cord',
#  '45.456156, 39.445658',
#  'no cord',
#  '45.227154, 38.999370',
#  'no cord',
#  'no cord',
#  '45.087765, 38.980757',
#  '44,5463990, 38,2235640',
#  '45.299099, 39.932770',
#  'no cord',
#  'no cord',
#  'no cord',
#  '44.923438, 37.983729',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '45.220209, 39.226760',
#  'no cord',
#  'no cord',
#  'no cord',
#  '45.032980, 38.997061',
#  'no cord',
#  '46.039774, 38.193887',
#  'no cord',
#  'no cord',
#  'no cord',
#  '45.290280, 39.556061',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '44.818409, 37.934841',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '44.748184, 39.006432',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '89-29, 8-985',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '10/17, 12.02',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '45.272083, 33.089038',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '16,17,18,19',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '29.05, 30.05',
#  'no cord',
#  '45.019481, 38.998771',
#  'no cord',
#  'no cord',
#  '44.175571, 40.619266',
#  'no cord',
#  '43.585636, 39.725936',
#  '45.056715, 39.010159',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '45.033369, 39.002047',
#  'no cord',
#  'no cord',
#  '45.151649, 41.121476',
#  'no cord',
#  '45.006367, 39.016321',
#  '45.036130, 39.011412',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord']

# %% [markdown]
# Парсим посты, копаем вглубь!

# %%
list_of_all_pages1 = list()

for i in my_list:
    URL = i
    
    html = requests.get(URL).content #url='google.com'
    sel = Selector(text=html)

    uClient = uReq(URL)
    page_html = uClient.read()
    uClient.close()
    page_soup = soup(page_html, "html.parser")
    containers2 = page_soup.findAll("div", {"class":"pagination"})
    containers22 = str(containers2)

    def page12(containers22):
        page1 = list()
        c = containers22.find("из ")
        page1.append(containers22[c+11])
        page1.append(containers22[c+12])
        if containers22[c+12] == "<":
            page1.pop()
            return page1

    if page12(containers22) is None:
        page_real = 1
    else:
        if len(page12(containers22)) == 2:
            page_real = int(page12(containers22)[0] + page12(containers22)[1])
        else:
            page_real = int(page12(containers22)[0])

        # Парсим
    course_as = sel.xpath('//a[contains(@class,"right-box right")]')
    hrefs_from_css = course_as.css('::attr(href)')

    if len(str(hrefs_from_css.extract())[1:]) == 1:
        links_to_follow = URL
        clean_link = URL[27:len(URL)]
    else:
        links_to_follow = "\"https://lizaalert.org/forum" + str(hrefs_from_css.extract()[0])[1:] + "\""
        clean_link = str(hrefs_from_css.extract()[0])[1:len(hrefs_from_css.extract()[0])-2]

    list_links = list()
    for i in range((page_real)):
        list_links.append(clean_link)


        #За 500 надо пояснить! Но это вроде несложно
    i=0
    list1 = [0]
    for i in range(0,(page_real-1)*10, 10):
        i = i + 10
        list1.append(i)

    result = [str(item) for item in list1]

    for i in range(len(list1)):
        if list_links[i].find("start") != -1:
            list_links[i] += result[i]
        
    for i in range(len(list_links)):
        list_links[i] = "https://lizaalert.org/forum" + list_links[i]
    
    list_of_all_pages1.append(list_links)

# %%
print(list_of_all_pages1[1])
list_vk_posts = []
for j in range(len(list_of_all_pages1)):
    vk_posts = 0
    vk_postes = []
    for item in range(len(list_of_all_pages1[j])):
        vk_post = []
        uClient = uReq(list_of_all_pages1[j][item])
        page_html = uClient.read()
        uClient.close()
        page_soup = soup(page_html, "html.parser")
        for p in range(len(page_soup.findAll("div", {"class":"content"}))):
            containers2 = page_soup.findAll("div", {"class":"content"})[p] #ЧТО ЭТО ЗА ХУЙНЯ?????????
            kirka = containers2.findAll(text=re.compile("vk.com"))
            vk_post.append(len(kirka))
        vk_postes.append(vk_post)
    vk_posts += vk_posts
    for i in range(len(vk_postes)):
        for k in range(len(vk_postes[i])):
            vk_posts += vk_postes[i][k]
    list_vk_posts.append(vk_posts)
# Out:
# ['https://lizaalert.org/forum/viewtopic.php?f=131&t=9861&sid=7b0d97815a102ff0f7262de9c3662d34']

# %%
print(list_of_all_pages1[1])
list_odn_posts = []
for j in range(len(list_of_all_pages1)):
    odn_posts = 0
    odn_postes = []
    odn_post = []
    for item in range(len(list_of_all_pages1[j])):
        uClient = uReq(list_of_all_pages1[j][item])
        page_html = uClient.read()
        uClient.close()
        page_soup = soup(page_html, "html.parser")
        for p in range(len(page_soup.findAll("div", {"class":"content"}))):
            containers2 = page_soup.findAll("div", {"class":"content"})[p] #ЧТО ЭТО ЗА ХУЙНЯ?????????
            kirka = containers2.findAll(text=re.compile(r'odnokl|ok.ru'))
            odn_post.append(len(kirka))
    odn_postes.append(odn_post)
    odn_posts += odn_posts
    for i in range(len(odn_postes)):
        for k in range(len(odn_postes[i])):
            odn_posts += odn_postes[i][k]
    list_odn_posts.append(odn_posts)
# Out:
# ['https://lizaalert.org/forum/viewtopic.php?f=131&t=9861&sid=7b0d97815a102ff0f7262de9c3662d34']

# %%
print(list_of_all_pages1[0])
list_ready_posts = []
for j in range(len(list_of_all_pages1)):
    ready_posts = 0
    ready_postes = []
    for item in range(len(list_of_all_pages1[j])):
        ready_post = []
        uClient = uReq(list_of_all_pages1[j][item])
        page_html = uClient.read()
        uClient.close()
        page_soup = soup(page_html, "html.parser")
        for p in range(len(page_soup.findAll("div", {"class":"content"}))):
            containers2 = page_soup.findAll("div", {"class":"content"})[p] #ЧТО ЭТО ЗА ХУЙНЯ?????????
            kirka = containers2.findAll(text=re.compile(r'[Гг]отов'))
            ready_post.append(len(kirka))
        ready_postes.append(ready_post)
    ready_posts += ready_posts
    for i in range(len(ready_postes)):
        for k in range(len(ready_postes[i])):
            ready_posts += ready_postes[i][k]
    list_ready_posts.append(ready_posts)
# Out:
# ['https://lizaalert.org/forum/viewtopic.php?f=131&t=11738&sid=7b0d97815a102ff0f7262de9c3662d34']

# %% [markdown]
# Для таблицы

# %%
list_of_lists.append(list_ready_posts)
list_of_lists.append(list_searchers)
list_of_lists.append(list_vk_posts)
list_of_lists.append(list_odn_posts)
list_of_lists.append(list_age11)
list_of_lists.append(list_height)
list_of_lists.append(list_help1)
list_of_lists.append(list_photo)
list_of_lists.append(list_posts)
list_of_lists.append(list_sex1)
list_of_lists.append(list_state1)
list_of_lists.append(list_hair_color)
list_of_lists.append(list_bodytype)
list_of_lists.append(list_eye)
list_of_lists.append(list_full)
list_of_lists.append(list_place)
list_of_lists.append(list_color_of_clothes) # Бабкен вставил
list_of_lists.append(list_podrobnost) # Бабкен вставил еще раз, но уже себе
list_of_lists.append(list_primeti)
list_of_lists.append(list_search_time)
list_of_lists.append(list_lost_time)
list_of_lists.append(list_find_time)
# Бабкен вставил снова, только Коле в пердачело

# %%
df1 = pd.DataFrame(columns = ['Готовые', 'Искатели', 'Репосты_вк', 'Репосты_одн', 'Возраст', 'Рост(Slava)', 'Мед. Состояние', 'Фото', 'Посты', 'Гендер(Slava)', 'Состояние(Slava)', 'Цвет волос', 'Телосложение', 'Цвет глаз', 'Url','Место', 'Одежда(яркая)', 'Одежда(подробность)', 'Приметы(кол-во)', 'Время поиска', "Время пропажи", "Время нахождения", "Координаты пропажи"])

# %%
for i, j in zip(list_of_lists, list(df1.columns)):
    df1[j] = pd.Series(i)

# %% [markdown]
# # Тадаам ! Вот , что мы получили

# %%
df1.head()
# Out:
#    Готовые  Искатели  Репосты_вк  Репосты_одн         Возраст Рост(Slava)  \
# 0  2        0         0           0            Коля объебался  Er
# 1  0        1         0           0            63              170
# 2  1        1         0           0            12              160
# 3  0        1         0           0            35              160
# 4  0        1         0           0            23              175
#
#           Мед. Состояние          Фото Посты Гендер(Slava)  ...   Цвет глаз  \
# 0  здоров                 отсутствует   1     Er            ...  Не указано
# 1  требуется мед. помощь  присутствует  5     Er            ...  голубые
# 2  здоров                 присутствует  6     Мужчина       ...  голубые
# 3  здоров                 присутствует  2     Мужчина       ...  голубые
# 4  здоров                 присутствует  2     Мужчина       ...  карие
#
#                                                                                             Url  \
# 0  https://lizaalert.org/forum/viewtopic.php?f=131&t=11738&sid=7b0d97815a102ff0f7262de9c3662d34
# 1  https://lizaalert.org/forum/viewtopic.php?f=131&t=9861&sid=7b0d97815a102ff0f7262de9c3662d34
# 2  https://lizaalert.org/forum/viewtopic.php?f=131&t=8973&sid=7b0d97815a102ff0f7262de9c3662d34
# 3  https://lizaalert.org/forum/viewtopic.php?f=131&t=8847&sid=7b0d97815a102ff0f7262de9c3662d34
# 4  https://lizaalert.org/forum/viewtopic.php?f=131&t=8748&sid=7b0d97815a102ff0f7262de9c3662d34
#
#   Место Одежда(яркая) Одежда(подробность) Приметы(кол-во) Время поиска  \
# 0        Не указано    Не указано          Не указано     NaN
# 1        Яркая         4                   0              NaN
# 2        Темная        4                   0              NaN
# 3        Не указано    4                   4              NaN
# 4        Яркая         4                   2              NaN
#
#   Время пропажи Время нахождения  Координаты пропажи
# 0 NaN           NaN               NaN
# 1 NaN           NaN               NaN
# 2 NaN           NaN               NaN
# 3 NaN           NaN               NaN
# 4 NaN           NaN               NaN
#
# [5 rows x 23 columns]

# %%
df1["Цвет волос"]
# Out:
# 0      Не указано
# 1      седые
# 2      русые
# 3      русые
# 4      русые
# 5      Не указано
# 6      светлорусые
# 7      русые
# 8      каштановые
# 9      седые
# 10     русые
# 11     русые
# 12     чёрные
# 13     каштановые
# 14     тёмный
# 15     русые
# 16     светлорусые
# 17     светлорусые
# 18     тёмные
# 19     седые
# 20     тёмные
# 21     тёмные
# 22     тёмные
# 23     седые
# 24     седые
# 25     тёмнорусые
# 26     Не указано
# 27     Не указано
# 28     русые
# 29     Не указано
# 30     Не указано
# 31     короткие
# 32     Не указано
# 33     светлорусые
# 34     седые
# 35     темные
# 36     Не указано
# 37     темные
# 38     светлорусые
# 39     седые
# 40     черные
# 41     короткие
# 42     Не указано
# 43     седые
# 44     русые
# 45     русые
# 46     русые
# 47     Не указано
# 48     светлорусые
# 49     русые
#        ...
# 348    Черные
# 349    Не указано
# 350    до
# 351    русые
# 352    Не указано
# 353    тёмные
# 354    Не указано
# 355    Не указано
# 356    Не указано
# 357    Не указано
# 358    Не указано
# 359    Не указано
# 360    Не указано
# 361    Не указано
# 362    прямые
# 363    Не указано
# 364    Не указано
# 365    Не указано
# 366    Не указано
# 367    на
# 368    Не указано
# 369    Не указано
# 370    чёрные
# 371    каштановые
# 372    седые
# 373    светлорусые
# 374    седые
# 375    рыжеватые
# 376    светлорусые
# 377    Не указано
# 378    короткие
# 379    Не указано
# 380    седые
# 381    седые
# 382    седые
# 383    седые
# 384    русые
# 385    светлокаштановые
# 386    Седые
# 387    седые
# 388    черные
# 389    Не указано
# 390    светлые
# 391    седые
# 392    тёмные
# 393    седые
# 394    седые
# 395    Не указано
# 396    седые
# 397    высветленные
# Name: Цвет волос, Length: 398, dtype: object

# %%
len(df1["Время поиска"][df1["Время поиска"] == "Ошибка"])/ len(df1["Время поиска"])

# %%
list_of_coor

# %% [markdown]
# Пока дальше не нужно смотреть ( Славе)

# %%
df1.shape

# %%
count = 0
for element in  df1["Телосложение"][:19]:
    if element == "Не указано":
        count += 1
count/len(df1["Телосложение"][:19])

# %% [markdown]
# TRY EXCEL

# %%
filename = "post7.csv"
f = open(filename, "w")
headers = "age1, height, posts\n"
f.write(headers)

# %% [markdown]
# Так, осталось выпарсить (хотя бы ублюдочно):
# 1) время пропажи
# 2) телосложение
# 3) цвет глаз
# 4) волосы
# 5) одежда???
#
# А сейчас PPPPANDA, PPPAND, PPPPPPPANDA:

# %%
# PAAAANDA, PPPPANDA, LADDDNO (c) illumate & obladaet
