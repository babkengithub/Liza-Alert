# %%
import numpy as np
import pandas as pd
import re
import bs4
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
from scrapy import Selector

# %%
# Import requests
import requests

# Create the string html containing the HTML source
html = requests.get('https://lizaalert.org/forum/viewforum.php?f=213').content #url='google.com'

# Create the Selector object sel from html
sel = Selector(text=html)


uClient = uReq('https://lizaalert.org/forum/viewforum.php?f=213')
page_html = uClient.read()
uClient.close()
page_soup = soup(page_html, "html.parser")
containers2 = page_soup.findAll("div", {"class":"pagination"})
containers22 = str(containers2)
#print(containers22)

def page12(containers22):
    page1 = list()
    c = containers22.find("из ")
    page1.append(containers22[c+11])
    page1.append(containers22[c+12])
    if containers22[c+12] == "<":
        page1.pop()
    return page1

print('ALOOOOOOOOOOOO', page12(containers22))
if len(page12(containers22)) == 2:
    page_real = int(page12(containers22)[0] + page12(containers22)[1])
else:
    page_real = int(page12(containers22)[0])
print(page_real)

# Парсим
course_as = sel.xpath('//a[contains(@class,"right-box right")]')
print(course_as)
hrefs_from_css = course_as.css('::attr(href)')
print(str(hrefs_from_css)[1:])
next1 = "https://lizaalert.org/forum" + str(hrefs_from_css.extract()[0])[1:]
print("ссылка=", next1)
links_to_follow = "\"https://lizaalert.org/forum" + str(hrefs_from_css.extract()[0])[1:] + "\""
print(links_to_follow)

clean_link = str(hrefs_from_css.extract()[0])[1:len(hrefs_from_css.extract()[0])-2]
print(clean_link)
list_links = list()
for i in range((page_real)-1):
    list_links.append(clean_link)
print(list_links)

#За 500 надо пояснить! Но это вроде несложно
i=0
list1 = list()
for i in range(0,(page_real-1)*25, 25):
    i = i + 25
    list1.append(i)
print(list1)

result = [str(item) for item in list1]

#print(type(result[2]))

for i in range(len(list1)):
    list_links[i] += result[i]
#print(list_links)

for i in range(len(list_links)):
    list_links[i] = "https://lizaalert.org/forum" + list_links[i]
#print(list_links[10])
print(list_links)
# Out:
# ALOOOOOOOOOOOO ['2', '2']
# 22
# [<Selector xpath='//a[contains(@class,"right-box right")]' data='<a href="./viewforum.php?f=213&amp;sid=4'>]
# <Selector xpath='descendant-or-self::*/@href' data='./viewforum.php?f=213&sid=4e67a8e2c583ed'>]
# ссылка= https://lizaalert.org/forum/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=25
# "https://lizaalert.org/forum/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=25"
# /viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=
# ['/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=', '/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=', '/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=', '/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=', '/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=', '/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=', '/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=', '/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=', '/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=', '/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=', '/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=', '/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=', '/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=', '/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=', '/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=', '/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=', '/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=', '/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=', '/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=', '/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=', '/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=']
# [25, 50, 75, 100, 125, 150, 175, 200, 225, 250, 275, 300, 325, 350, 375, 400, 425, 450, 475, 500, 525]
# ['https://lizaalert.org/forum/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=25', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=50', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=75', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=100', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=125', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=150', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=175', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=200', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=225', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=250', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=275', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=300', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=325', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=350', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=375', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=400', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=425', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=450', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=475', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=500', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=4e67a8e2c583edf450506cb972dd5dde&start=525']

# %%
list_full = list()
#url = "'" + list_links[5] + "'"
#url1 = list_links[7]
for i in range((page_real)-1):
    html = requests.get(list_links[i]).content #url='google.com'
    sel = Selector(text=html)

    course_as1 = sel.css('a.topictitle')
    hrefs1_from_css = course_as1.css('::attr(href)')
#syka
    list0 = list()
    for i in range(0, len(hrefs1_from_css.extract())):
        list0.append("https://lizaalert.org/forum" + str(hrefs1_from_css.extract()[i])[1:])
        list_full.append(list0[i])
#print(list_full)
print(len(list_full))
# Out:
# 533

# %%
list_photo = []
list_state1 = []
list_sex1 = []
list_age11 = []
list_posts = []
list_height = []
list_help1 = []
list_of_lists = []

# %%
import numpy as np
import pandas as pd
import re
import bs4
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=207&t=13895'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=120&t=23928'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=120&t=23870'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=120&t=23888'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=120&t=24848'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=278&t=17946'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=278&t=16803'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=278&t=16825'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=278&t=15587'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=278&t=13990'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=278&t=15023'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=278&t=15418'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=278&t=14037'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=278&t=14031'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=278&t=14139'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=120&t=25101'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=120&t=23673'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=120&t=23928'!!!
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=120&t=25066'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=120&t=25139'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=189&t=4292' 
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=189&t=23654'
#!my_url = 'https://lizaalert.org/forum/viewtopic.php?f=187&t=8495'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=187&t=18999'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=187&t=18845'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=123&t=23194'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=287&t=23834'


#my_list = ['https://lizaalert.org/forum/viewtopic.php?f=278&t=16825',
#'https://lizaalert.org/forum/viewtopic.php?f=120&t=23928',
#'https://lizaalert.org/forum/viewtopic.php?f=207&t=13895',
#'https://lizaalert.org/forum/viewtopic.php?f=120&t=23888',
#'https://lizaalert.org/forum/viewtopic.php?f=120&t=24848',
#'https://lizaalert.org/forum/viewtopic.php?f=278&t=17946',
#'https://lizaalert.org/forum/viewtopic.php?f=120&t=23870',
#'https://lizaalert.org/forum/viewtopic.php?f=278&t=15023',
#'https://lizaalert.org/forum/viewtopic.php?f=278&t=15587',
#'https://lizaalert.org/forum/viewtopic.php?f=278&t=13990',
#'https://lizaalert.org/forum/viewtopic.php?f=207&t=13895']

my_list = list_full

def photo1(containers11):
    if containers11.find("Изображение") != -1:
        photo =  'присутствует'
    else:
        photo = 'отсутствует'
    return photo

def state1(title1):
    if title1.find("Жив") != -1 or title1.find("ЖИВ") != -1:
        state = "живой"
    elif title1.find("Пропал") != -1 or title1.find("ПРОПАЛ") != -1:
        state = 'ищется'
    else:
        state = "мертвый"
    return state

def sex1(title1):
    if title1.find("Жив ") != -1 or title1.find("Жив,") != -1 or title1.find("ЖИВ ") != -1 or title1.find("жив ") != -1 or title1.find("Погиб ") != -1 or title1.find("ПОГИБ ") != -1:
        sex = 'мужской'
    elif title1.find("Жива") != -1 or title1.find("ЖИВА") != -1 or title1.find("Погибла") != -1 or title1.find("ПОГИБЛА") != -1:
        sex = 'женский'
    elif title1.find("Живы") != -1 or title1.find("ЖИВЫ") != -1 or title1.find("Погибли") != -1 or title1.find("ПОГИБЛИ") != -1:
        sex = 'несколько человек'
    else:
        sex = 'sboi'
    return sex

def age11(title1):
    c = title1.find("лет")
    if title1.find("лет") == -1:
        c = title1.find("года")
        if title1.find("года") == -1:
            c = title1.find("год")
    if title1[c-1] ==' ':
        age = list()
        age.append(title1[c-3])
        age.append(title1[c-2])
    else:
        age = list()
        age.append(title1[c-2])
        age.append(title1[c-1])

    if age[0] == ' ':
        age1 = age[1]
    else:
        age1 = age

    age1 = age[0] + age[1]  
    return age1

def posts1(containers22):
    a = containers22.find("Сообщений")
    posts = containers22[a+11] + containers22[a+12]
    return posts

def data1(containers88):
    d = containers88.find("Инфорг")
    if d == -1:
        data1, data2 = 'не','редактировали'
    else:
        data1 = containers88[d+11] + containers88[d+12] + containers88[d+13] + containers88[d+14] + containers88[d+15] + containers88[d+16] + containers88[d+17] + containers88[d+18] + containers88[d+19] + containers88[d+20] + containers88[d+21]
        data2 = containers88[d+24] + containers88[d+25] + containers88[d+26] + containers88[d+27] + containers88[d+28]
        data = data1 + ' ' + data2
    return data

def height(containers11):
    b = containers11.find("Рост")
    if containers11.find("Рост") == -1:
        b = containers11.find("рост") 
    if containers11[b+4] == ":":
        height = containers11[b+6] + containers11[b+7] + containers11[b+8]
    else:
        height = containers11[b+5] + containers11[b+6] + containers11[b+7]
    return height

def help1(containers11):
    if containers11.find("В МЕДИЦИНСКОЙ ПОМОЩИ") == -1 and containers11.find("в медицинской помощи") == -1:
        help1 = 'здоров'
    else:
        help1 = 'требуется мед. помощь'
    return help1

for i in range(len(my_list)):
    my_url = my_list[i]  
    uClient = uReq(my_url)
    page_html = uClient.read()
    uClient.close()
    page_soup = soup(page_html, "html.parser")
    title = page_soup.title
    title1 = str(title)
    #print(title)
    containers = page_soup.findAll("div", {"class":"content"})
    containers11 = str(containers)
    containers2 = page_soup.findAll("div", {"class":"pagination"})
    containers22 = str(containers2)
    containers8 = page_soup.findAll("div", {"class":"notice"})
    containers88 = str(containers8)   
    #print(photo1(containers11))
    list_photo.append(photo1(containers11))
    #print(state1(title1))
    list_state1.append(state1(title1))
    #print(sex1(title1))
    list_sex1.append(sex1(title1))
    #print(age11(title1))
    list_age11.append(age11(title1))
    #print(posts1(containers22))
    list_posts.append(posts1(containers22))
    #print(data1(containers88)) ALOOOOO!!!!!
    containers = page_soup.findAll("div", {"class":"content"})
    containers11 = str(containers)
    #print(height(containers11))
    list_height.append(height(containers11))
    #print(help1(containers11))
    list_help1.append(help1(containers11))
list_of_lists.append(list_age11)
list_of_lists.append(list_height)
list_of_lists.append(list_help1)
list_of_lists.append(list_photo)
list_of_lists.append(list_posts)
list_of_lists.append(list_sex1)
list_of_lists.append(list_state1)
    #rint(ser_help1)
    #print(help1(containers11))
    #list_of_data = [height(containers11), age11(title1), sex1(title1), photo1(containers11), state1(title1), posts1(containers22), help1(containers11)]
df1 = pd.DataFrame(columns = ['Возраст', 'Рост', 'Мед. Состояние', 'Фото', 'Посты', 'Гендер', 'Состояние'])
    #for i in range(0, 10):
       # df1.loc[i] = 

#df1

#if re.search(r'\bрост\b', 'рост'):
 #print("Привет")
    
#s = 'hi my name is ryan, and i am new to python and would like to learn more'
#m = re.search('name\s\w+\s(\w+)',s)
#m.group(1)

#f.write(title1 + title2 + "\n")
#f.close()

#print(containers2)
#print(containers)

# %%
list_of_lists
# Out:
# [['le',
#   '55',
#   '30',
#   '50',
#   '69',
#   '44',
#   '39',
#   '18',
#   '76',
#   '34',
#   '19',
#   '39',
#   '65',
#   '36',
#   '77',
#   '31',
#   '22',
#   '39',
#   '47',
#   '56',
#   '74',
#   '72',
#   '73',
#   '36',
#   '41',
#   '63',
#   'le',
#   '80',
#   'le',
#   '44',
#   '71',
#   '48',
#   '60',
#   '39',
#   '35',
#   '17',
#   'le',
#   '35',
#   '80',
#   'le',
#   '26',
#   '24',
#   '71',
#   '16',
#   'le',
#   '55',
#   '41',
#   '26',
#   '54',
#   '55',
#   '41',
#   '19',
#   'le',
#   '51',
#   '17',
#   '35',
#   '41',
#   '23',
#   '26',
#   '31',
#   '79',
#   '81',
#   '15',
#   '21',
#   '79',
#   '46',
#   '82',
#   '70',
#   '79',
#   '59',
#   '54',
#   '31',
#   '33',
#   '29',
#   '65',
#   '32',
#   '64',
#   '46',
#   'le',
#   '14',
#   '52',
#   '29',
#   '61',
#   '76',
#   '63',
#   'le',
#   '38',
#   '79',
#   '60',
#   '21',
#   '71',
#   '79',
#   '87',
#   '50',
#   '38',
#   '19',
#   '35',
#   '57',
#   '16',
#   '63',
#   '76',
#   '47',
#   '24',
#   '63',
#   'le',
#   'le',
#   '80',
#   'le',
#   '58',
#   '16',
#   '44',
#   '83',
#   '21',
#   '83',
#   '83',
#   '83',
#   '80',
#   '30',
#   '76',
#   '48',
#   '46',
#   '38',
#   '62',
#   '68',
#   '68',
#   '64',
#   '82',
#   '27',
#   '81',
#   '27',
#   'le',
#   '17',
#   'le',
#   '55',
#   '10',
#   '22',
#   '46',
#   '69',
#   '43',
#   'По',
#   '53',
#   '37',
#   '36',
#   '81',
#   '80',
#   '37',
#   '71',
#   '78',
#   '78',
#   '71',
#   '21',
#   '(8',
#   '36',
#   '31',
#   '76',
#   '67',
#   'le',
#   '64',
#   ' 4',
#   '55',
#   '22',
#   '39',
#   '59',
#   '81',
#   '55',
#   '74',
#   '59',
#   '37',
#   '80',
#   '44',
#   '71',
#   '79',
#   '57',
#   '68',
#   '16',
#   '34',
#   '29',
#   'le',
#   '54',
#   '76',
#   '34',
#   '66',
#   'le',
#   '36',
#   '21',
#   'le',
#   '35',
#   '30',
#   '68',
#   '77',
#   '49',
#   '51',
#   '70',
#   '84',
#   '72',
#   '34',
#   '43',
#   '66',
#   '65',
#   '71',
#   'le',
#   '36',
#   '33',
#   '15',
#   '14',
#   '64',
#   '58',
#   'le',
#   'le',
#   '13',
#   '13',
#   '71',
#   '68',
#   'le',
#   '41',
#   '87',
#   '51',
#   '37',
#   '49',
#   '36',
#   '29',
#   '25',
#   '43',
#   '82',
#   '25',
#   'le',
#   '61',
#   '10',
#   'le',
#   '30',
#   '19',
#   '33',
#   '28',
#   '49',
#   'le',
#   '15',
#   '10',
#   '80',
#   '69',
#   '82',
#   '25',
#   '44',
#   'le',
#   '36',
#   'le',
#   '20',
#   '43',
#   '30',
#   '88',
#   '33',
#   '37',
#   '40',
#   'le',
#   ' 9',
#   '31',
#   '21',
#   '68',
#   '77',
#   '36',
#   '14',
#   'le',
#   '71',
#   '49',
#   '78',
#   '23',
#   '60',
#   '62',
#   '65',
#   '21',
#   '27',
#   '64',
#   '61',
#   '18',
#   '39',
#   '74',
#   '87',
#   '28',
#   '85',
#   '55',
#   '71',
#   '40',
#   '41',
#   '60',
#   '26',
#   '35',
#   '33',
#   'le',
#   '25',
#   '16',
#   '74',
#   '22',
#   '32',
#   '76',
#   '82',
#   '17',
#   '74',
#   '40',
#   '34',
#   '79',
#   '67',
#   '79',
#   '79',
#   '18',
#   '24',
#   '71',
#   '70',
#   '22',
#   '21',
#   '29',
#   '32',
#   '71',
#   '37',
#   'le',
#   'le',
#   '28',
#   '61',
#   '16',
#   '16',
#   '21',
#   '58',
#   '26',
#   '53',
#   'le',
#   '68',
#   '20',
#   '14',
#   '86',
#   '72',
#   '23',
#   '30',
#   '86',
#   '81',
#   '42',
#   '66',
#   '74',
#   '76',
#   '78',
#   '14',
#   'le',
#   '46',
#   '22',
#   '10',
#   '37',
#   '24',
#   '13',
#   '78',
#   '29',
#   '38',
#   '34',
#   '38',
#   '81',
#   '82',
#   '56',
#   '76',
#   '75',
#   ' 4',
#   '86',
#   '19',
#   '22',
#   '23',
#   '59',
#   '17',
#   '76',
#   '11',
#   'le',
#   '19',
#   '67',
#   '24',
#   '38',
#   '62',
#   '14',
#   '42',
#   '72',
#   '59',
#   '30',
#   '31',
#   '86',
#   '72',
#   '60',
#   '66',
#   'Ва',
#   '55',
#   '60',
#   '34',
#   '55',
#   '52',
#   '30',
#   '75',
#   '31',
#   '36',
#   'le',
#   '28',
#   '41',
#   '14',
#   '37',
#   '16',
#   '31',
#   '34',
#   '13',
#   '48',
#   '16',
#   '21',
#   '37',
#   '28',
#   '50',
#   '36',
#   '29',
#   '46',
#   '35',
#   '24',
#   '55',
#   '62',
#   '59',
#   '44',
#   '31',
#   '33',
#   'le',
#   '46',
#   '51',
#   '40',
#   '27',
#   '31',
#   '41',
#   '39',
#   '49',
#   '62',
#   '21',
#   '75',
#   '62',
#   '28',
#   '77',
#   '75',
#   '81',
#   '83',
#   '36',
#   '32',
#   '60',
#   '46',
#   '22',
#   '73',
#   '12',
#   '14',
#   'le',
#   '16',
#   '15',
#   '81',
#   '30',
#   '78',
#   '62',
#   'le',
#   '50',
#   ' 5',
#   '84',
#   '77',
#   '51',
#   '22',
#   '72',
#   '43',
#   '53',
#   '86',
#   '62',
#   '29',
#   '28',
#   '52',
#   '35',
#   '19',
#   '17',
#   '41',
#   'le',
#   '79',
#   '26',
#   '75',
#   '82',
#   '27',
#   '27',
#   '24',
#   '59',
#   '35',
#   '61',
#   '37',
#   '78',
#   '55',
#   '86',
#   '40',
#   '54',
#   '80',
#   '40',
#   '25',
#   '72',
#   '22',
#   '56',
#   '45',
#   '28',
#   '40',
#   'le',
#   '14',
#   '54',
#   '21',
#   'le',
#   '15',
#   '51',
#   '76',
#   '68',
#   '19',
#   '15',
#   '61',
#   'le',
#   '26',
#   'le',
#   ',5',
#   'le',
#   '(8',
#   'le',
#   'le',
#   'le',
#   ' 7',
#   'le',
#   'le',
#   'le',
#   '72',
#   'le',
#   'le',
#   ' 3',
#   '11',
#   'le',
#   'le',
#   'le',
#   'le',
#   'le',
#   'le',
#   'le',
#   'le',
#   'le'],
#  ['v c',
#   '175',
#   '175',
#   '182',
#   '167',
#   '194',
#   '175',
#   '178',
#   '174',
#   '180',
#   '165',
#   '183',
#   '165',
#   '175',
#   '170',
#   '187',
#   '180',
#   '155',
#   '175',
#   '164',
#   '150',
#   '160',
#   '170',
#   '165',
#   '175',
#   '170',
#   'v c',
#   '174',
#   ', н',
#   '176',
#   '160',
#   '170',
#   '180',
#   '170',
#   '180',
#   '160',
#   '198',
#   '175',
#   '160',
#   '183',
#   '170',
#   '170',
#   '170',
#   '150',
#   '155',
#   '180',
#   '178',
#   '170',
#   '152',
#   '165',
#   '174',
#   '175',
#   'v c',
#   '185',
#   '161',
#   '180',
#   '170',
#   '178',
#   '170',
#   '175',
#   '172',
#   '175',
#   '170',
#   '168',
#   '164',
#   '176',
#   '174',
#   '175',
#   '170',
#   'v c',
#   '175',
#   '180',
#   '170',
#   '185',
#   '170',
#   '170',
#   '165',
#   '175',
#   'v c',
#   '170',
#   '175',
#   '170',
#   '175',
#   '180',
#   '160',
#   '160',
#   '175',
#   '150',
#   '173',
#   '180',
#   '160',
#   '150',
#   '167',
#   '176',
#   '168',
#   '160',
#   '180',
#   '180',
#   '180',
#   '172',
#   '160',
#   '164',
#   '175',
#   '170',
#   'v c',
#   '175',
#   '170',
#   '160',
#   '154',
#   '160',
#   '150',
#   '170',
#   '175',
#   '170',
#   '150',
#   '164',
#   '180',
#   '185',
#   '185',
#   '175',
#   '160',
#   '165',
#   '150',
#   '170',
#   '166',
#   '170',
#   '152',
#   '180',
#   '155',
#   '150',
#   'v c',
#   '185',
#   '165',
#   '175',
#   '160',
#   '180',
#   '170',
#   '185',
#   '167',
#   '160',
#   '170',
#   '163',
#   '182',
#   '150',
#   '160',
#   '175',
#   '155',
#   '165',
#   '170',
#   '150',
#   '180',
#   '120',
#   '183',
#   '176',
#   '154',
#   '178',
#   'v c',
#   '168',
#   '104',
#   '165',
#   '173',
#   '176',
#   '190',
#   '155',
#   '165',
#   '166',
#   '155',
#   '178',
#   '160',
#   '165',
#   '168',
#   '150',
#   '175',
#   '160',
#   '173',
#   '165',
#   '165',
#   '170',
#   '170',
#   '140',
#   '183',
#   '156',
#   'v c',
#   'ост',
#   '180',
#   '153',
#   '182',
#   '165',
#   '164',
#   '173',
#   '186',
#   '173',
#   '165',
#   '155',
#   '154',
#   '185',
#   '174',
#   '165',
#   '160',
#   '150',
#   '163',
#   '160',
#   '180',
#   '170',
#   '162',
#   '168',
#   ':16',
#   '173',
#   'v c',
#   '160',
#   '173',
#   '160',
#   '156',
#   '165',
#   '175',
#   '154',
#   '170',
#   '175',
#   '168',
#   '183',
#   '180',
#   '182',
#   '174',
#   '180',
#   '170',
#   '160',
#   '160',
#   '140',
#   '155',
#   '165',
#   '160',
#   '182',
#   '180',
#   '185',
#   'v c',
#   '168',
#   '140',
#   '155',
#   '164',
#   '145',
#   '175',
#   '165',
#   '150',
#   '189',
#   'v c',
#   '167',
#   '178',
#   '160',
#   '160',
#   '170',
#   '175',
#   '170',
#   '170',
#   '130',
#   '165',
#   '176',
#   'сре',
#   '162',
#   '187',
#   '170',
#   'v c',
#   '170',
#   '183',
#   '165',
#   '170',
#   '175',
#   '170',
#   '165',
#   '189',
#   '168',
#   '165',
#   '175',
#   '185',
#   '175',
#   '173',
#   '162',
#   '175',
#   '170',
#   '174',
#   '160',
#   'v c',
#   '180',
#   '167',
#   '173',
#   '175',
#   '160',
#   'v c',
#   '175',
#   '157',
#   '160',
#   '160',
#   '185',
#   '164',
#   '155',
#   '178',
#   '170',
#   '172',
#   '175',
#   '150',
#   '162',
#   '150',
#   '170',
#   '165',
#   '175',
#   '162',
#   '175',
#   '165',
#   '155',
#   '180',
#   '180',
#   '190',
#   '175',
#   'v c',
#   '160',
#   '185',
#   '175',
#   '172',
#   '150',
#   '184',
#   '172',
#   '175',
#   '167',
#   '165',
#   '168',
#   '160',
#   '160',
#   '165',
#   '175',
#   '175',
#   '182',
#   '154',
#   '170',
#   '183',
#   '150',
#   '175',
#   '172',
#   '155',
#   '167',
#   'v c',
#   '185',
#   '165',
#   '120',
#   '170',
#   '175',
#   '154',
#   '150',
#   '170',
#   '177',
#   '170',
#   '182',
#   '155',
#   '157',
#   '192',
#   '170',
#   '165',
#   '110',
#   '155',
#   '160',
#   '172',
#   '175',
#   '182',
#   '170',
#   '170',
#   '130',
#   'v c',
#   '172',
#   '160',
#   '185',
#   '170',
#   '170',
#   '157',
#   '190',
#   '160',
#   '190',
#   '170',
#   '170',
#   '165',
#   '170',
#   '172',
#   '150',
#   '175',
#   '190',
#   '175',
#   '184',
#   '180',
#   '175',
#   '165',
#   '187',
#   '190',
#   'v c',
#   'v c',
#   '165',
#   '185',
#   '160',
#   '175',
#   '170',
#   '180',
#   '176',
#   '158',
#   '158',
#   '175',
#   '165',
#   '185',
#   '185',
#   '175',
#   '175',
#   '197',
#   '160',
#   '170',
#   '169',
#   '152',
#   '170',
#   '170',
#   '170',
#   '165',
#   '175',
#   'v c',
#   '170',
#   '185',
#   '165',
#   '177',
#   '170',
#   '170',
#   '192',
#   '157',
#   '165',
#   '175',
#   '180',
#   '170',
#   '165',
#   '160',
#   '155',
#   '170',
#   '176',
#   '170',
#   '185',
#   '175',
#   '180',
#   '192',
#   '160',
#   '145',
#   '169',
#   'v c',
#   '173',
#   '170',
#   '164',
#   '182',
#   '165',
#   '170',
#   '120',
#   '185',
#   '110',
#   '168',
#   '158',
#   '170',
#   '175',
#   '152',
#   '168',
#   '162',
#   '180',
#   '172',
#   '165',
#   '170',
#   '167',
#   '182',
#   '175',
#   '170',
#   '176',
#   'v c',
#   '160',
#   '173',
#   '162',
#   '165',
#   '163',
#   '174',
#   '190',
#   '177',
#   '180',
#   '170',
#   '168',
#   '172',
#   '162',
#   '150',
#   '175',
#   '184',
#   '158',
#   '170',
#   '174',
#   '165',
#   '177',
#   '168',
#   '185',
#   '175',
#   '178',
#   'v c',
#   '165',
#   '157',
#   '150',
#   '172',
#   '162',
#   '180',
#   '180',
#   '190',
#   '178',
#   '180',
#   '164',
#   '164',
#   '170',
#   '175',
#   'око',
#   '170',
#   '120',
#   'v c',
#   '156',
#   '178',
#   '110',
#   'v c',
#   '187',
#   '180',
#   '178',
#   'v c',
#   '189',
#   '95-',
#   'v c',
#   '170',
#   '168',
#   '150',
#   '173',
#   '165',
#   '150',
#   '170',
#   'v c',
#   '150'],
#  ['здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'требуется мед. помощь',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'требуется мед. помощь',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'требуется мед. помощь',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'требуется мед. помощь',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'требуется мед. помощь',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'требуется мед. помощь',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'требуется мед. помощь',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'требуется мед. помощь',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'требуется мед. помощь',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров',
#   'здоров'],
#  ['отсутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'отсутствует',
#   'присутствует',
#   'присутствует',
#   'отсутствует',
#   'присутствует'],
#  ['s=',
#   '2\n',
#   '2\n',
#   '2\n',
#   '3\n',
#   '4\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   '2\n',
#   's=',
#   's=',
#   '2\n',
#   '2\n',
#   's=',
#   '2\n',
#   '3\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   '2\n',
#   's=',
#   's=',
#   '2\n',
#   's=',
#   's=',
#   '2\n',
#   's=',
#   '2\n',
#   's=',
#   '2\n',
#   's=',
#   's=',
#   '2\n',
#   '4\n',
#   's=',
#   '2\n',
#   's=',
#   '2\n',
#   '2\n',
#   's=',
#   '2\n',
#   '2\n',
#   's=',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   '5\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '4\n',
#   '3\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   '3\n',
#   's=',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '3\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   '2\n',
#   's=',
#   's=',
#   '2\n',
#   '3\n',
#   '2\n',
#   '2\n',
#   '3\n',
#   's=',
#   '2\n',
#   '2\n',
#   's=',
#   's=',
#   's=',
#   '2\n',
#   '2\n',
#   '2\n',
#   '3\n',
#   '2\n',
#   '2\n',
#   '3\n',
#   '2\n',
#   '3\n',
#   '2\n',
#   '2\n',
#   '3\n',
#   '2\n',
#   '2\n',
#   's=',
#   '2\n',
#   '2\n',
#   's=',
#   's=',
#   '2\n',
#   '2\n',
#   '3\n',
#   's=',
#   's=',
#   's=',
#   '2\n',
#   '3\n',
#   '3\n',
#   '2\n',
#   '4\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '3\n',
#   '2\n',
#   '2\n',
#   '6\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   '2\n',
#   's=',
#   '2\n',
#   's=',
#   '2\n',
#   's=',
#   '2\n',
#   '4\n',
#   '2\n',
#   's=',
#   '2\n',
#   '2\n',
#   '2\n',
#   '3\n',
#   '3\n',
#   '2\n',
#   's=',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   '2\n',
#   '2\n',
#   '3\n',
#   's=',
#   '2\n',
#   '2\n',
#   's=',
#   's=',
#   's=',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '3\n',
#   '2\n',
#   '5\n',
#   '2\n',
#   '3\n',
#   '2\n',
#   '3\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   '2\n',
#   '3\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   '2\n',
#   '2\n',
#   's=',
#   '3\n',
#   's=',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   '2\n',
#   's=',
#   '5\n',
#   '2\n',
#   '6\n',
#   's=',
#   '2\n',
#   's=',
#   '3\n',
#   's=',
#   '2\n',
#   's=',
#   '2\n',
#   '2\n',
#   's=',
#   '2\n',
#   '3\n',
#   '2\n',
#   '3\n',
#   's=',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   's=',
#   '4\n',
#   '2\n',
#   's=',
#   '2\n',
#   '2\n',
#   '3\n',
#   '2\n',
#   '2\n',
#   '3\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   '3\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   's=',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '3\n',
#   '3\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '3\n',
#   '2\n',
#   's=',
#   's=',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   '2\n',
#   '2\n',
#   '14',
#   's=',
#   's=',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   's=',
#   '14',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '3\n',
#   '3\n',
#   '2\n',
#   '2\n',
#   '3\n',
#   's=',
#   's=',
#   '2\n',
#   '2\n',
#   's=',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '3\n',
#   '2\n',
#   '3\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   's=',
#   's=',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   '2\n',
#   '2\n',
#   's=',
#   '3\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   's=',
#   '2\n',
#   's=',
#   '2\n',
#   's=',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   's=',
#   '2\n',
#   '2\n',
#   '2\n',
#   's=',
#   's=',
#   '3\n',
#   '2\n',
#   '3\n',
#   '2\n',
#   's=',
#   '2\n',
#   '3\n',
#   '2\n',
#   's=',
#   '2\n',
#   '2\n',
#   '4\n',
#   '3\n',
#   '3\n',
#   '2\n',
#   '7\n',
#   '2\n',
#   '3\n',
#   '3\n',
#   '2\n',
#   '4\n',
#   's=',
#   's=',
#   's=',
#   '2\n',
#   '2\n',
#   '2\n',
#   '3\n',
#   's=',
#   's=',
#   '3\n',
#   '2\n',
#   '2\n',
#   's=',
#   's=',
#   '7\n',
#   '2\n',
#   '10',
#   's=',
#   's=',
#   '2\n',
#   '2\n',
#   '7\n',
#   '2\n',
#   '7\n',
#   's=',
#   '4\n',
#   '4\n',
#   '3\n',
#   '6\n',
#   '4\n',
#   '3\n',
#   '3\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '2\n',
#   '3\n',
#   '5\n',
#   's=',
#   '2\n',
#   's=',
#   '3\n',
#   '6\n',
#   '7\n',
#   '3\n',
#   '4\n',
#   '10',
#   '3\n',
#   '3\n',
#   '2\n',
#   '2\n',
#   '6\n',
#   '3\n',
#   '51',
#   '2\n',
#   '2\n',
#   '5\n',
#   '5\n',
#   '4\n',
#   '6\n',
#   's=',
#   '2\n',
#   's=',
#   '4\n',
#   's=',
#   '4\n',
#   '6\n',
#   's=',
#   '2\n',
#   '9\n',
#   '3\n',
#   '2\n',
#   '4\n',
#   '7\n',
#   '2\n',
#   '5\n',
#   '10'],
#  ['sboi',
#   'мужской',
#   'мужской',
#   'мужской',
#   'женский',
#   'мужской',
#   'мужской',
#   'мужской',
#   'женский',
#   'мужской',
#   'мужской',
#   'мужской',
#   'женский',
#   'sboi',
#   'мужской',
#   'мужской',
#   'sboi',
#   'женский',
#   'sboi',
#   'мужской',
#   'женский',
#   'мужской',
#   'женский',
#   'мужской',
#   'мужской',
#   'sboi',
#   'sboi',
#   'мужской',
#   'sboi',
#   'sboi',
#   'мужской',
#   'sboi',
#   'sboi',
#   'мужской',
#   'мужской',
#   'женский',
#   'sboi',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'sboi',
#   'мужской',
#   'мужской',
#   'sboi',
#   'мужской',
#   'мужской',
#   'sboi',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'sboi',
#   'мужской',
#   'женский',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'женский',
#   'sboi',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'sboi',
#   'мужской',
#   'sboi',
#   'несколько человек',
#   'женский',
#   'мужской',
#   'мужской',
#   'мужской',
#   'женский',
#   'женский',
#   'мужской',
#   'женский',
#   'мужской',
#   'мужской',
#   'женский',
#   'женский',
#   'sboi',
#   'мужской',
#   'sboi',
#   'sboi',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'sboi',
#   'sboi',
#   'мужской',
#   'мужской',
#   'sboi',
#   'sboi',
#   'мужской',
#   'sboi',
#   'женский',
#   'женский',
#   'женский',
#   'мужской',
#   'мужской',
#   'sboi',
#   'женский',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'женский',
#   'sboi',
#   'женский',
#   'женский',
#   'sboi',
#   'sboi',
#   'женский',
#   'женский',
#   'мужской',
#   'sboi',
#   'sboi',
#   'sboi',
#   'несколько человек',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'женский',
#   'мужской',
#   'мужской',
#   'мужской',
#   'женский',
#   'sboi',
#   'мужской',
#   'мужской',
#   'женский',
#   'мужской',
#   'женский',
#   'мужской',
#   'мужской',
#   'sboi',
#   'мужской',
#   'sboi',
#   'sboi',
#   'sboi',
#   'sboi',
#   'мужской',
#   'мужской',
#   'sboi',
#   'sboi',
#   'мужской',
#   'женский',
#   'женский',
#   'мужской',
#   'женский',
#   'sboi',
#   'мужской',
#   'мужской',
#   'мужской',
#   'женский',
#   'мужской',
#   'женский',
#   'sboi',
#   'мужской',
#   'женский',
#   'мужской',
#   'sboi',
#   'женский',
#   'мужской',
#   'sboi',
#   'sboi',
#   'мужской',
#   'мужской',
#   'женский',
#   'мужской',
#   'мужской',
#   'sboi',
#   'мужской',
#   'мужской',
#   'женский',
#   'мужской',
#   'женский',
#   'женский',
#   'мужской',
#   'женский',
#   'мужской',
#   'мужской',
#   'женский',
#   'женский',
#   'женский',
#   'мужской',
#   'женский',
#   'мужской',
#   'женский',
#   'мужской',
#   'мужской',
#   'sboi',
#   'мужской',
#   'мужской',
#   'sboi',
#   'женский',
#   'мужской',
#   'мужской',
#   'женский',
#   'мужской',
#   'мужской',
#   'sboi',
#   'мужской',
#   'sboi',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'sboi',
#   'женский',
#   'мужской',
#   'мужской',
#   'sboi',
#   'женский',
#   'мужской',
#   'мужской',
#   'sboi',
#   'sboi',
#   'женский',
#   'мужской',
#   'женский',
#   'женский',
#   'женский',
#   'мужской',
#   'мужской',
#   'несколько человек',
#   'мужской',
#   'sboi',
#   'женский',
#   'мужской',
#   'женский',
#   'женский',
#   'sboi',
#   'sboi',
#   'мужской',
#   'мужской',
#   'мужской',
#   'sboi',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'женский',
#   'sboi',
#   'мужской',
#   'мужской',
#   'женский',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'sboi',
#   'женский',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'женский',
#   'sboi',
#   'мужской',
#   'мужской',
#   'женский',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'sboi',
#   'sboi',
#   'мужской',
#   'женский',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'женский',
#   'мужской',
#   'sboi',
#   'мужской',
#   'мужской',
#   'женский',
#   'женский',
#   'женский',
#   'мужской',
#   'женский',
#   'женский',
#   'женский',
#   'мужской',
#   'мужской',
#   'женский',
#   'мужской',
#   'мужской',
#   'sboi',
#   'sboi',
#   'sboi',
#   'женский',
#   'мужской',
#   'мужской',
#   'sboi',
#   'женский',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'женский',
#   'мужской',
#   'женский',
#   'женский',
#   'мужской',
#   'женский',
#   'мужской',
#   'мужской',
#   'женский',
#   'мужской',
#   'мужской',
#   'sboi',
#   'мужской',
#   'мужской',
#   'женский',
#   'женский',
#   'sboi',
#   'мужской',
#   'мужской',
#   'sboi',
#   'sboi',
#   'sboi',
#   'женский',
#   'женский',
#   'мужской',
#   'мужской',
#   'sboi',
#   'sboi',
#   'sboi',
#   'женский',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'женский',
#   'женский',
#   'sboi',
#   'мужской',
#   'sboi',
#   'sboi',
#   'мужской',
#   'мужской',
#   'sboi',
#   'мужской',
#   'женский',
#   'мужской',
#   'мужской',
#   'мужской',
#   'женский',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'sboi',
#   'sboi',
#   'мужской',
#   'мужской',
#   'женский',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'женский',
#   'sboi',
#   'мужской',
#   'sboi',
#   'sboi',
#   'sboi',
#   'мужской',
#   'женский',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'женский',
#   'мужской',
#   'женский',
#   'sboi',
#   'мужской',
#   'мужской',
#   'sboi',
#   'мужской',
#   'женский',
#   'мужской',
#   'мужской',
#   'женский',
#   'мужской',
#   'sboi',
#   'sboi',
#   'sboi',
#   'мужской',
#   'sboi',
#   'sboi',
#   'sboi',
#   'женский',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'женский',
#   'мужской',
#   'мужской',
#   'sboi',
#   'sboi',
#   'мужской',
#   'женский',
#   'женский',
#   'sboi',
#   'sboi',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'sboi',
#   'мужской',
#   'женский',
#   'женский',
#   'sboi',
#   'женский',
#   'женский',
#   'мужской',
#   'мужской',
#   'мужской',
#   'мужской',
#   'несколько человек',
#   'мужской',
#   'мужской',
#   'женский',
#   'женский',
#   'мужской',
#   'sboi',
#   'sboi',
#   'sboi',
#   'женский',
#   'мужской',
#   'мужской',
#   'мужской',
#   'sboi',
#   'sboi',
#   'мужской',
#   'мужской',
#   'женский',
#   'sboi',
#   'sboi',
#   'женский',
#   'мужской',
#   'sboi',
#   'sboi',
#   'sboi',
#   'мужской',
#   'мужской',
#   'мужской',
#   'sboi',
#   'мужской',
#   'sboi',
#   'sboi',
#   'женский',
#   'женский',
#   'мужской',
#   'sboi',
#   'женский',
#   'мужской',
#   'мужской',
#   'sboi',
#   'sboi',
#   'женский',
#   'sboi',
#   'sboi',
#   'sboi',
#   'sboi',
#   'женский',
#   'sboi',
#   'женский',
#   'sboi',
#   'sboi',
#   'sboi',
#   'sboi',
#   'sboi',
#   'мужской',
#   'мужской',
#   'женский',
#   'sboi',
#   'женский',
#   'sboi',
#   'sboi',
#   'sboi',
#   'мужской',
#   'несколько человек',
#   'женский',
#   'sboi',
#   'женский',
#   'sboi',
#   'sboi',
#   'sboi',
#   'sboi',
#   'sboi',
#   'sboi',
#   'sboi',
#   'несколько человек',
#   'sboi',
#   'sboi',
#   'женский',
#   'sboi',
#   'sboi',
#   'несколько человек',
#   'женский',
#   'sboi',
#   'женский'],
#  ['мертвый',
#   'мертвый',
#   'мертвый',
#   'живой',
#   'мертвый',
#   'мертвый',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'мертвый',
#   'живой',
#   'мертвый',
#   'ищется',
#   'живой',
#   'живой',
#   'ищется',
#   'живой',
#   'ищется',
#   'мертвый',
#   'живой',
#   'живой',
#   'мертвый',
#   'живой',
#   'живой',
#   'ищется',
#   'мертвый',
#   'мертвый',
#   'мертвый',
#   'ищется',
#   'живой',
#   'ищется',
#   'мертвый',
#   'живой',
#   'живой',
#   'живой',
#   'ищется',
#   'мертвый',
#   'мертвый',
#   'живой',
#   'мертвый',
#   'ищется',
#   'живой',
#   'живой',
#   'ищется',
#   'живой',
#   'живой',
#   'ищется',
#   'живой',
#   'мертвый',
#   'мертвый',
#   'мертвый',
#   'мертвый',
#   'мертвый',
#   'живой',
#   'мертвый',
#   'мертвый',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'ищется',
#   'живой',
#   'живой',
#   'мертвый',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'мертвый',
#   'живой',
#   'мертвый',
#   'живой',
#   'мертвый',
#   'живой',
#   'ищется',
#   'живой',
#   'мертвый',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'мертвый',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'ищется',
#   'живой',
#   'ищется',
#   'ищется',
#   'живой',
#   'мертвый',
#   'живой',
#   'живой',
#   'ищется',
#   'ищется',
#   'живой',
#   'мертвый',
#   'мертвый',
#   'ищется',
#   'живой',
#   'мертвый',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'ищется',
#   'живой',
#   'живой',
#   'мертвый',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'ищется',
#   'живой',
#   'живой',
#   'ищется',
#   'ищется',
#   'живой',
#   'живой',
#   'живой',
#   'ищется',
#   'мертвый',
#   'мертвый',
#   'живой',
#   'мертвый',
#   'живой',
#   'мертвый',
#   'мертвый',
#   'живой',
#   'живой',
#   'мертвый',
#   'живой',
#   'живой',
#   'мертвый',
#   'живой',
#   'ищется',
#   'мертвый',
#   'мертвый',
#   'живой',
#   'живой',
#   'живой',
#   'мертвый',
#   'мертвый',
#   'ищется',
#   'мертвый',
#   'ищется',
#   'ищется',
#   'мертвый',
#   'ищется',
#   'живой',
#   'мертвый',
#   'ищется',
#   'ищется',
#   'живой',
#   'живой',
#   'живой',
#   'мертвый',
#   'мертвый',
#   'ищется',
#   'мертвый',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'ищется',
#   'живой',
#   'живой',
#   'мертвый',
#   'ищется',
#   'живой',
#   'мертвый',
#   'ищется',
#   'мертвый',
#   'мертвый',
#   'живой',
#   'живой',
#   'мертвый',
#   'живой',
#   'ищется',
#   'живой',
#   'мертвый',
#   'мертвый',
#   'мертвый',
#   'мертвый',
#   'мертвый',
#   'мертвый',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'мертвый',
#   'мертвый',
#   'живой',
#   'живой',
#   'ищется',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'ищется',
#   'живой',
#   'ищется',
#   'живой',
#   'мертвый',
#   'живой',
#   'мертвый',
#   'мертвый',
#   'мертвый',
#   'живой',
#   'живой',
#   'ищется',
#   'живой',
#   'живой',
#   'живой',
#   'ищется',
#   'мертвый',
#   'живой',
#   'живой',
#   'мертвый',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'мертвый',
#   'мертвый',
#   'живой',
#   'мертвый',
#   'живой',
#   'мертвый',
#   'ищется',
#   'ищется',
#   'живой',
#   'живой',
#   'живой',
#   'ищется',
#   'живой',
#   'живой',
#   'мертвый',
#   'живой',
#   'живой',
#   'мертвый',
#   'живой',
#   'мертвый',
#   'живой',
#   'живой',
#   'живой',
#   'мертвый',
#   'живой',
#   'ищется',
#   'живой',
#   'живой',
#   'живой',
#   'мертвый',
#   'живой',
#   'живой',
#   'живой',
#   'ищется',
#   'мертвый',
#   'мертвый',
#   'живой',
#   'мертвый',
#   'живой',
#   'мертвый',
#   'живой',
#   'мертвый',
#   'ищется',
#   'мертвый',
#   'живой',
#   'живой',
#   'живой',
#   'мертвый',
#   'живой',
#   'живой',
#   'живой',
#   'мертвый',
#   'ищется',
#   'живой',
#   'живой',
#   'мертвый',
#   'живой',
#   'живой',
#   'мертвый',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'мертвый',
#   'ищется',
#   'ищется',
#   'мертвый',
#   'живой',
#   'живой',
#   'живой',
#   'ищется',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'мертвый',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'ищется',
#   'живой',
#   'мертвый',
#   'живой',
#   'живой',
#   'мертвый',
#   'мертвый',
#   'живой',
#   'ищется',
#   'ищется',
#   'ищется',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'ищется',
#   'ищется',
#   'ищется',
#   'живой',
#   'мертвый',
#   'мертвый',
#   'живой',
#   'живой',
#   'мертвый',
#   'живой',
#   'мертвый',
#   'живой',
#   'ищется',
#   'ищется',
#   'живой',
#   'живой',
#   'мертвый',
#   'живой',
#   'живой',
#   'живой',
#   'мертвый',
#   'мертвый',
#   'живой',
#   'живой',
#   'мертвый',
#   'мертвый',
#   'живой',
#   'ищется',
#   'ищется',
#   'живой',
#   'мертвый',
#   'живой',
#   'мертвый',
#   'живой',
#   'мертвый',
#   'живой',
#   'мертвый',
#   'мертвый',
#   'мертвый',
#   'ищется',
#   'живой',
#   'мертвый',
#   'мертвый',
#   'ищется',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'мертвый',
#   'живой',
#   'мертвый',
#   'ищется',
#   'живой',
#   'мертвый',
#   'ищется',
#   'мертвый',
#   'живой',
#   'живой',
#   'живой',
#   'мертвый',
#   'мертвый',
#   'ищется',
#   'ищется',
#   'ищется',
#   'живой',
#   'мертвый',
#   'ищется',
#   'ищется',
#   'мертвый',
#   'живой',
#   'мертвый',
#   'мертвый',
#   'мертвый',
#   'мертвый',
#   'мертвый',
#   'живой',
#   'ищется',
#   'ищется',
#   'мертвый',
#   'живой',
#   'мертвый',
#   'ищется',
#   'ищется',
#   'живой',
#   'живой',
#   'мертвый',
#   'живой',
#   'ищется',
#   'живой',
#   'живой',
#   'мертвый',
#   'мертвый',
#   'живой',
#   'живой',
#   'мертвый',
#   'мертвый',
#   'живой',
#   'мертвый',
#   'живой',
#   'живой',
#   'мертвый',
#   'живой',
#   'живой',
#   'мертвый',
#   'ищется',
#   'ищется',
#   'ищется',
#   'живой',
#   'мертвый',
#   'мертвый',
#   'живой',
#   'ищется',
#   'ищется',
#   'живой',
#   'живой',
#   'живой',
#   'ищется',
#   'мертвый',
#   'мертвый',
#   'мертвый',
#   'ищется',
#   'ищется',
#   'ищется',
#   'мертвый',
#   'живой',
#   'мертвый',
#   'ищется',
#   'мертвый',
#   'ищется',
#   'ищется',
#   'мертвый',
#   'живой',
#   'мертвый',
#   'ищется',
#   'живой',
#   'живой',
#   'мертвый',
#   'мертвый',
#   'живой',
#   'живой',
#   'ищется',
#   'живой',
#   'ищется',
#   'мертвый',
#   'живой',
#   'ищется',
#   'живой',
#   'ищется',
#   'ищется',
#   'живой',
#   'мертвый',
#   'ищется',
#   'живой',
#   'живой',
#   'мертвый',
#   'ищется',
#   'живой',
#   'живой',
#   'ищется',
#   'ищется',
#   'живой',
#   'живой',
#   'мертвый',
#   'ищется',
#   'мертвый',
#   'мертвый',
#   'живой',
#   'живой',
#   'живой',
#   'мертвый',
#   'мертвый',
#   'мертвый',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'живой',
#   'мертвый',
#   'живой',
#   'живой',
#   'мертвый',
#   'мертвый']]

# %%
for i, j in zip(list_of_lists, list(df1.columns)):
    df1[j] = pd.Series(i)

# %% [markdown]
# # Тадаам ! Вот , что мы получили

# %%
df1.head()
# Out:
#   Возраст Рост Мед. Состояние          Фото Посты   Гендер Состояние
# 0      le  v c         здоров   отсутствует    s=     sboi   мертвый
# 1      55  175         здоров  присутствует   2\n  мужской   мертвый
# 2      30  175         здоров  присутствует   2\n  мужской   мертвый
# 3      50  182         здоров  присутствует   2\n  мужской     живой
# 4      69  167         здоров   отсутствует   3\n  женский   мертвый

# %%
df1
# Out:
#     Возраст Рост         Мед. Состояние          Фото Посты  \
# 0        le  v c                 здоров   отсутствует    s=
# 1        55  175                 здоров  присутствует   2\n
# 2        30  175                 здоров  присутствует   2\n
# 3        50  182                 здоров  присутствует   2\n
# 4        69  167                 здоров   отсутствует   3\n
# 5        44  194                 здоров   отсутствует   4\n
# 6        39  175  требуется мед. помощь   отсутствует   2\n
# 7        18  178                 здоров  присутствует   2\n
# 8        76  174                 здоров  присутствует   2\n
# 9        34  180                 здоров  присутствует   2\n
# 10       19  165                 здоров  присутствует    s=
# 11       39  183                 здоров  присутствует   2\n
# 12       65  165  требуется мед. помощь  присутствует    s=
# 13       36  175                 здоров  присутствует    s=
# 14       77  170  требуется мед. помощь  присутствует   2\n
# 15       31  187  требуется мед. помощь  присутствует   2\n
# 16       22  180                 здоров  присутствует    s=
# 17       39  155                 здоров  присутствует   2\n
# 18       47  175                 здоров  присутствует   3\n
# 19       56  164                 здоров   отсутствует   2\n
# 20       74  150                 здоров  присутствует   2\n
# 21       72  160                 здоров  присутствует   2\n
# 22       73  170                 здоров  присутствует   2\n
# 23       36  165                 здоров  присутствует    s=
# 24       41  175                 здоров   отсутствует   2\n
# 25       63  170                 здоров  присутствует    s=
# 26       le  v c                 здоров   отсутствует    s=
# 27       80  174                 здоров  присутствует   2\n
# 28       le  , н                 здоров  присутствует    s=
# 29       44  176                 здоров  присутствует    s=
# ..      ...  ...                    ...           ...   ...
# 503      19  178  требуется мед. помощь   отсутствует   3\n
# 504      15  180                 здоров   отсутствует   3\n
# 505      61  164                 здоров   отсутствует   2\n
# 506      le  164                 здоров   отсутствует   2\n
# 507      26  170  требуется мед. помощь   отсутствует   6\n
# 508      le  175                 здоров   отсутствует   3\n
# 509      ,5  око                 здоров  присутствует    51
# 510      le  170                 здоров   отсутствует   2\n
# 511      (8  120                 здоров   отсутствует   2\n
# 512      le  v c                 здоров   отсутствует   5\n
# 513      le  156                 здоров   отсутствует   5\n
# 514      le  178                 здоров   отсутствует   4\n
# 515       7  110                 здоров  присутствует   6\n
# 516      le  v c                 здоров   отсутствует    s=
# 517      le  187                 здоров   отсутствует   2\n
# 518      le  180                 здоров   отсутствует    s=
# 519      72  178                 здоров   отсутствует   4\n
# 520      le  v c                 здоров   отсутствует    s=
# 521      le  189                 здоров  присутствует   4\n
# 522       3  95-                 здоров   отсутствует   6\n
# 523      11  v c                 здоров   отсутствует    s=
# 524      le  170                 здоров   отсутствует   2\n
# 525      le  168                 здоров   отсутствует   9\n
# 526      le  150                 здоров   отсутствует   3\n
# 527      le  173                 здоров   отсутствует   2\n
# 528      le  165                 здоров   отсутствует   4\n
# 529      le  150                 здоров  присутствует   7\n
# 530      le  170                 здоров  присутствует   2\n
# 531      le  v c                 здоров   отсутствует   5\n
# 532      le  150                 здоров  присутствует    10
#
#                 Гендер Состояние
# 0                 sboi   мертвый
# 1              мужской   мертвый
# 2              мужской   мертвый
# 3              мужской     живой
# 4              женский   мертвый
# 5              мужской   мертвый
# 6              мужской     живой
# 7              мужской     живой
# 8              женский     живой
# 9              мужской     живой
# 10             мужской   мертвый
# 11             мужской     живой
# 12             женский   мертвый
# 13                sboi    ищется
# 14             мужской     живой
# 15             мужской     живой
# 16                sboi    ищется
# 17             женский     живой
# 18                sboi    ищется
# 19             мужской   мертвый
# 20             женский     живой
# 21             мужской     живой
# 22             женский   мертвый
# 23             мужской     живой
# 24             мужской     живой
# 25                sboi    ищется
# 26                sboi   мертвый
# 27             мужской   мертвый
# 28                sboi   мертвый
# 29                sboi    ищется
# ..                 ...       ...
# 503            мужской     живой
# 504            мужской     живой
# 505            женский   мертвый
# 506               sboi    ищется
# 507            женский     живой
# 508               sboi     живой
# 509               sboi    ищется
# 510               sboi    ищется
# 511            мужской     живой
# 512  несколько человек     живой
# 513            женский   мертвый
# 514               sboi    ищется
# 515            женский   мертвый
# 516               sboi   мертвый
# 517               sboi     живой
# 518               sboi     живой
# 519               sboi     живой
# 520               sboi   мертвый
# 521               sboi   мертвый
# 522               sboi   мертвый
# 523  несколько человек     живой
# 524               sboi     живой
# 525               sboi     живой
# 526            женский     живой
# 527               sboi     живой
# 528               sboi   мертвый
# 529  несколько человек     живой
# 530            женский     живой
# 531               sboi   мертвый
# 532            женский   мертвый
#
# [533 rows x 7 columns]

# %% [markdown]
# Пока дальше не нужно смотреть ( Славе)

# %%
df1.shape
# Out:
# (533, 7)

# %% [markdown]
# Этот код для идентицикации фото-портрета:

# %%
def photo(photo, containers11):
    if containers11.find("Изображение") != -1:
        photo =  'присутствует'
    else:
        photo = 'отсутствует'
    return photo


photo(photo, containers11)
# Out:
# 'присутствует'

# %% [markdown]
# Это код для идентификации состояния пропавшего человека:

# %%
def state(state, title1):
    if title1.find("Жив") != -1 or title1.find("ЖИВ") != -1:
        state = "живой"
    elif title1.find("Пропал") != -1 or title1.find("ПРОПАЛ") != -1:
        state = 'ищется'
    else:
        state = "мертвый"
    return state

state(state, title1)
# Out:
# 'мертвый'

# %% [markdown]
# Это код для идентицикации пола пропавшего человека/ людей:

# %%
def sex(sex, title1):
    if title1.find("Жив ") != -1 or title1.find("Жив,") != -1 or title1.find("ЖИВ ") != -1 or title1.find("жив ") != -1 or title1.find("Погиб ") != -1 or title1.find("ПОГИБ ") != -1:
        sex = 'мужской'
    elif title1.find("Жива") != -1 or title1.find("ЖИВА") != -1 or title1.find("Погибла") != -1 or title1.find("ПОГИБЛА") != -1:
        sex = 'женский'
    elif title1.find("Живы") != -1 or title1.find("ЖИВЫ") != -1 or title1.find("Погибли") != -1 or title1.find("ПОГИБЛИ") != -1:
        sex = 'несколько человек'
    else:
        sex = 'sboi'
    return sex

sex(sex, title1)
# Out:
# 'женский'

# %% [markdown]
# Это код для идентицикации возраста:

# %%
def age1(age1, title1):
    c = title1.find("лет")
    if title1.find("лет") == -1:
        c = title1.find("года")
        if title1.find("года") == -1:
            c = title1.find("год")
    if title1[c-1] ==' ':
        age = list()
        age.append(title1[c-3])
        age.append(title1[c-2])
    else:
        age = list()
        age.append(title1[c-2])
        age.append(title1[c-1])

    if age[0] == ' ':
        age1 = age[1]
    else:
        age1 = age

    age1 = age[0] + age[1]  
    return age1
    
print(title1.find("лет"))
print(title1)
age1(age1, title1)
# Out:
# -1
# <title>Погибла Бурдина Даша, 1998 г.р., Асбест Свердловская обл. • Форум lizaalert.org</title>
# 'le'

# %% [markdown]
# Этот код определяет количество сообщений в теме (активность поста)

# %%
def posts(posts, containers22):
    a = containers22.find("Сообщений")
    posts = containers22[a+11] + containers22[a+12]
    return posts

posts(posts, containers22)
# Out:
# '10'

# %% [markdown]
# Этот код определяет дату последнего редактирования поста (нахождения человека):

# %%
def data(data, containers88):
    d = containers88.find("Инфорг")
    if d == -1:
        data1, data2 = 'не','редактировали'
    else:
        data1 = containers88[d+11] + containers88[d+12] + containers88[d+13] + containers88[d+14] + containers88[d+15] + containers88[d+16] + containers88[d+17] + containers88[d+18] + containers88[d+19] + containers88[d+20] + containers88[d+21]
        data2 = containers88[d+24] + containers88[d+25] + containers88[d+26] + containers88[d+27] + containers88[d+28]
        data = data1 + ' ' + data2
    return data

data(data, containers88)
# Out:
# <function __main__.data(data, containers88)>

# %% [markdown]
# Это код для роста:

# %%
def height(height, containers11):
    b = containers11.find("Рост")
    if containers11.find("Рост") == -1:
        b = containers11.find("рост") 
    if containers11[b+4] == ":":
        height = containers11[b+6] + containers11[b+7] + containers11[b+8]
    else:
        height = containers11[b+5] + containers11[b+6] + containers11[b+7]
    return height

height(height, containers11)
# Out:
# '150'

# %% [markdown]
# Это код для идентификации состояния здоровья пропавшего человека:

# %%
def help1(help1, containers11):
    if containers11.find("В МЕДИЦИНСКОЙ ПОМОЩИ") == -1 and containers11.find("в медицинской помощи") == -1:
        help1 = 'здоров'
    else:
        help1 = 'требуется мед. помощь'
    return help1

help1(help1, containers11)
# Out:
# 'здоров'

# %% [markdown]
# TRY EXCEL

# %%
filename = "post7.csv"
f = open(filename, "w")
headers = "age1, height, posts\n"
f.write(headers)
# Out:
# 20

# %% [markdown]
# Так, осталось выпарсить (хотя бы ублюдочно):
# 1) время пропажи
# 2) телосложение
# 3) цвет глаз
# 4) волосы
# 5) одежда???
#
# А сейчас PPPPANDA, PPPAND, PPPPPPPANDA:

# %%
df = pd.DataFrame({'сообщения к посту': [posts], 'рост': [height], 'возраст': [age1], 'пол': [sex], 'состояние': [state], 'здоровье': [help1], 'фото': [photo]})
df

df.to_csv('pondaass.csv', index=True)
print(df)
# Out:
#                  сообщения к посту                              рост  \
# 0  <function posts at 0x12398a9d8>  <function height at 0x123c782f0>
#
#                           возраст                            пол  \
# 0  <function age1 at 0x12398a840>  <function sex at 0x12398a488>
#
#                          состояние                         здоровье  \
# 0  <function state at 0x123977ea0>  <function help1 at 0x123c78488>
#
#                               фото
# 0  <function photo at 0x123977d90>

# %%
# ДЛЯ КОЛИ!!!!!!!!!!!!!!!!!!!!!
html1 = requests.get('https://lizaalert.org/forum/viewforum.php?f=183').content #url='google.com'
sel1 = Selector(text=html1)
course_as11 = sel1.xpath('//a[contains(@class,"forumtitle")]')
print(course_as11)
hrefs11_from_css = course_as11.css('::attr(href)')
print(hrefs11_from_css.extract())
hrefz = list()
#print("\"https://lizaalert.org/forum" + str(hrefs11_from_css.extract()[4])[1:] + "\"")
for i in range(len(hrefs11_from_css.extract())):
    clean_link1 = "\"https://lizaalert.org/forum" + str(hrefs11_from_css.extract()[i])[1:] + "\""
    hrefz.append(clean_link1)
#for i in hrefs11_from_css.extract():
 #   hrefs11_from_css.extract()[i] = "\"https://lizaalert.org/forum" + str(hrefs11_from_css.extract()[i])[1:] + "\""
print(hrefz[2])
