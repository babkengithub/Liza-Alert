# %%
import numpy as np
import pandas as pd
import re
import bs4
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
from scrapy import Selector
from nltk import word_tokenize
import nltk
nltk.download('punkt') #winlocker
pd.set_option("display.max_rows", 400)
pd.set_option("display.max_columns", 50)
pd.set_option('display.max_colwidth', -1)
import datetime
from datetime import datetime, time, date
import scrapy
from scrapy.selector import Selector
import requests
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nikzo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# Данные для поиска силы лис

# %%
names_df = pd.read_excel('names_df.xlsx')

# %%
names_list = list(names_df["Unnamed: 0"])
#names_list = list(names_df.index)

# %%
#names_list = list(names_df.index)

# %%
messages_list = list(names_df["Количество сообщений"])

# %% [markdown]
# Привязка к tracks10

# %%
df_coor = pd.read_excel("final_coords.xlsx")
list_x_tracks = []
for i in range(len(df_coor["liza"])):
    list_x_tracks.append(float('%.10g' % df_coor["liza"][i]))
list_url = list(df_coor["url"])
list_km = list(df_coor["km"])
list_teams = list(df_coor["teams"])
list_date1 = list(df_coor["date1"])
list_date2 = list(df_coor["date2"])

# %% [markdown]
# Привязка (шаг 0) закончена

# %%
# ДЛЯ КОЛИ!!!!!!!!!!!!!!!!!!!!!
import requests
#ssylka = 'https://lizaalert.org/forum/viewforum.php?f=180'
ssylka = 'https://lizaalert.org/forum/viewforum.php?f=111'
#ssylka = 'https://lizaalert.org/forum/viewforum.php?f=133'
html1 = requests.get(ssylka).content #url='google.com'
sel1 = Selector(text=html1)
course_as11 = sel1.xpath('//a[contains(@class,"forumtitle")]')
hrefs11_from_css = course_as11.css('::attr(href)')


hrefz = list()
for i in range(len(hrefs11_from_css.extract())):
    clean_link1 = "https://lizaalert.org/forum" + str(hrefs11_from_css.extract()[i])[1:]
    hrefz.append(clean_link1)

# %%
hrefz
# Out:
# ['https://lizaalert.org/forum/viewforum.php?f=282&sid=fd14deb88d234b2289b484cccc9ff7b6',
#  'https://lizaalert.org/forum/viewforum.php?f=261&sid=fd14deb88d234b2289b484cccc9ff7b6',
#  'https://lizaalert.org/forum/viewforum.php?f=246&sid=fd14deb88d234b2289b484cccc9ff7b6',
#  'https://lizaalert.org/forum/viewforum.php?f=223&sid=fd14deb88d234b2289b484cccc9ff7b6',
#  'https://lizaalert.org/forum/viewforum.php?f=249&sid=fd14deb88d234b2289b484cccc9ff7b6',
#  'https://lizaalert.org/forum/viewforum.php?f=250&sid=fd14deb88d234b2289b484cccc9ff7b6',
#  'https://lizaalert.org/forum/viewforum.php?f=251&sid=fd14deb88d234b2289b484cccc9ff7b6',
#  'https://lizaalert.org/forum/viewforum.php?f=252&sid=fd14deb88d234b2289b484cccc9ff7b6']

# %%
hrefz.append(ssylka)
hrefz.append('https://lizaalert.org/forum/viewforum.php?f=167')
hrefz.append('https://lizaalert.org/forum/viewforum.php?f=42')
hrefz.append('https://lizaalert.org/forum/viewforum.php?f=216')
hrefz.append('https://lizaalert.org/forum/viewforum.php?f=227')
hrefz.append('https://lizaalert.org/forum/viewforum.php?f=207')
hrefz.append('https://lizaalert.org/forum/viewforum.php?f=243')
hrefz.append('https://lizaalert.org/forum/viewforum.php?f=285')
hrefz.append('https://lizaalert.org/forum/viewforum.php?f=134')
#hrefz.append('https://lizaalert.org/forum/viewforum.php?f=276')
#hrefz.append('https://lizaalert.org/forum/viewforum.php?f=41')

# %%
hrefzz = []
for i in range(len(hrefz)):
    html = requests.get(hrefz[i]).content #url='google.com'
    selka = Selector(text=html)
    course90 = selka.xpath('//a[contains(@class,"forumtitle")]')
    hrefs90_from_css = course90.css('::attr(href)')
    for i in range(len(hrefs90_from_css.extract())):
        clean_link11 = "https://lizaalert.org/forum" + str(hrefs90_from_css.extract()[i])[1:]
        hrefzz.append(clean_link11)
for i in range(len(hrefz)):
    hrefzz.append(hrefz[i])

# %%
hrefzz.append('https://lizaalert.org/forum/viewforum.php?f=281')
hrefzz.append('https://lizaalert.org/forum/viewforum.php?f=276')
hrefzz.append('https://lizaalert.org/forum/viewforum.php?f=41')

# %%
# Import requests
import requests

list_of_all_pages = list()
# Create the string html containing the HTML source
for i in range(len(hrefzz)):
    html = requests.get(hrefzz[i]).content #url='google.com'
    sel = Selector(text=html)

    uClient = uReq(hrefzz[i])
    page_html = uClient.read()
    uClient.close()
    page_soup = soup(page_html, "html.parser")
    containers2 = page_soup.findAll("div", {"class":"pagination"})
    containers22 = str(containers2)

    def page12(containers22):
        page1 = list()
        c = containers22.find("из ")
        page1.append(containers22[c+11])
        page1.append(containers22[c+12])
        if containers22[c+12] == "<":
            page1.pop()
        return page1

    if len(page12(containers22)) == 2:
        page_real = int(page12(containers22)[0] + page12(containers22)[1])
    else:
        page_real = int(page12(containers22)[0])

    # Парсим
    course_as = sel.xpath('//a[contains(@class,"right-box right")]')
    hrefs_from_css = course_as.css('::attr(href)')
    
    if len(str(hrefs_from_css.extract())[1:]) == 1:
        links_to_follow = ssylka
        clean_link = ssylka
    else:
        links_to_follow = "\"https://lizaalert.org/forum" + str(hrefs_from_css.extract()[0])[1:] + "\""
        clean_link = str(hrefs_from_css.extract()[0])[1:len(hrefs_from_css.extract()[0])-2]
    list_links = list()
    for i in range((page_real)-1):
        list_links.append(clean_link)

    #За 500 надо пояснить! Но это вроде несложно
    i=0
    list1 = list()
    for i in range(0,(page_real-1)*25, 25):
        i = i + 25
        list1.append(i)

    result = [str(item) for item in list1]

    for i in range(len(list1)):
        list_links[i] += result[i]

    for i in range(len(list_links)):
        list_links[i] = "https://lizaalert.org/forum" + list_links[i]
    list_of_all_pages.append(list_links)

# %%
print(len(list_of_all_pages))
listSYKA = list()
for i in range(len(list_of_all_pages)):
    for j in range(len(list_of_all_pages[i])):
        listSYKA.append(list_of_all_pages[i][j])

for j in range(len(hrefzz)):
    listSYKA.append(hrefzz[j])
listSYKA.append(ssylka)
# Out:
# 60

# %%
list_full = list()
for i in range(len(listSYKA)):
    #html = requests.get(list_links[i]).content #url='google.com'
    html = requests.get(listSYKA[i]).content #url='google.com'
    sel = Selector(text=html)

    course_as1 = sel.css('a.topictitle')
    hrefs1_from_css = course_as1.css('::attr(href)')

    list0 = list()
    for i in range(0, len(hrefs1_from_css.extract())):
        list0.append("https://lizaalert.org/forum" + str(hrefs1_from_css.extract()[i])[1:])
        list_full.append(list0[i])
#print(list_full)
print(len(list_full))
# Out:
# 5808

# %%
my_list = list_full

# %%
my_list[0]
print(len(my_list))
# Out:
# 5808

# %% [markdown]
# Стоп-остановись, паровоз

# %%
del my_list[1397] #Polyakov

# %%
del my_list[1945+1397-1] #Belova

# %%
del my_list[1945+1397+164-2] #kidnapping in Belgorod

# %% [markdown]
# # Здесь соберем все вспомогательные перменные

# %%
list_searchers = []
list_photo = []
list_state1 = []
list_sex1 = []
list_age11 = []
list_posts = []
list_height = []
list_help1 = []
list_hair_color = []
list_bodytype = []
list_eye = []
list_of_lists = []  ## Здесь нужно додумать
list_place = []
list_color_of_clothes = []# Бабкен Вставил
list_of_lists = []  ## Здесь нужно додумать
list_podrobnost = []
list_primeti = []
list_search_time =[]
list_lost_time = []
list_find_time = []
list_of_coor = []
list_x_tracks1 = []
list_url1 = []
list_km1 = []
list_teams1 = []
list_date11 = []
list_date22 = []
list_delta = []
list_of_power = []
list_month = []
list_year = []

# %%
english_stops = ['.', ',', ':', ';', "!", "?", '-', ')', '(']
months_num = {"сет": 9, "янв": 1, "фев": 2, "мар": 3,"апр": 4,"мая": 5, "май": 5,"июн": 6,"июл": 7,"авг": 8,"сен": 9,"окт": 10,"ноя": 11,"дек": 12, "Янв": 1, "Фев": 2, "Мар": 3,"Апр": 4,"Мая": 5, "Май": 5,"Июн": 6,"Июл": 7,"Авг": 8,"Сен": 9,"Окт": 10,"Ноя": 11,"Дек": 12, "ЯНВ": 1, "ФЕВ": 2, "МАР": 3,"АПР": 4,"МАЯ": 5, "МАЙ": 5,"ИЮН": 6,"ИЮЛ": 7,"АВГ": 8,"СЕН": 9,"ОКТ": 10,"НОЯ": 11,"ДЕК": 12}
match_months = {'01': 'Январь', '02': ' Февраль', '03': 'Март', '04': 'Апрель', '05': 'Май', '06': 'Июнь', '07': 'Июль', '08': 'Август', '09': 'Сентябрь', '10': 'Октябрь', '11': 'Ноябрь', '12': 'Декабрь'}

# %% [markdown]
# # Напишем все функции, которые нам понадобятся в сборе признаков

# %%
def fox_power(containers228, names_list, messages_list):
    sila = 0
    if containers228 == 'ebanyi obychenie':
        sila = 0
    else:
        kerka = containers228.findAll(text=re.compile(r'\w+'))
        for i in range(len(names_list)):
            for j in range(len(kerka)):
                if names_list[i] in kerka[j]:
                    sila += int(messages_list[i])
    return sila

# %%
def searchers(containers228):
    if containers228 == 'ebanyi obychenie':
        searchers = 0
    else:
        kerka = containers228.findAll(text=re.compile(r'\w+'))
        kerka1 = containers228.findAll(text=re.compile(r'На месте|НА МЕСТЕ|Дом|ДОМ|Экипаж|ЭКИПАЖ'))
        searchers = (len(kerka) - len(kerka1))
    return searchers

# %%
def photo1(containers11):
    if containers11.find("Изображение") != -1:
        photo =  'присутствует'
    else:
        photo = 'отсутствует'
    return photo

# %%
def state1(title1):
    if title1.find("Жив") != -1 or title1.find("ЖИВ") != -1 or title1.find("Найден") != -1 or title1.find("НАЙДЕН") != -1:
        state = "живой"
    elif title1.find("Пропал") != -1 or title1.find("ПРОПАЛ") != -1:
        state = 'ищется'
    elif title1.find("Погиб") != -1 or title1.find("ПОГИБ") != -1 or title1.find("Мертв") != -1 or title1.find("МЕРТВ") != -1:
        state = 'мертвый'
    else:
        state = "Не указано"
    return state

# %%
def sex1(title1): # Слава вставил 8 мая 
    sex = re.search(r'[Пп]ропала|[Вв]ышла|[Уу]шла|[Нн]айдена|[Жж]ива|[Ее]ё|[Ее]е|[Ее]го|[Уу]ехала|[Пп]огибла|[Вв]ернулась|не [Вв]ернулась|[Вв]ышел|[Уу]шёл|[Уу]шел|[Пп]ропал|[Нн]айден|[Жж]ив|[Ее]го|[Уу]ехал|[Пп]огиб|[Вв]ернулся|не [Вв]ернулся', title1)
    if sex is None:
        return "Er"
    sex = str(sex.group(0))
    if sex == "вышел" or sex == "Вышел" or sex == "ушел" or sex == "Ушел" or sex == 'ушёл' or sex == 'пропал' or sex == 'Пропал' or sex == 'Найден' or sex == 'найден' or sex == 'ушел'or sex == 'ушёл'or sex == 'пропал'or sex == 'найден'or sex == 'Найден'or sex == 'вышел' or sex == 'Жив'or sex == 'жив' or sex == 'уехал'or sex == 'Погиб'or sex == 'погиб'or sex == 'вернулся':
        sex = "Мужчина"
    else:
        sex = "Женщина"
    return sex

# %%
def age11(title1):
    preage = re.search(r'\d+', str(title1))
    if preage is None:
        return "Коля объебался"
    else:
        age = preage.group()
        if len(age) == 4:
            age = 2019 - int(age)
    return age

# %%
def posts1(containers2):
    posts = re.search(r'\d+', str(containers2)).group()
    return posts

# %%
def data1(containers88):
    d = containers88.find("Инфорг")
    if d == -1:
        data1, data2 = 'не','редактировали'
    else:
        data1 = containers88[d+11] + containers88[d+12] + containers88[d+13] + containers88[d+14] + containers88[d+15] + containers88[d+16] + containers88[d+17] + containers88[d+18] + containers88[d+19] + containers88[d+20] + containers88[d+21]
        data2 = containers88[d+24] + containers88[d+25] + containers88[d+26] + containers88[d+27] + containers88[d+28]
        data = data1 + ' ' + data2
    return data

# %%
def height(containers11): # Вставил Слава 8.05.2019
    high = re.search(r'[Рр]ост \d{3}|[Рр]оста \d{3}|[Рр]оста\d{3}|[Рр]ост: \d{3}|[Рр]ост - \d{3}|рост\d{3}-|Рост:\d{3}| росто \d{3}', containers11 )
    if high is None:
        return "Er"
    high = str(high.group(0))

    height = re.findall(r'\d+',high)
    height = int(" ".join(height))
    return height

# %%
def help1(containers11):
    if containers11.find("В МЕДИЦИНСКОЙ ПОМОЩИ") == -1 and containers11.find("в медицинской помощи") == -1:
        help1 = 'здоров'
    else:
        help1 = 'требуется мед. помощь'
    return help1

# %%
def hair_color(contents):
    hc = 'Не указано'
    for string in contents:
        if "олосы" in string:
            no_stops_string_1 = ''.join([t for t in string if t not in english_stops])
            tokens_1 = word_tokenize(no_stops_string_1)
            for i in range(len(tokens_1)):
                if "олосы" in tokens_1[i]:
                    if i < (len(tokens_1) - 1):
                        hc = tokens_1[i + 1]
                    else:
                        hc = tokens_1[i-1]
    return hc

# %%
## Нужно доработать код! Или сделать заново
def body_type(contents):
    body = "Не указано"
    for string in contents:
        if "елосложени" in string:
            no_stops_string = ''.join([t for t in string if t not in english_stops])
            tokens = word_tokenize(no_stops_string)
            tokens.append("Ты объебался")
            for i in range(len(tokens)):
                if "елосложени" in tokens[i]:
                    if tokens[i][-1] == "я":
                        body = tokens[i - 1]
                        break
                    else:
                        body = tokens[i + 1]
                        break
    return body

# %%
## Нужно доработать код! Или сделать заново
def eyes_color(contents):
    ec = "Не указано"
    for string in contents:
        if "лаз" in string:
            no_stops_string = ''.join([t for t in string if t not in english_stops])
            tokens = word_tokenize(no_stops_string)
            tokens.append("Кто-то объебался")
            for i in range(len(tokens)):
                if "лаз" in tokens[i]:
                    ec = tokens[i + 1]
                if ec == "Кто-то объебался":
                    ec = tokens[i-1]
                    break
    return ec

# %%
def yebanskii(sel):
    p = sel.css("div.content").xpath('./span[@style="font-size: 140%; line-height: 116%;"]/span[@style="font-weight: bold"]/text()').extract()
    a = str(p)
    b = re.split('\s+', a)
    b1 = b[5:]
    t = str(b1)
    p = t.replace("\'", "")
    p1 = p.replace(']', '')
    p2 = p1.replace('[', '')
    p3 = p2.replace('"', '')
    p4 = p3.replace(', ', " ")
    p5 = p4.replace('- ','-')
    return p5

# %%
def color_cloth(containers11):
    containers1 = re.split('<span style="font-weight: bold">', containers11)
    if len(containers1) < 4:
        return "Не указано"
    else:
        containers_new = containers1[3]
        black = len(re.findall(r'черн', containers_new))
        white = len(re.findall(r'бел', containers_new))
        yellow = len(re.findall(r'желт', containers_new))
        orange = len(re.findall(r'оранж', containers_new))
        br_grey = len(re.findall(r'тло-сер', containers_new))
        grey = len(re.findall(r'сер', containers_new))
        beg = len(re.findall(r'бежев', containers_new))
        br_blue = len(re.findall(r'тло-син', containers_new))
        blue = len(re.findall(r'син', containers_new))
        green = len(re.findall(r'зелен', containers_new))
        violent = len(re.findall(r'фиол', containers_new))
        black1 = len(re.findall(r'чёрн', containers_new))
        brown = len(re.findall(r'коричн', containers_new))
        al_colors = black + yellow + orange + grey + beg + blue + green + violent + black1
        br_colors1 = white + yellow + orange + br_grey + beg + br_blue + green + violent
        br_colors2 = white + yellow + orange + beg + br_blue + green + violent
        br_colors3 = white + yellow + orange + br_grey + beg + green + violent
        br_colors4 = white + yellow + orange + beg + green + violent
        dk_colors1 = black + black1 + brown
        dk_colors2 = black + grey + black1 + brown
        dk_colors3 = black + blue + black1 + brown
        dk_colors4 = black + blue + grey + black1 + brown
        if al_colors == 0:
            return "Не указано" 
        elif (br_grey == 0 and br_blue == 0) and br_colors4 >= dk_colors4:
            return "Яркая"
        elif (br_grey == 0 and br_blue == 0) and br_colors4 < dk_colors4:
            return "Темная"
        elif ((br_grey != 0 and grey != 0) or (br_blue != 0 and blue != 0 )) and br_colors1 >= dk_colors4:
            return "Яркая"
        elif ((br_grey != 0 and grey != 0) or (br_blue != 0 and blue != 0 )) and br_colors1 < dk_colors4:
            return "Темная"
        elif (br_grey == 0) and br_colors2 >= dk_colors2:
            return "Яркая" 
        elif (br_grey == 0) and br_colors2 < dk_colors2:
            return "Темная" 
        elif (br_blue == 0) and br_colors3 >= dk_colors3:
            return "Яркая"

# %%
def podrobnost(containers11):
    containers1 = re.split('<span style="font-weight: bold">', containers11)
    if len(containers1) < 4:
        return("Не указано")
    else:
        containers_new = containers1[3]
        containers_new_sep = containers_new.split(',')
        l = len(containers_new_sep)
        if l > 3:
            return 4
        elif 2 <= l < 3:
            return 3
        else:
            return 0

# %%
def primeti(containers11):
    containers1 = re.split('<span style="font-weight: bold">', containers11)
    if len(containers1) < 5:
        return("Не указано")
    else:
        containers_new = containers1[4]
        containers_new_sep = containers_new.split(',')
        l = len(containers_new_sep)
        if l > 3:
            return 4
        elif 2 <= l < 3:
            return 2
        else:
            return 0

# %%
def lost_timing(x, y):
    if re.search(r'\d+ \w+ \d{4}|\d{2}[.]\d{2}[.]\d{4}', x) == None:
        if re.search(r'\d+\s\w+\s\d+', y) != None:
            lost_time = re.search(r'\d+\s\w+\s\d+', y).group()
            lts = lost_time.split()
            lts[1] = months_num[lts[1][:3]]
            lts = list(map(int, lts))
            lost_time = date(lts[-1], lts[-2], lts[-3])
            return lost_time
        else:
            return "Сбой"
    else:
        lost_time = re.search(r'\d+ \w+ \d{4}|\d{2}[.]\d{2}[.]\d{4}', x).group()
        if "я" in lost_time or "т" in lost_time:
            lts = lost_time.split()
            lts[1] = months_num[lts[1][:3]]
            lts = list(map(int, lts))
            lost_time = date(lts[-1], lts[-2], lts[-3])
            return lost_time
        elif "Я" in lost_time or "Т" in lost_time:
            lts = lost_time.split()
            lts[1] = months_num[lts[1][:3]]
            lts = list(map(int, lts))
            lost_time = date(lts[-1], lts[-2], lts[-3])
            return lost_time
        else:
            lts = lost_time.split('.')
            lts = list(map(int, lts))
            lost_time = date(lts[-1], lts[-2], lts[-3])
            return lost_time

# %%
def find_timing(x, y):
    if re.search(r'\d+ \w+ \d{4}|\d{2}[.]\d{2}[.]\d{4}', x) == None:
        if re.search(r'\d+\s\w+\s\d{4}', y) != None:
            find_time = re.search(r'\d+\s\w+\s\d{4}', y).group()
            fts = find_time.split()
            fts[1] = months_num[fts[1]]
            fts = list(map(int, fts))
            find_time = date(fts[-1], fts[-2], fts[-3])
            return find_time
        else:
            return "Сбой"
    else:
        find_time = re.search(r'\d+ \w+ \d{4}|\d{2}[.]\d{2}[.]\d{4}', x).group()
        fts = find_time.split()
        fts[1] = months_num[fts[1]]
        fts = list(map(int, fts))
        find_time = date(fts[-1], fts[-2], fts[-3])
        return find_time

# %%
def search_timing(x, y, babken, slava):
    return (find_timing(y, slava) - lost_timing(x, babken)).days

# %%
def super_format(function, x, y):
    if len(str(function(x, y).day)) == 1:
        day = "0" + str(function(x, y).day)
    else:
        day = str(function(x, y).day)
    if len(str(function(x, y).month)) == 1:
        month = "0" + str(function(x, y).month)
    else:
        month = str(function(x, y).month)
    return day + "." + month + "." + str(function(x, y).year)

# %%
def find_cor(comp):
    for i in range (len(comp)):
        contents = page_soup.findAll("div", {"class":"content"})[i].contents
        kavka = re.search(r'\d+.\d+, \d+.\d+|\d+.\d+,\d+.\d+|\d+.\d+ \d+.\d+', str(contents))
        if kavka is not None:
            kavkaz = kavka.group()
            break
        else:
            kavkaz = 'no cord'
    return kavkaz

# %% [markdown]
# # Перейдем к сбору признаков

# %%
for i in my_list:
    my_url = i
    vanya_url = requests.get(my_url).content
    vanya_selector = Selector(text=vanya_url)
    uClient = uReq(my_url)
    page_html = uClient.read()
    uClient.close()
    page_soup = soup(page_html, "html.parser")
    title = page_soup.title
    title1 = str(title)

    comp = page_soup.findAll("div", {"class":"content"})
    containers = page_soup.findAll("div", {"class":"content"})
    contents = page_soup.findAll("div", {"class":"content"})[0].contents
    containers11 = str(containers)
    containers2 = page_soup.findAll("div", {"class":"pagination"})
    containers22 = str(containers2)
    containers8 = page_soup.findAll("div", {"class":"notice"})
    containers88 = str(containers8) 
    containers1 = re.split('<span style="font-weight: bold">', containers11)
    if len(page_soup.findAll("div", {"class":"content"})) > 1:
        containers228 = page_soup.findAll("div", {"class":"content"})[1]
    else:
        containers228 = 'ebanyi obychenie'
    
    list_searchers.append(searchers(containers228))
    list_photo.append(photo1(containers11))
    list_state1.append(state1(title1))
    list_sex1.append(sex1(title1))
    list_age11.append(age11(title1))
    list_posts.append(posts1(containers22))
    list_hair_color.append(hair_color(contents))
    list_bodytype.append(body_type(contents))
    list_eye.append(eyes_color(contents))
    containers = page_soup.findAll("div", {"class":"content"})
    containers11 = str(containers)
    list_height.append(height(containers11))
    list_help1.append(help1(containers11))
    list_place.append(yebanskii(vanya_selector))
    list_color_of_clothes.append(color_cloth(containers11)) # Бабкен вставил
    list_podrobnost.append(podrobnost(containers11)) # Бабкен вставил еще раз, но уже Ване
    list_primeti.append(primeti(containers11))
    
    
    babken = page_soup.find('p', {'class': 'author'}).text
    if vanya_selector.xpath('//p[@class="author"]/text()').extract_first() != None:
        juk_slava = vanya_selector.xpath('//p[@class="author"]/text()').extract()[-1]
    else:
        juk_slava = 'Сбой'
    if vanya_selector.xpath('//div[@class="content"]/text()').extract_first() != None:
        main = vanya_selector.xpath('//div[@class="content"]/text()').extract_first()
    else:
        main = "Сбой"
    if lost_timing(main, babken) != "Сбой":
        list_lost_time.append(super_format(lost_timing, main, babken))
    else:
        list_lost_time.append("Ошибка")
        
    if vanya_selector.xpath('//div[@class="notice"]/text()').extract_first() != None:
        if len(vanya_selector.xpath('//div[@class="notice"]/text()').extract()) >= 2:
            notmain = vanya_selector.xpath('//div[@class="notice"]/text()').extract()[1]
        else:
            notmain = vanya_selector.xpath('//div[@class="notice"]/text()').extract()[0]
            
    else:
        notmain = "Сбой"
    if find_timing(notmain, juk_slava) != "Сбой":
            list_find_time.append(super_format(find_timing, notmain, juk_slava))
    else:
        list_find_time.append("Ошибка")

        
        
    if lost_timing(main, babken) != "Сбой" and find_timing(notmain, juk_slava) != "Сбой":
        list_search_time.append(search_timing(main, notmain, babken, juk_slava))
    else:
        list_search_time.append("Ошибка") 
            
    list_month.append(match_months[super_format(lost_timing, main, babken)[3:5]])
    list_year.append(super_format(lost_timing, main, babken)[-4:])
    list_of_coor.append(find_cor(comp))
    list_x_tracks1.append(0)
    list_url1.append(0)
    list_km1.append(0)
    list_teams1.append(0)
    list_date11.append(0)
    list_date22.append(0)
    list_delta.append(0)
    list_of_power.append(fox_power(containers228, names_list, messages_list))

# %%
len(my_list)
# Out:
# 5805

# %%
for i in range(len(list_of_coor)):
    for j in range(len(list_x_tracks)):
        if str(list_x_tracks[j]) in (list_of_coor[i]):
            list_x_tracks1[i] = str(list_x_tracks[j])
            list_url1[i] = str(list_url[j])
            list_km1[i] = str(list_km[j])
            list_date11[i] = str(list_date1[j])
            list_date22[i] = str(list_date2[j])
            list_teams1[i] = str(list_teams[j])

# %% [markdown]
# Delta dates in processing...

# %%
for i in range(len(list_date22)):
    if re.search('май', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('май', '05')
    if re.search('апр', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('апр', '04')
    if re.search('мар', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('мар', '03')
    if re.search('фев', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('фев', '02')
    if re.search('янв', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('янв', '01')
    if re.search('дек', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('дек', '12')
    if re.search('ноя', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('ноя', '11')
    if re.search('окт', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('окт', '10')
    if re.search('сен', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('сен', '09')
    if re.search('авг', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('авг', '08')
    if re.search('июл', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('июл', '07')
    if re.search('июн', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('июн', '06')

# %%
for i in range(len(list_date11)):
    if re.search('май', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('май', '05')
    if re.search('апр', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('апр', '04')
    if re.search('мар', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('мар', '03')
    if re.search('фев', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('фев', '02')
    if re.search('янв', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('янв', '01')
    if re.search('дек', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('дек', '12')
    if re.search('ноя', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('ноя', '11')
    if re.search('окт', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('окт', '10')
    if re.search('сен', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('сен', '09')
    if re.search('авг', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('авг', '08')
    if re.search('июл', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('июл', '07')
    if re.search('июн', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('июн', '06')

# %%
for i in range(len(list_date11)):
    if str(list_date11[i]) != '0' and str(list_date22[i]) != '0' and str(list_date22[i]) != '   0:':
        date2k = datetime.strptime(str(list_date22[i]), "%d-%m-%y  %H:%M")
        date1k = datetime.strptime(str(list_date11[i]), "%d-%m-%y  %H:%M")
        delta = (date2k - date1k).seconds/3600
        list_delta[i] = delta

# %% [markdown]
# Парсим посты, копаем вглубь!

# %%
list_of_all_pages1 = list()

for i in my_list:
    URL = i
    
    html = requests.get(URL).content #url='google.com'
    sel = Selector(text=html)

    uClient = uReq(URL)
    page_html = uClient.read()
    uClient.close()
    page_soup = soup(page_html, "html.parser")
    containers2 = page_soup.findAll("div", {"class":"pagination"})
    containers22 = str(containers2)

    def page12(containers22):
        page1 = list()
        c = containers22.find("из ")
        page1.append(containers22[c+11])
        page1.append(containers22[c+12])
        if containers22[c+12] == "<":
            page1.pop()
            return page1

    if page12(containers22) is None:
        page_real = 1
    else:
        if len(page12(containers22)) == 2:
            page_real = int(page12(containers22)[0] + page12(containers22)[1])
        else:
            page_real = int(page12(containers22)[0])

        # Парсим
    course_as = sel.xpath('//a[contains(@class,"right-box right")]')
    hrefs_from_css = course_as.css('::attr(href)')

    if len(str(hrefs_from_css.extract())[1:]) == 1:
        links_to_follow = URL
        clean_link = URL[27:len(URL)]
    else:
        links_to_follow = "\"https://lizaalert.org/forum" + str(hrefs_from_css.extract()[0])[1:] + "\""
        clean_link = str(hrefs_from_css.extract()[0])[1:len(hrefs_from_css.extract()[0])-2]

    list_links = list()
    for i in range((page_real)):
        list_links.append(clean_link)


        #За 500 надо пояснить! Но это вроде несложно
    i=0
    list1 = [0]
    for i in range(0,(page_real-1)*10, 10):
        i = i + 10
        list1.append(i)

    result = [str(item) for item in list1]

    for i in range(len(list1)):
        if list_links[i].find("start") != -1:
            list_links[i] += result[i]
        
    for i in range(len(list_links)):
        list_links[i] = "https://lizaalert.org/forum" + list_links[i]
    
    list_of_all_pages1.append(list_links)

# %%
list_vk_posts = []
list_odn_posts = []
list_ready_posts = []
for j in range(len(list_of_all_pages1)):
    vk_posts = 0
    vk_postes = []
    odn_posts = 0
    odn_postes = []
    odn_post = []
    ready_posts = 0
    ready_postes = []
    for item in range(len(list_of_all_pages1[j])):
        odn_post = []
        ready_post = []
        vk_post = []
        uClient = uReq(list_of_all_pages1[j][item])
        page_html = uClient.read()
        uClient.close()
        page_soup = soup(page_html, "html.parser")
        for p in range(len(page_soup.findAll("div", {"class":"content"}))):
            containers2 = page_soup.findAll("div", {"class":"content"})[p] #ЧТО ЭТО ЗА ХУЙНЯ?????????
            kirka0 = containers2.findAll(text=re.compile("vk.com"))
            vk_post.append(len(kirka0))
            kirka1 = containers2.findAll(text=re.compile(r'odnokl|ok.ru'))
            odn_post.append(len(kirka1))
            kirka2 = containers2.findAll(text=re.compile(r'[Гг]отов'))
            ready_post.append(len(kirka2))
        vk_postes.append(vk_post)
        ready_postes.append(ready_post)
        odn_postes.append(odn_post)
    odn_posts += odn_posts   
    vk_posts += vk_posts
    ready_posts += ready_posts
    for i in range(len(vk_postes)):
        for k in range(len(vk_postes[i])):
            vk_posts += vk_postes[i][k]
    list_vk_posts.append(vk_posts)
    for i in range(len(odn_postes)):
        for k in range(len(odn_postes[i])):
            odn_posts += odn_postes[i][k]
    list_odn_posts.append(odn_posts)
    for i in range(len(ready_postes)):
        for k in range(len(ready_postes[i])):
            ready_posts += ready_postes[i][k]
    list_ready_posts.append(ready_posts)

# %% [markdown]
# Для таблицы

# %%
list_of_lists.append(list_ready_posts)
list_of_lists.append(list_searchers)
list_of_lists.append(list_of_power)
list_of_lists.append(list_vk_posts)
list_of_lists.append(list_odn_posts)
list_of_lists.append(list_age11)
list_of_lists.append(list_height)
list_of_lists.append(list_help1)
list_of_lists.append(list_photo)
list_of_lists.append(list_posts)
list_of_lists.append(list_sex1)
list_of_lists.append(list_state1)
list_of_lists.append(list_hair_color)
list_of_lists.append(list_bodytype)
list_of_lists.append(list_eye)
list_of_lists.append(list_full)
list_of_lists.append(list_place)
list_of_lists.append(list_color_of_clothes) # Бабкен вставил
list_of_lists.append(list_podrobnost) # Бабкен вставил еще раз, но уже себе
list_of_lists.append(list_primeti)
list_of_lists.append(list_search_time)
list_of_lists.append(list_lost_time)
list_of_lists.append(list_find_time)
list_of_lists.append(list_x_tracks1)
list_of_lists.append(list_url1)
list_of_lists.append(list_km1)
list_of_lists.append(list_teams1)
list_of_lists.append(list_date11)
list_of_lists.append(list_date22)
list_of_lists.append(list_delta)
list_of_lists.append(list_month)
list_of_lists.append(list_year)
# Бабкен вставил снова, только Коле в пердачело

# %%
df1 = pd.DataFrame(columns = ['Готовые', 'Искатели', 'Сила искателей', 'Репосты_вк', 'Репосты_одн', 'Возраст', 'Рост', 'Мед. Состояние', 'Фото', 'Посты', 'Гендер', 'Состояние', 'Цвет волос', 'Телосложение', 'Цвет глаз', 'Url','Место', 'Одежда_ярк', 'Одежда_колво', 'Приметы_колво', 'Время поиска', "Время пропажи", "Время нахождения", "Координаты пропажи", 'url_tracks', 'km', 'teams','date1', 'date2', 'delta_dates', 'Месяц', 'Год'])

# %%
for i, j in zip(list_of_lists, list(df1.columns)):
    df1[j] = pd.Series(i)

# %% [markdown]
# # Тадаам ! Вот , что мы получили

# %%
df1
# Out:
#       Готовые  Искатели  Сила искателей  Репосты_вк  Репосты_одн  \
# 0     2        0         0               0           0
# 1     11       57        32730           0           0
# 2     13       17        12              0           0
# 3     0        1         0               1           0
# 4     0        1         0               0           0
# 5     0        1         0               2           1
# 6     1        1         0               0           0
# 7     0        5         1330            0           0
# 8     0        1         0               0           0
# 9     0        6         0               0           0
# 10    1        1         0               2           0
# 11    0        2         158             2           1
# 12    0        2         0               0           0
# 13    0        1         0               0           0
# 14    0        5         5               0           0
# 15    1        1         1               0           0
# 16    0        1         0               0           0
# 17    1        1         0               2           0
# 18    0        1         0               0           0
# 19    1        4         71              0           0
# 20    8        9         1621            0           0
# 21    4        34        29495           0           0
# 22    1        1         0               3           1
# 23    0        1         0               0           0
# 24    0        2         762             0           0
# 25    0        1         0               0           0
# 26    2        0         0               0           0
# 27    8        22        85              3           1
# 28    0        1         0               2           1
# 29    0        2         1               0           0
# 30    0        1         0               0           0
# 31    0        1         0               2           1
# 32    0        1         0               0           0
# 33    2        21        2499            0           0
# 34    0        1         0               0           0
# 35    1        5         0               0           0
# 36    0        1         0               1           0
# 37    0        1         0               0           0
# 38    0        1         0               0           0
# 39    0        3         6               0           0
# 40    0        1         0               0           0
# 41    0        1         0               0           0
# 42    0        1         0               1           1
# 43    0        1         0               0           0
# 44    0        1         0               0           0
# 45    0        1         0               0           0
# 46    1        1         0               1           0
# 47    0        1         0               0           0
# 48    0        1         0               0           0
# 49    0        1         0               0           0
# 50    0        1         0               0           0
# 51    1        21        29436           0           0
# 52    2        0         0               0           0
# 53    0        2         0               0           0
# 54    0        1         0               0           0
# 55    0        1         0               0           0
# 56    0        1         0               0           0
# 57    0        1         0               0           0
# 58    0        1         0               0           0
# 59    0        1         0               0           0
# 60    11       30        280             3           0
# 61    1        1         158             0           0
# 62    0        1         0               0           0
# 63    0        2         15              0           0
# 64    0        1         0               0           0
# 65    0        3         6               0           0
# 66    0        1         0               0           0
# 67    1        1         0               0           0
# 68    0        1         17              0           0
# 69    0        1         0               0           0
# 70    0        1         0               1           0
# 71    0        1         0               0           0
# 72    0        1         0               0           0
# 73    0        20        1377            0           0
# 74    0        1         0               0           0
# 75    0        1         0               0           0
# 76    1        2         0               0           0
# 77    0        1         0               0           0
# 78    2        0         0               0           0
# 79    0        1         0               0           0
# 80    0        1         0               0           0
# 81    2        1         0               0           0
# 82    0        1         0               1           0
# 83    4        7         10              25          1
# 84    0        1         0               0           0
# 85    1        1         0               0           0
# 86    0        1         0               0           0
# 87    0        1         0               0           0
# 88    0        1         0               0           0
# 89    1        1         0               3           1
# 90    1        1         0               0           0
# 91    0        1         0               0           0
# 92    5        9         58              0           0
# 93    0        1         0               0           0
# 94    0        1         0               0           0
# 95    1        1         0               0           0
# 96    0        1         0               0           0
# 97    0        1         0               0           0
# 98    0        1         0               0           0
# 99    0        1         0               0           0
# 100   0        1         49              0           0
# 101   0        1         0               0           0
# 102   0        1         0               0           0
# 103   0        2         29330           0           0
# 104   2        0         0               0           0
# 105   0        1         0               0           0
# 106   0        1         0               0           0
# 107   0        2         0               0           0
# 108   0        1         0               0           0
# 109   0        5         7               0           0
# 110   2        0         0               0           0
# 111   1        1         0               0           0
# 112   1        1         0               0           0
# 113   0        1         0               0           0
# 114   0        6         27              0           0
# 115   0        1         0               0           0
# 116   0        1         0               0           0
# 117   0        1         0               0           0
# 118   0        1         0               0           0
# 119   0        1         0               0           0
# 120   2        9         947             0           0
# 121   0        1         0               0           0
# 122   0        1         0               0           0
# 123   0        1         0               0           0
# 124   0        1         0               1           0
# 125   0        1         0               0           0
# 126   2        0         0               0           0
# 127   0        1         0               0           0
# 128   1        1         0               0           0
# 129   0        1         0               0           0
# 130   1        3         14              0           0
# 131   0        9         969             0           0
# 132   2        21        29406           1           0
# 133   0        1         49              0           0
# 134   0        1         0               0           0
# 135   0        1         0               0           0
# 136   0        1         0               0           0
# 137   2        21        115             0           0
# 138   0        1         0               0           0
# 139   0        3         12              0           0
# 140   0        1         0               0           0
# 141   0        1         0               0           0
# 142   0        1         0               0           0
# 143   1        2         0               0           0
# 144   3        4         29336           1           0
# 145   0        1         0               0           0
# 146   0        1         0               0           0
# 147   0        1         0               0           0
# 148   1        2         0               0           0
# 149   6        1         0               0           0
# 150   0        1         0               0           0
# 151   2        27        218             0           0
# 152   2        0         0               0           0
# 153   0        1         0               0           0
# 154   0        1         0               0           0
# 155   0        5         5               0           0
# 156   0        1         0               0           0
# 157   1        1         0               0           0
# 158   3        28        242             0           0
# 159   1        1         0               0           0
# 160   0        1         0               0           0
# 161   3        1         0               0           0
# 162   0        1         0               0           0
# 163   0        1         0               0           0
# 164   0        1         0               0           0
# 165   1        1         0               0           0
# 166   2        1         0               0           0
# 167   0        3         0               0           0
# 168   8        6         0               0           0
# 169   3        22        38              0           0
# 170   0        1         0               0           0
# 171   3        1         0               0           0
# 172   1        1         0               0           0
# 173   0        1         0               0           0
# 174   0        1         0               0           0
# 175   8        32        29601           0           0
# 176   2        1         0               0           0
# 177   0        1         0               0           0
# 178   2        0         0               0           0
# 179   0        1         0               0           0
# 180   0        1         0               0           0
# 181   0        1         0               0           0
# 182   0        1         0               1           0
# 183   1        1         0               0           0
# 184   0        3         762             0           0
# 185   0        1         0               0           0
# 186   0        1         12              0           0
# 187   0        1         0               0           0
# 188   0        1         0               0           0
# 189   0        1         0               0           0
# 190   1        2         0               0           0
# 191   0        2         0               0           0
# 192   0        1         0               0           0
# 193   0        1         0               0           0
# 194   0        1         0               0           0
# 195   0        1         0               0           0
# 196   0        2         0               0           0
# 197   0        1         0               0           0
# 198   8        101       31390           0           0
# 199   0        1         0               0           0
# ...  ..       ..        ..              ..          ..
# 5605  0        4         717             0           0
# 5606  3        4         0               0           0
# 5607  2        0         0               0           0
# 5608  2        0         0               0           0
# 5609  2        0         0               0           0
# 5610  2        0         0               0           0
# 5611  2        0         0               0           0
# 5612  2        0         0               0           0
# 5613  2        0         0               0           0
# 5614  2        0         0               0           0
# 5615  2        0         0               0           0
# 5616  0        1         0               0           0
# 5617  0        2         0               0           0
# 5618  0        1         0               0           0
# 5619  0        1         0               0           0
# 5620  0        1         0               0           0
# 5621  0        3         340             0           0
# 5622  0        1         0               0           0
# 5623  0        1         0               0           0
# 5624  0        1         0               0           0
# 5625  0        1         0               0           0
# 5626  0        1         0               0           0
# 5627  0        1         0               0           0
# 5628  1        1         0               0           0
# 5629  0        1         0               0           0
# 5630  0        1         0               0           0
# 5631  1        1         0               2           0
# 5632  1        1         0               0           0
# 5633  0        1         0               0           0
# 5634  0        2         0               0           0
# 5635  0        1         0               0           0
# 5636  0        1         0               0           0
# 5637  1        2         0               0           0
# 5638  2        2         0               0           0
# 5639  0        1         0               0           0
# 5640  0        1         0               0           0
# 5641  2        0         0               0           0
# 5642  2        0         0               0           0
# 5643  2        0         0               0           0
# 5644  2        0         0               0           0
# 5645  2        0         0               0           0
# 5646  17       32        1578            0           0
# 5647  8        24        1403            0           0
# 5648  5        71        1396            0           0
# 5649  2        8         244             0           0
# 5650  0        5         762             0           0
# 5651  4        13        59              0           0
# 5652  6        10        16              0           0
# 5653  1        16        1029            0           0
# 5654  2        15        58              0           0
# 5655  1        9         774             0           0
# 5656  3        13        68              0           0
# 5657  5        8         6               0           0
# 5658  4        2         37              0           0
# 5659  5        43        3424            0           0
# 5660  1        1         0               0           0
# 5661  1        2         40              0           0
# 5662  4        14        574             0           0
# 5663  0        2         5               0           0
# 5664  7        15        18              0           0
# 5665  1        19        151             0           0
# 5666  11       57        2701            0           0
# 5667  3        11        190             0           0
# 5668  1        11        2286            0           0
# 5669  21       19        54              0           0
# 5670  2        6         61              0           0
# 5671  2        0         0               0           0
# 5672  5        5         3               0           0
# 5673  2        1         0               0           0
# 5674  13       2         758             0           0
# 5675  4        2         0               0           0
# 5676  5        20        925             0           0
# 5677  3        9         116             0           0
# 5678  2        1         0               0           0
# 5679  1        2         0               0           0
# 5680  0        1         0               0           0
# 5681  0        1         0               0           0
# 5682  8        1         0               0           0
# 5683  4        1         0               0           0
# 5684  11       20        187             0           0
# 5685  4        2         17              0           0
# 5686  4        2         19              0           0
# 5687  8        18        465             0           0
# 5688  3        51        509             0           0
# 5689  0        2         0               0           0
# 5690  6        9         822             0           0
# 5691  9        17        349             0           0
# 5692  14       29        1061            1           0
# 5693  2        0         0               0           0
# 5694  5        9         1237            0           0
# 5695  0        1         3               0           0
# 5696  0        3         17              0           0
# 5697  6        14        204             0           0
# 5698  2        8         63              0           0
# 5699  1        3         0               0           0
# 5700  2        0         0               0           0
# 5701  2        0         0               0           0
# 5702  2        37        1622            2           1
# 5703  0        1         0               0           0
# 5704  3        1         0               0           0
# 5705  0        1         0               0           0
# 5706  5        79        2111            0           0
# 5707  0        2         7               0           0
# 5708  10       28        1164            4           0
# 5709  0        1         0               0           0
# 5710  0        1         0               0           0
# 5711  0        2         0               0           0
# 5712  2        1         50              0           0
# 5713  0        1         0               0           0
# 5714  0        1         0               121         0
# 5715  5        18        28              0           0
# 5716  0        1         0               6           0
# 5717  0        1         0               39          0
# 5718  9        13        14              20          0
# 5719  0        5         60              0           0
# 5720  1        14        4               2           0
# 5721  0        1         0               0           0
# 5722  0        1         0               0           0
# 5723  1        4         3               0           0
# 5724  2        1         0               0           0
# 5725  12       16        157             0           0
# 5726  0        1         0               0           0
# 5727  2        0         0               0           0
# 5728  7        1         0               0           0
# 5729  5        52        29526           0           0
# 5730  4        55        30971           0           0
# 5731  18       53        273             0           0
# 5732  0        1         0               0           0
# 5733  11       29        29491           0           0
# 5734  0        3         32              0           0
# 5735  4        32        1067            0           0
# 5736  1        11        1280            0           0
# 5737  1        2         27              0           0
# 5738  4        31        3293            0           0
# 5739  1        1         0               0           0
# 5740  8        15        216             0           0
# 5741  4        3         762             0           0
# 5742  3        98        31646           1           0
# 5743  4        27        190             0           0
# 5744  5        9         232             0           0
# 5745  2        30        1324            0           0
# 5746  15       27        747             0           0
# 5747  8        29        81              0           0
# 5748  1        1         0               0           0
# 5749  6        29        30392           0           0
# 5750  9        10        31              0           0
# 5751  3        14        121             0           0
# 5752  2        0         0               0           0
# 5753  2        0         0               0           0
# 5754  0        3         49              0           0
# 5755  1        1         0               0           0
# 5756  7        106       30146           1           0
# 5757  5        5         937             1           0
# 5758  2        1         0               0           0
# 5759  1        1         0               0           0
# 5760  1        6         69              0           0
# 5761  0        1         0               0           0
# 5762  0        11        126             0           0
# 5763  0        5         16              0           0
# 5764  4        1         0               3           0
# 5765  0        1         0               0           0
# 5766  0        5         29346           0           0
# 5767  1        2         0               0           0
# 5768  0        1         0               0           0
# 5769  15       8         681             1           0
# 5770  1        3         1               0           0
# 5771  7        7         8               2           0
# 5772  0        1         0               0           0
# 5773  3        754       1017693         0           0
# 5774  4        11        6               0           0
# 5775  0        5         0               1           0
# 5776  0        1         0               0           0
# 5777  1        1         0               0           0
# 5778  0        1         0               0           0
# 5779  2        0         0               0           0
# 5780  0        1         0               0           0
# 5781  0        2         0               0           0
# 5782  0        1         0               0           0
# 5783  0        1         0               0           0
# 5784  0        1         0               0           0
# 5785  0        3         340             0           0
# 5786  0        1         0               0           0
# 5787  0        1         0               0           0
# 5788  0        1         0               0           0
# 5789  0        1         0               0           0
# 5790  0        1         0               0           0
# 5791  0        1         0               0           0
# 5792  1        1         0               0           0
# 5793  0        1         0               0           0
# 5794  0        1         0               0           0
# 5795  1        1         0               2           0
# 5796  1        1         0               0           0
# 5797  0        1         0               0           0
# 5798  0        2         0               0           0
# 5799  0        1         0               0           0
# 5800  0        1         0               0           0
# 5801  1        2         0               0           0
# 5802  2        2         0               0           0
# 5803  0        1         0               0           0
# 5804  0        1         0               0           0
#
#              Возраст Рост         Мед. Состояние          Фото Посты   Гендер  \
# 0     Коля объебался  Er   здоров                 отсутствует   1     Er
# 1     34              160  здоров                 присутствует  86    Женщина
# 2     56              152  требуется мед. помощь  присутствует  30    Женщина
# 3     58              165  здоров                 присутствует  10    Женщина
# 4     41              175  здоров                 присутствует  8     Мужчина
# 5     47              177  здоров                 присутствует  6     Мужчина
# 6     32              170  требуется мед. помощь  присутствует  5     Er
# 7     47              176  здоров                 присутствует  5     Женщина
# 8     20              175  здоров                 присутствует  5     Женщина
# 9     70              176  здоров                 присутствует  8     Мужчина
# 10    22              176  здоров                 присутствует  7     Женщина
# 11    32              164  требуется мед. помощь  отсутствует   4     Мужчина
# 12    80              170  здоров                 присутствует  2     Мужчина
# 13    Коля объебался  170  здоров                 присутствует  3     Мужчина
# 14    66              165  здоров                 присутствует  4     Er
# 15    53              180  здоров                 присутствует  7     Мужчина
# 16    56              175  здоров                 присутствует  3     Мужчина
# 17    58              179  здоров                 присутствует  14    Мужчина
# 18    18              175  здоров                 присутствует  2     Женщина
# 19    47              174  здоров                 присутствует  8     Мужчина
# 20    56              170  здоров                 присутствует  38    Мужчина
# 21    42              153  здоров                 присутствует  58    Женщина
# 22    41              176  требуется мед. помощь  присутствует  21    Мужчина
# 23    40              180  здоров                 присутствует  10    Мужчина
# 24    44              170  здоров                 присутствует  2     Мужчина
# 25    38              182  требуется мед. помощь  присутствует  4     Женщина
# 26    Коля объебался  Er   здоров                 отсутствует   1     Er
# 27    37              170  здоров                 присутствует  30    Мужчина
# 28    50              180  здоров                 присутствует  3     Женщина
# 29    41              175  здоров                 присутствует  6     Мужчина
# 30    32              170  здоров                 присутствует  10    Мужчина
# 31    26              168  здоров                 присутствует  9     Мужчина
# 32    26              170  здоров                 присутствует  5     Мужчина
# 33    78              165  требуется мед. помощь  присутствует  40    Женщина
# 34    38              172  здоров                 присутствует  4     Мужчина
# 35    34              170  здоров                 присутствует  7     Женщина
# 36    36              180  здоров                 присутствует  4     Мужчина
# 37    76              170  здоров                 присутствует  3     Мужчина
# 38    54              150  требуется мед. помощь  присутствует  4     Женщина
# 39    59              173  требуется мед. помощь  присутствует  5     Женщина
# 40    70              170  здоров                 присутствует  6     Мужчина
# 41    52              175  требуется мед. помощь  присутствует  6     Мужчина
# 42    21              176  здоров                 присутствует  9     Мужчина
# 43    31              160  здоров                 присутствует  11    Женщина
# 44    26              176  здоров                 присутствует  4     Мужчина
# 45    66              162  здоров                 присутствует  3     Мужчина
# 46    52              164  здоров                 присутствует  9     Женщина
# 47    36              174  здоров                 присутствует  5     Мужчина
# 48    43              165  требуется мед. помощь  присутствует  3     Женщина
# 49    56              165  здоров                 присутствует  5     Мужчина
# 50    41              158  здоров                 присутствует  5     Женщина
# 51    73              154  требуется мед. помощь  отсутствует   14    Женщина
# 52    Коля объебался  Er   здоров                 отсутствует   1     Er
# 53    49              155  требуется мед. помощь  присутствует  7     Женщина
# 54    40              160  здоров                 присутствует  5     Женщина
# 55    21              195  здоров                 присутствует  4     Мужчина
# 56    35              167  требуется мед. помощь  присутствует  3     Женщина
# 57    50              170  здоров                 присутствует  3     Женщина
# 58    33              180  здоров                 присутствует  4     Мужчина
# 59    60              165  здоров                 присутствует  5     Мужчина
# 60    32              187  здоров                 присутствует  33    Мужчина
# 61    66              168  здоров                 присутствует  4     Мужчина
# 62    29              180  здоров                 присутствует  3     Мужчина
# 63    20              176  здоров                 присутствует  8     Мужчина
# 64    36              178  здоров                 присутствует  3     Мужчина
# 65    47              170  требуется мед. помощь  присутствует  3     Мужчина
# 66    28              172  здоров                 присутствует  3     Мужчина
# 67    44              183  здоров                 присутствует  6     Мужчина
# 68    44              173  здоров                 присутствует  4     Мужчина
# 69    76              160  требуется мед. помощь  присутствует  6     Женщина
# 70    39              168  здоров                 присутствует  4     Мужчина
# 71    46              176  здоров                 присутствует  3     Мужчина
# 72    59              170  здоров                 присутствует  6     Мужчина
# 73    33              176  здоров                 присутствует  17    Мужчина
# 74    52              Er   здоров                 присутствует  5     Мужчина
# 75    22              170  здоров                 присутствует  2     Мужчина
# 76    47              170  здоров                 присутствует  5     Мужчина
# 77    40              196  здоров                 присутствует  3     Мужчина
# 78    Коля объебался  Er   здоров                 отсутствует   1     Er
# 79    37              162  здоров                 присутствует  5     Мужчина
# 80    34              176  здоров                 присутствует  5     Мужчина
# 81    57              175  здоров                 присутствует  6     Женщина
# 82    20              175  здоров                 присутствует  8     Мужчина
# 83    41              164  здоров                 присутствует  33    Женщина
# 84    79              158  здоров                 присутствует  2     Женщина
# 85    42              184  требуется мед. помощь  отсутствует   5     Мужчина
# 86    49              176  здоров                 присутствует  4     Женщина
# 87    32              165  здоров                 присутствует  5     Женщина
# 88    41              Er   здоров                 присутствует  6     Мужчина
# 89    31              176  требуется мед. помощь  присутствует  4     Мужчина
# 90    52              167  здоров                 присутствует  4     Мужчина
# 91    21              176  здоров                 присутствует  3     Мужчина
# 92    36              173  здоров                 присутствует  27    Мужчина
# 93    31              160  здоров                 присутствует  5     Женщина
# 94    60              175  здоров                 присутствует  3     Мужчина
# 95    89              155  требуется мед. помощь  присутствует  7     Женщина
# 96    57              170  здоров                 присутствует  5     Мужчина
# 97    20              180  здоров                 присутствует  2     Мужчина
# 98    56              180  здоров                 присутствует  2     Мужчина
# 99    35              180  здоров                 присутствует  6     Мужчина
# 100   30              176  здоров                 присутствует  3     Мужчина
# 101   41              178  здоров                 присутствует  2     Мужчина
# 102   71              176  требуется мед. помощь  присутствует  10    Мужчина
# 103   52              170  требуется мед. помощь  присутствует  3     Женщина
# 104   Коля объебался  Er   здоров                 отсутствует   1     Er
# 105   38              180  здоров                 присутствует  2     Мужчина
# 106   43              190  здоров                 присутствует  4     Мужчина
# 107   35              160  здоров                 присутствует  2     Женщина
# 108   80              165  здоров                 отсутствует   6     Женщина
# 109   50              189  здоров                 присутствует  3     Мужчина
# 110   Коля объебался  Er   здоров                 отсутствует   1     Er
# 111   17              160  здоров                 присутствует  4     Мужчина
# 112   12              167  здоров                 присутствует  4     Женщина
# 113   17              176  здоров                 присутствует  8     Мужчина
# 114   16              160  здоров                 присутствует  4     Мужчина
# 115   13              150  здоров                 присутствует  3     Мужчина
# 116   13              156  здоров                 присутствует  3     Женщина
# 117   15              160  здоров                 присутствует  3     Женщина
# 118   17              Er   здоров                 присутствует  4     Мужчина
# 119   14              173  здоров                 присутствует  6     Женщина
# 120   3               100  здоров                 присутствует  6     Мужчина
# 121   12              158  здоров                 присутствует  2     Мужчина
# 122   39              Er   здоров                 присутствует  4     Мужчина
# 123   16              155  здоров                 отсутствует   4     Женщина
# 124   17              173  здоров                 присутствует  8     Женщина
# 125   15              155  здоров                 присутствует  3     Женщина
# 126   Коля объебался  Er   здоров                 отсутствует   1     Er
# 127   42              177  здоров                 присутствует  4     Мужчина
# 128   22              185  здоров                 присутствует  4     Мужчина
# 129   41              168  здоров                 присутствует  5     Мужчина
# 130   51              168  требуется мед. помощь  присутствует  18    Мужчина
# 131   30              187  здоров                 присутствует  10    Мужчина
# 132   18              180  здоров                 присутствует  25    Мужчина
# 133   43              166  здоров                 присутствует  4     Женщина
# 134   29              185  здоров                 присутствует  2     Мужчина
# 135   25              186  здоров                 присутствует  3     Мужчина
# 136   30              187  здоров                 присутствует  4     Мужчина
# 137   27              181  здоров                 присутствует  24    Мужчина
# 138   52              164  требуется мед. помощь  присутствует  2     Женщина
# 139   34              190  здоров                 присутствует  13    Мужчина
# 140   23              170  здоров                 присутствует  6     Мужчина
# 141   80              150  здоров                 присутствует  4     Женщина
# 142   23              168  здоров                 присутствует  3     Мужчина
# 143   80              160  здоров                 присутствует  8     Женщина
# 144   54              180  здоров                 присутствует  8     Мужчина
# 145   35              168  здоров                 присутствует  7     Женщина
# 146   61              160  требуется мед. помощь  присутствует  4     Женщина
# 147   30              182  здоров                 присутствует  2     Мужчина
# 148   36              180  здоров                 присутствует  11    Мужчина
# 149   58              165  здоров                 присутствует  35    Женщина
# 150   30              165  здоров                 присутствует  3     Женщина
# 151   72              165  здоров                 присутствует  39    Мужчина
# 152   Коля объебался  Er   здоров                 отсутствует   1     Er
# 153   20              192  здоров                 присутствует  2     Мужчина
# 154   39              180  здоров                 отсутствует   4     Мужчина
# 155   77              145  здоров                 присутствует  11    Женщина
# 156   27              157  здоров                 присутствует  3     Женщина
# 157   79              166  требуется мед. помощь  присутствует  5     Женщина
# 158   39              165  требуется мед. помощь  присутствует  17    Мужчина
# 159   63              160  здоров                 присутствует  6     Женщина
# 160   83              154  здоров                 присутствует  3     Женщина
# 161   43              158  здоров                 присутствует  7     Женщина
# 162   46              178  требуется мед. помощь  присутствует  4     Мужчина
# 163   34              175  требуется мед. помощь  присутствует  3     Мужчина
# 164   81              170  здоров                 присутствует  4     Мужчина
# 165   85              152  здоров                 присутствует  5     Женщина
# 166   24              180  здоров                 присутствует  9     Мужчина
# 167   53              176  требуется мед. помощь  присутствует  8     Женщина
# 168   55              172  требуется мед. помощь  присутствует  31    Мужчина
# 169   78              165  здоров                 присутствует  45    Женщина
# 170   21              175  здоров                 присутствует  4     Мужчина
# 171   42              190  требуется мед. помощь  присутствует  10    Мужчина
# 172   81              150  здоров                 присутствует  3     Женщина
# 173   81              160  требуется мед. помощь  присутствует  6     Женщина
# 174   49              163  требуется мед. помощь  присутствует  3     Мужчина
# 175   63              Er   требуется мед. помощь  присутствует  41    Мужчина
# 176   81              172  требуется мед. помощь  присутствует  8     Женщина
# 177   81              160  здоров                 присутствует  3     Женщина
# 178   Коля объебался  Er   здоров                 отсутствует   1     Er
# 179   54              167  здоров                 присутствует  5     Мужчина
# 180   24              175  здоров                 присутствует  3     Мужчина
# 181   51              173  здоров                 присутствует  2     Мужчина
# 182   35              160  здоров                 присутствует  34    Женщина
# 183   36              Er   здоров                 присутствует  4     Мужчина
# 184   62              170  здоров                 присутствует  4     Мужчина
# 185   75              170  здоров                 присутствует  4     Мужчина
# 186   82              155  здоров                 присутствует  4     Мужчина
# 187   Коля объебался  Er   здоров                 присутствует  3     Мужчина
# 188   22              175  здоров                 отсутствует   3     Мужчина
# 189   25              180  здоров                 присутствует  3     Мужчина
# 190   70              156  здоров                 присутствует  4     Женщина
# 191   42              183  здоров                 присутствует  8     Мужчина
# 192   75              170  здоров                 присутствует  5     Мужчина
# 193   20              167  здоров                 присутствует  4     Женщина
# 194   77              167  требуется мед. помощь  присутствует  5     Мужчина
# 195   48              165  здоров                 присутствует  6     Мужчина
# 196   19              182  требуется мед. помощь  присутствует  6     Женщина
# 197   21              179  здоров                 отсутствует   3     Мужчина
# 198   85              152  здоров                 присутствует  207   Женщина
# 199   04              175  здоров                 присутствует  5     Мужчина
# ...   ..              ...     ...                          ... ..         ...
# 5605  90              175  здоров                 присутствует  17    Мужчина
# 5606  87              Er   здоров                 отсутствует   49    Женщина
# 5607  Коля объебался  Er   здоров                 отсутствует   1     Er
# 5608  Коля объебался  Er   здоров                 отсутствует   1     Er
# 5609  Коля объебался  Er   здоров                 отсутствует   1     Er
# 5610  Коля объебался  Er   здоров                 отсутствует   1     Er
# 5611  Коля объебался  Er   здоров                 отсутствует   1     Er
# 5612  Коля объебался  Er   здоров                 отсутствует   1     Er
# 5613  Коля объебался  Er   здоров                 отсутствует   1     Er
# 5614  Коля объебался  Er   здоров                 отсутствует   1     Er
# 5615  Коля объебался  Er   здоров                 отсутствует   1     Er
# 5616  83              160  требуется мед. помощь  отсутствует   4     Мужчина
# 5617  38              Er   здоров                 присутствует  2     Женщина
# 5618  17              160  требуется мед. помощь  присутствует  7     Женщина
# 5619  79              180  здоров                 отсутствует   3     Мужчина
# 5620  90              175  здоров                 присутствует  2     Женщина
# 5621  12              176  здоров                 присутствует  2     Мужчина
# 5622  8               160  требуется мед. помощь  присутствует  3     Женщина
# 5623  55              170  здоров                 присутствует  3     Мужчина
# 5624  49              160  здоров                 присутствует  2     Женщина
# 5625  38              180  здоров                 присутствует  4     Мужчина
# 5626  17              Er   здоров                 отсутствует   4     Мужчина
# 5627  79              168  требуется мед. помощь  отсутствует   4     Мужчина
# 5628  30              Er   здоров                 отсутствует   5     Мужчина
# 5629  24              175  требуется мед. помощь  отсутствует   3     Мужчина
# 5630  73              168  здоров                 присутствует  5     Мужчина
# 5631  42              188  здоров                 отсутствует   5     Мужчина
# 5632  29              Er   здоров                 присутствует  5     Мужчина
# 5633  44              193  здоров                 присутствует  4     Мужчина
# 5634  24              185  здоров                 присутствует  2     Мужчина
# 5635  35              186  здоров                 присутствует  3     Мужчина
# 5636  25              Er   здоров                 отсутствует   6     Мужчина
# 5637  79              152  здоров                 отсутствует   3     Мужчина
# 5638  2               Er   здоров                 отсутствует   11    Мужчина
# 5639  18              175  здоров                 присутствует  5     Мужчина
# 5640  62              160  требуется мед. помощь  отсутствует   9     Женщина
# 5641  Коля объебался  Er   здоров                 отсутствует   1     Er
# 5642  Коля объебался  Er   здоров                 отсутствует   1     Er
# 5643  Коля объебался  Er   здоров                 отсутствует   1     Er
# 5644  Коля объебался  Er   здоров                 отсутствует   1     Er
# 5645  Коля объебался  Er   здоров                 отсутствует   1     Er
# 5646  77              170  здоров                 присутствует  80    Мужчина
# 5647  80              172  здоров                 присутствует  55    Мужчина
# 5648  25              185  здоров                 присутствует  150   Мужчина
# 5649  Коля объебался  170  здоров                 присутствует  16    Мужчина
# 5650  75              175  здоров                 присутствует  6     Мужчина
# 5651  18              175  здоров                 присутствует  23    Мужчина
# 5652  33              170  здоров                 отсутствует   19    Мужчина
# 5653  71              173  здоров                 отсутствует   31    Мужчина
# 5654  82              165  здоров                 присутствует  27    Мужчина
# 5655  58              175  здоров                 отсутствует   14    Мужчина
# 5656  51              163  здоров                 присутствует  14    Женщина
# 5657  28              162  здоров                 присутствует  21    Женщина
# ...
# 173   0                0                0.000000     Июнь      2017
# 174   0                0                0.000000     Ноябрь    2017
# 175   0                0                0.000000     Август    2017
# 176   0                0                0.000000     Ноябрь    2017
# 177   0                0                0.000000     Ноябрь    2017
# 178   0                0                0.000000     Март      2016
# 179   0                0                0.000000     Ноябрь    2017
# 180   0                0                0.000000     Октябрь   2017
# 181   0                0                0.000000     Октябрь   2017
# 182   0                0                0.000000     Октябрь   2017
# 183   0                0                0.000000     Ноябрь    2017
# 184   0                0                0.000000     Октябрь   2017
# 185   0                0                0.000000     Октябрь   2017
# 186   0                0                0.000000     Март      2017
# 187   0                0                0.000000     Октябрь   2017
# 188   0                0                0.000000     Октябрь   2017
# 189   0                0                0.000000     Октябрь   2017
# 190   0                0                0.000000     Октябрь   2017
# 191   0                0                0.000000     Сентябрь  2017
# 192   0                0                0.000000     Октябрь   2017
# 193   0                0                0.000000     Сентябрь  2017
# 194   0                0                0.000000     Декабрь   2016
# 195   0                0                0.000000     Сентябрь  2017
# 196   0                0                0.000000     Сентябрь  2017
# 197   0                0                0.000000     Сентябрь  2017
# 198   0                0                0.000000     Октябрь   2015
# 199   0                0                0.000000     Июнь      2017
# ...  ..               ..                     ...      ...       ...
# 5605  0                0                0.000000     Июль      2011
# 5606  0                0                0.000000     Июнь      2011
# 5607  0                0                0.000000     Март      2016
# 5608  0                0                0.000000     Март      2016
# 5609  0                0                0.000000     Март      2016
# 5610  0                0                0.000000     Март      2016
# 5611  0                0                0.000000     Март      2016
# 5612  0                0                0.000000     Март      2016
# 5613  0                0                0.000000     Март      2016
# 5614  0                0                0.000000     Март      2016
# 5615  0                0                0.000000     Март      2016
# 5616  0                0                0.000000     Сентябрь  2014
# 5617  0                0                0.000000     Сентябрь  2014
# 5618  0                0                0.000000     Сентябрь  2014
# 5619  0                0                0.000000     Сентябрь  2014
# 5620  0                0                0.000000     Сентябрь  2014
# 5621  0                0                0.000000     Сентябрь  2014
# 5622  0                0                0.000000     Сентябрь  2014
# 5623  0                0                0.000000     Сентябрь  2014
# 5624  0                0                0.000000     Сентябрь  2014
# 5625  0                0                0.000000     Сентябрь  2014
# 5626  0                0                0.000000     Сентябрь  2014
# 5627  0                0                0.000000     Сентябрь  2014
# 5628  0                0                0.000000     Сентябрь  2014
# 5629  0                0                0.000000     Сентябрь  2014
# 5630  0                0                0.000000     Сентябрь  2014
# 5631  0                0                0.000000     Август    2014
# 5632  0                0                0.000000     Сентябрь  2014
# 5633  0                0                0.000000     Август    2014
# 5634  0                0                0.000000     Сентябрь  2014
# 5635  0                0                0.000000     Сентябрь  2014
# 5636  0                0                0.000000     Август    2014
# 5637  0                0                0.000000     Август    2014
# 5638  0                0                0.000000     Сентябрь  2014
# 5639  0                0                0.000000     Ноябрь    1981
# 5640  0                0                0.000000     Август    2014
# 5641  0                0                0.000000     Март      2016
# 5642  0                0                0.000000     Март      2016
# 5643  0                0                0.000000     Март      2016
# 5644  0                0                0.000000     Март      2016
# 5645  0                0                0.000000     Март      2016
# 5646  0                0                0.000000     Сентябрь  2016
# 5647  0                0                0.000000     Июнь      2016
# 5648  0                0                0.000000     Июнь      2016
# 5649  0                0                0.000000     Сентябрь  2016
# 5650  0                0                0.000000     Декабрь   2016
# 5651  0                0                0.000000     Декабрь   2016
# 5652  0                0                0.000000     Декабрь   2016
# 5653  0                0                0.000000     Декабрь   2016
# 5654  0                0                0.000000     Декабрь   2016
# 5655  0                0                0.000000     Декабрь   2016
# 5656  0                0                0.000000     Декабрь   2016
# 5657  0                0                0.000000     Декабрь   2016
# 5658  0                0                0.000000     Декабрь   2016
# 5659  0                0                0.000000     Декабрь   2016
# 5660  0                0                0.000000     Декабрь   2016
# 5661  0                0                0.000000     Декабрь   2016
# 5662  0                0                0.000000     Декабрь   2016
# 5663  0                0                0.000000     Декабрь   2016
# 5664  0                0                0.000000     Декабрь   2016
# 5665  0                0                0.000000     Декабрь   2016
# 5666  0                0                0.000000     Декабрь   2016
# 5667  0                0                0.000000     Ноябрь    2016
# 5668  0                0                0.000000     Ноябрь    2016
# 5669  0                0                0.000000     Ноябрь    2016
# 5670  0                0                0.000000     Ноябрь    2016
# 5671  0                0                0.000000     Март      2016
# 5672  0                0                0.000000     Октябрь   2017
# 5673  0                0                0.000000     Сентябрь  2017
# 5674  0                0                0.000000     Сентябрь  2017
# 5675  0                0                0.000000     Сентябрь  2017
# 5676  0                0                0.000000     Сентябрь  2017
# 5677  0                0                0.000000     Сентябрь  2017
# 5678  0                0                0.000000     Сентябрь  2017
# 5679  0                0                0.000000     Сентябрь  2017
# 5680  0                0                0.000000     Сентябрь  2017
# 5681  0                0                0.000000     Сентябрь  2017
# 5682  0                0                0.000000     Сентябрь  2017
# 5683  0                0                0.000000     Август    2017
# 5684  0                0                0.000000     Август    2017
# 5685  0                0                0.000000     Август    2017
# 5686  0                0                0.000000     Июль      2017
# 5687  0                0                0.000000     Июль      2017
# 5688  0                0                0.000000     Июль      2017
# 5689  0                0                0.000000     Июль      2017
# 5690  0                0                0.000000     Июль      2017
# 5691  0                0                0.000000     Апрель    2017
# 5692  0                0                0.000000     Апрель    2017
# 5693  0                0                0.000000     Март      2016
# 5694  0                0                0.000000     Октябрь   2018
# 5695  0                0                0.000000     Август    2018
# 5696  0                0                0.000000     Август    2018
# 5697  0                0                0.000000     Июль      2018
# 5698  0                0                0.000000     Июль      2018
# 5699  0                0                0.000000      Февраль  2018
# 5700  0                0                0.000000     Март      2016
# 5701  0                0                0.000000     Март      2016
# 5702  0                0                0.000000     Октябрь   2017
# 5703  0                0                0.000000     Октябрь   2014
# 5704  0                0                0.000000     Август    2017
# 5705  0                0                0.000000     Май       2017
# 5706  0                0                0.000000     Июнь      2017
# 5707  0                0                0.000000     Январь    2015
# 5708  0                0                0.000000     Август    2015
# 5709  0                0                0.000000     Август    2014
# 5710  0                0                0.000000     Март      2016
# 5711  0                0                0.000000     Январь    2016
# 5712  0                0                0.000000     Ноябрь    2012
# 5713  0                0                0.000000     Июль      2017
# 5714  0                0                0.000000     Октябрь   2017
# 5715  0                0                0.000000     Апрель    2017
# 5716  0                0                0.000000     Декабрь   2014
# 5717  0                0                0.000000     Апрель    2014
# 5718  0                0                0.000000     Апрель    2014
# 5719  0                0                0.000000     Август    2017
# 5720  0                0                0.000000      Февраль  2017
# 5721  0                0                0.000000     Декабрь   2015
# 5722  0                0                0.000000     Апрель    2015
# 5723  0                0                0.000000     Октябрь   2017
# 5724  0                0                0.000000     Октябрь   2017
# 5725  0                0                0.000000     Сентябрь  2017
# 5726  0                0                0.000000     Сентябрь  2017
# 5727  0                0                0.000000     Март      2016
# 5728  0                0                0.000000     Июнь      2019
# 5729  0                0                0.000000     Май       2019
# 5730  0                0                0.000000     Май       2019
# 5731  0                0                0.000000     Июнь      2019
# 5732  0                0                0.000000     Июнь      2019
# 5733  0                0                0.000000     Май       2019
# 5734  0                0                0.000000     Май       2019
# 5735  0                0                0.000000     Май       2019
# 5736  0                0                0.000000     Май       2019
# 5737  0                0                0.000000     Май       2019
# 5738  0                0                0.000000     Май       2019
# 5739  0                0                0.000000     Май       2019
# 5740  0                0                0.000000     Май       2019
# 5741  0                0                0.000000     Май       2019
# 5742  0                0                0.000000     Май       2019
# 5743  0                0                0.000000     Май       2019
# 5744  0                0                0.000000     Май       2019
# 5745  0                0                0.000000     Май       2019
# 5746  0                0                0.000000     Май       2019
# 5747  0                0                0.000000     Май       2019
# 5748  0                0                0.000000     Май       2019
# 5749  0                0                0.000000     Май       2019
# 5750  0                0                0.000000     Май       2019
# 5751  0                0                0.000000     Май       2019
# 5752  0                0                0.000000     Май       2019
# 5753  0                0                0.000000     Март      2016
# 5754  0                0                0.000000     Декабрь   2011
# 5755  0                0                0.000000     Май       2019
# 5756  01-05-19 08:23   01-05-19  16:13  7.833333     Апрель    2019
# 5757  0                0                0.000000      Февраль  2019
# 5758  0                0                0.000000     Май       2019
# 5759  0                0                0.000000     Май       2019
# 5760  0                0                0.000000     Май       2019
# 5761  0                0                0.000000     Май       2019
# 5762  0                0                0.000000     Май       2019
# 5763  0                0                0.000000     Май       2019
# 5764  0                0                0.000000     Май       2019
# 5765  0                0                0.000000     Май       2019
# 5766  0                0                0.000000     Май       2019
# 5767  0                0                0.000000     Декабрь   2018
# 5768  0                0                0.000000     Май       2019
# 5769  0                0                0.000000     Май       2019
# 5770  0                0                0.000000     Май       2019
# 5771  0                0                0.000000     Май       2019
# 5772  0                0                0.000000     Май       2019
# 5773  29-08-18  20:14  30-08-18 01:19   5.083333     Август    2018
# 5774  0                0                0.000000     Май       2019
# 5775  0                0                0.000000     Апрель    2019
# 5776  0                0                0.000000     Сентябрь  2018
# 5777  0                0                0.000000     Май       2019
# 5778  0                0                0.000000     Май       2019
# 5779  0                0                0.000000     Март      2016
# 5780  0                0                0.000000     Сентябрь  2014
# 5781  0                0                0.000000     Сентябрь  2014
# 5782  0                0                0.000000     Сентябрь  2014
# 5783  0                0                0.000000     Сентябрь  2014
# 5784  0                0                0.000000     Сентябрь  2014
# 5785  0                0                0.000000     Сентябрь  2014
# 5786  0                0                0.000000     Сентябрь  2014
# 5787  0                0                0.000000     Сентябрь  2014
# 5788  0                0                0.000000     Сентябрь  2014
# 5789  0                0                0.000000     Сентябрь  2014
# 5790  0                0                0.000000     Сентябрь  2014
# 5791  0                0                0.000000     Сентябрь  2014
# 5792  0                0                0.000000     Сентябрь  2014
# 5793  0                0                0.000000     Сентябрь  2014
# 5794  0                0                0.000000     Сентябрь  2014
# 5795  0                0                0.000000     Август    2014
# 5796  0                0                0.000000     Сентябрь  2014
# 5797  0                0                0.000000     Август    2014
# 5798  0                0                0.000000     Сентябрь  2014
# 5799  0                0                0.000000     Сентябрь  2014
# 5800  0                0                0.000000     Август    2014
# 5801  0                0                0.000000     Август    2014
# 5802  0                0                0.000000     Сентябрь  2014
# 5803  0                0                0.000000     Ноябрь    1981
# 5804  0                0                0.000000     Август    2014
#
# [5805 rows x 32 columns]

# %%
df1.to_excel("Moscow.xlsx")
