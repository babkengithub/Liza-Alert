# %%
import numpy as np
import pandas as pd
import re
import bs4
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
from scrapy import Selector
from nltk import word_tokenize
import nltk
nltk.download('punkt') #winlocker
pd.set_option("display.max_rows", 400)
pd.set_option("display.max_columns", 50)
pd.set_option('display.max_colwidth', -1)
from datetime import datetime, time, date
import scrapy
from scrapy.selector import Selector
import requests
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nikzo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# Привязка к tracks10

# %%
df_coor = pd.read_excel("final_coords.xlsx")
list_x_tracks = list(df_coor["liza"])
list_url = list(df_coor["url"])
list_km = list(df_coor["km"])
list_teams = list(df_coor["teams"])
list_date1 = list(df_coor["date1"])
list_date2 = list(df_coor["date2"])

# %% [markdown]
# Привязка (шаг 0) закончена

# %%
# ДЛЯ КОЛИ!!!!!!!!!!!!!!!!!!!!!
import requests
#ssylka = 'https://lizaalert.org/forum/viewforum.php?f=184'
ssylka = 'https://lizaalert.org/forum/viewforum.php?f=180'
html1 = requests.get(ssylka).content #url='google.com'
sel1 = Selector(text=html1)
course_as11 = sel1.xpath('//a[contains(@class,"forumtitle")]')
hrefs11_from_css = course_as11.css('::attr(href)')


hrefz = list()
for i in range(len(hrefs11_from_css.extract())):
    clean_link1 = "https://lizaalert.org/forum" + str(hrefs11_from_css.extract()[i])[1:]
    hrefz.append(clean_link1)

# %%
# Import requests
import requests

list_of_all_pages = list()
# Create the string html containing the HTML source
for i in range(len(hrefz)):
    html = requests.get(hrefz[i]).content #url='google.com'
    sel = Selector(text=html)


    uClient = uReq(hrefz[i])
    page_html = uClient.read()
    uClient.close()
    page_soup = soup(page_html, "html.parser")
    containers2 = page_soup.findAll("div", {"class":"pagination"})
    containers22 = str(containers2)

    def page12(containers22):
        page1 = list()
        c = containers22.find("из ")
        page1.append(containers22[c+11])
        page1.append(containers22[c+12])
        if containers22[c+12] == "<":
            page1.pop()
        return page1

    if len(page12(containers22)) == 2:
        page_real = int(page12(containers22)[0] + page12(containers22)[1])
    else:
        page_real = int(page12(containers22)[0])

    # Парсим
    course_as = sel.xpath('//a[contains(@class,"right-box right")]')
    hrefs_from_css = course_as.css('::attr(href)')
    
    if len(str(hrefs_from_css.extract())[1:]) == 1:
        links_to_follow = ssylka
        clean_link = ssylka
    else:
        links_to_follow = "\"https://lizaalert.org/forum" + str(hrefs_from_css.extract()[0])[1:] + "\""
        clean_link = str(hrefs_from_css.extract()[0])[1:len(hrefs_from_css.extract()[0])-2]
    list_links = list()
    for i in range((page_real)-1):
        list_links.append(clean_link)

    #За 500 надо пояснить! Но это вроде несложно
    i=0
    list1 = list()
    for i in range(0,(page_real-1)*25, 25):
        i = i + 25
        list1.append(i)

    result = [str(item) for item in list1]

    for i in range(len(list1)):
        list_links[i] += result[i]

    for i in range(len(list_links)):
        list_links[i] = "https://lizaalert.org/forum" + list_links[i]
    list_of_all_pages.append(list_links)

# %%
print(len(list_of_all_pages))
listSYKA = list()
for i in range(len(list_of_all_pages)):
    for j in range(len(list_of_all_pages[i])):
        listSYKA.append(list_of_all_pages[i][j])

for j in range(len(hrefz)):
    listSYKA.append(hrefz[j])
listSYKA.append(ssylka)
# Out:
# 4

# %%
list_full = list()
for i in range(len(listSYKA)):
    #html = requests.get(list_links[i]).content #url='google.com'
    html = requests.get(listSYKA[i]).content #url='google.com'
    sel = Selector(text=html)

    course_as1 = sel.css('a.topictitle')
    hrefs1_from_css = course_as1.css('::attr(href)')

    list0 = list()
    for i in range(0, len(hrefs1_from_css.extract())):
        list0.append("https://lizaalert.org/forum" + str(hrefs1_from_css.extract()[i])[1:])
        list_full.append(list0[i])
#print(list_full)
print(len(list_full))
# Out:
# 400

# %%
my_list = list_full

# %%
my_list[0]
print(len(list_full))
# Out:
# 400

# %% [markdown]
# # Здесь соберем все вспомогательные перменные

# %%
list_searchers = []
list_photo = []
list_state1 = []
list_sex1 = []
list_age11 = []
list_posts = []
list_height = []
list_help1 = []
list_hair_color = []
list_bodytype = []
list_eye = []
list_of_lists = []  ## Здесь нужно додумать
list_place = []
list_color_of_clothes = []# Бабкен Вставил
list_of_lists = []  ## Здесь нужно додумать
list_podrobnost = []
list_primeti = []
list_search_time =[]
list_lost_time = []
list_find_time = []
list_of_coor = []
list_x_tracks1 = []
list_url1 = []
list_km1 = []
list_teams1 = []
list_date11 = []
list_date22 = []

# %%
english_stops = ['.', ',', ':', ';', "!", "?", '-', ')', '(']
months_num = {"янв": 1, "фев": 2, "мар": 3,"апр": 4,"мая": 5, "май": 5,"июн": 6,"июл": 7,"авг": 8,"сен": 9,"окт": 10,"ноя": 11,"дек": 12}

# %% [markdown]
# # Напишем все функции, которые нам понадобятся в сборе признаков

# %%
def searchers(containers228):
    if containers228 == 'ebanyi obychenie':
        searchers = 0
    else:
        kerka = containers228.findAll(text=re.compile(r'\w+'))
        kerka1 = containers228.findAll(text=re.compile(r'На месте|НА МЕСТЕ|Дом|ДОМ|Экипаж|ЭКИПАЖ'))
        searchers = (len(kerka) - len(kerka1))
    return searchers

# %%
def photo1(containers11):
    if containers11.find("Изображение") != -1:
        photo =  'присутствует'
    else:
        photo = 'отсутствует'
    return photo

# %%
def state1(title1):
    if title1.find("Жив") != -1 or title1.find("ЖИВ") != -1 or title1.find("Найден") != -1 or title1.find("НАЙДЕН") != -1:
        state = "живой"
    elif title1.find("Пропал") != -1 or title1.find("ПРОПАЛ") != -1:
        state = 'ищется'
    elif title1.find("Погиб") != -1 or title1.find("ПОГИБ") != -1 or title1.find("Мертв") != -1 or title1.find("МЕРТВ") != -1:
        state = 'мертвый'
    else:
        state = "Не указано"
    return state

# %%
def sex1(title1): # Слава вставил 8 мая 
    sex = re.search(r'[Пп]ропала|[Вв]ышла|[Уу]шла|[Нн]айдена|[Жж]ива|[Ее]ё|[Ее]е|[Ее]го|[Уу]ехала|[Пп]огибла|[Вв]ернулась|не [Вв]ернулась|[Вв]ышел|[Уу]шёл|[Уу]шел|[Пп]ропал|[Нн]айден|[Жж]ив|[Ее]го|[Уу]ехал|[Пп]огиб|[Вв]ернулся|не [Вв]ернулся', title1)
    if sex is None:
        return "Er"
    sex = str(sex.group(0))
    if sex == "вышел" or sex == "Вышел" or sex == "ушел" or sex == "Ушел" or sex == 'ушёл' or sex == 'пропал' or sex == 'Пропал' or sex == 'Найден' or sex == 'найден' or sex == 'ушел'or sex == 'ушёл'or sex == 'пропал'or sex == 'найден'or sex == 'Найден'or sex == 'вышел' or sex == 'Жив'or sex == 'жив' or sex == 'уехал'or sex == 'Погиб'or sex == 'погиб'or sex == 'вернулся':
        sex = "Мужчина"
    else:
        sex = "Женщина"
    return sex

# %%
def age11(title1):
    preage = re.search(r'\d+', str(title1))
    if preage is None:
        return "Коля объебался"
    else:
        age = preage.group()
        if len(age) == 4:
            age = 2019 - int(age)
    return age

# %%
def posts1(containers2):
    posts = re.search(r'\d+', str(containers2)).group()
    return posts

# %%
def data1(containers88):
    d = containers88.find("Инфорг")
    if d == -1:
        data1, data2 = 'не','редактировали'
    else:
        data1 = containers88[d+11] + containers88[d+12] + containers88[d+13] + containers88[d+14] + containers88[d+15] + containers88[d+16] + containers88[d+17] + containers88[d+18] + containers88[d+19] + containers88[d+20] + containers88[d+21]
        data2 = containers88[d+24] + containers88[d+25] + containers88[d+26] + containers88[d+27] + containers88[d+28]
        data = data1 + ' ' + data2
    return data

# %%
def height(containers11): # Вставил Слава 8.05.2019
    high = re.search(r'[Рр]ост \d{3}|[Рр]оста \d{3}|[Рр]оста\d{3}|[Рр]ост: \d{3}|[Рр]ост - \d{3}|рост\d{3}-|Рост:\d{3}| росто \d{3}', containers11 )
    if high is None:
        return "Er"
    high = str(high.group(0))

    height = re.findall(r'\d+',high)
    height = int(" ".join(height))
    return height

# %%
def help1(containers11):
    if containers11.find("В МЕДИЦИНСКОЙ ПОМОЩИ") == -1 and containers11.find("в медицинской помощи") == -1:
        help1 = 'здоров'
    else:
        help1 = 'требуется мед. помощь'
    return help1

# %%
def hair_color(contents):
    hc = 'Не указано'
    for string in contents:
        if "олосы" in string:
            no_stops_string_1 = ''.join([t for t in string if t not in english_stops])
            tokens_1 = word_tokenize(no_stops_string_1)
            for i in range(len(tokens_1)):
                if "олосы" in tokens_1[i]:
                    if i < (len(tokens_1) - 1):
                        hc = tokens_1[i + 1]
                    else:
                        hc = tokens_1[i-1]
    return hc

# %%
## Нужно доработать код! Или сделать заново
def body_type(contents):
    body = "Не указано"
    for string in contents:
        if "елосложени" in string:
            no_stops_string = ''.join([t for t in string if t not in english_stops])
            tokens = word_tokenize(no_stops_string)
            tokens.append("Ты объебался")
            for i in range(len(tokens)):
                if "елосложени" in tokens[i]:
                    if tokens[i][-1] == "я":
                        body = tokens[i - 1]
                        break
                    else:
                        body = tokens[i + 1]
                        break
    return body

# %%
## Нужно доработать код! Или сделать заново
def eyes_color(contents):
    ec = "Не указано"
    for string in contents:
        if "лаз" in string:
            no_stops_string = ''.join([t for t in string if t not in english_stops])
            tokens = word_tokenize(no_stops_string)
            tokens.append("Кто-то объебался")
            for i in range(len(tokens)):
                if "лаз" in tokens[i]:
                    ec = tokens[i + 1]
                if ec == "Кто-то объебался":
                    ec = tokens[i-1]
                    break
    return ec

# %%
def yebanskii(sel):
    p = sel.css("div.content").xpath('./span[@style="font-size: 140%; line-height: 116%;"]/span[@style="font-weight: bold"]/text()').extract()
    a = str(p)
    b = re.split('\s+', a)
    b1 = b[5:]
    t = str(b1)
    p = t.replace("\'", "")
    p1 = p.replace(']', '')
    p2 = p1.replace('[', '')
    p3 = p2.replace('"', '')
    p4 = p3.replace(', ', " ")
    p5 = p4.replace('- ','-')
    return p5

# %%
def color_cloth(containers11):
    containers1 = re.split('<span style="font-weight: bold">', containers11)
    if len(containers1) < 4:
        return "Не указано"
    else:
        containers_new = containers1[3]
        black = len(re.findall(r'черн', containers_new))
        white = len(re.findall(r'бел', containers_new))
        yellow = len(re.findall(r'желт', containers_new))
        orange = len(re.findall(r'оранж', containers_new))
        br_grey = len(re.findall(r'тло-сер', containers_new))
        grey = len(re.findall(r'сер', containers_new))
        beg = len(re.findall(r'бежев', containers_new))
        br_blue = len(re.findall(r'тло-син', containers_new))
        blue = len(re.findall(r'син', containers_new))
        green = len(re.findall(r'зелен', containers_new))
        violent = len(re.findall(r'фиол', containers_new))
        black1 = len(re.findall(r'чёрн', containers_new))
        brown = len(re.findall(r'коричн', containers_new))
        al_colors = black + yellow + orange + grey + beg + blue + green + violent + black1
        br_colors1 = white + yellow + orange + br_grey + beg + br_blue + green + violent
        br_colors2 = white + yellow + orange + beg + br_blue + green + violent
        br_colors3 = white + yellow + orange + br_grey + beg + green + violent
        br_colors4 = white + yellow + orange + beg + green + violent
        dk_colors1 = black + black1 + brown
        dk_colors2 = black + grey + black1 + brown
        dk_colors3 = black + blue + black1 + brown
        dk_colors4 = black + blue + grey + black1 + brown
        if al_colors == 0:
            return "Не указано" 
        elif (br_grey == 0 and br_blue == 0) and br_colors4 >= dk_colors4:
            return "Яркая"
        elif (br_grey == 0 and br_blue == 0) and br_colors4 < dk_colors4:
            return "Темная"
        elif ((br_grey != 0 and grey != 0) or (br_blue != 0 and blue != 0 )) and br_colors1 >= dk_colors4:
            return "Яркая"
        elif ((br_grey != 0 and grey != 0) or (br_blue != 0 and blue != 0 )) and br_colors1 < dk_colors4:
            return "Темная"
        elif (br_grey == 0) and br_colors2 >= dk_colors2:
            return "Яркая" 
        elif (br_grey == 0) and br_colors2 < dk_colors2:
            return "Темная" 
        elif (br_blue == 0) and br_colors3 >= dk_colors3:
            return "Яркая"

# %%
def podrobnost(containers11):
    containers1 = re.split('<span style="font-weight: bold">', containers11)
    if len(containers1) < 4:
        return("Не указано")
    else:
        containers_new = containers1[3]
        containers_new_sep = containers_new.split(',')
        l = len(containers_new_sep)
        if l > 3:
            return 4
        elif 2 <= l < 3:
            return 3
        else:
            return 0

# %%
def primeti(containers11):
    containers1 = re.split('<span style="font-weight: bold">', containers11)
    if len(containers1) < 5:
        return("Не указано")
    else:
        containers_new = containers1[4]
        containers_new_sep = containers_new.split(',')
        l = len(containers_new_sep)
        if l > 3:
            return 4
        elif 2 <= l < 3:
            return 2
        else:
            return 0

# %%
def lost_timing(x):
    if re.search(r'\d+ [января, февраля, марта, апреля, мая, июня, июля, августа, сентября, октября, ноября, декабря] \d{4}|\d{2}[.]\d{2}[.]\d{4}', x) == None:
        return "Сбой"
    else:
        lost_time = re.search(r'\d+ [января, февраля, марта, апреля, мая, июня, июля, августа, сентября, октября, ноября, декабря] \d{4}|\d{2}[.]\d{2}[.]\d{4}', x).group()
        print(lost_time)
        if "я" in lost_time or "т" in lost_time:
            lts = lost_time.split()
            print(lts)
            lts[1] = months_num[lts[1][:3]]
            lts = list(map(int, lts))
            lost_time = date(lts[-1], lts[-2], lts[-3])
            return lost_time
            #lost_time = date(lts[-1], [-2], [-3])
        else:
            lts = lost_time.split('.')
            lts = list(map(int, lts))
            lost_time = date(lts[-1], lts[-2], lts[-3])
            return lost_time

# %%
def find_timing(x):
    if re.search(r'\d+ \w+ \d{4}|\d{2}.\d{2}.\d{4}', x) == None:
        return "Сбой"
    else:
        find_time = re.search(r'\d+ \w+ \d{4}|\d{2}.\d{2}.\d{4}', x).group()
        print(find_time)
        fts = find_time.split()
        print(fts)
        fts[1] = months_num[fts[1]]
        fts = list(map(int, fts))
        find_time = date(fts[-1], fts[-2], fts[-3])
        return find_time

# %%
def search_timing(x, y):
    return (find_timing(y) - lost_timing(x)).days

# %%
def super_format(function, x):
    if len(str(function(x).day)) == 1:
        day = "0" + str(function(x).day)
    else:
        day = str(function(x).day)
    if len(str(function(x).month)) == 1:
        month = "0" + str(function(x).month)
    else:
        month = str(function(x).month)
    return day + "." + month + "." + str(function(x).year)

# %%
def find_cor(comp):
    for i in range (len(comp)):
        contents = page_soup.findAll("div", {"class":"content"})[i].contents
        kavka = re.search(r'\d+.\d+, \d+.\d+|\d+.\d+,\d+.\d+|\d+.\d+ \d+.\d+', str(contents))
        if kavka is not None:
            kavkaz = kavka.group()
            break
        else:
            kavkaz = 'no cord'
    return kavkaz

# %% [markdown]
# # Перейдем к сбору признаков

# %%
for i in my_list:
    my_url = i
    uClient = uReq(my_url)
    page_html = uClient.read()
    uClient.close()
    page_soup = soup(page_html, "html.parser")
    title = page_soup.title
    title1 = str(title)

    comp = page_soup.findAll("div", {"class":"content"})
    containers = page_soup.findAll("div", {"class":"content"})
    contents = page_soup.findAll("div", {"class":"content"})[0].contents
    containers11 = str(containers)
    containers2 = page_soup.findAll("div", {"class":"pagination"})
    containers22 = str(containers2)
    containers8 = page_soup.findAll("div", {"class":"notice"})
    containers88 = str(containers8) 
    containers1 = re.split('<span style="font-weight: bold">', containers11)
    if len(page_soup.findAll("div", {"class":"content"})) > 1:
        containers228 = page_soup.findAll("div", {"class":"content"})[1]
    else:
        containers228 = 'ebanyi obychenie'
    
    list_searchers.append(searchers(containers228))
    list_photo.append(photo1(containers11))
    list_state1.append(state1(title1))
    list_sex1.append(sex1(title1))
    list_age11.append(age11(title1))
    list_posts.append(posts1(containers22))
    list_hair_color.append(hair_color(contents))
    list_bodytype.append(body_type(contents))
    list_eye.append(eyes_color(contents))
    containers = page_soup.findAll("div", {"class":"content"})
    containers11 = str(containers)
    list_height.append(height(containers11))
    list_help1.append(help1(containers11))
    list_place.append(yebanskii(sel))
    list_color_of_clothes.append(color_cloth(containers11)) # Бабкен вставил
    list_podrobnost.append(podrobnost(containers11)) # Бабкен вставил еще раз, но уже Ване
    list_primeti.append(primeti(containers11))
    
    
    if page_soup.find('div', {'class':'content'}) != None:
        main = page_soup.find('div', {'class':'content'}).text
        if lost_timing(main) != "Сбой":
            list_lost_time.append(super_format(lost_timing, main))
        else:
            list_lost_time.append("Ошибка")
    else:
        list_lost_time.append("Ошибка")
        main = "СБой"
        
    if page_soup.find('div', {'class':'notice'}) != None:
        notmain = page_soup.find('div', {'class':'notice'}).text
        if find_timing(notmain) != "Сбой":
            list_find_time.append(super_format(find_timing,notmain))
        else:
            list_find_time.append("Ошибка")
    else:
        list_find_time.append("Ошибка")
        notmain = "Сбой"
        
        
    if lost_timing(main) != "Сбой" and find_timing(notmain) != "Сбой":
        list_search_time.append(search_timing(main, notmain))
    else:
        list_search_time.append("Ошибка")      
    list_of_coor.append(find_cor(comp))
    list_x_tracks1.append(0)
    list_url1.append(0)
    list_km1.append(0)
    list_teams1.append(0)
    list_date11.append(0)
    list_date22.append(0)
# Out:
# 19.11.1951
# 19.11.1951
# 19.11.1951
# 19.11.1951
# 19.11.1951
# 19.11.1951
# 19.11.1951
# 14.03.2002
# 14.03.2002
# 14.03.2002
# 14.03.2002
# 14.03.2002
# 14.03.2002
# 14.03.2002
# 08.08.1979
# 08.08.1979
# 08.08.1979
# 08.08.1979
# 08.08.1979
# 08.08.1979
# 08.08.1979
# 18.12.1938
# 18.12.1938
# 18.12.1938
# 18.12.1938
# 18.12.1938
# 18.12.1938
# 18.12.1938
# 01.08.1933
# 01.08.1933
# 01.08.1933
# 01.08.1933
# 01.08.1933
# 01.08.1933
# 01.08.1933
# 19.04.1985
# 19.04.1985
# 19.04.1985
# 19.04.1985
# 19.04.1985
# 19.04.1985
# 19.04.1985
# 14.04.2014
# 14.04.2014
# 14.04.2014
# 14.04.2014
# 14.04.2014
# 14.04.2014
# 14.04.2014
# 16.04.2014
# 16.04.2014
# 16.04.2014
# 16.04.2014
# 16.04.2014
# 16.04.2014
# 16.04.2014
# 31.07.2006
# 31.07.2006
# 31.07.2006
# 31.07.2006
# 31.07.2006
# 31.07.2006
# 31.07.2006
# 15.02.2014
# 15.02.2014
# 15.02.2014
# 15.02.2014
# 15.02.2014
# 15.02.2014
# 15.02.2014
# 06.02.1973
# 06.02.1973
# 06.02.1973
# 06.02.1973
# 06.02.1973
# 06.02.1973
# 06.02.1973
# 26.01.2014
# 26.01.2014
# 26.01.2014
# 26.01.2014
# 26.01.2014
# 26.01.2014
# 26.01.2014
# 28.03.1973
# 28.03.1973
# 28.03.1973
# 28.03.1973
# 28.03.1973
# 28.03.1973
# 28.03.1973
# 07.01.1983
# 07.01.1983
# 07.01.1983
# 07.01.1983
# 07.01.1983
# 07.01.1983
# 07.01.1983
# 02.11.2013
# 02.11.2013
# 02.11.2013
# 02.11.2013
# 02.11.2013
# 02.11.2013
# 02.11.2013
# 07.02.1928
# 07.02.1928
# 07.02.1928
# 07.02.1928
# 07.02.1928
# 07.02.1928
# 07.02.1928
# 27.08.2013
# 27.08.2013
# 27.08.2013
# 27.08.2013
# 27.08.2013
# 27.08.2013
# 27.08.2013
# 22.06.2013
# 22.06.2013
# 22.06.2013
# 22.06.2013
# 22.06.2013
# 22.06.2013
# 22.06.2013
# 13.05.2013
# 13.05.2013
# 13.05.2013
# 13.05.2013
# 13.05.2013
# 13.05.2013
# 19 июн 2013
# ['19', 'июн', '2013']
# 19 июн 2013
# ['19', 'июн', '2013']
# 19 июн 2013
# ['19', 'июн', '2013']
# 19 июн 2013
# ['19', 'июн', '2013']
# 19 июн 2013
# ['19', 'июн', '2013']
# 19 июн 2013
# ['19', 'июн', '2013']
# 13.05.2013
# 19 июн 2013
# ['19', 'июн', '2013']
# 19 июн 2013
# ['19', 'июн', '2013']
# 13.05.2013
# 21.07.1995
# 21.07.1995
# 21.07.1995
# 21.07.1995
# 21.07.1995
# 21.07.1995
# 15 май 2013
# ['15', 'май', '2013']
# 15 май 2013
# ['15', 'май', '2013']
# 15 май 2013
# ['15', 'май', '2013']
# 15 май 2013
# ['15', 'май', '2013']
# 15 май 2013
# ['15', 'май', '2013']
# 15 май 2013
# ['15', 'май', '2013']
# 21.07.1995
# 15 май 2013
# ['15', 'май', '2013']
# 15 май 2013
# ['15', 'май', '2013']
# 21.07.1995
# 27.10.2012
# 27.10.2012
# 27.10.2012
# 27.10.2012
# 27.10.2012
# 27.10.2012
# 27.10.2012
# 28 ноя 2013
# ['28', 'ноя', '2013']
# 28 ноя 2013
# ['28', 'ноя', '2013']
# 28 ноя 2013
# ['28', 'ноя', '2013']
# 28 ноя 2013
# ['28', 'ноя', '2013']
# 28 ноя 2013
# ['28', 'ноя', '2013']
# 28 ноя 2013
# ['28', 'ноя', '2013']
# 17 авг 2011
# ['17', 'авг', '2011']
# 17 авг 2011
# ['17', 'авг', '2011']
# 17 авг 2011
# ['17', 'авг', '2011']
# 17 авг 2011
# ['17', 'авг', '2011']
# 17 авг 2011
# ['17', 'авг', '2011']
# 17 авг 2011
# ['17', 'авг', '2011']
# 13.12.2010
# 13.12.2010
# 13.12.2010
# 13.12.2010
# 13.12.2010
# 13.12.2010
# 13 дек 2010
# ['13', 'дек', '2010']
# 13 дек 2010
# ['13', 'дек', '2010']
# 13 дек 2010
# ['13', 'дек', '2010']
# 13 дек 2010
# ['13', 'дек', '2010']
# 13 дек 2010
# ['13', 'дек', '2010']
# 13 дек 2010
# ['13', 'дек', '2010']
# 13.12.2010
# 13 дек 2010
# ['13', 'дек', '2010']
# 13 дек 2010
# ['13', 'дек', '2010']
# 13.12.2010
# 03 май 2019
# ['03', 'май', '2019']
# 03 май 2019
# ['03', 'май', '2019']
# 03 май 2019
# ['03', 'май', '2019']
# 03 май 2019
# ['03', 'май', '2019']
# 03 май 2019
# ['03', 'май', '2019']
# 03 май 2019
# ['03', 'май', '2019']
# 19 апр 2019
# ['19', 'апр', '2019']
# 19 апр 2019
# ['19', 'апр', '2019']
# 19 апр 2019
# ['19', 'апр', '2019']
# 19 апр 2019
# ['19', 'апр', '2019']
# 19 апр 2019
# ['19', 'апр', '2019']
# 19 апр 2019
# ['19', 'апр', '2019']
# 03 май 2019
# ['03', 'май', '2019']
# 03 май 2019
# ['03', 'май', '2019']
# 03 май 2019
# ['03', 'май', '2019']
# 03 май 2019
# ['03', 'май', '2019']
# 03 май 2019
# ['03', 'май', '2019']
# 03 май 2019
# ['03', 'май', '2019']
# 18 апр 2019
# ['18', 'апр', '2019']
# 18 апр 2019
# ['18', 'апр', '2019']
# 18 апр 2019
# ['18', 'апр', '2019']
# 18 апр 2019
# ['18', 'апр', '2019']
# 18 апр 2019
# ['18', 'апр', '2019']
# 18 апр 2019
# ['18', 'апр', '2019']
# 17.04.2019
# 17.04.2019
# 17.04.2019
# 17.04.2019
# 17.04.2019
# 17.04.2019
# 19 апр 2019
# ['19', 'апр', '2019']
# 19 апр 2019
# ['19', 'апр', '2019']
# 19 апр 2019
# ['19', 'апр', '2019']
# 19 апр 2019
# ['19', 'апр', '2019']
# 19 апр 2019
# ['19', 'апр', '2019']
# 19 апр 2019
# ['19', 'апр', '2019']
# 17.04.2019
# 19 апр 2019
# ['19', 'апр', '2019']
# 19 апр 2019
# ['19', 'апр', '2019']
# 17.04.2019
# 09 апр 2019
# ['09', 'апр', '2019']
# 09 апр 2019
# ['09', 'апр', '2019']
# 09 апр 2019
# ['09', 'апр', '2019']
# 09 апр 2019
# ['09', 'апр', '2019']
# 09 апр 2019
# ['09', 'апр', '2019']
# 09 апр 2019
# ['09', 'апр', '2019']
# 07 апр 2019
# ['07', 'апр', '2019']
# 07 апр 2019
# ['07', 'апр', '2019']
# 07 апр 2019
# ['07', 'апр', '2019']
# 07 апр 2019
# ['07', 'апр', '2019']
# 07 апр 2019
# ['07', 'апр', '2019']
# 07 апр 2019
# ['07', 'апр', '2019']
# 06 апр 2019
# ['06', 'апр', '2019']
# 06 апр 2019
# ['06', 'апр', '2019']
# 06 апр 2019
# ['06', 'апр', '2019']
# 06 апр 2019
# ['06', 'апр', '2019']
# 06 апр 2019
# ['06', 'апр', '2019']
# 06 апр 2019
# ['06', 'апр', '2019']
# 03.04.2019
# 03.04.2019
# 03.04.2019
# 03.04.2019
# 03.04.2019
# 03.04.2019
# 04 апр 2019
# ['04', 'апр', '2019']
# 04 апр 2019
# ['04', 'апр', '2019']
# 04 апр 2019
# ['04', 'апр', '2019']
# 04 апр 2019
# ['04', 'апр', '2019']
# 04 апр 2019
# ['04', 'апр', '2019']
# 04 апр 2019
# ['04', 'апр', '2019']
# 03.04.2019
# 04 апр 2019
# ['04', 'апр', '2019']
# 04 апр 2019
# ['04', 'апр', '2019']
# 03.04.2019
# 01 апр 2019
# ['01', 'апр', '2019']
# 01 апр 2019
# ['01', 'апр', '2019']
# 01 апр 2019
# ['01', 'апр', '2019']
# 01 апр 2019
# ['01', 'апр', '2019']
# 01 апр 2019
# ['01', 'апр', '2019']
# 01 апр 2019
# ['01', 'апр', '2019']
# 25 мар 2019
# ['25', 'мар', '2019']
# 25 мар 2019
# ['25', 'мар', '2019']
# 25 мар 2019
# ['25', 'мар', '2019']
# 25 мар 2019
# ['25', 'мар', '2019']
# 25 мар 2019
# ['25', 'мар', '2019']
# 25 мар 2019
# ['25', 'мар', '2019']
# 22 мар 2019
# ['22', 'мар', '2019']
# 22 мар 2019
# ['22', 'мар', '2019']
# 22 мар 2019
# ['22', 'мар', '2019']
# 22 мар 2019
# ['22', 'мар', '2019']
# 22 мар 2019
# ['22', 'мар', '2019']
# 22 мар 2019
# ['22', 'мар', '2019']
# 22 мар 2019
# ['22', 'мар', '2019']
# 22 мар 2019
# ['22', 'мар', '2019']
# 22 мар 2019
# ['22', 'мар', '2019']
# 22 мар 2019
# ['22', 'мар', '2019']
# 22 мар 2019
# ['22', 'мар', '2019']
# 22 мар 2019
# ['22', 'мар', '2019']
# 17 мар 2019
# ['17', 'мар', '2019']
# 17 мар 2019
# ['17', 'мар', '2019']
# 17 мар 2019
# ['17', 'мар', '2019']
# 17 мар 2019
# ['17', 'мар', '2019']
# 17 мар 2019
# ['17', 'мар', '2019']
# 17 мар 2019
# ['17', 'мар', '2019']
# 17 мар 2019
# ['17', 'мар', '2019']
# 17 мар 2019
# ['17', 'мар', '2019']
# 17 мар 2019
# ['17', 'мар', '2019']
# 17 мар 2019
# ['17', 'мар', '2019']
# 17 мар 2019
# ['17', 'мар', '2019']
# 17 мар 2019
# ['17', 'мар', '2019']
# 17 мар 2019
# ['17', 'мар', '2019']
# 17 мар 2019
# ['17', 'мар', '2019']
# 17 мар 2019
# ['17', 'мар', '2019']
# 17 мар 2019
# ['17', 'мар', '2019']
# 17 мар 2019
# ['17', 'мар', '2019']
# 17 мар 2019
# ['17', 'мар', '2019']
# 05 мар 2019
# ['05', 'мар', '2019']
# 05 мар 2019
# ['05', 'мар', '2019']
# 05 мар 2019
# ['05', 'мар', '2019']
# 05 мар 2019
# ['05', 'мар', '2019']
# 05 мар 2019
# ['05', 'мар', '2019']
# 05 мар 2019
# ['05', 'мар', '2019']
# 02 мар 2019
# ['02', 'мар', '2019']
# 02 мар 2019
# ['02', 'мар', '2019']
# 02 мар 2019
# ['02', 'мар', '2019']
# 02 мар 2019
# ['02', 'мар', '2019']
# 02 мар 2019
# ['02', 'мар', '2019']
# 02 мар 2019
# ['02', 'мар', '2019']
# 28 фев 2019
# ['28', 'фев', '2019']
# 28 фев 2019
# ['28', 'фев', '2019']
# 28 фев 2019
# ['28', 'фев', '2019']
# 28 фев 2019
# ['28', 'фев', '2019']
# 28 фев 2019
# ['28', 'фев', '2019']
# 28 фев 2019
# ['28', 'фев', '2019']
# 27 фев 2019
# ['27', 'фев', '2019']
# 27 фев 2019
# ['27', 'фев', '2019']
# 27 фев 2019
# ['27', 'фев', '2019']
# 27 фев 2019
# ['27', 'фев', '2019']
# 27 фев 2019
# ['27', 'фев', '2019']
# 27 фев 2019
# ['27', 'фев', '2019']
# 24.10.2018
# 24.10.2018
# 24.10.2018
# 24.10.2018
# 24.10.2018
# 24.10.2018
# 06 мар 2019
# ['06', 'мар', '2019']
# 06 мар 2019
# ['06', 'мар', '2019']
# 06 мар 2019
# ['06', 'мар', '2019']
# 06 мар 2019
# ['06', 'мар', '2019']
# 06 мар 2019
# ['06', 'мар', '2019']
# 06 мар 2019
# ['06', 'мар', '2019']
# 24.10.2018
# 06 мар 2019
# ['06', 'мар', '2019']
# 06 мар 2019
# ['06', 'мар', '2019']
# 24.10.2018
# 24 фев 2019
# ['24', 'фев', '2019']
# 24 фев 2019
# ['24', 'фев', '2019']
# 24 фев 2019
# ['24', 'фев', '2019']
# 24 фев 2019
# ['24', 'фев', '2019']
# 24 фев 2019
# ['24', 'фев', '2019']
# 24 фев 2019
# ['24', 'фев', '2019']
# 20 фев 2019
# ['20', 'фев', '2019']
# 20 фев 2019
# ['20', 'фев', '2019']
# 20 фев 2019
# ['20', 'фев', '2019']
# 20 фев 2019
# ['20', 'фев', '2019']
# 20 фев 2019
# ['20', 'фев', '2019']
# 20 фев 2019
# ['20', 'фев', '2019']
# 24 мар 2019
# ['24', 'мар', '2019']
# 24 мар 2019
# ['24', 'мар', '2019']
# 24 мар 2019
# ['24', 'мар', '2019']
# 24 мар 2019
# ['24', 'мар', '2019']
# 24 мар 2019
# ['24', 'мар', '2019']
# 24 мар 2019
# ['24', 'мар', '2019']
# 14 фев 2019
# ['14', 'фев', '2019']
# 14 фев 2019
# ['14', 'фев', '2019']
# 14 фев 2019
# ['14', 'фев', '2019']
# 14 фев 2019
# ['14', 'фев', '2019']
# 14 фев 2019
# ['14', 'фев', '2019']
# 14 фев 2019
# ['14', 'фев', '2019']
# 28 фев 2019
# ['28', 'фев', '2019']
# 28 фев 2019
# ['28', 'фев', '2019']
# 28 фев 2019
# ['28', 'фев', '2019']
# 28 фев 2019
# ['28', 'фев', '2019']
# 28 фев 2019
# ['28', 'фев', '2019']
# 28 фев 2019
# ['28', 'фев', '2019']
# 28.01.2019
# 28.01.2019
# 28.01.2019
# 28.01.2019
# 28.01.2019
# 28.01.2019
# 28.01.2019
# 04 фев 2019
# ['04', 'фев', '2019']
# 04 фев 2019
# ['04', 'фев', '2019']
# 04 фев 2019
# ['04', 'фев', '2019']
# 04 фев 2019
# ['04', 'фев', '2019']
# 04 фев 2019
# ['04', 'фев', '2019']
# 04 фев 2019
# ['04', 'фев', '2019']
# 03 фев 2019
# ['03', 'фев', '2019']
# 03 фев 2019
# ['03', 'фев', '2019']
# 03 фев 2019
# ['03', 'фев', '2019']
# 03 фев 2019
# ['03', 'фев', '2019']
# 03 фев 2019
# ['03', 'фев', '2019']
# 03 фев 2019
# ['03', 'фев', '2019']
# 28 янв 2019
# ['28', 'янв', '2019']
# 28 янв 2019
# ['28', 'янв', '2019']
# 28 янв 2019
# ['28', 'янв', '2019']
# 28 янв 2019
# ['28', 'янв', '2019']
# 28 янв 2019
# ['28', 'янв', '2019']
# 28 янв 2019
# ['28', 'янв', '2019']
# 25 янв 2019
# ['25', 'янв', '2019']
# 25 янв 2019
# ['25', 'янв', '2019']
# 25 янв 2019
# ['25', 'янв', '2019']
# 25 янв 2019
# ['25', 'янв', '2019']
# 25 янв 2019
# ['25', 'янв', '2019']
# 25 янв 2019
# ['25', 'янв', '2019']
# 22 янв 2019
# ['22', 'янв', '2019']
# 22 янв 2019
# ['22', 'янв', '2019']
# 22 янв 2019
# ['22', 'янв', '2019']
# 22 янв 2019
# ['22', 'янв', '2019']
# 22 янв 2019
# ['22', 'янв', '2019']
# 22 янв 2019
# ['22', 'янв', '2019']
# 21 янв 2019
# ['21', 'янв', '2019']
# 21 янв 2019
# ['21', 'янв', '2019']
# 21 янв 2019
# ['21', 'янв', '2019']
# 21 янв 2019
# ['21', 'янв', '2019']
# 21 янв 2019
# ['21', 'янв', '2019']
# 21 янв 2019
# ['21', 'янв', '2019']
# 20.01.2019
# 20.01.2019
# 20.01.2019
# 20.01.2019
# 20.01.2019
# 20.01.2019
# 21 янв 2019
# ['21', 'янв', '2019']
# 21 янв 2019
# ['21', 'янв', '2019']
# 21 янв 2019
# ['21', 'янв', '2019']
# 21 янв 2019
# ['21', 'янв', '2019']
# 21 янв 2019
# ['21', 'янв', '2019']
# 21 янв 2019
# ['21', 'янв', '2019']
# 20.01.2019
# 21 янв 2019
# ['21', 'янв', '2019']
# 21 янв 2019
# ['21', 'янв', '2019']
# 20.01.2019
# 19 янв 2019
# ['19', 'янв', '2019']
# 19 янв 2019
# ['19', 'янв', '2019']
# 19 янв 2019
# ['19', 'янв', '2019']
# 19 янв 2019
# ['19', 'янв', '2019']
# 19 янв 2019
# ['19', 'янв', '2019']
# 19 янв 2019
# ['19', 'янв', '2019']
# 13 янв 2019
# ['13', 'янв', '2019']
# 13 янв 2019
# ['13', 'янв', '2019']
# 13 янв 2019
# ['13', 'янв', '2019']
# 13 янв 2019
# ['13', 'янв', '2019']
# 13 янв 2019
# ['13', 'янв', '2019']
# 13 янв 2019
# ['13', 'янв', '2019']
# 12 янв 2019
# ['12', 'янв', '2019']
# 12 янв 2019
# ['12', 'янв', '2019']
# 12 янв 2019
# ['12', 'янв', '2019']
# 12 янв 2019
# ['12', 'янв', '2019']
# 12 янв 2019
# ['12', 'янв', '2019']
# 12 янв 2019
# ['12', 'янв', '2019']
# 08 янв 2019
# ['08', 'янв', '2019']
# 08 янв 2019
# ['08', 'янв', '2019']
# 08 янв 2019
# ['08', 'янв', '2019']
# 08 янв 2019
# ['08', 'янв', '2019']
# 08 янв 2019
# ['08', 'янв', '2019']
# 08 янв 2019
# ['08', 'янв', '2019']
# 08 янв 2019
# ['08', 'янв', '2019']
# 08 янв 2019
# ['08', 'янв', '2019']
# 08 янв 2019
# ['08', 'янв', '2019']
# 08 янв 2019
# ['08', 'янв', '2019']
# 08 янв 2019
# ['08', 'янв', '2019']
# 08 янв 2019
# ['08', 'янв', '2019']
# 04 янв 2019
# ['04', 'янв', '2019']
# 04 янв 2019
# ['04', 'янв', '2019']
# 04 янв 2019
# ['04', 'янв', '2019']
# 04 янв 2019
# ['04', 'янв', '2019']
# 04 янв 2019
# ['04', 'янв', '2019']
# 04 янв 2019
# ['04', 'янв', '2019']
# 01 янв 2019
# ['01', 'янв', '2019']
# 01 янв 2019
# ['01', 'янв', '2019']
# 01 янв 2019
# ['01', 'янв', '2019']
# 01 янв 2019
# ['01', 'янв', '2019']
# 01 янв 2019
# ['01', 'янв', '2019']
# 01 янв 2019
# ['01', 'янв', '2019']
# 28 дек 2018
# ['28', 'дек', '2018']
# 28 дек 2018
# ['28', 'дек', '2018']
# 28 дек 2018
# ['28', 'дек', '2018']
# 28 дек 2018
# ['28', 'дек', '2018']
# 28 дек 2018
# ['28', 'дек', '2018']
# 28 дек 2018
# ['28', 'дек', '2018']
# 22 дек 2018
# ['22', 'дек', '2018']
# 22 дек 2018
# ['22', 'дек', '2018']
# 22 дек 2018
# ['22', 'дек', '2018']
# 22 дек 2018
# ['22', 'дек', '2018']
# 22 дек 2018
# ['22', 'дек', '2018']
# 22 дек 2018
# ['22', 'дек', '2018']
# 14 дек 2018
# ['14', 'дек', '2018']
# 14 дек 2018
# ['14', 'дек', '2018']
# 14 дек 2018
# ['14', 'дек', '2018']
# 14 дек 2018
# ['14', 'дек', '2018']
# 14 дек 2018
# ['14', 'дек', '2018']
# 14 дек 2018
# ['14', 'дек', '2018']
# 12 дек 2018
# ['12', 'дек', '2018']
# 12 дек 2018
# ['12', 'дек', '2018']
# 12 дек 2018
# ['12', 'дек', '2018']
# 12 дек 2018
# ['12', 'дек', '2018']
# 12 дек 2018
# ['12', 'дек', '2018']
# 12 дек 2018
# ['12', 'дек', '2018']
# 10 дек 2018
# ['10', 'дек', '2018']
# 10 дек 2018
# ['10', 'дек', '2018']
# 10 дек 2018
# ['10', 'дек', '2018']
# 10 дек 2018
# ['10', 'дек', '2018']
# 10 дек 2018
# ['10', 'дек', '2018']
# 10 дек 2018
# ['10', 'дек', '2018']
# 29.10.2018
# 29.10.2018
# 29.10.2018
# 29.10.2018
# 29.10.2018
# 29.10.2018
# 10 дек 2018
# ['10', 'дек', '2018']
# 10 дек 2018
# ['10', 'дек', '2018']
# 10 дек 2018
# ['10', 'дек', '2018']
# 10 дек 2018
# ['10', 'дек', '2018']
# 10 дек 2018
# ['10', 'дек', '2018']
# 10 дек 2018
# ['10', 'дек', '2018']
# 29.10.2018
# 10 дек 2018
# ['10', 'дек', '2018']
# 10 дек 2018
# ['10', 'дек', '2018']
# 29.10.2018
# 06 дек 2018
# ['06', 'дек', '2018']
# 06 дек 2018
# ['06', 'дек', '2018']
# 06 дек 2018
# ['06', 'дек', '2018']
# 06 дек 2018
# ['06', 'дек', '2018']
# 06 дек 2018
# ['06', 'дек', '2018']
# 06 дек 2018
# ['06', 'дек', '2018']
# 04 дек 2018
# ['04', 'дек', '2018']
# 04 дек 2018
# ['04', 'дек', '2018']
# 04 дек 2018
# ['04', 'дек', '2018']
# 04 дек 2018
# ['04', 'дек', '2018']
# 04 дек 2018
# ['04', 'дек', '2018']
# 04 дек 2018
# ['04', 'дек', '2018']
# 02 дек 2018
# ['02', 'дек', '2018']
# 02 дек 2018
# ['02', 'дек', '2018']
# 02 дек 2018
# ['02', 'дек', '2018']
# 02 дек 2018
# ['02', 'дек', '2018']
# 02 дек 2018
# ['02', 'дек', '2018']
# 02 дек 2018
# ['02', 'дек', '2018']
# 10.11.2018
# 10.11.2018
# 10.11.2018
# 10.11.2018
# 10.11.2018
# 10.11.2018
# 01 дек 2018
# ['01', 'дек', '2018']
# 01 дек 2018
# ['01', 'дек', '2018']
# 01 дек 2018
# ['01', 'дек', '2018']
# 01 дек 2018
# ['01', 'дек', '2018']
# 01 дек 2018
# ['01', 'дек', '2018']
# 01 дек 2018
# ['01', 'дек', '2018']
# 10.11.2018
# 01 дек 2018
# ['01', 'дек', '2018']
# 01 дек 2018
# ['01', 'дек', '2018']
# 10.11.2018
# 06.11.2018
# 06.11.2018
# 06.11.2018
# 06.11.2018
# 06.11.2018
# 06.11.2018
# 28 ноя 2018
# ['28', 'ноя', '2018']
# 28 ноя 2018
# ['28', 'ноя', '2018']
# 28 ноя 2018
# ['28', 'ноя', '2018']
# 28 ноя 2018
# ['28', 'ноя', '2018']
# 28 ноя 2018
# ['28', 'ноя', '2018']
# 28 ноя 2018
# ['28', 'ноя', '2018']
# 06.11.2018
# 28 ноя 2018
# ['28', 'ноя', '2018']
# 28 ноя 2018
# ['28', 'ноя', '2018']
# 06.11.2018
# 22 ноя 2018
# ['22', 'ноя', '2018']
# 22 ноя 2018
# ['22', 'ноя', '2018']
# 22 ноя 2018
# ['22', 'ноя', '2018']
# 22 ноя 2018
# ['22', 'ноя', '2018']
# 22 ноя 2018
# ['22', 'ноя', '2018']
# 22 ноя 2018
# ['22', 'ноя', '2018']
# 22 ноя 2018
# ['22', 'ноя', '2018']
# 22 ноя 2018
# ['22', 'ноя', '2018']
# 22 ноя 2018
# ['22', 'ноя', '2018']
# 22 ноя 2018
# ['22', 'ноя', '2018']
# 22 ноя 2018
# ['22', 'ноя', '2018']
# 22 ноя 2018
# ['22', 'ноя', '2018']
# 16 ноя 2018
# ['16', 'ноя', '2018']
# 16 ноя 2018
# ['16', 'ноя', '2018']
# 16 ноя 2018
# ['16', 'ноя', '2018']
# 16 ноя 2018
# ['16', 'ноя', '2018']
# 16 ноя 2018
# ['16', 'ноя', '2018']
# 16 ноя 2018
# ['16', 'ноя', '2018']
# 15 ноя 2018
# ['15', 'ноя', '2018']
# 15 ноя 2018
# ['15', 'ноя', '2018']
# 15 ноя 2018
# ['15', 'ноя', '2018']
# 15 ноя 2018
# ['15', 'ноя', '2018']
# 15 ноя 2018
# ['15', 'ноя', '2018']
# 15 ноя 2018
# ['15', 'ноя', '2018']
# 21.10.2018
# 21.10.2018
# 21.10.2018
# 21.10.2018
# 21.10.2018
# 21.10.2018
# 15 ноя 2018
# ['15', 'ноя', '2018']
# 15 ноя 2018
# ['15', 'ноя', '2018']
# 15 ноя 2018
# ['15', 'ноя', '2018']
# 15 ноя 2018
# ['15', 'ноя', '2018']
# 15 ноя 2018
# ['15', 'ноя', '2018']
# 15 ноя 2018
# ['15', 'ноя', '2018']
# 21.10.2018
# 15 ноя 2018
# ['15', 'ноя', '2018']
# 15 ноя 2018
# ['15', 'ноя', '2018']
# 21.10.2018
# 07.11.2018
# 07.11.2018
# 07.11.2018
# 07.11.2018
# 07.11.2018
# 07.11.2018
# 15 ноя 2018
# ['15', 'ноя', '2018']
# 15 ноя 2018
# ['15', 'ноя', '2018']
# 15 ноя 2018
# ['15', 'ноя', '2018']
# 15 ноя 2018
# ['15', 'ноя', '2018']
# 15 ноя 2018
# ['15', 'ноя', '2018']
# 15 ноя 2018
# ['15', 'ноя', '2018']
# 07.11.2018
# 15 ноя 2018
# ['15', 'ноя', '2018']
# 15 ноя 2018
# ['15', 'ноя', '2018']
# 07.11.2018
# 06.11.2018
# 06.11.2018
# 06.11.2018
# 06.11.2018
# 06.11.2018
# 06.11.2018
# 06.11.2018
# 07 ноя 2018
# ['07', 'ноя', '2018']
# 07 ноя 2018
# ['07', 'ноя', '2018']
# 07 ноя 2018
# ['07', 'ноя', '2018']
# 07 ноя 2018
# ['07', 'ноя', '2018']
# 07 ноя 2018
# ['07', 'ноя', '2018']
# 07 ноя 2018
# ['07', 'ноя', '2018']
# 22 окт 2018
# ['22', 'окт', '2018']
# 22 окт 2018
# ['22', 'окт', '2018']
# 22 окт 2018
# ['22', 'окт', '2018']
# 22 окт 2018
# ['22', 'окт', '2018']
# 22 окт 2018
# ['22', 'окт', '2018']
# 22 окт 2018
# ['22', 'окт', '2018']
# 19 окт 2018
# ['19', 'окт', '2018']
# 19 окт 2018
# ['19', 'окт', '2018']
# 19 окт 2018
# ['19', 'окт', '2018']
# 19 окт 2018
# ['19', 'окт', '2018']
# 19 окт 2018
# ['19', 'окт', '2018']
# 19 окт 2018
# ['19', 'окт', '2018']
# 18 окт 2018
# ['18', 'окт', '2018']
# 18 окт 2018
# ['18', 'окт', '2018']
# 18 окт 2018
# ['18', 'окт', '2018']
# 18 окт 2018
# ['18', 'окт', '2018']
# 18 окт 2018
# ['18', 'окт', '2018']
# 18 окт 2018
# ['18', 'окт', '2018']
# 16 окт 2018
# ['16', 'окт', '2018']
# 16 окт 2018
# ['16', 'окт', '2018']
# 16 окт 2018
# ['16', 'окт', '2018']
# 16 окт 2018
# ['16', 'окт', '2018']
# 16 окт 2018
# ['16', 'окт', '2018']
# 16 окт 2018
# ['16', 'окт', '2018']
# 13.10.2018
# 13.10.2018
# 13.10.2018
# 13.10.2018
# 13.10.2018
# 13.10.2018
# 13.10.2018
# 14 окт 2018
# ['14', 'окт', '2018']
# 14 окт 2018
# ['14', 'окт', '2018']
# 14 окт 2018
# ['14', 'окт', '2018']
# 14 окт 2018
# ['14', 'окт', '2018']
# 14 окт 2018
# ['14', 'окт', '2018']
# 14 окт 2018
# ['14', 'окт', '2018']
# 07.09.2018
# 07.09.2018
# 07.09.2018
# 07.09.2018
# 07.09.2018
# 07.09.2018
# 09 окт 2018
# ['09', 'окт', '2018']
# 09 окт 2018
# ['09', 'окт', '2018']
# 09 окт 2018
# ['09', 'окт', '2018']
# 09 окт 2018
# ['09', 'окт', '2018']
# 09 окт 2018
# ['09', 'окт', '2018']
# 09 окт 2018
# ['09', 'окт', '2018']
# 07.09.2018
# 09 окт 2018
# ['09', 'окт', '2018']
# 09 окт 2018
# ['09', 'окт', '2018']
# 07.09.2018
# 02 окт 2018
# ['02', 'окт', '2018']
# 02 окт 2018
# ['02', 'окт', '2018']
# 02 окт 2018
# ['02', 'окт', '2018']
# 02 окт 2018
# ['02', 'окт', '2018']
# 02 окт 2018
# ['02', 'окт', '2018']
# 02 окт 2018
# ['02', 'окт', '2018']
# 28 сен 2018
# ['28', 'сен', '2018']
# 28 сен 2018
# ['28', 'сен', '2018']
# 28 сен 2018
# ['28', 'сен', '2018']
# 28 сен 2018
# ['28', 'сен', '2018']
# 28 сен 2018
# ['28', 'сен', '2018']
# 28 сен 2018
# ['28', 'сен', '2018']
# 20 сен 2018
# ['20', 'сен', '2018']
# 20 сен 2018
# ['20', 'сен', '2018']
# 20 сен 2018
# ['20', 'сен', '2018']
# 20 сен 2018
# ['20', 'сен', '2018']
# 20 сен 2018
# ['20', 'сен', '2018']
# 20 сен 2018
# ['20', 'сен', '2018']
# 20 сен 2018
# ['20', 'сен', '2018']
# 20 сен 2018
# ['20', 'сен', '2018']
# 20 сен 2018
# ['20', 'сен', '2018']
# 20 сен 2018
# ['20', 'сен', '2018']
# 20 сен 2018
# ['20', 'сен', '2018']
# 20 сен 2018
# ['20', 'сен', '2018']
# 04 сен 2018
# ['04', 'сен', '2018']
# 04 сен 2018
# ['04', 'сен', '2018']
# 04 сен 2018
# ['04', 'сен', '2018']
# 04 сен 2018
# ['04', 'сен', '2018']
# 04 сен 2018
# ['04', 'сен', '2018']
# 04 сен 2018
# ['04', 'сен', '2018']
# 24 июл 2018
# ['24', 'июл', '2018']
# 24 июл 2018
# ['24', 'июл', '2018']
# 24 июл 2018
# ['24', 'июл', '2018']
# 24 июл 2018
# ['24', 'июл', '2018']
# 24 июл 2018
# ['24', 'июл', '2018']
# 24 июл 2018
# ['24', 'июл', '2018']
# 03.07.2018
# 03.07.2018
# 03.07.2018
# 03.07.2018
# 03.07.2018
# 03.07.2018
# 13 июл 2018
# ['13', 'июл', '2018']
# 13 июл 2018
# ['13', 'июл', '2018']
# 13 июл 2018
# ['13', 'июл', '2018']
# 13 июл 2018
# ['13', 'июл', '2018']
# 13 июл 2018
# ['13', 'июл', '2018']
# 13 июл 2018
# ['13', 'июл', '2018']
# 03.07.2018
# 13 июл 2018
# ['13', 'июл', '2018']
# 13 июл 2018
# ['13', 'июл', '2018']
# 03.07.2018
# 08.06.2018
# 08.06.2018
# 08.06.2018
# 08.06.2018
# 08.06.2018
# 08.06.2018
# 09 июн 2018
# ['09', 'июн', '2018']
# 09 июн 2018
# ['09', 'июн', '2018']
# 09 июн 2018
# ['09', 'июн', '2018']
# 09 июн 2018
# ['09', 'июн', '2018']
# 09 июн 2018
# ['09', 'июн', '2018']
# 09 июн 2018
# ['09', 'июн', '2018']
# 08.06.2018
# 09 июн 2018
# ['09', 'июн', '2018']
# 09 июн 2018
# ['09', 'июн', '2018']
# 08.06.2018
# 26.05.2017
# 26.05.2017
# 26.05.2017
# 26.05.2017
# 26.05.2017
# 26.05.2017
# 27 май 2018
# ['27', 'май', '2018']
# 27 май 2018
# ['27', 'май', '2018']
# 27 май 2018
# ['27', 'май', '2018']
# 27 май 2018
# ['27', 'май', '2018']
# 27 май 2018
# ['27', 'май', '2018']
# 27 май 2018
# ['27', 'май', '2018']
# 26.05.2017
# 27 май 2018
# ['27', 'май', '2018']
# 27 май 2018
# ['27', 'май', '2018']
# 26.05.2017
# 04 май 2018
# ['04', 'май', '2018']
# 04 май 2018
# ['04', 'май', '2018']
# 04 май 2018
# ['04', 'май', '2018']
# 04 май 2018
# ['04', 'май', '2018']
# 04 май 2018
# ['04', 'май', '2018']
# 04 май 2018
# ['04', 'май', '2018']
# 01 апр 2018
# ['01', 'апр', '2018']
# 01 апр 2018
# ['01', 'апр', '2018']
# 01 апр 2018
# ['01', 'апр', '2018']
# 01 апр 2018
# ['01', 'апр', '2018']
# 01 апр 2018
# ['01', 'апр', '2018']
# 01 апр 2018
# ['01', 'апр', '2018']
# 22.03.2018
# 22.03.2018
# 22.03.2018
# 22.03.2018
# 22.03.2018
# 22.03.2018
# 23 мар 2018
# ['23', 'мар', '2018']
# 23 мар 2018
# ['23', 'мар', '2018']
# 23 мар 2018
# ['23', 'мар', '2018']
# 23 мар 2018
# ['23', 'мар', '2018']
# 23 мар 2018
# ['23', 'мар', '2018']
# 23 мар 2018
# ['23', 'мар', '2018']
# 22.03.2018
# 23 мар 2018
# ['23', 'мар', '2018']
# 23 мар 2018
# ['23', 'мар', '2018']
# 22.03.2018
# 13.03.2018
# 13.03.2018
# 13.03.2018
# 13.03.2018
# 13.03.2018
# 13.03.2018
# 15 мар 2018
# ['15', 'мар', '2018']
# 15 мар 2018
# ['15', 'мар', '2018']
# 15 мар 2018
# ['15', 'мар', '2018']
# 15 мар 2018
# ['15', 'мар', '2018']
# 15 мар 2018
# ['15', 'мар', '2018']
# 15 мар 2018
# ['15', 'мар', '2018']
# 13.03.2018
# 15 мар 2018
# ['15', 'мар', '2018']
# 15 мар 2018
# ['15', 'мар', '2018']
# 13.03.2018
# 30.06.2017
# 30.06.2017
# 30.06.2017
# 30.06.2017
# 30.06.2017
# 30.06.2017
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 30.06.2017
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 30.06.2017
# 02.07.2017
# 02.07.2017
# 02.07.2017
# 02.07.2017
# 02.07.2017
# 02.07.2017
# 10 июл 2017
# ['10', 'июл', '2017']
# 10 июл 2017
# ['10', 'июл', '2017']
# 10 июл 2017
# ['10', 'июл', '2017']
# 10 июл 2017
# ['10', 'июл', '2017']
# 10 июл 2017
# ['10', 'июл', '2017']
# 10 июл 2017
# ['10', 'июл', '2017']
# 02.07.2017
# 10 июл 2017
# ['10', 'июл', '2017']
# 10 июл 2017
# ['10', 'июл', '2017']
# 02.07.2017
# 05.06.2017
# 05.06.2017
# 05.06.2017
# 05.06.2017
# 05.06.2017
# 05.06.2017
# 05.06.2017
# 21.06.2017
# 21.06.2017
# 21.06.2017
# 21.06.2017
# 21.06.2017
# 21.06.2017
# 21.06.2017
# 07.06.2017
# 07.06.2017
# 07.06.2017
# 07.06.2017
# 07.06.2017
# 07.06.2017
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 07.06.2017
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 07.06.2017
# 20.06.2017
# 20.06.2017
# 20.06.2017
# 20.06.2017
# 20.06.2017
# 20.06.2017
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 20.06.2017
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 20.06.2017
# 19.06.2017
# 19.06.2017
# 19.06.2017
# 19.06.2017
# 19.06.2017
# 19.06.2017
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 19.06.2017
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 19.06.2017
# 17 ноя 2017
# ['17', 'ноя', '2017']
# 17 ноя 2017
# ['17', 'ноя', '2017']
# 17 ноя 2017
# ['17', 'ноя', '2017']
# 17 ноя 2017
# ['17', 'ноя', '2017']
# 17 ноя 2017
# ['17', 'ноя', '2017']
# 17 ноя 2017
# ['17', 'ноя', '2017']
# 25 окт 2017
# ['25', 'окт', '2017']
# 25 окт 2017
# ['25', 'окт', '2017']
# 25 окт 2017
# ['25', 'окт', '2017']
# 25 окт 2017
# ['25', 'окт', '2017']
# 25 окт 2017
# ['25', 'окт', '2017']
# 25 окт 2017
# ['25', 'окт', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 11 июл 2017
# ['11', 'июл', '2017']
# 21.06.2017
# 21.06.2017
# 21.06.2017
# 21.06.2017
# 21.06.2017
# 21.06.2017
# 08 июл 2017
# ['08', 'июл', '2017']
# 08 июл 2017
# ['08', 'июл', '2017']
# 08 июл 2017
# ['08', 'июл', '2017']
# 08 июл 2017
# ['08', 'июл', '2017']
# 08 июл 2017
# ['08', 'июл', '2017']
# 08 июл 2017
# ['08', 'июл', '2017']
# 21.06.2017
# 08 июл 2017
# ['08', 'июл', '2017']
# 08 июл 2017
# ['08', 'июл', '2017']
# 21.06.2017
# 17.06.2017
# 17.06.2017
# 17.06.2017
# 17.06.2017
# 17.06.2017
# 17.06.2017
# 23 июн 2017
# ['23', 'июн', '2017']
# 23 июн 2017
# ['23', 'июн', '2017']
# 23 июн 2017
# ['23', 'июн', '2017']
# 23 июн 2017
# ['23', 'июн', '2017']
# 23 июн 2017
# ['23', 'июн', '2017']
# 23 июн 2017
# ['23', 'июн', '2017']
# 17.06.2017
# 23 июн 2017
# ['23', 'июн', '2017']
# 23 июн 2017
# ['23', 'июн', '2017']
# 17.06.2017
# 04 июн 2017
# ['04', 'июн', '2017']
# 04 июн 2017
# ['04', 'июн', '2017']
# 04 июн 2017
# ['04', 'июн', '2017']
# 04 июн 2017
# ['04', 'июн', '2017']
# 04 июн 2017
# ['04', 'июн', '2017']
# 04 июн 2017
# ['04', 'июн', '2017']
# 08 июн 2017
# ['08', 'июн', '2017']
# 08 июн 2017
# ['08', 'июн', '2017']
# 08 июн 2017
# ['08', 'июн', '2017']
# 08 июн 2017
# ['08', 'июн', '2017']
# 08 июн 2017
# ['08', 'июн', '2017']
# 08 июн 2017
# ['08', 'июн', '2017']
# 18.05.2017
# 18.05.2017
# 18.05.2017
# 18.05.2017
# 18.05.2017
# 18.05.2017
# 03 июн 2017
# ['03', 'июн', '2017']
# 03 июн 2017
# ['03', 'июн', '2017']
# 03 июн 2017
# ['03', 'июн', '2017']
# 03 июн 2017
# ['03', 'июн', '2017']
# 03 июн 2017
# ['03', 'июн', '2017']
# 03 июн 2017
# ['03', 'июн', '2017']
# 18.05.2017
# 03 июн 2017
# ['03', 'июн', '2017']
# 03 июн 2017
# ['03', 'июн', '2017']
# 18.05.2017
# 22.05.2017
# 22.05.2017
# 22.05.2017
# 22.05.2017
# 22.05.2017
# 22.05.2017
# 22.05.2017
# 23 май 2017
# ['23', 'май', '2017']
# 23 май 2017
# ['23', 'май', '2017']
# 23 май 2017
# ['23', 'май', '2017']
# 23 май 2017
# ['23', 'май', '2017']
# 23 май 2017
# ['23', 'май', '2017']
# 23 май 2017
# ['23', 'май', '2017']
# 30.04.2017
# 30.04.2017
# 30.04.2017
# 30.04.2017
# 30.04.2017
# 30.04.2017
# 10 май 2017
# ['10', 'май', '2017']
# 10 май 2017
# ['10', 'май', '2017']
# 10 май 2017
# ['10', 'май', '2017']
# 10 май 2017
# ['10', 'май', '2017']
# 10 май 2017
# ['10', 'май', '2017']
# 10 май 2017
# ['10', 'май', '2017']
# 30.04.2017
# 10 май 2017
# ['10', 'май', '2017']
# 10 май 2017
# ['10', 'май', '2017']
# 30.04.2017
# 10.04.2017
# 10.04.2017
# 10.04.2017
# 10.04.2017
# 10.04.2017
# 10.04.2017
# 10.04.2017
# 07.02.2016
# 07.02.2016
# 07.02.2016
# 07.02.2016
# 07.02.2016
# 07.02.2016
# 25 янв 2017
# ['25', 'янв', '2017']
# 25 янв 2017
# ['25', 'янв', '2017']
# 25 янв 2017
# ['25', 'янв', '2017']
# 25 янв 2017
# ['25', 'янв', '2017']
# 25 янв 2017
# ['25', 'янв', '2017']
# 25 янв 2017
# ['25', 'янв', '2017']
# 07.02.2016
# 25 янв 2017
# ['25', 'янв', '2017']
# 25 янв 2017
# ['25', 'янв', '2017']
# 07.02.2016
# 20.06.2016
# 20.06.2016
# 20.06.2016
# 20.06.2016
# 20.06.2016
# 20.06.2016
# 20.06.2016
# 11 апр 2013
# ['11', 'апр', '2013']
# 11 апр 2013
# ['11', 'апр', '2013']
# 11 апр 2013
# ['11', 'апр', '2013']
# 11 апр 2013
# ['11', 'апр', '2013']
# 11 апр 2013
# ['11', 'апр', '2013']
# 11 апр 2013
# ['11', 'апр', '2013']
# 29.11.1975
# 29.11.1975
# 29.11.1975
# 29.11.1975
# 29.11.1975
# 29.11.1975
# 13 дек 2013
# ['13', 'дек', '2013']
# 13 дек 2013
# ['13', 'дек', '2013']
# 13 дек 2013
# ['13', 'дек', '2013']
# 13 дек 2013
# ['13', 'дек', '2013']
# 13 дек 2013
# ['13', 'дек', '2013']
# 13 дек 2013
# ['13', 'дек', '2013']
# 29.11.1975
# 13 дек 2013
# ['13', 'дек', '2013']
# 13 дек 2013
# ['13', 'дек', '2013']
# 29.11.1975
# 26.01.1989
# 26.01.1989
# 26.01.1989
# 26.01.1989
# 26.01.1989
# 26.01.1989
# 22 ноя 2013
# ['22', 'ноя', '2013']
# 22 ноя 2013
# ['22', 'ноя', '2013']
# 22 ноя 2013
# ['22', 'ноя', '2013']
# 22 ноя 2013
# ['22', 'ноя', '2013']
# 22 ноя 2013
# ['22', 'ноя', '2013']
# 22 ноя 2013
# ['22', 'ноя', '2013']
# 26.01.1989
# 22 ноя 2013
# ['22', 'ноя', '2013']
# 22 ноя 2013
# ['22', 'ноя', '2013']
# 26.01.1989
# 25.07.2013
# 25.07.2013
# 25.07.2013
# 25.07.2013
# 25.07.2013
# 25.07.2013
# 25.07.2013
# 07 авг 2013
# ['07', 'авг', '2013']
# 07 авг 2013
# ['07', 'авг', '2013']
# 07 авг 2013
# ['07', 'авг', '2013']
# 07 авг 2013
# ['07', 'авг', '2013']
# 07 авг 2013
# ['07', 'авг', '2013']
# 07 авг 2013
# ['07', 'авг', '2013']
# 23.07.2013
# 23.07.2013
# 23.07.2013
# 23.07.2013
# 23.07.2013
# 23.07.2013
# 22 ноя 2013
# ['22', 'ноя', '2013']
# 22 ноя 2013
# ['22', 'ноя', '2013']
# 22 ноя 2013
# ['22', 'ноя', '2013']
# 22 ноя 2013
# ['22', 'ноя', '2013']
# 22 ноя 2013
# ['22', 'ноя', '2013']
# 22 ноя 2013
# ['22', 'ноя', '2013']
# 23.07.2013
# 22 ноя 2013
# ['22', 'ноя', '2013']
# 22 ноя 2013
# ['22', 'ноя', '2013']
# 23.07.2013
# 01.05.2009
# 01.05.2009
# 01.05.2009
# 01.05.2009
# 01.05.2009
# 01.05.2009
# 01.05.2009
# 19.06.2013
# 19.06.2013
# 19.06.2013
# 19.06.2013
# 19.06.2013
# 19.06.2013
# 19.06.2013
# 24.07.2013
# 24.07.2013
# 24.07.2013
# 24.07.2013
# 24.07.2013
# 24.07.2013
# 24.07.2013
# 31.01.2013
# 31.01.2013
# 31.01.2013
# 31.01.2013
# 31.01.2013
# 31.01.2013
# 31.01.2013
# 28.07.2013
# 28.07.2013
# 28.07.2013
# 28.07.2013
# 28.07.2013
# 28.07.2013
# 28.07.2013
# 27.07.2013
# 27.07.2013
# 27.07.2013
# 27.07.2013
# 27.07.2013
# 27.07.2013
# 27.07.2013
# 26 июл 2013
# ['26', 'июл', '2013']
# 26 июл 2013
# ['26', 'июл', '2013']
# 26 июл 2013
# ['26', 'июл', '2013']
# 26 июл 2013
# ['26', 'июл', '2013']
# 26 июл 2013
# ['26', 'июл', '2013']
# 26 июл 2013
# ['26', 'июл', '2013']
# 25 июл 2013
# ['25', 'июл', '2013']
# 25 июл 2013
# ['25', 'июл', '2013']
# 25 июл 2013
# ['25', 'июл', '2013']
# 25 июл 2013
# ['25', 'июл', '2013']
# 25 июл 2013
# ['25', 'июл', '2013']
# 25 июл 2013
# ['25', 'июл', '2013']
# 22.01.1987
# 22.01.1987
# 22.01.1987
# 22.01.1987
# 22.01.1987
# 22.01.1987
# 22.01.1987
# 06.07.2013
# 06.07.2013
# 06.07.2013
# 06.07.2013
# 06.07.2013
# 06.07.2013
# 15 июл 2013
# ['15', 'июл', '2013']
# 15 июл 2013
# ['15', 'июл', '2013']
# 15 июл 2013
# ['15', 'июл', '2013']
# 15 июл 2013
# ['15', 'июл', '2013']
# 15 июл 2013
# ['15', 'июл', '2013']
# 15 июл 2013
# ['15', 'июл', '2013']
# 06.07.2013
# 15 июл 2013
# ['15', 'июл', '2013']
# 15 июл 2013
# ['15', 'июл', '2013']
# 06.07.2013
# 07.12.1993
# 07.12.1993
# 07.12.1993
# 07.12.1993
# 07.12.1993
# 07.12.1993
# 30 май 2013
# ['30', 'май', '2013']
# 30 май 2013
# ['30', 'май', '2013']
# 30 май 2013
# ['30', 'май', '2013']
# 30 май 2013
# ['30', 'май', '2013']
# 30 май 2013
# ['30', 'май', '2013']
# 30 май 2013
# ['30', 'май', '2013']
# 07.12.1993
# 30 май 2013
# ['30', 'май', '2013']
# 30 май 2013
# ['30', 'май', '2013']
# 07.12.1993
# 16.03.1970
# 16.03.1970
# 16.03.1970
# 16.03.1970
# 16.03.1970
# 16.03.1970
# 16.03.1970
# 18 мар 2013
# ['18', 'мар', '2013']
# 18 мар 2013
# ['18', 'мар', '2013']
# 18 мар 2013
# ['18', 'мар', '2013']
# 18 мар 2013
# ['18', 'мар', '2013']
# 18 мар 2013
# ['18', 'мар', '2013']
# 18 мар 2013
# ['18', 'мар', '2013']
# 20.01.2013
# 20.01.2013
# 20.01.2013
# 20.01.2013
# 20.01.2013
# 20.01.2013
# 20.01.2013
# 23.04.1977
# 23.04.1977
# 23.04.1977
# 23.04.1977
# 23.04.1977
# 23.04.1977
# 23.04.1977
# 26.11.2012
# 26.11.2012
# 26.11.2012
# 26.11.2012
# 26.11.2012
# 26.11.2012
# 26.11.2012
# 31.03.1981
# 31.03.1981
# 31.03.1981
# 31.03.1981
# 31.03.1981
# 31.03.1981
# 28 ноя 2012
# ['28', 'ноя', '2012']
# 28 ноя 2012
# ['28', 'ноя', '2012']
# 28 ноя 2012
# ['28', 'ноя', '2012']
# 28 ноя 2012
# ['28', 'ноя', '2012']
# 28 ноя 2012
# ['28', 'ноя', '2012']
# 28 ноя 2012
# ['28', 'ноя', '2012']
# 31.03.1981
# 28 ноя 2012
# ['28', 'ноя', '2012']
# 28 ноя 2012
# ['28', 'ноя', '2012']
# 31.03.1981
# 30.10.2012
# 30.10.2012
# 30.10.2012
# 30.10.2012
# 30.10.2012
# 30.10.2012
# 30.10.2012
# 25 окт 2012
# ['25', 'окт', '2012']
# 25 окт 2012
# ['25', 'окт', '2012']
# 25 окт 2012
# ['25', 'окт', '2012']
# 25 окт 2012
# ['25', 'окт', '2012']
# 25 окт 2012
# ['25', 'окт', '2012']
# 25 окт 2012
# ['25', 'окт', '2012']
# 22 окт 2012
# ['22', 'окт', '2012']
# 22 окт 2012
# ['22', 'окт', '2012']
# 22 окт 2012
# ['22', 'окт', '2012']
# 22 окт 2012
# ['22', 'окт', '2012']
# 22 окт 2012
# ['22', 'окт', '2012']
# 22 окт 2012
# ['22', 'окт', '2012']
# 19 окт 2012
# ['19', 'окт', '2012']
# 19 окт 2012
# ['19', 'окт', '2012']
# 19 окт 2012
# ['19', 'окт', '2012']
# 19 окт 2012
# ['19', 'окт', '2012']
# 19 окт 2012
# ['19', 'окт', '2012']
# 19 окт 2012
# ['19', 'окт', '2012']
# 15 мар 2019
# ['15', 'мар', '2019']
# 15 мар 2019
# ['15', 'мар', '2019']
# 15 мар 2019
# ['15', 'мар', '2019']
# 15 мар 2019
# ['15', 'мар', '2019']
# 15 мар 2019
# ['15', 'мар', '2019']
# 15 мар 2019
# ['15', 'мар', '2019']
# 12 мар 2019
# ['12', 'мар', '2019']
# 12 мар 2019
# ['12', 'мар', '2019']
# 12 мар 2019
# ['12', 'мар', '2019']
# 12 мар 2019
# ['12', 'мар', '2019']
# 12 мар 2019
# ['12', 'мар', '2019']
# 12 мар 2019
# ['12', 'мар', '2019']
# 27 фев 2019
# ['27', 'фев', '2019']
# 27 фев 2019
# ['27', 'фев', '2019']
# 27 фев 2019
# ['27', 'фев', '2019']
# 27 фев 2019
# ['27', 'фев', '2019']
# 27 фев 2019
# ['27', 'фев', '2019']
# 27 фев 2019
# ['27', 'фев', '2019']
# 21 фев 2019
# ['21', 'фев', '2019']
# 21 фев 2019
# ['21', 'фев', '2019']
# 21 фев 2019
# ['21', 'фев', '2019']
# 21 фев 2019
# ['21', 'фев', '2019']
# 21 фев 2019
# ['21', 'фев', '2019']
# 21 фев 2019
# ['21', 'фев', '2019']
# 19 фев 2019
# ['19', 'фев', '2019']
# 19 фев 2019
# ['19', 'фев', '2019']
# 19 фев 2019
# ['19', 'фев', '2019']
# 19 фев 2019
# ['19', 'фев', '2019']
# 19 фев 2019
# ['19', 'фев', '2019']
# 19 фев 2019
# ['19', 'фев', '2019']
# 17 фев 2019
# ['17', 'фев', '2019']
# 17 фев 2019
# ['17', 'фев', '2019']
# 17 фев 2019
# ['17', 'фев', '2019']
# 17 фев 2019
# ['17', 'фев', '2019']
# 17 фев 2019
# ['17', 'фев', '2019']
# 17 фев 2019
# ['17', 'фев', '2019']
# 12.02.2019
# 12.02.2019
# 12.02.2019
# 12.02.2019
# 12.02.2019
# 12.02.2019
# 13 фев 2019
# ['13', 'фев', '2019']
# 13 фев 2019
# ['13', 'фев', '2019']
# 13 фев 2019
# ['13', 'фев', '2019']
# 13 фев 2019
# ['13', 'фев', '2019']
# 13 фев 2019
# ['13', 'фев', '2019']
# 13 фев 2019
# ['13', 'фев', '2019']
# 12.02.2019
# 13 фев 2019
# ['13', 'фев', '2019']
# 13 фев 2019
# ['13', 'фев', '2019']
# 12.02.2019
# 08 фев 2019
# ['08', 'фев', '2019']
# 08 фев 2019
# ['08', 'фев', '2019']
# 08 фев 2019
# ['08', 'фев', '2019']
# 08 фев 2019
# ['08', 'фев', '2019']
# 08 фев 2019
# ['08', 'фев', '2019']
# 08 фев 2019
# ['08', 'фев', '2019']
# 31.01.2019
# 31.01.2019
# 31.01.2019
# 31.01.2019
# 31.01.2019
# 31.01.2019
# 01 фев 2019
# ['01', 'фев', '2019']
# 01 фев 2019
# ['01', 'фев', '2019']
# 01 фев 2019
# ['01', 'фев', '2019']
# 01 фев 2019
# ['01', 'фев', '2019']
# 01 фев 2019
# ['01', 'фев', '2019']
# 01 фев 2019
# ['01', 'фев', '2019']
# 31.01.2019
# 01 фев 2019
# ['01', 'фев', '2019']
# 01 фев 2019
# ['01', 'фев', '2019']
# 31.01.2019
# 25 янв 2019
# ['25', 'янв', '2019']
# 25 янв 2019
# ['25', 'янв', '2019']
# 25 янв 2019
# ['25', 'янв', '2019']
# 25 янв 2019
# ['25', 'янв', '2019']
# 25 янв 2019
# ['25', 'янв', '2019']
# 25 янв 2019
# ['25', 'янв', '2019']
# 24 янв 2019
# ['24', 'янв', '2019']
# 24 янв 2019
# ['24', 'янв', '2019']
# 24 янв 2019
# ['24', 'янв', '2019']
# 24 янв 2019
# ['24', 'янв', '2019']
# 24 янв 2019
# ['24', 'янв', '2019']
# 24 янв 2019
# ['24', 'янв', '2019']
# 11 янв 2019
# ['11', 'янв', '2019']
# 11 янв 2019
# ['11', 'янв', '2019']
# 11 янв 2019
# ['11', 'янв', '2019']
# 11 янв 2019
# ['11', 'янв', '2019']
# 11 янв 2019
# ['11', 'янв', '2019']
# 11 янв 2019
# ['11', 'янв', '2019']
# 08 янв 2019
# ['08', 'янв', '2019']
# 08 янв 2019
# ['08', 'янв', '2019']
# 08 янв 2019
# ['08', 'янв', '2019']
# 08 янв 2019
# ['08', 'янв', '2019']
# 08 янв 2019
# ['08', 'янв', '2019']
# 08 янв 2019
# ['08', 'янв', '2019']
# 23 дек 2018
# ['23', 'дек', '2018']
# 23 дек 2018
# ['23', 'дек', '2018']
# 23 дек 2018
# ['23', 'дек', '2018']
# 23 дек 2018
# ['23', 'дек', '2018']
# 23 дек 2018
# ['23', 'дек', '2018']
# 23 дек 2018
# ['23', 'дек', '2018']
# 20.12.2018
# 20.12.2018
# 20.12.2018
# 20.12.2018
# 20.12.2018
# 20.12.2018
# 22 дек 2018
# ['22', 'дек', '2018']
# 22 дек 2018
# ['22', 'дек', '2018']
# 22 дек 2018
# ['22', 'дек', '2018']
# 22 дек 2018
# ['22', 'дек', '2018']
# 22 дек 2018
# ['22', 'дек', '2018']
# 22 дек 2018
# ['22', 'дек', '2018']
# 20.12.2018
# 22 дек 2018
# ['22', 'дек', '2018']
# 22 дек 2018
# ['22', 'дек', '2018']
# 20.12.2018
# 21 дек 2018
# ['21', 'дек', '2018']
# 21 дек 2018
# ['21', 'дек', '2018']
# 21 дек 2018
# ['21', 'дек', '2018']
# 21 дек 2018
# ['21', 'дек', '2018']
# 21 дек 2018
# ['21', 'дек', '2018']
# 21 дек 2018
# ['21', 'дек', '2018']
# 09.12.2018
# 09.12.2018
# 09.12.2018
# 09.12.2018
# 09.12.2018
# 09.12.2018
# 09 дек 2018
# ['09', 'дек', '2018']
# 09 дек 2018
# ['09', 'дек', '2018']
# 09 дек 2018
# ['09', 'дек', '2018']
# 09 дек 2018
# ['09', 'дек', '2018']
# 09 дек 2018
# ['09', 'дек', '2018']
# 09 дек 2018
# ['09', 'дек', '2018']
# 09.12.2018
# 09 дек 2018
# ['09', 'дек', '2018']
# 09 дек 2018
# ['09', 'дек', '2018']
# 09.12.2018
# 02 дек 2018
# ['02', 'дек', '2018']
# 02 дек 2018
# ['02', 'дек', '2018']
# 02 дек 2018
# ['02', 'дек', '2018']
# 02 дек 2018
# ['02', 'дек', '2018']
# 02 дек 2018
# ['02', 'дек', '2018']
# 02 дек 2018
# ['02', 'дек', '2018']
# 21.05.2015
# 21.05.2015
# 21.05.2015
# 21.05.2015
# 21.05.2015
# 21.05.2015
# 21.05.2015
# 16.08.2014
# 16.08.2014
# 16.08.2014
# 16.08.2014
# 16.08.2014
# 16.08.2014
# 16.08.2014
# 18.11.1962
# 18.11.1962
# 18.11.1962
# 18.11.1962
# 18.11.1962
# 18.11.1962
# 18.11.1962
# 08.04.2013
# 08.04.2013
# 08.04.2013
# 08.04.2013
# 08.04.2013
# 08.04.2013
# 08.04.2013
# 09 сен 2013
# ['09', 'сен', '2013']
# 09 сен 2013
# ['09', 'сен', '2013']
# 09 сен 2013
# ['09', 'сен', '2013']
# 09 сен 2013
# ['09', 'сен', '2013']
# 09 сен 2013
# ['09', 'сен', '2013']
# 09 сен 2013
# ['09', 'сен', '2013']
# 06.09.2013
# 06.09.2013
# 06.09.2013
# 06.09.2013
# 06.09.2013
# 06.09.2013
# 12 сен 2013
# ['12', 'сен', '2013']
# 12 сен 2013
# ['12', 'сен', '2013']
# 12 сен 2013
# ['12', 'сен', '2013']
# 12 сен 2013
# ['12', 'сен', '2013']
# 12 сен 2013
# ['12', 'сен', '2013']
# 12 сен 2013
# ['12', 'сен', '2013']
# 06.09.2013
# 12 сен 2013
# ['12', 'сен', '2013']
# 12 сен 2013
# ['12', 'сен', '2013']
# 06.09.2013
# 28 июн 2013
# ['28', 'июн', '2013']
# 28 июн 2013
# ['28', 'июн', '2013']
# 28 июн 2013
# ['28', 'июн', '2013']
# 28 июн 2013
# ['28', 'июн', '2013']
# 28 июн 2013
# ['28', 'июн', '2013']
# 28 июн 2013
# ['28', 'июн', '2013']
# 11.04.2013
# 11.04.2013
# 11.04.2013
# 11.04.2013
# 11.04.2013
# 11.04.2013
# 28 июн 2013
# ['28', 'июн', '2013']
# 28 июн 2013
# ['28', 'июн', '2013']
# 28 июн 2013
# ['28', 'июн', '2013']
# 28 июн 2013
# ['28', 'июн', '2013']
# 28 июн 2013
# ['28', 'июн', '2013']
# 28 июн 2013
# ['28', 'июн', '2013']
# 11.04.2013
# 28 июн 2013
# ['28', 'июн', '2013']
# 28 июн 2013
# ['28', 'июн', '2013']
# 11.04.2013
# 05 фев 2013
# ['05', 'фев', '2013']
# 05 фев 2013
# ['05', 'фев', '2013']
# 05 фев 2013
# ['05', 'фев', '2013']
# 05 фев 2013
# ['05', 'фев', '2013']
# 05 фев 2013
# ['05', 'фев', '2013']
# 05 фев 2013
# ['05', 'фев', '2013']
# 02.04.2013
# 02.04.2013
# 02.04.2013
# 02.04.2013
# 02.04.2013
# 02.04.2013
# 20 апр 2013
# ['20', 'апр', '2013']
# 20 апр 2013
# ['20', 'апр', '2013']
# 20 апр 2013
# ['20', 'апр', '2013']
# 20 апр 2013
# ['20', 'апр', '2013']
# 20 апр 2013
# ['20', 'апр', '2013']
# 20 апр 2013
# ['20', 'апр', '2013']
# 02.04.2013
# 20 апр 2013
# ['20', 'апр', '2013']
# 20 апр 2013
# ['20', 'апр', '2013']
# 02.04.2013
# 17.04.2013
# 17.04.2013
# 17.04.2013
# 17.04.2013
# 17.04.2013
# 17.04.2013
# 20 апр 2013
# ['20', 'апр', '2013']
# 20 апр 2013
# ['20', 'апр', '2013']
# 20 апр 2013
# ['20', 'апр', '2013']
# 20 апр 2013
# ['20', 'апр', '2013']
# 20 апр 2013
# ['20', 'апр', '2013']
# 20 апр 2013
# ['20', 'апр', '2013']
# 17.04.2013
# 20 апр 2013
# ['20', 'апр', '2013']
# 20 апр 2013
# ['20', 'апр', '2013']
# 17.04.2013
# 13.04.2013
# 13.04.2013
# 13.04.2013
# 13.04.2013
# 13.04.2013
# 13.04.2013
# 18 апр 2013
# ['18', 'апр', '2013']
# 18 апр 2013
# ['18', 'апр', '2013']
# 18 апр 2013
# ['18', 'апр', '2013']
# 18 апр 2013
# ['18', 'апр', '2013']
# 18 апр 2013
# ['18', 'апр', '2013']
# 18 апр 2013
# ['18', 'апр', '2013']
# 13.04.2013
# 18 апр 2013
# ['18', 'апр', '2013']
# 18 апр 2013
# ['18', 'апр', '2013']
# 13.04.2013
# 21.01.2013
# 21.01.2013
# 21.01.2013
# 21.01.2013
# 21.01.2013
# 21.01.2013
# 08 апр 2013
# ['08', 'апр', '2013']
# 08 апр 2013
# ['08', 'апр', '2013']
# 08 апр 2013
# ['08', 'апр', '2013']
# 08 апр 2013
# ['08', 'апр', '2013']
# 08 апр 2013
# ['08', 'апр', '2013']
# 08 апр 2013
# ['08', 'апр', '2013']
# 21.01.2013
# 08 апр 2013
# ['08', 'апр', '2013']
# 08 апр 2013
# ['08', 'апр', '2013']
# 21.01.2013
# 01.04.2013
# 01.04.2013
# 01.04.2013
# 01.04.2013
# 01.04.2013
# 01.04.2013
# 07 апр 2013
# ['07', 'апр', '2013']
# 07 апр 2013
# ['07', 'апр', '2013']
# 07 апр 2013
# ['07', 'апр', '2013']
# 07 апр 2013
# ['07', 'апр', '2013']
# 07 апр 2013
# ['07', 'апр', '2013']
# 07 апр 2013
# ['07', 'апр', '2013']
# 01.04.2013
# 07 апр 2013
# ['07', 'апр', '2013']
# 07 апр 2013
# ['07', 'апр', '2013']
# 01.04.2013
# 03 апр 2013
# ['03', 'апр', '2013']
# 03 апр 2013
# ['03', 'апр', '2013']
# 03 апр 2013
# ['03', 'апр', '2013']
# 03 апр 2013
# ['03', 'апр', '2013']
# 03 апр 2013
# ['03', 'апр', '2013']
# 03 апр 2013
# ['03', 'апр', '2013']
# 22.03.2013
# 22.03.2013
# 22.03.2013
# 22.03.2013
# 22.03.2013
# 22.03.2013
# 03 апр 2013
# ['03', 'апр', '2013']
# 03 апр 2013
# ['03', 'апр', '2013']
# 03 апр 2013
# ['03', 'апр', '2013']
# 03 апр 2013
# ['03', 'апр', '2013']
# 03 апр 2013
# ['03', 'апр', '2013']
# 03 апр 2013
# ['03', 'апр', '2013']
# 22.03.2013
# 03 апр 2013
# ['03', 'апр', '2013']
# 03 апр 2013
# ['03', 'апр', '2013']
# 22.03.2013
# 24.08.1989
# 24.08.1989
# 24.08.1989
# 24.08.1989
# 24.08.1989
# 24.08.1989
# 20 фев 2013
# ['20', 'фев', '2013']
# 20 фев 2013
# ['20', 'фев', '2013']
# 20 фев 2013
# ['20', 'фев', '2013']
# 20 фев 2013
# ['20', 'фев', '2013']
# 20 фев 2013
# ['20', 'фев', '2013']
# 20 фев 2013
# ['20', 'фев', '2013']
# 24.08.1989
# 20 фев 2013
# ['20', 'фев', '2013']
# 20 фев 2013
# ['20', 'фев', '2013']
# 24.08.1989
# 05.02.2013
# 05.02.2013
# 05.02.2013
# 05.02.2013
# 05.02.2013
# 05.02.2013
# 31 мар 2013
# ['31', 'мар', '2013']
# 31 мар 2013
# ['31', 'мар', '2013']
# 31 мар 2013
# ['31', 'мар', '2013']
# 31 мар 2013
# ['31', 'мар', '2013']
# 31 мар 2013
# ['31', 'мар', '2013']
# 31 мар 2013
# ['31', 'мар', '2013']
# 05.02.2013
# 31 мар 2013
# ['31', 'мар', '2013']
# 31 мар 2013
# ['31', 'мар', '2013']
# 05.02.2013
# 22.03.2013
# 22.03.2013
# 22.03.2013
# 22.03.2013
# 22.03.2013
# 22.03.2013
# 26 мар 2013
# ['26', 'мар', '2013']
# 26 мар 2013
# ['26', 'мар', '2013']
# 26 мар 2013
# ['26', 'мар', '2013']
# 26 мар 2013
# ['26', 'мар', '2013']
# 26 мар 2013
# ['26', 'мар', '2013']
# 26 мар 2013
# ['26', 'мар', '2013']
# 22.03.2013
# 26 мар 2013
# ['26', 'мар', '2013']
# 26 мар 2013
# ['26', 'мар', '2013']
# 22.03.2013
# 22.03.2013
# 22.03.2013
# 22.03.2013
# 22.03.2013
# 22.03.2013
# 22.03.2013
# 25 мар 2013
# ['25', 'мар', '2013']
# 25 мар 2013
# ['25', 'мар', '2013']
# 25 мар 2013
# ['25', 'мар', '2013']
# 25 мар 2013
# ['25', 'мар', '2013']
# 25 мар 2013
# ['25', 'мар', '2013']
# 25 мар 2013
# ['25', 'мар', '2013']
# 22.03.2013
# 25 мар 2013
# ['25', 'мар', '2013']
# 25 мар 2013
# ['25', 'мар', '2013']
# 22.03.2013
# 19.03.2013
# 19.03.2013
# 19.03.2013
# 19.03.2013
# 19.03.2013
# 19.03.2013
# 19.03.2013
# 07.02.2013
# 07.02.2013
# 07.02.2013
# 07.02.2013
# 07.02.2013
# 07.02.2013
# 22 мар 2013
# ['22', 'мар', '2013']
# 22 мар 2013
# ['22', 'мар', '2013']
# 22 мар 2013
# ['22', 'мар', '2013']
# 22 мар 2013
# ['22', 'мар', '2013']
# 22 мар 2013
# ['22', 'мар', '2013']
# 22 мар 2013
# ['22', 'мар', '2013']
# 07.02.2013
# 22 мар 2013
# ['22', 'мар', '2013']
# 22 мар 2013
# ['22', 'мар', '2013']
# 07.02.2013
# 17 мар 2013
# ['17', 'мар', '2013']
# 17 мар 2013
# ['17', 'мар', '2013']
# 17 мар 2013
# ['17', 'мар', '2013']
# 17 мар 2013
# ['17', 'мар', '2013']
# 17 мар 2013
# ['17', 'мар', '2013']
# 17 мар 2013
# ['17', 'мар', '2013']
# 12.03.2013
# 12.03.2013
# 12.03.2013
# 12.03.2013
# 12.03.2013
# 12.03.2013
# 16 мар 2013
# ['16', 'мар', '2013']
# 16 мар 2013
# ['16', 'мар', '2013']
# 16 мар 2013
# ['16', 'мар', '2013']
# 16 мар 2013
# ['16', 'мар', '2013']
# 16 мар 2013
# ['16', 'мар', '2013']
# 16 мар 2013
# ['16', 'мар', '2013']
# 12.03.2013
# 16 мар 2013
# ['16', 'мар', '2013']
# 16 мар 2013
# ['16', 'мар', '2013']
# 12.03.2013
# 09.03.2013
# 09.03.2013
# 09.03.2013
# 09.03.2013
# 09.03.2013
# 09.03.2013
# 15 мар 2013
# ['15', 'мар', '2013']
# 15 мар 2013
# ['15', 'мар', '2013']
# 15 мар 2013
# ['15', 'мар', '2013']
# 15 мар 2013
# ['15', 'мар', '2013']
# 15 мар 2013
# ['15', 'мар', '2013']
# 15 мар 2013
# ['15', 'мар', '2013']
# 09.03.2013
# 15 мар 2013
# ['15', 'мар', '2013']
# 15 мар 2013
# ['15', 'мар', '2013']
# 09.03.2013
# 04.03.2013
# 04.03.2013
# 04.03.2013
# 04.03.2013
# 04.03.2013
# 04.03.2013
# 11 мар 2013
# ['11', 'мар', '2013']
# 11 мар 2013
# ['11', 'мар', '2013']
# 11 мар 2013
# ['11', 'мар', '2013']
# 11 мар 2013
# ['11', 'мар', '2013']
# 11 мар 2013
# ['11', 'мар', '2013']
# 11 мар 2013
# ['11', 'мар', '2013']
# 04.03.2013
# 11 мар 2013
# ['11', 'мар', '2013']
# 11 мар 2013
# ['11', 'мар', '2013']
# 04.03.2013
# 04.03.3013
# 04.03.3013
# 04.03.3013
# 04.03.3013
# 04.03.3013
# 04.03.3013
# 05 мар 2013
# ['05', 'мар', '2013']
# 05 мар 2013
# ['05', 'мар', '2013']
# 05 мар 2013
# ['05', 'мар', '2013']
# 05 мар 2013
# ['05', 'мар', '2013']
# 05 мар 2013
# ['05', 'мар', '2013']
# 05 мар 2013
# ['05', 'мар', '2013']
# 04.03.3013
# 05 мар 2013
# ['05', 'мар', '2013']
# 05 мар 2013
# ['05', 'мар', '2013']
# 04.03.3013
# 27.08.1941
# 27.08.1941
# 27.08.1941
# 27.08.1941
# 27.08.1941
# 27.08.1941
# 04 мар 2013
# ['04', 'мар', '2013']
# 04 мар 2013
# ['04', 'мар', '2013']
# 04 мар 2013
# ['04', 'мар', '2013']
# 04 мар 2013
# ['04', 'мар', '2013']
# 04 мар 2013
# ['04', 'мар', '2013']
# 04 мар 2013
# ['04', 'мар', '2013']
# 27.08.1941
# 04 мар 2013
# ['04', 'мар', '2013']
# 04 мар 2013
# ['04', 'мар', '2013']
# 27.08.1941
# 25 фев 2013
# ['25', 'фев', '2013']
# 25 фев 2013
# ['25', 'фев', '2013']
# 25 фев 2013
# ['25', 'фев', '2013']
# 25 фев 2013
# ['25', 'фев', '2013']
# 25 фев 2013
# ['25', 'фев', '2013']
# 25 фев 2013
# ['25', 'фев', '2013']
# 18.02.2013
# 18.02.2013
# 18.02.2013
# 18.02.2013
# 18.02.2013
# 18.02.2013
# 24 фев 2013
# ['24', 'фев', '2013']
# 24 фев 2013
# ['24', 'фев', '2013']
# 24 фев 2013
# ['24', 'фев', '2013']
# 24 фев 2013
# ['24', 'фев', '2013']
# 24 фев 2013
# ['24', 'фев', '2013']
# 24 фев 2013
# ['24', 'фев', '2013']
# 18.02.2013
# 24 фев 2013
# ['24', 'фев', '2013']
# 24 фев 2013
# ['24', 'фев', '2013']
# 18.02.2013
# 20 фев 2013
# ['20', 'фев', '2013']
# 20 фев 2013
# ['20', 'фев', '2013']
# 20 фев 2013
# ['20', 'фев', '2013']
# 20 фев 2013
# ['20', 'фев', '2013']
# 20 фев 2013
# ['20', 'фев', '2013']
# 20 фев 2013
# ['20', 'фев', '2013']
# 20 фев 2013
# ['20', 'фев', '2013']
# 20 фев 2013
# ['20', 'фев', '2013']
# 20 фев 2013
# ['20', 'фев', '2013']
# 20 фев 2013
# ['20', 'фев', '2013']
# 20 фев 2013
# ['20', 'фев', '2013']
# 20 фев 2013
# ['20', 'фев', '2013']
# 19 фев 2013
# ['19', 'фев', '2013']
# 19 фев 2013
# ['19', 'фев', '2013']
# 19 фев 2013
# ['19', 'фев', '2013']
# 19 фев 2013
# ['19', 'фев', '2013']
# 19 фев 2013
# ['19', 'фев', '2013']
# 19 фев 2013
# ['19', 'фев', '2013']
# 02 фев 2013
# ['02', 'фев', '2013']
# 02 фев 2013
# ['02', 'фев', '2013']
# 02 фев 2013
# ['02', 'фев', '2013']
# 02 фев 2013
# ['02', 'фев', '2013']
# 02 фев 2013
# ['02', 'фев', '2013']
# 02 фев 2013
# ['02', 'фев', '2013']
# 02.06.1975
# 02.06.1975
# 02.06.1975
# 02.06.1975
# 02.06.1975
# 02.06.1975
# 03 фев 2013
# ['03', 'фев', '2013']
# 03 фев 2013
# ['03', 'фев', '2013']
# 03 фев 2013
# ['03', 'фев', '2013']
# 03 фев 2013
# ['03', 'фев', '2013']
# 03 фев 2013
# ['03', 'фев', '2013']
# 03 фев 2013
# ['03', 'фев', '2013']
# 02.06.1975
# 03 фев 2013
# ['03', 'фев', '2013']
# 03 фев 2013
# ['03', 'фев', '2013']
# 02.06.1975
# 03 фев 2013
# ['03', 'фев', '2013']
# 03 фев 2013
# ['03', 'фев', '2013']
# 03 фев 2013
# ['03', 'фев', '2013']
# 03 фев 2013
# ['03', 'фев', '2013']
# 03 фев 2013
# ['03', 'фев', '2013']
# 03 фев 2013
# ['03', 'фев', '2013']
# 13.02.1985
# 13.02.1985
# 13.02.1985
# 13.02.1985
# 13.02.1985
# 13.02.1985
# 10 янв 2013
# ['10', 'янв', '2013']
# 10 янв 2013
# ['10', 'янв', '2013']
# 10 янв 2013
# ['10', 'янв', '2013']
# 10 янв 2013
# ['10', 'янв', '2013']
# 10 янв 2013
# ['10', 'янв', '2013']
# 10 янв 2013
# ['10', 'янв', '2013']
# 13.02.1985
# 10 янв 2013
# ['10', 'янв', '2013']
# 10 янв 2013
# ['10', 'янв', '2013']
# 13.02.1985
# 23 янв 2013
# ['23', 'янв', '2013']
# 23 янв 2013
# ['23', 'янв', '2013']
# 23 янв 2013
# ['23', 'янв', '2013']
# 23 янв 2013
# ['23', 'янв', '2013']
# 23 янв 2013
# ['23', 'янв', '2013']
# 23 янв 2013
# ['23', 'янв', '2013']
# 06.09.1988
# 06.09.1988
# 06.09.1988
# 06.09.1988
# 06.09.1988
# 06.09.1988
# 03 фев 2013
# ['03', 'фев', '2013']
# 03 фев 2013
# ['03', 'фев', '2013']
# 03 фев 2013
# ['03', 'фев', '2013']
# 03 фев 2013
# ['03', 'фев', '2013']
# 03 фев 2013
# ['03', 'фев', '2013']
# 03 фев 2013
# ['03', 'фев', '2013']
# 06.09.1988
# 03 фев 2013
# ['03', 'фев', '2013']
# 03 фев 2013
# ['03', 'фев', '2013']
# 06.09.1988
# 20.01.1937
# 20.01.1937
# 20.01.1937
# 20.01.1937
# 20.01.1937
# 20.01.1937
# 03 фев 2013
# ['03', 'фев', '2013']
# 03 фев 2013
# ['03', 'фев', '2013']
# 03 фев 2013
# ['03', 'фев', '2013']
# 03 фев 2013
# ['03', 'фев', '2013']
# 03 фев 2013
# ['03', 'фев', '2013']
# 03 фев 2013
# ['03', 'фев', '2013']
# 20.01.1937
# 03 фев 2013
# ['03', 'фев', '2013']
# 03 фев 2013
# ['03', 'фев', '2013']
# 20.01.1937
# 01.01.2013
# 01.01.2013
# 01.01.2013
# 01.01.2013
# 01.01.2013
# 01.01.2013
# 01.01.2013
# 28.07.1998
# 28.07.1998
# 28.07.1998
# 28.07.1998
# 28.07.1998
# 28.07.1998
# 08 ноя 2012
# ['08', 'ноя', '2012']
# 08 ноя 2012
# ['08', 'ноя', '2012']
# 08 ноя 2012
# ['08', 'ноя', '2012']
# 08 ноя 2012
# ['08', 'ноя', '2012']
# 08 ноя 2012
# ['08', 'ноя', '2012']
# 08 ноя 2012
# ['08', 'ноя', '2012']
# 28.07.1998
# 08 ноя 2012
# ['08', 'ноя', '2012']
# 08 ноя 2012
# ['08', 'ноя', '2012']
# 28.07.1998
# 21 окт 2012
# ['21', 'окт', '2012']
# 21 окт 2012
# ['21', 'окт', '2012']
# 21 окт 2012
# ['21', 'окт', '2012']
# 21 окт 2012
# ['21', 'окт', '2012']
# 21 окт 2012
# ['21', 'окт', '2012']
# 21 окт 2012
# ['21', 'окт', '2012']
# 29 сен 2012
# ['29', 'сен', '2012']
# 29 сен 2012
# ['29', 'сен', '2012']
# 29 сен 2012
# ['29', 'сен', '2012']
# 29 сен 2012
# ['29', 'сен', '2012']
# 29 сен 2012
# ['29', 'сен', '2012']
# 29 сен 2012
# ['29', 'сен', '2012']
# 20 сен 2012
# ['20', 'сен', '2012']
# 20 сен 2012
# ['20', 'сен', '2012']
# 20 сен 2012
# ['20', 'сен', '2012']
# 20 сен 2012
# ['20', 'сен', '2012']
# 20 сен 2012
# ['20', 'сен', '2012']
# 20 сен 2012
# ['20', 'сен', '2012']
# 17.08.2012
# 17.08.2012
# 17.08.2012
# 17.08.2012
# 17.08.2012
# 17.08.2012
# 17.08.2012
# 24 авг 2012
# ['24', 'авг', '2012']
# 24 авг 2012
# ['24', 'авг', '2012']
# 24 авг 2012
# ['24', 'авг', '2012']
# 24 авг 2012
# ['24', 'авг', '2012']
# 24 авг 2012
# ['24', 'авг', '2012']
# 24 авг 2012
# ['24', 'авг', '2012']
# 15 авг 2012
# ['15', 'авг', '2012']
# 15 авг 2012
# ['15', 'авг', '2012']
# 15 авг 2012
# ['15', 'авг', '2012']
# 15 авг 2012
# ['15', 'авг', '2012']
# 15 авг 2012
# ['15', 'авг', '2012']
# 15 авг 2012
# ['15', 'авг', '2012']
# 19 авг 2012
# ['19', 'авг', '2012']
# 19 авг 2012
# ['19', 'авг', '2012']
# 19 авг 2012
# ['19', 'авг', '2012']
# 19 авг 2012
# ['19', 'авг', '2012']
# 19 авг 2012
# ['19', 'авг', '2012']
# 19 авг 2012
# ['19', 'авг', '2012']
# 03 ноя 2018
# ['03', 'ноя', '2018']
# 03 ноя 2018
# ['03', 'ноя', '2018']
# 03 ноя 2018
# ['03', 'ноя', '2018']
# 03 ноя 2018
# ['03', 'ноя', '2018']
# 03 ноя 2018
# ['03', 'ноя', '2018']
# 03 ноя 2018
# ['03', 'ноя', '2018']
# 23 май 2018
# ['23', 'май', '2018']
# 23 май 2018
# ['23', 'май', '2018']
# 23 май 2018
# ['23', 'май', '2018']
# 23 май 2018
# ['23', 'май', '2018']
# 23 май 2018
# ['23', 'май', '2018']
# 23 май 2018
# ['23', 'май', '2018']
# 17 дек 2017
# ['17', 'дек', '2017']
# 17 дек 2017
# ['17', 'дек', '2017']
# 17 дек 2017
# ['17', 'дек', '2017']
# 17 дек 2017
# ['17', 'дек', '2017']
# 17 дек 2017
# ['17', 'дек', '2017']
# 17 дек 2017
# ['17', 'дек', '2017']
# 22 сен 2017
# ['22', 'сен', '2017']
# 22 сен 2017
# ['22', 'сен', '2017']
# 22 сен 2017
# ['22', 'сен', '2017']
# 22 сен 2017
# ['22', 'сен', '2017']
# 22 сен 2017
# ['22', 'сен', '2017']
# 22 сен 2017
# ['22', 'сен', '2017']
# 09.08.2004
# 09.08.2004
# 09.08.2004
# 09.08.2004
# 09.08.2004
# 09.08.2004
# 09.08.2004
# 05.02.1941
# 05.02.1941
# 05.02.1941
# 05.02.1941
# 05.02.1941
# 05.02.1941
# 05.02.1941
# 02.02.1939
# 02.02.1939
# 02.02.1939
# 02.02.1939
# 02.02.1939
# 02.02.1939
# 02.02.1939
# 15.07.2016
# 15.07.2016
# 15.07.2016
# 15.07.2016
# 15.07.2016
# 15.07.2016
# 26 авг 2016
# ['26', 'авг', '2016']
# 26 авг 2016
# ['26', 'авг', '2016']
# 26 авг 2016
# ['26', 'авг', '2016']
# 26 авг 2016
# ['26', 'авг', '2016']
# 26 авг 2016
# ['26', 'авг', '2016']
# 26 авг 2016
# ['26', 'авг', '2016']
# 15.07.2016
# 26 авг 2016
# ['26', 'авг', '2016']
# 26 авг 2016
# ['26', 'авг', '2016']
# 15.07.2016
# 29.05.1935
# 29.05.1935
# 29.05.1935
# 29.05.1935
# 29.05.1935
# 29.05.1935
# 29.05.1935
# 16.07.2016
# 16.07.2016
# 16.07.2016
# 16.07.2016
# 16.07.2016
# 16.07.2016
# 16.07.2016
# 05.08.1945
# 05.08.1945
# 05.08.1945
# 05.08.1945
# 05.08.1945
# 05.08.1945
# 05.08.1945
# 29.11.1937
# 29.11.1937
# 29.11.1937
# 29.11.1937
# 29.11.1937
# 29.11.1937
# 29.11.1937
# 18.10.1935
# 18.10.1935
# 18.10.1935
# 18.10.1935
# 18.10.1935
# 18.10.1935
# 18.10.1935
# 28.11.1955
# 28.11.1955
# 28.11.1955
# 28.11.1955
# 28.11.1955
# 28.11.1955
# 28.11.1955
# 04.05.1952
# 04.05.1952
# 04.05.1952
# 04.05.1952
# 04.05.1952
# 04.05.1952
# 04.05.1952
# 28.03.1945
# 28.03.1945
# 28.03.1945
# 28.03.1945
# 28.03.1945
# 28.03.1945
# 28.03.1945
# 25 май 2019
# ['25', 'май', '2019']
# 25 май 2019
# ['25', 'май', '2019']
# 25 май 2019
# ['25', 'май', '2019']
# 25 май 2019
# ['25', 'май', '2019']
# 25 май 2019
# ['25', 'май', '2019']
# 25 май 2019
# ['25', 'май', '2019']
# 24 май 2019
# ['24', 'май', '2019']
# 24 май 2019
# ['24', 'май', '2019']
# 24 май 2019
# ['24', 'май', '2019']
# 24 май 2019
# ['24', 'май', '2019']
# 24 май 2019
# ['24', 'май', '2019']
# 24 май 2019
# ['24', 'май', '2019']
# 24 май 2019
# ['24', 'май', '2019']
# 24 май 2019
# ['24', 'май', '2019']
# 24 май 2019
# ['24', 'май', '2019']
# 24 май 2019
# ['24', 'май', '2019']
# 24 май 2019
# ['24', 'май', '2019']
# 24 май 2019
# ['24', 'май', '2019']
# 22 май 2019
# ['22', 'май', '2019']
# 22 май 2019
# ['22', 'май', '2019']
# 22 май 2019
# ['22', 'май', '2019']
# 22 май 2019
# ['22', 'май', '2019']
# 22 май 2019
# ['22', 'май', '2019']
# 22 май 2019
# ['22', 'май', '2019']
# 19 май 2019
# ['19', 'май', '2019']
# 19 май 2019
# ['19', 'май', '2019']
# 19 май 2019
# ['19', 'май', '2019']
# 19 май 2019
# ['19', 'май', '2019']
# 19 май 2019
# ['19', 'май', '2019']
# 19 май 2019
# ['19', 'май', '2019']
# 11.05.2019
# 11.05.2019
# 11.05.2019
# 11.05.2019
# 11.05.2019
# 11.05.2019
# 14 май 2019
# ['14', 'май', '2019']
# 14 май 2019
# ['14', 'май', '2019']
# 14 май 2019
# ['14', 'май', '2019']
# 14 май 2019
# ['14', 'май', '2019']
# 14 май 2019
# ['14', 'май', '2019']
# 14 май 2019
# ['14', 'май', '2019']
# 11.05.2019
# 14 май 2019
# ['14', 'май', '2019']
# 14 май 2019
# ['14', 'май', '2019']
# 11.05.2019
# 18 май 2019
# ['18', 'май', '2019']
# 18 май 2019
# ['18', 'май', '2019']
# 18 май 2019
# ['18', 'май', '2019']
# 18 май 2019
# ['18', 'май', '2019']
# 18 май 2019
# ['18', 'май', '2019']
# 18 май 2019
# ['18', 'май', '2019']
# 17 май 2019
# ['17', 'май', '2019']
# 17 май 2019
# ['17', 'май', '2019']
# 17 май 2019
# ['17', 'май', '2019']
# 17 май 2019
# ['17', 'май', '2019']
# 17 май 2019
# ['17', 'май', '2019']
# 17 май 2019
# ['17', 'май', '2019']
# 18 май 2019
# ['18', 'май', '2019']
# 18 май 2019
# ['18', 'май', '2019']
# 18 май 2019
# ['18', 'май', '2019']
# 18 май 2019
# ['18', 'май', '2019']
# 18 май 2019
# ['18', 'май', '2019']
# 18 май 2019
# ['18', 'май', '2019']
# 15 май 2019
# ['15', 'май', '2019']
# 15 май 2019
# ['15', 'май', '2019']
# 15 май 2019
# ['15', 'май', '2019']
# 15 май 2019
# ['15', 'май', '2019']
# 15 май 2019
# ['15', 'май', '2019']
# 15 май 2019
# ['15', 'май', '2019']
# 14 май 2019
# ['14', 'май', '2019']
# 14 май 2019
# ['14', 'май', '2019']
# 14 май 2019
# ['14', 'май', '2019']
# 14 май 2019
# ['14', 'май', '2019']
# 14 май 2019
# ['14', 'май', '2019']
# 14 май 2019
# ['14', 'май', '2019']
# 06 май 2019
# ['06', 'май', '2019']
# 06 май 2019
# ['06', 'май', '2019']
# 06 май 2019
# ['06', 'май', '2019']
# 06 май 2019
# ['06', 'май', '2019']
# 06 май 2019
# ['06', 'май', '2019']
# 06 май 2019
# ['06', 'май', '2019']
# 06 май 2019
# ['06', 'май', '2019']
# 06 май 2019
# ['06', 'май', '2019']
# 06 май 2019
# ['06', 'май', '2019']
# 06 май 2019
# ['06', 'май', '2019']
# 06 май 2019
# ['06', 'май', '2019']
# 06 май 2019
# ['06', 'май', '2019']
# 05 май 2019
# ['05', 'май', '2019']
# 05 май 2019
# ['05', 'май', '2019']
# 05 май 2019
# ['05', 'май', '2019']
# 05 май 2019
# ['05', 'май', '2019']
# 05 май 2019
# ['05', 'май', '2019']
# 05 май 2019
# ['05', 'май', '2019']
# 03 май 2019
# ['03', 'май', '2019']
# 03 май 2019
# ['03', 'май', '2019']
# 03 май 2019
# ['03', 'май', '2019']
# 03 май 2019
# ['03', 'май', '2019']
# 03 май 2019
# ['03', 'май', '2019']
# 03 май 2019
# ['03', 'май', '2019']
# 03 май 2019
# ['03', 'май', '2019']
# 03 май 2019
# ['03', 'май', '2019']
# 03 май 2019
# ['03', 'май', '2019']
# 03 май 2019
# ['03', 'май', '2019']
# 03 май 2019
# ['03', 'май', '2019']
# 03 май 2019
# ['03', 'май', '2019']
# 02 май 2019
# ['02', 'май', '2019']
# 02 май 2019
# ['02', 'май', '2019']
# 02 май 2019
# ['02', 'май', '2019']
# 02 май 2019
# ['02', 'май', '2019']
# 02 май 2019
# ['02', 'май', '2019']
# 02 май 2019
# ['02', 'май', '2019']
# 02 май 2019
# ['02', 'май', '2019']
# 02 май 2019
# ['02', 'май', '2019']
# 02 май 2019
# ['02', 'май', '2019']
# 02 май 2019
# ['02', 'май', '2019']
# 02 май 2019
# ['02', 'май', '2019']
# 02 май 2019
# ['02', 'май', '2019']
# 20 май 2019
# ['20', 'май', '2019']
# 20 май 2019
# ['20', 'май', '2019']
# 20 май 2019
# ['20', 'май', '2019']
# 20 май 2019
# ['20', 'май', '2019']
# 20 май 2019
# ['20', 'май', '2019']
# 20 май 2019
# ['20', 'май', '2019']
# 19 май 2019
# ['19', 'май', '2019']
# 19 май 2019
# ['19', 'май', '2019']
# 19 май 2019
# ['19', 'май', '2019']
# 19 май 2019
# ['19', 'май', '2019']
# 19 май 2019
# ['19', 'май', '2019']
# 19 май 2019
# ['19', 'май', '2019']
# 15.05.2019
# 15.05.2019
# 15.05.2019
# 15.05.2019
# 15.05.2019
# 15.05.2019
# 15 май 2019
# ['15', 'май', '2019']
# 15 май 2019
# ['15', 'май', '2019']
# 15 май 2019
# ['15', 'май', '2019']
# 15 май 2019
# ['15', 'май', '2019']
# 15 май 2019
# ['15', 'май', '2019']
# 15 май 2019
# ['15', 'май', '2019']
# 15.05.2019
# 15 май 2019
# ['15', 'май', '2019']
# 15 май 2019
# ['15', 'май', '2019']
# 15.05.2019
# 16 май 2019
# ['16', 'май', '2019']
# 16 май 2019
# ['16', 'май', '2019']
# 16 май 2019
# ['16', 'май', '2019']
# 16 май 2019
# ['16', 'май', '2019']
# 16 май 2019
# ['16', 'май', '2019']
# 16 май 2019
# ['16', 'май', '2019']
# 12 май 2019
# ['12', 'май', '2019']
# 12 май 2019
# ['12', 'май', '2019']
# 12 май 2019
# ['12', 'май', '2019']
# 12 май 2019
# ['12', 'май', '2019']
# 12 май 2019
# ['12', 'май', '2019']
# 12 май 2019
# ['12', 'май', '2019']
# 30 апр 2019
# ['30', 'апр', '2019']
# 30 апр 2019
# ['30', 'апр', '2019']
# 30 апр 2019
# ['30', 'апр', '2019']
# 30 апр 2019
# ['30', 'апр', '2019']
# 30 апр 2019
# ['30', 'апр', '2019']
# 30 апр 2019
# ['30', 'апр', '2019']
# 16 апр 2019
# ['16', 'апр', '2019']
# 16 апр 2019
# ['16', 'апр', '2019']
# 16 апр 2019
# ['16', 'апр', '2019']
# 16 апр 2019
# ['16', 'апр', '2019']
# 16 апр 2019
# ['16', 'апр', '2019']
# 16 апр 2019
# ['16', 'апр', '2019']
# 09 апр 2019
# ['09', 'апр', '2019']
# 09 апр 2019
# ['09', 'апр', '2019']
# 09 апр 2019
# ['09', 'апр', '2019']
# 09 апр 2019
# ['09', 'апр', '2019']
# 09 апр 2019
# ['09', 'апр', '2019']
# 09 апр 2019
# ['09', 'апр', '2019']
# 03 апр 2019
# ['03', 'апр', '2019']
# 03 апр 2019
# ['03', 'апр', '2019']
# 03 апр 2019
# ['03', 'апр', '2019']
# 03 апр 2019
# ['03', 'апр', '2019']
# 03 апр 2019
# ['03', 'апр', '2019']
# 03 апр 2019
# ['03', 'апр', '2019']
# 29 мар 2019
# ['29', 'мар', '2019']
# 29 мар 2019
# ['29', 'мар', '2019']
# 29 мар 2019
# ['29', 'мар', '2019']
# 29 мар 2019
# ['29', 'мар', '2019']
# 29 мар 2019
# ['29', 'мар', '2019']
# 29 мар 2019
# ['29', 'мар', '2019']
# 28 мар 2019
# ['28', 'мар', '2019']
# 28 мар 2019
# ['28', 'мар', '2019']
# 28 мар 2019
# ['28', 'мар', '2019']
# 28 мар 2019
# ['28', 'мар', '2019']
# 28 мар 2019
# ['28', 'мар', '2019']
# 28 мар 2019
# ['28', 'мар', '2019']
# 24 мар 2019
# ['24', 'мар', '2019']
# 24 мар 2019
# ['24', 'мар', '2019']
# 24 мар 2019
# ['24', 'мар', '2019']
# 24 мар 2019
# ['24', 'мар', '2019']
# 24 мар 2019
# ['24', 'мар', '2019']
# 24 мар 2019
# ['24', 'мар', '2019']
# 21 мар 2019
# ['21', 'мар', '2019']
# 21 мар 2019
# ['21', 'мар', '2019']
# 21 мар 2019
# ['21', 'мар', '2019']
# 21 мар 2019
# ['21', 'мар', '2019']
# 21 мар 2019
# ['21', 'мар', '2019']
# 21 мар 2019
# ['21', 'мар', '2019']
# 16 мар 2019
# ['16', 'мар', '2019']
# 16 мар 2019
# ['16', 'мар', '2019']
# 16 мар 2019
# ['16', 'мар', '2019']
# 16 мар 2019
# ['16', 'мар', '2019']
# 16 мар 2019
# ['16', 'мар', '2019']
# 16 мар 2019
# ['16', 'мар', '2019']
# 15 мар 2019
# ['15', 'мар', '2019']
# 15 мар 2019
# ['15', 'мар', '2019']
# 15 мар 2019
# ['15', 'мар', '2019']
# 15 мар 2019
# ['15', 'мар', '2019']
# 15 мар 2019
# ['15', 'мар', '2019']
# 15 мар 2019
# ['15', 'мар', '2019']
# 03.04.2013
# 03.04.2013
# 03.04.2013
# 03.04.2013
# 03.04.2013
# 03.04.2013
# 03.04.2013
# 31.08.2013
# 31.08.2013
# 31.08.2013
# 31.08.2013
# 31.08.2013
# 31.08.2013
# 31.08.2013
# 11.01.2018
# 11.01.2018
# 11.01.2018
# 11.01.2018
# 11.01.2018
# 11.01.2018
# 11.01.2018
# 06.04.2013
# 06.04.2013
# 06.04.2013
# 06.04.2013
# 06.04.2013
# 06.04.2013
# 06.04.2013
# 06.04.2013
# 06.04.2013
# 06.04.2013
# 06.04.2013
# 06.04.2013
# 06.04.2013
# 06.04.2013
# 18.11.2017
# 18.11.2017
# 18.11.2017
# 18.11.2017
# 18.11.2017
# 18.11.2017
# 18.11.2017
# 24.06.2017
# 24.06.2017
# 24.06.2017
# 24.06.2017
# 24.06.2017
# 24.06.2017
# 24.06.2017
# 06.04.2017
# 06.04.2017
# 06.04.2017
# 06.04.2017
# 06.04.2017
# 06.04.2017
# 06.04.2017
# 25.06.2017
# 25.06.2017
# 25.06.2017
# 25.06.2017
# 25.06.2017
# 25.06.2017
# 25.06.2017
# 04.04.2017
# 04.04.2017
# 04.04.2017
# 04.04.2017
# 04.04.2017
# 04.04.2017
# 04.04.2017
# 07.05.2017
# 07.05.2017
# 07.05.2017
# 07.05.2017
# 07.05.2017
# 07.05.2017
# 07.05.2017
# 15.03.2017
# 15.03.2017
# 15.03.2017
# 15.03.2017
# 15.03.2017
# 15.03.2017
# 15.03.2017
# 16.02.2017
# 16.02.2017
# 16.02.2017
# 16.02.2017
# 16.02.2017
# 16.02.2017
# 16.02.2017
# 19.05.2017
# 19.05.2017
# 19.05.2017
# 19.05.2017
# 19.05.2017
# 19.05.2017
# 19.05.2017
# 17 сен 2017
# ['17', 'сен', '2017']
# 17 сен 2017
# ['17', 'сен', '2017']
# 17 сен 2017
# ['17', 'сен', '2017']
# 17 сен 2017
# ['17', 'сен', '2017']
# 17 сен 2017
# ['17', 'сен', '2017']
# 17 сен 2017
# ['17', 'сен', '2017']
# 31.05.2017
# 31.05.2017
# 31.05.2017
# 31.05.2017
# 31.05.2017
# 31.05.2017
# 28 июн 2017
# ['28', 'июн', '2017']
# 28 июн 2017
# ['28', 'июн', '2017']
# 28 июн 2017
# ['28', 'июн', '2017']
# 28 июн 2017
# ['28', 'июн', '2017']
# 28 июн 2017
# ['28', 'июн', '2017']
# 28 июн 2017
# ['28', 'июн', '2017']
# 31.05.2017
# 28 июн 2017
# ['28', 'июн', '2017']
# 28 июн 2017
# ['28', 'июн', '2017']
# 31.05.2017
# 27.11.1965
# 27.11.1965
# 27.11.1965
# 27.11.1965
# 27.11.1965
# 27.11.1965
# 23 апр 2013
# ['23', 'апр', '2013']
# 23 апр 2013
# ['23', 'апр', '2013']
# 23 апр 2013
# ['23', 'апр', '2013']
# 23 апр 2013
# ['23', 'апр', '2013']
# 23 апр 2013
# ['23', 'апр', '2013']
# 23 апр 2013
# ['23', 'апр', '2013']
# 27.11.1965
# 23 апр 2013
# ['23', 'апр', '2013']
# 23 апр 2013
# ['23', 'апр', '2013']
# 27.11.1965
# 24.11.1994
# 24.11.1994
# 24.11.1994
# 24.11.1994
# 24.11.1994
# 24.11.1994
# 24.11.1994

# %%
for i in range(len(list_of_coor)):
    for j in range(len(list_x_tracks)):
        if str(list_x_tracks[j]) in (list_of_coor[i]):
            list_x_tracks1[i] = str(list_x_tracks[j])
            list_url1[i] = str(list_url[j])
            list_km1[i] = str(list_km[j])
            list_date11[i] = str(list_date1[j])
            list_date22[i] = str(list_date2[j])
            list_teams1[i] = str(list_teams[j])

# %% [markdown]
# Парсим посты, копаем вглубь!

# %%
list_of_all_pages1 = list()

for i in my_list:
    URL = i
    
    html = requests.get(URL).content #url='google.com'
    sel = Selector(text=html)

    uClient = uReq(URL)
    page_html = uClient.read()
    uClient.close()
    page_soup = soup(page_html, "html.parser")
    containers2 = page_soup.findAll("div", {"class":"pagination"})
    containers22 = str(containers2)

    def page12(containers22):
        page1 = list()
        c = containers22.find("из ")
        page1.append(containers22[c+11])
        page1.append(containers22[c+12])
        if containers22[c+12] == "<":
            page1.pop()
            return page1

    if page12(containers22) is None:
        page_real = 1
    else:
        if len(page12(containers22)) == 2:
            page_real = int(page12(containers22)[0] + page12(containers22)[1])
        else:
            page_real = int(page12(containers22)[0])

        # Парсим
    course_as = sel.xpath('//a[contains(@class,"right-box right")]')
    hrefs_from_css = course_as.css('::attr(href)')

    if len(str(hrefs_from_css.extract())[1:]) == 1:
        links_to_follow = URL
        clean_link = URL[27:len(URL)]
    else:
        links_to_follow = "\"https://lizaalert.org/forum" + str(hrefs_from_css.extract()[0])[1:] + "\""
        clean_link = str(hrefs_from_css.extract()[0])[1:len(hrefs_from_css.extract()[0])-2]

    list_links = list()
    for i in range((page_real)):
        list_links.append(clean_link)


        #За 500 надо пояснить! Но это вроде несложно
    i=0
    list1 = [0]
    for i in range(0,(page_real-1)*10, 10):
        i = i + 10
        list1.append(i)

    result = [str(item) for item in list1]

    for i in range(len(list1)):
        if list_links[i].find("start") != -1:
            list_links[i] += result[i]
        
    for i in range(len(list_links)):
        list_links[i] = "https://lizaalert.org/forum" + list_links[i]
    
    list_of_all_pages1.append(list_links)

# %%
print(list_of_all_pages1[1])
list_vk_posts = []
for j in range(len(list_of_all_pages1)):
    vk_posts = 0
    vk_postes = []
    for item in range(len(list_of_all_pages1[j])):
        vk_post = []
        uClient = uReq(list_of_all_pages1[j][item])
        page_html = uClient.read()
        uClient.close()
        page_soup = soup(page_html, "html.parser")
        for p in range(len(page_soup.findAll("div", {"class":"content"}))):
            containers2 = page_soup.findAll("div", {"class":"content"})[p] #ЧТО ЭТО ЗА ХУЙНЯ?????????
            kirka = containers2.findAll(text=re.compile("vk.com"))
            vk_post.append(len(kirka))
        vk_postes.append(vk_post)
    vk_posts += vk_posts
    for i in range(len(vk_postes)):
        for k in range(len(vk_postes[i])):
            vk_posts += vk_postes[i][k]
    list_vk_posts.append(vk_posts)
# Out:
# ['https://lizaalert.org/forum/viewtopic.php?f=131&t=9861&sid=7a9e4a70a216de19d1586c95731d6241']

# %%
print(list_of_all_pages1[1])
list_odn_posts = []
for j in range(len(list_of_all_pages1)):
    odn_posts = 0
    odn_postes = []
    odn_post = []
    for item in range(len(list_of_all_pages1[j])):
        uClient = uReq(list_of_all_pages1[j][item])
        page_html = uClient.read()
        uClient.close()
        page_soup = soup(page_html, "html.parser")
        for p in range(len(page_soup.findAll("div", {"class":"content"}))):
            containers2 = page_soup.findAll("div", {"class":"content"})[p] #ЧТО ЭТО ЗА ХУЙНЯ?????????
            kirka = containers2.findAll(text=re.compile(r'odnokl|ok.ru'))
            odn_post.append(len(kirka))
    odn_postes.append(odn_post)
    odn_posts += odn_posts
    for i in range(len(odn_postes)):
        for k in range(len(odn_postes[i])):
            odn_posts += odn_postes[i][k]
    list_odn_posts.append(odn_posts)
# Out:
# ['https://lizaalert.org/forum/viewtopic.php?f=131&t=9861&sid=7a9e4a70a216de19d1586c95731d6241']

# %%
print(list_of_all_pages1[0])
list_ready_posts = []
for j in range(len(list_of_all_pages1)):
    ready_posts = 0
    ready_postes = []
    for item in range(len(list_of_all_pages1[j])):
        ready_post = []
        uClient = uReq(list_of_all_pages1[j][item])
        page_html = uClient.read()
        uClient.close()
        page_soup = soup(page_html, "html.parser")
        for p in range(len(page_soup.findAll("div", {"class":"content"}))):
            containers2 = page_soup.findAll("div", {"class":"content"})[p] #ЧТО ЭТО ЗА ХУЙНЯ?????????
            kirka = containers2.findAll(text=re.compile(r'[Гг]отов'))
            ready_post.append(len(kirka))
        ready_postes.append(ready_post)
    ready_posts += ready_posts
    for i in range(len(ready_postes)):
        for k in range(len(ready_postes[i])):
            ready_posts += ready_postes[i][k]
    list_ready_posts.append(ready_posts)
# Out:
# ['https://lizaalert.org/forum/viewtopic.php?f=131&t=11738&sid=7a9e4a70a216de19d1586c95731d6241']

# %% [markdown]
# Для таблицы

# %%
list_of_lists.append(list_ready_posts)
list_of_lists.append(list_searchers)
list_of_lists.append(list_vk_posts)
list_of_lists.append(list_odn_posts)
list_of_lists.append(list_age11)
list_of_lists.append(list_height)
list_of_lists.append(list_help1)
list_of_lists.append(list_photo)
list_of_lists.append(list_posts)
list_of_lists.append(list_sex1)
list_of_lists.append(list_state1)
list_of_lists.append(list_hair_color)
list_of_lists.append(list_bodytype)
list_of_lists.append(list_eye)
list_of_lists.append(list_full)
list_of_lists.append(list_place)
list_of_lists.append(list_color_of_clothes) # Бабкен вставил
list_of_lists.append(list_podrobnost) # Бабкен вставил еще раз, но уже себе
list_of_lists.append(list_primeti)
list_of_lists.append(list_search_time)
list_of_lists.append(list_lost_time)
list_of_lists.append(list_find_time)
list_of_lists.append(list_x_tracks1)
list_of_lists.append(list_url1)
list_of_lists.append(list_km1)
list_of_lists.append(list_teams1)
list_of_lists.append(list_date11)
list_of_lists.append(list_date22)
# Бабкен вставил снова, только Коле в пердачело

# %%
df1 = pd.DataFrame(columns = ['Готовые', 'Искатели', 'Репосты_вк', 'Репосты_одн', 'Возраст', 'Рост(Slava)', 'Мед. Состояние', 'Фото', 'Посты', 'Гендер(Slava)', 'Состояние(Slava)', 'Цвет волос', 'Телосложение', 'Цвет глаз', 'Url','Место', 'Одежда(яркая)', 'Одежда(подробность)', 'Приметы(кол-во)', 'Время поиска', "Время пропажи", "Время нахождения", "Координаты пропажи", 'url_tracks', 'km', 'teams','date1', 'date2'])

# %%
for i, j in zip(list_of_lists, list(df1.columns)):
    df1[j] = pd.Series(i)

# %% [markdown]
# # Тадаам ! Вот , что мы получили

# %%
df1
# Out:
#      Готовые  Искатели  Репосты_вк  Репосты_одн         Возраст Рост(Slava)  \
# 0    2        0         0           0            Коля объебался  Er
# 1    0        1         0           0            63              170
# 2    1        1         0           0            12              160
# 3    0        1         0           0            35              160
# 4    0        1         0           0            23              175
# 5    0        1         0           0            75              178
# 6    0        1         0           0            81              175
# 7    0        1         0           0            29              167
# 8    0        2         0           0            Коля объебался  173
# 9    0        1         0           0            76              Er
# 10   0        1         0           0            80              160
# 11   0        1         0           0            7               110
# 12   0        1         0           0            41              185
# 13   0        97        31          1            36              165
# 14   0        3         29          6            40              180
# 15   0        1         0           0            14              Er
# 16   0        1         0           0            40              176
# 17   0        1         0           0            30              172
# 18   0        2         0           0            25              186
# 19   0        2         0           0            Коля объебался  160
# 20   0        156       423         0            72              170
# 21   0        21        0           7            88              163
# 22   0        2         0           0            Коля объебался  175
# 23   0        0         0           0            100             163
# 24   0        2         0           0            94              160
# 25   0        1         0           0            71              176
# 26   2        0         0           0            Коля объебался  Er
# 27   0        1         0           0            21              170
# 28   0        0         0           0            33              185
# 29   1        6         0           0            4               Er
# 30   0        2         0           0            5               Er
# 31   0        4         0           0            4               Er
# 32   2        0         0           0            Коля объебался  Er
# 33   0        1         0           0            49              168
# 34   0        10        193         1            43              165
# 35   0        16        210         1            30              185
# 36   0        13        194         1            89              155
# 37   0        2         113         0            41              Er
# 38   0        21        65          0            81              Er
# 39   0        16        69          1            35              170
# 40   0        25        132         34           33              175
# 41   0        0         0           0            62              168
# 42   0        13        1           1            21              160
# 43   0        16        1           1            45              165
# 44   0        4         0           0            89              165
# 45   0        10        1           1            85              Er
# 46   0        19        1           2            20              167
# 47   0        16        1           1            30              150
# 48   0        1         0           0            60              180
# 49   0        16        211         1            21              150
# 50   0        0         0           0            80              170
# 51   0        16        152         1            31              173
# 52   0        12        371         1            72              172
# 53   0        16        3           17           38              160
# 54   0        1         0           0            78              165
# 55   0        11        16          13           28              172
# 56   0        0         0           0            78              155
# 57   0        9         9           16           42              190
# 58   2        0         0           0            Коля объебался  Er
# 59   0        4         13          21           25              175
# 60   0        20        39          13           12              154
# 61   0        76        25          0            36              185
# 62   0        10        1           0            88              165
# 63   0        15        174         1            69              165
# 64   0        10        0           0            85              160
# 65   0        16        198         1            40              175
# 66   0        19        17          1            40              160
# 67   0        15        24          1            39              180
# 68   0        59        2           1            62              175
# 69   0        16        1           1            24              178
# 70   0        0         0           0            42              162
# 71   0        0         0           0            35              184
# 72   0        4         26          21           30              180
# 73   0        13        190         1            70              164
# 74   0        4         1           0            64              170
# 75   0        16        1           1            63              162
# 76   1        16        30          8            53              168
# 77   0        136       41          13           62              160
# 78   0        16        38          1            65              185
# 79   1        22        32          6            79              170
# 80   0        16        1           1            38              165
# 81   0        16        12          9            77              168
# 82   0        14        485         1            76              163
# 83   0        16        3           31           52              170
# 84   2        0         0           0            Коля объебался  Er
# 85   0        13        37          1            28              170
# 86   0        13        51          1            59              165
# 87   0        0         0           0            13              158
# 88   0        13        1           1            41              185
# 89   0        29        321         1            24              176
# 90   0        13        1           1            56              172
# 91   0        29        1           1            37              175
# 92   0        13        157         1            16              167
# 93   0        13        186         1            66              162
# 94   0        13        151         1            18              180
# 95   0        25        201         2            40              180
# 96   0        13        151         1            49              165
# 97   0        152       139         0            66              160
# 98   0        9         200         0            11              145
# 99   0        22        150         1            64              170
# 100  0        29        1           1            34              192
# 101  0        19        82          1            77              170
# 102  0        13        61          0            44              175
# 103  0        13        0           0            37              180
# 104  0        13        0           0            70              170
# 105  0        9         0           0            42              172
# 106  0        29        1           1            39              165
# 107  0        13        41          1            31              Er
# 108  0        13        0           0            12              130
# 109  0        9         1           1            19              170
# 110  2        0         0           0            Коля объебался  Er
# 111  0        29        251         1            40              180
# 112  0        13        167         1            68              175
# 113  0        29        1           1            82              160
# 114  0        13        272         0            59              170
# 115  0        24        1           1            57              165
# 116  0        13        424         1            81              168
# 117  0        9         0           0            85              175
# 118  0        13        424         1            51              174
# 119  0        13        1           1            33              150
# 120  0        12        350         1            81              165
# 121  1        11        41          0            69              160
# 122  0        1         1           1            53              175
# 123  0        13        485         1            41              165
# 124  0        9         291         0            82              180
# 125  0        9         350         0            78              150
# 126  0        152       300         0            83              145
# 127  0        16        221         1            75              170
# 128  0        1         276         1            16              170
# 129  0        11        351         1            10              147
# 130  1        6         0           0            7               110
# 131  5        18        1           1            14              174
# 132  0        7         0           0            12              120
# 133  0        17        1           1            16              150
# 134  1        17        542         1            13              147
# 135  0        2         114         13           81              190
# 136  2        0         0           0            Коля объебался  Er
# 137  1        2         0           0            16              170
# 138  0        2         229         1            7               110
# 139  0        1         0           0            29              175
# 140  0        0         0           0            62              170
# 141  0        1         46          1            40              Er
# 142  0        6         1           0            81              Er
# 143  0        5         396         1            84              160
# 144  0        1         45          0            79              Er
# 145  0        1         373         1            69              Er
# 146  0        1         2           1            31              165
# 147  0        5         38          0            40              165
# 148  0        5         28          1            50              182
# 149  2        6         0           0            9               123
# 150  2        5         1           1            14              150
# 151  0        5         580         1            38              165
# 152  0        6         2           1            29              160
# 153  0        1         50          0            52              Er
# 154  0        6         1           0            37              170
# 155  0        1         472         1            37              165
# 156  0        1         490         1            90              Er
# 157  0        1         0           0            52              170
# 158  1        1         0           0            Коля объебался  Er
# 159  0        1         3           0            15              Er
# 160  0        1         114         0            22              Er
# 161  0        16        34          24           14              150
# 162  2        0         0           0            Коля объебался  Er
# 163  0        1         316         1            80              Er
# 164  0        57        418         1            Коля объебался  Er
# 165  0        18        53          0            Коля объебался  Er
# 166  0        1         0           0            54              165
# 167  0        27        9           0            10              Er
# 168  0        56        1023        1            17              145
# 169  0        31        581         32           8               120
# 170  0        69        35          0            30              164
# 171  0        4         1           0            Коля объебался  180
# 172  0        0         0           0            Коля объебался  Er
# 173  0        1         0           0            44              180
# 174  0        42        14          0            26              158
# 175  0        1         0           0            31              170
# 176  0        1         0           0            8               180
# 177  0        111       67          0            39              185
# 178  0        26        67          19           3               Er
# 179  0        0         0           0            54              Er
# 180  0        0         0           0            Коля объебался  Er
# 181  0        0         0           0            60              190
# 182  0        1         0           0            3               Er
# 183  0        1         0           0            49              158
# 184  0        33        25          0            32              197
# 185  0        105       35          0            57              Er
# 186  0        60        35          0            66              Er
# 187  0        84        66          2            32              170
# 188  2        0         0           0            Коля объебался  Er
# 189  0        96        26          40           16              Er
# 190  0        0         0           0            18              164
# 191  0        4         13          0            55              175
# 192  0        1         0           0            26              195
# 193  0        0         0           0            30              Er
# 194  0        0         0           0            58              Er
# 195  0        0         0           0            39              163
# 196  0        4         0           0            49              176
# 197  0        4         1           0            47              160
# 198  0        28        28          12           43              185
# 199  1        2         0           0            35              Er
# 200  0        1         1           0            30              180
# 201  0        1         0           0            31              170
# 202  0        6         9           0            15              165
# 203  0        1         0           0            14              172
# 204  0        4         1           1            14              Er
# 205  0        1         0           0            39              180
# 206  1        1         0           0            19              155
# 207  2        0         0           0            Коля объебался  Er
# 208  0        1         0           0            36              165
# 209  0        1         0           0            54              174
# 210  0        1         0           0            35              180
# 211  0        1         0           0            84              170
# 212  0        1         0           0            39              167
# 213  0        1         0           0            73              170
# 214  0        1         0           0            39              186
# 215  0        1         0           0            12              160
# 216  0        1         0           0            14              165
# 217  0        2         0           0            84              165
# 218  0        1         0           0            46              170
# 219  0        11        0           0            80              165
# 220  0        1         0           0            40              170
# 221  0        1         0           0            60              178
# 222  0        1         0           0            23              175
# 223  0        23        0           0            81              155
# 224  0        1         0           0            25              180
# 225  1        12        0           0            39              186
# 226  0        1         0           0            67              175
# 227  2        0         0           0            Коля объебался  Er
# 228  0        1         0           0            Коля объебался  Er
# 229  0        4         0           0            25              Er
# 230  0        4         0           0            18              175
# 231  0        4         70          0            44              180
# 232  0        25        82          0            42              Er
# 233  0        84        70          11           90              150
# 234  0        84        111         0            84              155
# 235  0        60        0           20           36              Er
# 236  0        66        43          20           29              169
# 237  0        43        128         2            34              Er
# 238  0        96        104         13           31              Er
# 239  0        60        48          20           78              165
# 240  0        4         0           0            31              165
# 241  0        54        116         0            66              180
# 242  0        7         0           16           55              170
# 243  0        42        0           14           24              175
# 244  0        63        106         24           25              170
# 245  0        18        76          15           67              167
# 246  0        1         0           10           24              170
# 247  0        10        0           13           46              180
# 248  0        30        0           10           78              165
# 249  0        30        211         10           40              172
# 250  0        78        0           26           27              185
# 251  0        7         3           5            88              155
# 252  0        1         0           0            42              165
# 253  2        0         0           0            Коля объебался  Er
# 254  0        1         66          29           19              160
# 255  0        7         0           0            77              165
# 256  0        86        19          17           66              160
# 257  0        1         0           17           80              Er
# 258  0        13        0           13           78              170
# 259  0        10        0           0            38              172
# 260  0        0         0           10           68              Er
# 261  0        0         0           0            41              Er
# 262  0        7         0           10           49              168
# 263  0        27        0           9            9               Er
# 264  0        6         0           0            27              170
# 265  0        7         0           12           80              Er
# 266  0        4         0           11           28              175
# 267  0        1         0           0            02              Er
# 268  0        2         56          14           18              135
# 269  0        1         0           0            13              165
# 270  0        1         7           11           Коля объебался  Er
# 271  0        6         0           0            06              185
# 272  0        1         0           0            82              168
# 273  0        0         0           0            26              176
# 274  0        0         0           0            31              156
# 275  0        96        31          0            14              Er
# 276  0        1         0           0            16              157
# 277  0        1         0           0            13              172
# 278  0        1         0           0            22              160
# 279  2        0         0           0            Коля объебался  Er
# 280  2        20        5           0            9               134
# 281  0        0         0           0            Коля объебался  Er
# 282  0        1         1           0            37              175
# 283  0        2         0           0            49              155
# 284  0        1         0           0            25              180
# 285  0        2         0           0            23              170
# 286  0        1         0           0            42              Er
# 287  2        0         0           0            Коля объебался  Er
# 288  0        19        3           1            32              162
# 289  0        8         1           1            20              160
# 290  0        2         0           0            81              175
# 291  1        19        0           0            7               115
# 292  0        1         0           0            76              160
# 293  0        1         0           0            71              Er
# 294  0        1         0           0            12              167
# 295  2        1         1           0            54              165
# 296  0        1         0           0            76              170
# 297  0        1         0           0            78              174
# 298  0        1         0           0            85              155
# 299  0        1         1           0            65              160
# 300  0        1         0           0            81              167
# 301  0        1         0           0            86              Er
# 302  0        1         0           0            11              140
# 303  0        1         1           0            4               Er
# 304  0        4         0           0            75              150
# 305  1        10        0           0            86              170
# 306  0        8         0           0            70              175
# 307  0        1         0           0            75              183
# 308  0        1         0           0            77              158
# 309  0        2         0           0            79              160
# 310  1        122       41          0            58              165
# 311  0        1         0           0            63              170
# 312  5        4         3           0            70              165
# 313  2        0         0           0            Коля объебался  Er
# 314  1        16        1           1            16              165
# 315  0        18        23          24           57              160
# 316  0        10        26          0            87              170
# 317  0        9         2           1            78              163
# 318  0        13        1           1            61              160
# 319  0        19        1           1            24              165
# 320  4        432       44          9            10              120
# 321  0        16        1           1            59              165
# 322  0        12        1           1            80              160
# 323  0        9         0           0            70              180
# 324  0        0         0           0            73              160
# 325  0        13        1           1            60              155
# 326  0        19        1           1            64              155
# 327  0        16        1           1            76              156
# 328  0        13        1           1            52              172
# 329  0        19        1           1            69              165
# 330  0        1         0           0            23              163
# 331  0        18        1           1            65              182
# 332  0        9         0           0            66              160
# 333  0        19        71          1            45              165
# 334  0        4         18          10           34              160
# 335  0        18        1           1            45              172
# 336  0        16        31          1            39              170
# 337  0        9         79          6            72              182
# 338  0        15        54          1            24              175
# 339  2        0         0           0            Коля объебался  Er
# 340  0        0         0           0            36              170
# 341  0        1         0           0            47              165
# 342  0        1         0           0            62              164
# 343  0        1         0           0            Коля объебался  170
# 344  0        2         0           0            71              170
# 345  0        5         0           0            49              175
# 346  0        0         0           0            18              170
# 347  0        1         0           0            11              155
# 348  0        1         0           0            75              180
# 349  0        1         0           0            3               Er
# 350  0        2         0           0            45              168
# 351  0        1         0           0            25              Er
# 352  0        1         0           0            65              180
# 353  0        1         0           0            81              180
# 354  0        1         0           0            66              170
# 355  0        1         0           0            31              170
# 356  0        2         0           0            66              160
# 357  0        1         0           0            27              176
# 358  0        1         0           0            64              160
# 359  0        1         0           0            27              180
# 360  0        1         0           0            34              174
# 361  0        1         0           0            41              175
# 362  0        2         0           0            78              170
# 363  0        1         0           0            15              170
# 364  0        8         0           0            72              160
# 365  2        0         0           0            Коля объебался  Er
# 366  0        1         0           0            Коля объебался  Er
# 367  0        6         115         37           9               130
# 368  0        105       165         2            94              180
# 369  0        60        20          0            59              175
# 370  0        21        35          12           Коля объебался  Er
# 371  0        1         0           0            51              170
# 372  0        1         0           0            54              170
# 373  0        78        0           26           54              170
# 374  0        12        26          20           69              165
# 375  0        9         26          20           79              150
# 376  0        1         0           0            20              150
# 377  0        1         128         0            25              159
# 378  0        1         0           0            17              160
# 379  0        94        546         0            13              150
# 380  0        1         0           0            19              167
# 381  0        1         0           0            92              165
# 382  0        1         0           0            23              165
# 383  0        58        49          0            70              155
# 384  0        1         0           0            16              160
# 385  0        40        183         0            56              155
# 386  0        1         0           0            45              177
# 387  0        24        1985        0            6               110
# 388  0        1         0           0            87              162
# 389  0        1         0           0            18              165
# 390  0        79        71          0            20              170
# 391  2        0         0           0            Коля объебался  Er
# 392  0        1         0           0            46              173
# 393  0        1         0           0            49              170
# 394  0        1         0           0            15              173
# 395  1        11        67          0            3               Er
# 396  0        1         0           0            13              160
# 397  0        1         0           0            65              176
# 398  0        1         0           0            47              160
# 399  0        2         0           0            17              172
#
#             Мед. Состояние          Фото Посты Гендер(Slava) Состояние(Slava)  \
# 0    здоров                 отсутствует   1     Er            Не указано
# 1    требуется мед. помощь  присутствует  5     Er            живой
# 2    здоров                 присутствует  6     Мужчина       живой
# 3    здоров                 присутствует  2     Мужчина       мертвый
# 4    здоров                 присутствует  2     Мужчина       ищется
# 5    здоров                 присутствует  3     Мужчина       живой
# 6    здоров                 присутствует  3     Мужчина       ищется
# 7    здоров                 присутствует  2     Женщина       живой
# 8    здоров                 присутствует  4     Мужчина       ищется
# 9    здоров                 присутствует  4     Женщина       мертвый
# 10   здоров                 отсутствует   2     Женщина       ищется
# 11   здоров                 присутствует  2     Мужчина       мертвый
# 12   здоров                 присутствует  3     Мужчина       мертвый
# 13   здоров                 присутствует  4     Женщина       мертвый
# 14   здоров                 присутствует  6     Мужчина       мертвый
# 15   здоров                 присутствует  2     Женщина       живой
# 16   здоров                 присутствует  2     Мужчина       живой
# 17   здоров                 присутствует  3     Мужчина       живой
# 18   здоров                 присутствует  3     Мужчина       живой
# 19   здоров                 присутствует  3     Мужчина       живой
# 20   здоров                 присутствует  18    Мужчина       живой
# 21   здоров                 присутствует  7     Мужчина       живой
# 22   здоров                 присутствует  4     Мужчина       мертвый
# 23   здоров                 присутствует  1     Мужчина       ищется
# 24   здоров                 присутствует  4     Женщина       мертвый
# 25   здоров                 присутствует  2     Мужчина       ищется
# 26   здоров                 отсутствует   1     Er            Не указано
# 27   здоров                 присутствует  2     Женщина       живой
# 28   здоров                 отсутствует   1     Er            Не указано
# 29   здоров                 присутствует  134   Er            Не указано
# 30   здоров                 отсутствует   12    Er            Не указано
# 31   здоров                 присутствует  860   Er            Не указано
# 32   здоров                 отсутствует   1     Er            Не указано
# 33   здоров                 отсутствует   2     Er            живой
# 34   здоров                 отсутствует   9     Женщина       ищется
# 35   здоров                 отсутствует   9     Мужчина       ищется
# 36   требуется мед. помощь  отсутствует   8     Er            живой
# 37   здоров                 отсутствует   6     Мужчина       живой
# 38   здоров                 присутствует  10    Женщина       мертвый
# 39   требуется мед. помощь  отсутствует   4     Мужчина       ищется
# 40   здоров                 отсутствует   7     Мужчина       живой
# 41   здоров                 отсутствует   1     Мужчина       ищется
# 42   здоров                 отсутствует   4     Женщина       живой
# 43   здоров                 отсутствует   3     Er            живой
# 44   здоров                 отсутствует   2     Мужчина       живой
# 45   здоров                 отсутствует   4     Женщина       ищется
# 46   требуется мед. помощь  отсутствует   4     Er            живой
# 47   здоров                 отсутствует   2     Мужчина       ищется
# 48   здоров                 отсутствует   2     Er            живой
# 49   здоров                 отсутствует   14    Женщина       мертвый
# 50   здоров                 отсутствует   1     Мужчина       живой
# 51   здоров                 отсутствует   7     Женщина       мертвый
# 52   требуется мед. помощь  отсутствует   19    Женщина       живой
# 53   здоров                 отсутствует   4     Женщина       мертвый
# 54   здоров                 отсутствует   2     Er            мертвый
# 55   требуется мед. помощь  отсутствует   5     Er            живой
# 56   здоров                 отсутствует   1     Женщина       ищется
# 57   здоров                 отсутствует   5     Мужчина       живой
# 58   здоров                 отсутствует   1     Er            Не указано
# 59   здоров                 отсутствует   4     Мужчина       мертвый
# 60   требуется мед. помощь  отсутствует   5     Женщина       живой
# 61   здоров                 отсутствует   2     Мужчина       ищется
# 62   здоров                 отсутствует   7     Мужчина       живой
# 63   здоров                 присутствует  27    Женщина       мертвый
# 64   здоров                 отсутствует   4     Женщина       мертвый
# 65   здоров                 отсутствует   7     Мужчина       мертвый
# 66   здоров                 отсутствует   4     Женщина       ищется
# 67   здоров                 присутствует  3     Мужчина       живой
# 68   здоров                 отсутствует   4     Er            мертвый
# 69   здоров                 отсутствует   2     Мужчина       живой
# 70   требуется мед. помощь  отсутствует   1     Женщина       ищется
# 71   здоров                 отсутствует   1     Мужчина       ищется
# 72   здоров                 отсутствует   4     Женщина       живой
# 73   здоров                 отсутствует   8     Мужчина       мертвый
# 74   здоров                 отсутствует   3     Мужчина       ищется
# 75   здоров                 отсутствует   12    Женщина       живой
# 76   требуется мед. помощь  отсутствует   9     Мужчина       живой
# 77   здоров                 отсутствует   5     Мужчина       мертвый
# 78   здоров                 отсутствует   4     Мужчина       мертвый
# 79   здоров                 отсутствует   26    Мужчина       живой
# 80   здоров                 отсутствует   2     Мужчина       ищется
# 81   требуется мед. помощь  отсутствует   18    Мужчина       ищется
# 82   требуется мед. помощь  отсутствует   32    Женщина       живой
# 83   здоров                 отсутствует   4     Мужчина       мертвый
# 84   здоров                 отсутствует   1     Er            Не указано
# 85   здоров                 отсутствует   3     Мужчина       ищется
# 86   здоров                 отсутствует   23    Женщина       мертвый
# 87   здоров                 присутствует  1     Мужчина       живой
# 88   здоров                 отсутствует   4     Мужчина       мертвый
# 89   здоров                 отсутствует   11    Мужчина       живой
# 90   здоров                 отсутствует   3     Мужчина       ищется
# 91   здоров                 отсутствует   2     Мужчина       ищется
# 92   здоров                 присутствует  12    Мужчина       живой
# 93   здоров                 отсутствует   9     Женщина       живой
# 94   здоров                 отсутствует   7     Мужчина       живой
# 95   здоров                 присутствует  6     Мужчина       ищется
# 96   здоров                 отсутствует   7     Женщина       живой
# 97   здоров                 присутствует  6     Женщина       мертвый
# 98   здоров                 отсутствует   13    Мужчина       живой
# 99   требуется мед. помощь  отсутствует   13    Мужчина       живой
# 100  здоров                 отсутствует   3     Мужчина       живой
# 101  здоров                 отсутствует   16    Мужчина       мертвый
# 102  здоров                 отсутствует   5     Мужчина       мертвый
# 103  здоров                 отсутствует   3     Мужчина       мертвый
# 104  здоров                 отсутствует   3     Мужчина       живой
# 105  здоров                 отсутствует   2     Мужчина       ищется
# 106  здоров                 отсутствует   2     Мужчина       ищется
# 107  здоров                 отсутствует   5     Мужчина       живой
# 108  здоров                 отсутствует   3     Мужчина       живой
# 109  здоров                 отсутствует   4     Мужчина       живой
# 110  здоров                 отсутствует   1     Er            Не указано
# 111  здоров                 отсутствует   8     Мужчина       живой
# 112  здоров                 отсутствует   7     Мужчина       ищется
# 113  здоров                 отсутствует   2     Er            Не указано
# 114  здоров                 отсутствует   9     Мужчина       живой
# 115  здоров                 отсутствует   3     Мужчина       ищется
# 116  здоров                 отсутствует   19    Мужчина       живой
# 117  здоров                 отсутствует   4     Мужчина       живой
# 118  здоров                 отсутствует   12    Мужчина       ищется
# 119  здоров                 отсутствует   4     Женщина       живой
# 120  здоров                 отсутствует   12    Мужчина       ищется
# 121  здоров                 отсутствует   14    Мужчина       живой
# 122  здоров                 отсутствует   3     Мужчина       ищется
# 123  здоров                 отсутствует   13    Женщина       ищется
# 124  здоров                 отсутствует   14    Мужчина       ищется
# 125  здоров                 отсутствует   14    Женщина       живой
# 126  здоров                 присутствует  10    Женщина       живой
# 127  здоров                 присутствует  8     Мужчина       живой
# 128  здоров                 отсутствует   16    Мужчина       живой
# 129  здоров                 отсутствует   19    Мужчина       живой
# 130  здоров                 отсутствует   4     Мужчина       живой
# 131  здоров                 отсутствует   17    Мужчина       мертвый
# 132  здоров                 отсутствует   8     Мужчина       живой
# 133  здоров                 отсутствует   4     Мужчина       живой
# 134  требуется мед. помощь  отсутствует   22    Женщина       живой
# 135  требуется мед. помощь  отсутствует   14    Мужчина       живой
# 136  здоров                 отсутствует   1     Er            Не указано
# 137  здоров                 отсутствует   11    Мужчина       живой
# 138  здоров                 отсутствует   19    Женщина       мертвый
# 139  здоров                 отсутствует   17    Мужчина       мертвый
# 140  здоров                 отсутствует   1     Мужчина       ищется
# 141  здоров                 отсутствует   7     Мужчина       ищется
# 142  здоров                 отсутствует   17    Женщина       ищется
# 143  здоров                 отсутствует   23    Женщина       ищется
# 144  здоров                 отсутствует   6     Мужчина       ищется
# 145  здоров                 отсутствует   19    Мужчина       ищется
# 146  здоров                 отсутствует   8     Мужчина       ищется
# 147  здоров                 отсутствует   7     Мужчина       ищется
# 148  здоров                 отсутствует   7     Мужчина       ищется
# 149  здоров                 отсутствует   10    Мужчина       живой
# 150  здоров                 отсутствует   18    Мужчина       живой
# 151  здоров                 отсутствует   20    Мужчина       живой
# 152  здоров                 отсутствует   4     Мужчина       ищется
# 153  требуется мед. помощь  отсутствует   7     Мужчина       живой
# 154  здоров                 отсутствует   3     Женщина       живой
# 155  здоров                 отсутствует   20    Женщина       живой
# 156  здоров                 отсутствует   19    Женщина       живой
# 157  требуется мед. помощь  отсутствует   2     Мужчина       живой
# 158  здоров                 отсутствует   10    Мужчина       живой
# 159  здоров                 отсутствует   4     Мужчина       живой
# 160  здоров                 отсутствует   7     Мужчина       живой
# 161  здоров                 отсутствует   8     Женщина       мертвый
# 162  здоров                 отсутствует   1     Er            Не указано
# 163  здоров                 отсутствует   15    Мужчина       живой
# 164  здоров                 отсутствует   20    Женщина       живой
# 165  здоров                 отсутствует   6     Er            Не указано
# 166  здоров                 отсутствует   3     Мужчина       живой
# 167  здоров                 отсутствует   5     Мужчина       живой
# 168  здоров                 отсутствует   14    Женщина       живой
# 169  здоров                 отсутствует   20    Женщина       ищется
# 170  здоров                 присутствует  4     Женщина       ищется
# 171  здоров                 отсутствует   2     Мужчина       ищется
# 172  здоров                 отсутствует   1     Er            Не указано
# 173  здоров                 присутствует  3     Мужчина       мертвый
# 174  здоров                 присутствует  3     Er            живой
# 175  здоров                 присутствует  2     Женщина       живой
# 176  здоров                 присутствует  3     Мужчина       живой
# 177  здоров                 присутствует  4     Er            живой
# 178  здоров                 отсутствует   7     Er            Не указано
# 179  здоров                 присутствует  1     Er            Не указано
# 180  здоров                 отсутствует   1     Мужчина       ищется
# 181  здоров                 присутствует  1     Мужчина       ищется
# 182  здоров                 присутствует  2     Женщина       ищется
# 183  здоров                 присутствует  2     Женщина       живой
# 184  здоров                 отсутствует   4     Мужчина       мертвый
# 185  здоров                 присутствует  3     Женщина       живой
# 186  здоров                 отсутствует   3     Er            Не указано
# 187  здоров                 отсутствует   6     Женщина       ищется
# 188  здоров                 отсутствует   1     Er            Не указано
# 189  здоров                 присутствует  4     Мужчина       мертвый
# 190  здоров                 присутствует  1     Er            живой
# 191  здоров                 присутствует  3     Мужчина       мертвый
# 192  здоров                 отсутствует   4     Мужчина       живой
# 193  здоров                 присутствует  1     Мужчина       ищется
# 194  здоров                 отсутствует   1     Er            Не указано
# 195  здоров                 присутствует  1     Женщина       ищется
# 196  здоров                 присутствует  5     Er            живой
# 197  здоров                 присутствует  3     Женщина       мертвый
# 198  здоров                 присутствует  5     Мужчина       ищется
# 199  здоров                 отсутствует   2     Мужчина       живой
# ...
# 19   0                 0
# 20   0                 0
# 21   0                 0
# 22   0                 0
# 23   0                 0
# 24   0                 0
# 25   0                 0
# 26   0                 0
# 27   0                 0
# 28   0                 0
# 29   0                 0
# 30   0                 0
# 31   0                 0
# 32   0                 0
# 33   0                 0
# 34   0                 0
# 35   0                 0
# 36   0                 0
# 37   0                 0
# 38   17-апр-19  13:14  17-апр-19  16:55
# 39   0                 0
# 40   0                 0
# 41   0                 0
# 42   0                 0
# 43   0                 0
# 44   0                 0
# 45   0                 0
# 46   0                 0
# 47   0                 0
# 48   0                 0
# 49   0                 0
# 50   0                 0
# 51   0                 0
# 52   0                 0
# 53   0                 0
# 54   0                 0
# 55   23-май-19  13:17  23-май-19  14:33
# 56   0                 0
# 57   0                 0
# 58   0                 0
# 59   0                 0
# 60   0                 0
# 61   0                 0
# 62   0                 0
# 63   0                 0
# 64   0                 0
# 65   0                 0
# 66   0                 0
# 67   0                 0
# 68   0                 0
# 69   0                 0
# 70   0                 0
# 71   0                 0
# 72   0                 0
# 73   0                 0
# 74   0                 0
# 75   0                 0
# 76   0                 0
# 77   0                 0
# 78   0                 0
# 79   0                 0
# 80   0                 0
# 81   0                 0
# 82   0                 0
# 83   0                 0
# 84   0                 0
# 85   0                 0
# 86   0                 0
# 87   0                 0
# 88   0                 0
# 89   0                 0
# 90   0                 0
# 91   0                 0
# 92   0                 0
# 93   0                 0
# 94   0                 0
# 95   0                 0
# 96   0                 0
# 97   0                 0
# 98   0                 0
# 99   0                 0
# 100  0                 0
# 101  0                 0
# 102  0                 0
# 103  0                 0
# 104  0                 0
# 105  0                 0
# 106  0                 0
# 107  0                 0
# 108  0                 0
# 109  0                 0
# 110  0                 0
# 111  0                 0
# 112  0                 0
# 113  0                 0
# 114  0                 0
# 115  0                 0
# 116  0                 0
# 117  0                 0
# 118  0                 0
# 119  0                 0
# 120  0                 0
# 121  0                 0
# 122  0                 0
# 123  0                 0
# 124  0                 0
# 125  0                 0
# 126  0                 0
# 127  0                 0
# 128  0                 0
# 129  0                 0
# 130  0                 0
# 131  0                 0
# 132  0                 0
# 133  0                 0
# 134  0                 0
# 135  0                 0
# 136  0                 0
# 137  0                 0
# 138  0                 0
# 139  0                 0
# 140  0                 0
# 141  0                 0
# 142  0                 0
# 143  0                 0
# 144  0                 0
# 145  0                 0
# 146  0                 0
# 147  0                 0
# 148  0                 0
# 149  0                 0
# 150  0                 0
# 151  0                 0
# 152  0                 0
# 153  0                 0
# 154  0                 0
# 155  0                 0
# 156  0                 0
# 157  0                 0
# 158  0                 0
# 159  0                 0
# 160  0                 0
# 161  0                 0
# 162  0                 0
# 163  0                 0
# 164  0                 0
# 165  0                 0
# 166  0                 0
# 167  0                 0
# 168  0                 0
# 169  0                 0
# 170  0                 0
# 171  0                 0
# 172  0                 0
# 173  0                 0
# 174  0                 0
# 175  0                 0
# 176  0                 0
# 177  0                 0
# 178  0                 0
# 179  0                 0
# 180  0                 0
# 181  0                 0
# 182  0                 0
# 183  0                 0
# 184  0                 0
# 185  0                 0
# 186  0                 0
# 187  0                 0
# 188  0                 0
# 189  0                 0
# 190  0                 0
# 191  0                 0
# 192  0                 0
# 193  0                 0
# 194  0                 0
# 195  0                 0
# 196  0                 0
# 197  0                 0
# 198  0                 0
# 199  0                 0
# 200  0                 0
# 201  0                 0
# 202  0                 0
# 203  0                 0
# 204  0                 0
# 205  0                 0
# 206  0                 0
# 207  0                 0
# 208  0                 0
# 209  0                 0
# 210  0                 0
# 211  0                 0
# 212  0                 0
# 213  0                 0
# 214  0                 0
# 215  0                 0
# 216  0                 0
# 217  0                 0
# 218  0                 0
# 219  0                 0
# 220  0                 0
# 221  0                 0
# 222  0                 0
# 223  0                 0
# 224  0                 0
# 225  0                 0
# 226  0                 0
# 227  0                 0
# 228  0                 0
# 229  0                 0
# 230  0                 0
# 231  0                 0
# 232  0                 0
# 233  0                 0
# 234  0                 0
# 235  0                 0
# 236  0                 0
# 237  0                 0
# 238  0                 0
# 239  0                 0
# 240  0                 0
# 241  0                 0
# 242  0                 0
# 243  0                 0
# 244  0                 0
# 245  0                 0
# 246  0                 0
# 247  0                 0
# 248  0                 0
# 249  0                 0
# 250  0                 0
# 251  0                 0
# 252  0                 0
# 253  0                 0
# 254  0                 0
# 255  0                 0
# 256  0                 0
# 257  0                 0
# 258  0                 0
# 259  0                 0
# 260  0                 0
# 261  0                 0
# 262  0                 0
# 263  0                 0
# 264  0                 0
# 265  0                 0
# 266  0                 0
# 267  0                 0
# 268  0                 0
# 269  0                 0
# 270  0                 0
# 271  0                 0
# 272  0                 0
# 273  0                 0
# 274  0                 0
# 275  0                 0
# 276  0                 0
# 277  0                 0
# 278  0                 0
# 279  0                 0
# 280  0                 0
# 281  0                 0
# 282  0                 0
# 283  0                 0
# 284  0                 0
# 285  0                 0
# 286  0                 0
# 287  0                 0
# 288  0                 0
# 289  0                 0
# 290  0                 0
# 291  0                 0
# 292  0                 0
# 293  0                 0
# 294  0                 0
# 295  0                 0
# 296  0                 0
# 297  0                 0
# 298  0                 0
# 299  0                 0
# 300  0                 0
# 301  0                 0
# 302  0                 0
# 303  0                 0
# 304  0                 0
# 305  0                 0
# 306  0                 0
# 307  0                 0
# 308  0                 0
# 309  0                 0
# 310  0                 0
# 311  0                 0
# 312  0                 0
# 313  0                 0
# 314  0                 0
# 315  0                 0
# 316  0                 0
# 317  0                 0
# 318  0                 0
# 319  0                 0
# 320  12-май-19  19:25  13-май-19 00:06
# 321  0                 0
# 322  0                 0
# 323  0                 0
# 324  0                 0
# 325  0                 0
# 326  0                 0
# 327  0                 0
# 328  0                 0
# 329  0                 0
# 330  0                 0
# 331  0                 0
# 332  0                 0
# 333  0                 0
# 334  0                 0
# 335  0                 0
# 336  0                 0
# 337  0                 0
# 338  0                 0
# 339  0                 0
# 340  0                 0
# 341  0                 0
# 342  0                 0
# 343  0                 0
# 344  0                 0
# 345  0                 0
# 346  0                 0
# 347  0                 0
# 348  0                 0
# 349  0                 0
# 350  0                 0
# 351  0                 0
# 352  0                 0
# 353  0                 0
# 354  0                 0
# 355  0                 0
# 356  0                 0
# 357  0                 0
# 358  0                 0
# 359  0                 0
# 360  0                 0
# 361  0                 0
# 362  0                 0
# 363  0                 0
# 364  0                 0
# 365  0                 0
# 366  0                 0
# 367  0                 0
# 368  0                 0
# 369  0                 0
# 370  0                 0
# 371  0                 0
# 372  0                 0
# 373  0                 0
# 374  0                 0
# 375  0                 0
# 376  0                 0
# 377  0                 0
# 378  0                 0
# 379  0                 0
# 380  0                 0
# 381  0                 0
# 382  0                 0
# 383  0                 0
# 384  0                 0
# 385  0                 0
# 386  0                 0
# 387  0                 0
# 388  0                 0
# 389  0                 0
# 390  0                 0
# 391  0                 0
# 392  0                 0
# 393  0                 0
# 394  0                 0
# 395  0                 0
# 396  0                 0
# 397  0                 0
# 398  0                 0
# 399  0                 0

# %%
#df1["Цвет волос"]

# %%
len(df1["Время поиска"][df1["Время поиска"] == "Ошибка"])/ len(df1["Время поиска"])
# Out:
# 0.8320802005012531

# %%
list_of_coor
# Out:
# ['no cord',
#  '14:00 23.05',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '303-9011, 8-964',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '44.798627, 38.637727',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '45.024527, 38.974713',
#  '46,185300, 39,436079',
#  'no cord',
#  '7 988 474-97',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '44.731529, 37.741134',
#  'no cord',
#  '45.456156, 39.445658',
#  'no cord',
#  'no cord',
#  '45.227154, 38.999370',
#  'no cord',
#  '45.087765, 38.980757',
#  '44,5463990, 38,2235640',
#  '45.299099, 39.932770',
#  'no cord',
#  'no cord',
#  'no cord',
#  '44.923438, 37.983729',
#  'no cord',
#  'no cord',
#  'no cord',
#  '7 918 936-75',
#  'no cord',
#  'no cord',
#  '45.220209, 39.226760',
#  'no cord',
#  'no cord',
#  'no cord',
#  '45.032980, 38.997061',
#  'no cord',
#  '46.039774, 38.193887',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '45.290280, 39.556061',
#  '7 918 259-59',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '11.18 23:00',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '7 988 144-69',
#  '44.818409, 37.934841',
#  'no cord',
#  'no cord',
#  '04.18 8:54',
#  '23.03 10:06',
#  'no cord',
#  '8918 6011160',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '44.748184, 39.006432',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '8 800 700 54',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '89-29, 8-985',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '8 928 844 22',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '10/17, 12.02',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '45.272083, 33.089038',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '8 90 444 600',
#  '8928 11 00 935',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '8 928 11 00',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '8 90 444 600',
#  'no cord',
#  'no cord',
#  'no cord',
#  '8 90 444 600',
#  '3.00 04.03',
#  'no cord',
#  'no cord',
#  'no cord',
#  '8928 11 00 935',
#  'no cord',
#  'no cord',
#  '8 90 444 600',
#  'no cord',
#  '8 928 11 00',
#  '8 90 444 600',
#  '8 90 444 600',
#  'no cord',
#  '8-928 11 00',
#  'no cord',
#  '8928 11 00 935',
#  '8 90 444 600',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '407 21 42',
#  'no cord',
#  '8 90 444 600',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '18:30 17.09',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '14:45 05.02',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '29.05, 30.05',
#  'no cord',
#  '7 928 278-93',
#  '45.026527, 38.963015',
#  '7 918 932-73',
#  'no cord',
#  'no cord',
#  '44.175571, 40.619266',
#  '7 988 474-97',
#  '43.585636, 39.725936',
#  '45.056715, 39.010159',
#  'no cord',
#  '7 989 283-42',
#  'no cord',
#  '7 918 932-73',
#  '7 989 812-11',
#  'no cord',
#  'no cord',
#  'no cord',
#  '45.033369, 39.002047',
#  'no cord',
#  'no cord',
#  '45.151649, 41.121476',
#  'no cord',
#  '45.006367, 39.016321',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '8 928 11 00',
#  'no cord',
#  'no cord',
#  'no cord',
#  '8928 11 00 935',
#  '8905 42 64 932',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord',
#  '7 938 133 07',
#  'no cord',
#  '7 918 576-86',
#  'no cord',
#  'no cord',
#  'no cord',
#  'no cord']

# %% [markdown]
# Пока дальше не нужно смотреть ( Славе)

# %%
df1.shape
# Out:
# (399, 23)

# %%
df1.to_excel("sumTableSouthRegion.xlsx")

# %%
count = 0
for element in  df1["Телосложение"][:19]:
    if element == "Не указано":
        count += 1
count/len(df1["Телосложение"][:19])
# Out:
# 0.10526315789473684

# %% [markdown]
# TRY EXCEL

# %%
filename = "post7.csv"
f = open(filename, "w")
headers = "age1, height, posts\n"
f.write(headers)
# Out:
# 20

# %% [markdown]
# Так, осталось выпарсить (хотя бы ублюдочно):
# 1) время пропажи
# 2) телосложение
# 3) цвет глаз
# 4) волосы
# 5) одежда???
#
# А сейчас PPPPANDA, PPPAND, PPPPPPPANDA:

# %%
# PAAAANDA, PPPPANDA, LADDDNO (c) illumate & obladaet
