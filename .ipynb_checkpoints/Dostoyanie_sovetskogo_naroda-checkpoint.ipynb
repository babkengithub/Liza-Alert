# %%
import numpy as np
import pandas as pd
import re
import bs4
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
from scrapy import Selector
from nltk import word_tokenize
import nltk
nltk.download('punkt') #winlocker
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# ДЛЯ КОЛИ!!!!!!!!!!!!!!!!!!!!!
import requests
#ssylka = 'https://lizaalert.org/forum/viewforum.php?f=182'
ssylka = 'https://lizaalert.org/forum/viewforum.php?f=184'
html1 = requests.get(ssylka).content #url='google.com'
sel1 = Selector(text=html1)
course_as11 = sel1.xpath('//a[contains(@class,"forumtitle")]')
print(course_as11)
hrefs11_from_css = course_as11.css('::attr(href)')
print(hrefs11_from_css.extract())
hrefz = list()
#print("\"https://lizaalert.org/forum" + str(hrefs11_from_css.extract()[4])[1:] + "\"")
for i in range(len(hrefs11_from_css.extract())):
    clean_link1 = "https://lizaalert.org/forum" + str(hrefs11_from_css.extract()[i])[1:]
    hrefz.append(clean_link1)
#for i in hrefs11_from_css.extract():
 #   hrefs11_from_css.extract()[i] = "\"https://lizaalert.org/forum" + str(hrefs11_from_css.extract()[i])[1:] + "\""
print(len(hrefz))
# Out:
# [<Selector xpath='//a[contains(@class,"forumtitle")]' data='<a href="./viewforum.php?f=292&amp;sid=2'>, <Selector xpath='//a[contains(@class,"forumtitle")]' data='<a href="./viewforum.php?f=173&amp;sid=2'>, <Selector xpath='//a[contains(@class,"forumtitle")]' data='<a href="./viewforum.php?f=291&amp;sid=2'>]
# ['./viewforum.php?f=292&sid=28a0b6d45787ce2347d8d94d58587c9b', './viewforum.php?f=173&sid=28a0b6d45787ce2347d8d94d58587c9b', './viewforum.php?f=291&sid=28a0b6d45787ce2347d8d94d58587c9b']
# 3

# %%
# Import requests
import requests

list_of_all_pages = list()
# Create the string html containing the HTML source
for i in range(len(hrefz)):
    html = requests.get(hrefz[i]).content #url='google.com'

    # Create the Selector object sel from html
    sel = Selector(text=html)


    uClient = uReq(hrefz[i])
    page_html = uClient.read()
    uClient.close()
    page_soup = soup(page_html, "html.parser")
    containers2 = page_soup.findAll("div", {"class":"pagination"})
    containers22 = str(containers2)
    #print(containers22)

    def page12(containers22):
        page1 = list()
        c = containers22.find("из ")
        page1.append(containers22[c+11])
        page1.append(containers22[c+12])
        if containers22[c+12] == "<":
            page1.pop()
        return page1

    print('ALOOOOOOOOOOOO', page12(containers22))
    if len(page12(containers22)) == 2:
        page_real = int(page12(containers22)[0] + page12(containers22)[1])
    else:
        page_real = int(page12(containers22)[0])
    print(page_real)

    # Парсим
    course_as = sel.xpath('//a[contains(@class,"right-box right")]')
    print(course_as)
    hrefs_from_css = course_as.css('::attr(href)')
    print(len(str(hrefs_from_css.extract())[1:]))
    #next1 = "https://lizaalert.org/forum" + str(hrefs_from_css.extract()[0])[1:]
    #print("ссылка=", next1)
    if len(str(hrefs_from_css.extract())[1:]) == 1:
        links_to_follow = ssylka
        clean_link = ssylka
    else:
        links_to_follow = "\"https://lizaalert.org/forum" + str(hrefs_from_css.extract()[0])[1:] + "\""
        clean_link = str(hrefs_from_css.extract()[0])[1:len(hrefs_from_css.extract()[0])-2]
    print(clean_link)
    list_links = list()
    for i in range((page_real)-1):
        list_links.append(clean_link)
    print(list_links)

    #За 500 надо пояснить! Но это вроде несложно
    i=0
    list1 = list()
    for i in range(0,(page_real-1)*25, 25):
        i = i + 25
        list1.append(i)
    print(list1)

    result = [str(item) for item in list1]

    #print(type(result[2]))

    for i in range(len(list1)):
        list_links[i] += result[i]
    #print(list_links)

    for i in range(len(list_links)):
        list_links[i] = "https://lizaalert.org/forum" + list_links[i]
    list_of_all_pages.append(list_links)
    print(list_of_all_pages)
    print(list_links)
    
print(list_of_all_pages, "ГДЕ Я БЛЯТЬ")
# Out:
# ALOOOOOOOOOOOO ['1']
# 1
# []
# 1
# https://lizaalert.org/forum/viewforum.php?f=184
# []
# []
# [[]]
# []
# ALOOOOOOOOOOOO ['4']
# 4
# [<Selector xpath='//a[contains(@class,"right-box right")]' data='<a href="./viewforum.php?f=173&amp;sid=e'>]
# 70
# /viewforum.php?f=173&sid=e00f9ecde2636a8932675c884c8dc512&start=
# ['/viewforum.php?f=173&sid=e00f9ecde2636a8932675c884c8dc512&start=', '/viewforum.php?f=173&sid=e00f9ecde2636a8932675c884c8dc512&start=', '/viewforum.php?f=173&sid=e00f9ecde2636a8932675c884c8dc512&start=']
# [25, 50, 75]
# [[], ['https://lizaalert.org/forum/viewforum.php?f=173&sid=e00f9ecde2636a8932675c884c8dc512&start=25', 'https://lizaalert.org/forum/viewforum.php?f=173&sid=e00f9ecde2636a8932675c884c8dc512&start=50', 'https://lizaalert.org/forum/viewforum.php?f=173&sid=e00f9ecde2636a8932675c884c8dc512&start=75']]
# ['https://lizaalert.org/forum/viewforum.php?f=173&sid=e00f9ecde2636a8932675c884c8dc512&start=25', 'https://lizaalert.org/forum/viewforum.php?f=173&sid=e00f9ecde2636a8932675c884c8dc512&start=50', 'https://lizaalert.org/forum/viewforum.php?f=173&sid=e00f9ecde2636a8932675c884c8dc512&start=75']
# ALOOOOOOOOOOOO ['1']
# 1
# []
# 1
# https://lizaalert.org/forum/viewforum.php?f=184
# []
# []
# [[], ['https://lizaalert.org/forum/viewforum.php?f=173&sid=e00f9ecde2636a8932675c884c8dc512&start=25', 'https://lizaalert.org/forum/viewforum.php?f=173&sid=e00f9ecde2636a8932675c884c8dc512&start=50', 'https://lizaalert.org/forum/viewforum.php?f=173&sid=e00f9ecde2636a8932675c884c8dc512&start=75'], []]
# []
# [[], ['https://lizaalert.org/forum/viewforum.php?f=173&sid=e00f9ecde2636a8932675c884c8dc512&start=25', 'https://lizaalert.org/forum/viewforum.php?f=173&sid=e00f9ecde2636a8932675c884c8dc512&start=50', 'https://lizaalert.org/forum/viewforum.php?f=173&sid=e00f9ecde2636a8932675c884c8dc512&start=75'], []] ГДЕ Я БЛЯТЬ

# %%
print(len(list_of_all_pages))
listSYKA = list()
for i in range(len(list_of_all_pages)):
    for j in range(len(list_of_all_pages[i])):
        listSYKA.append(list_of_all_pages[i][j])
print(listSYKA)
print(hrefz)
for j in range(len(hrefz)):
    listSYKA.append(hrefz[j])
listSYKA.append(ssylka)
print(len(listSYKA))
print(listSYKA)
# Out:
# 3
# ['https://lizaalert.org/forum/viewforum.php?f=173&sid=e00f9ecde2636a8932675c884c8dc512&start=25', 'https://lizaalert.org/forum/viewforum.php?f=173&sid=e00f9ecde2636a8932675c884c8dc512&start=50', 'https://lizaalert.org/forum/viewforum.php?f=173&sid=e00f9ecde2636a8932675c884c8dc512&start=75']
# ['https://lizaalert.org/forum/viewforum.php?f=292&sid=28a0b6d45787ce2347d8d94d58587c9b', 'https://lizaalert.org/forum/viewforum.php?f=173&sid=28a0b6d45787ce2347d8d94d58587c9b', 'https://lizaalert.org/forum/viewforum.php?f=291&sid=28a0b6d45787ce2347d8d94d58587c9b']
# 7
# ['https://lizaalert.org/forum/viewforum.php?f=173&sid=e00f9ecde2636a8932675c884c8dc512&start=25', 'https://lizaalert.org/forum/viewforum.php?f=173&sid=e00f9ecde2636a8932675c884c8dc512&start=50', 'https://lizaalert.org/forum/viewforum.php?f=173&sid=e00f9ecde2636a8932675c884c8dc512&start=75', 'https://lizaalert.org/forum/viewforum.php?f=292&sid=28a0b6d45787ce2347d8d94d58587c9b', 'https://lizaalert.org/forum/viewforum.php?f=173&sid=28a0b6d45787ce2347d8d94d58587c9b', 'https://lizaalert.org/forum/viewforum.php?f=291&sid=28a0b6d45787ce2347d8d94d58587c9b', 'https://lizaalert.org/forum/viewforum.php?f=184']

# %%
list_full = list()
print(page_real)
for i in range(len(listSYKA)):
    #html = requests.get(list_links[i]).content #url='google.com'
    html = requests.get(listSYKA[i]).content #url='google.com'
    sel = Selector(text=html)

    course_as1 = sel.css('a.topictitle')
    hrefs1_from_css = course_as1.css('::attr(href)')
#syka
    list0 = list()
    for i in range(0, len(hrefs1_from_css.extract())):
        list0.append("https://lizaalert.org/forum" + str(hrefs1_from_css.extract()[i])[1:])
        list_full.append(list0[i])
#print(list_full)
print(len(list_full))
print(list_full[17])
# Out:
# 1
# 104
# https://lizaalert.org/forum/viewtopic.php?f=173&t=22473&sid=e00f9ecde2636a8932675c884c8dc512

# %%
my_list = list_full

# %% [markdown]
# # Здесь соберем все вспомогательные перменные

# %%
list_photo = []
list_state1 = []
list_sex1 = []
list_age11 = []
list_posts = []
list_height = []
list_help1 = []
list_hair_color = []
list_bodytype = []
list_eye = []
list_place = []
list_color_of_clothes = [] # Бабкен Вставил
list_of_lists = []  ## Здесь нужно додумать

# %%
english_stops = ['.', ',', ':', ';', "!", "?", '-', ')', '(']

# %% [markdown]
# # Напишем все функции, которые нам понадобятся в сборе признаков

# %%
def photo1(containers11):
    if containers11.find("Изображение") != -1:
        photo =  'присутствует'
    else:
        photo = 'отсутствует'
    return photo

# %%
def state1(title1): # Слава вставил 8 мая 
    sit = re.search(r'[Жж]ива|[Жж]ив|[Пп]огиб|[Пп]огибла|[Нн]айден|[Нн]айдена',title1)
    if sit is None:
        return "Ищут"
    sit = str(sit.group(0))
    if sit == 'Жива' or sit == 'Жив' or sit == 'жива' or sit == 'жив' or sit == 'Найден' or sit == 'найден' or sit == 'найдена'or sit == 'Найдена':
        sit = 'Живой'
    else:
        sit = 'Погиб'
    return sit

# %%
def sex1(title1): # Слава вставил 8 мая 
    sex = re.search(r'[Вв]ышел|[Вв]ышла|[Уу]шла|[Уу]шёл|[Уу]шел|[Пп]ропал|[Пп]ропала|[Нн]айден|[Нн]айдена|[Жж]ива|[Жж]ив|[Ее]го|[Ее]ё|[Ее]е|[Уу]ехал|[Уу]ехала', title1)
    if sex is None:
        return "Er"
    sex = str(sex.group(0))
    if sex == "вышел" or sex == "Вышел" or sex == "ушел" or sex == "Ушел" or sex == 'ушёл' or sex == 'пропал' or sex == 'Пропал' or sex == 'Найден' or sex == 'найден' or sex == 'ушел'or sex == 'пропал'or sex == 'найден'or sex == 'Найден'or sex == 'вышел' or sex == 'Жив'or sex == 'жив' or sex == 'уехал':
        sex = "Мужчина"
    else:
        sex = 'Женщина'
    return sex

# %%
def age11(title1):
    age = re.search(r'\d+ ',title1)
    if age is None:
        return "Er"
    age = int(age.group(0)) # эТО уже у нас число)) Ура!!!!
    if age < 100:
            age = age
    else:
            age = 2019 - age
    return age

# %%
def posts1(containers2):
    posts = re.search(r'\d+', str(containers2)).group()
    return posts

# %%
def data1(containers88):
    d = containers88.find("Инфорг")
    if d == -1:
        data1, data2 = 'не','редактировали'
    else:
        data1 = containers88[d+11] + containers88[d+12] + containers88[d+13] + containers88[d+14] + containers88[d+15] + containers88[d+16] + containers88[d+17] + containers88[d+18] + containers88[d+19] + containers88[d+20] + containers88[d+21]
        data2 = containers88[d+24] + containers88[d+25] + containers88[d+26] + containers88[d+27] + containers88[d+28]
        data = data1 + ' ' + data2
    return data

# %%
def height(containers11): # Вставил Слава 8.05.2019
    high = re.search(r'[Рр]ост \d{3}|[Рр]оста \d{3}|[Рр]оста\d{3}|[Рр]ост: \d{3}|[Рр]ост - \d{3}', containers11 )
    if high is None:
        return "Er"
    high = str(high.group(0))

    height = re.findall(r'\d+',high)
    height = int(" ".join(height))
    return height

# %%
def help1(containers11):
    if containers11.find("В МЕДИЦИНСКОЙ ПОМОЩИ") == -1 and containers11.find("в медицинской помощи") == -1:
        help1 = 'здоров'
    else:
        help1 = 'требуется мед. помощь'
    return help1

# %%
def hair_color(contents):
    hc = 'Не указано'
    for string in contents:
        if "олосы" in string:
            no_stops_string_1 = ''.join([t for t in string if t not in english_stops])
            tokens_1 = word_tokenize(no_stops_string_1)
            for i in range(len(tokens_1)):
                if "олосы" in tokens_1[i]:
                    hc = tokens_1[i + 1]
    return hc

# %%
## Нужно доработать код! Или сделать заново
def body_type(contents):
    body = "Не указано"
    for string in contents:
        if "елосложени" in string:
            no_stops_string = ''.join([t for t in string if t not in english_stops])
            tokens = word_tokenize(no_stops_string)
            tokens.append("Ты объебался")
            for i in range(len(tokens)):
                if "елосложени" in tokens[i]:
                    if tokens[i][-1] == "я":
                        body = tokens[i - 1]
                        break
                    else:
                        body = tokens[i + 1]
                        break
    return body

# %%
## Нужно доработать код! Или сделать заново
def eyes_color(contents):
    ec = "Не указано"
    for string in contents:
        if "лаз" in string:
            no_stops_string = ''.join([t for t in string if t not in english_stops])
            tokens = word_tokenize(no_stops_string)
            tokens.append("Кто-то объебался")
            for i in range(len(tokens)):
                if "лаз" in tokens[i]:
                    ec = tokens[i + 1]
                if ec == "Кто-то объебался":
                    ec = tokens[i-1]
                    break
    return ec

# %%
def yebanskii(sel):
    p = sel.css("div.content").xpath('./span[@style="font-size: 140%; line-height: 116%;"]/span[@style="font-weight: bold"]/text()').extract()
    a = str(p)
    b = re.split('\s+', a)
    b1 = b[5:]
    t = str(b1)
    p = t.replace("\'", "")
    p1 = p.replace(']', '')
    p2 = p1.replace('[', '')
    p3 = p2.replace('"', '')
    p4 = p3.replace(', ', " ")
    p5 = p4.replace('- ','-')
    return p5

# %%
# Бабкен вставил
def color_cloth(containers11):
    containers1 = re.split('<span style="font-weight: bold">', containers11)
    if len(containers1) < 4:
        return "Не указано"
    else:
        containers_new = containers1[3]
        black = len(re.findall(r'черн', containers_new))
        white = len(re.findall(r'бел', containers_new))
        yellow = len(re.findall(r'желт', containers_new))
        orange = len(re.findall(r'оранж', containers_new))
        br_grey = len(re.findall(r'тло-сер', containers_new))
        grey = len(re.findall(r'сер', containers_new))
        beg = len(re.findall(r'бежев', containers_new))
        br_blue = len(re.findall(r'тло-син', containers_new))
        blue = len(re.findall(r'син', containers_new))
        green = len(re.findall(r'зелен', containers_new))
        violent = len(re.findall(r'фиол', containers_new))
        black1 = len(re.findall(r'чёрн', containers_new))
        brown = len(re.findall(r'коричн', containers_new))
        al_colors = black + yellow + orange + grey + beg + blue + green + violent + black1
        br_colors1 = white + yellow + orange + br_grey + beg + br_blue + green + violent
        br_colors2 = white + yellow + orange + beg + br_blue + green + violent
        br_colors3 = white + yellow + orange + br_grey + beg + green + violent
        br_colors4 = white + yellow + orange + beg + green + violent
        dk_colors1 = black + black1 + brown
        dk_colors2 = black + grey + black1 + brown
        dk_colors3 = black + blue + black1 + brown
        dk_colors4 = black + blue + grey + black1 + brown
        if al_colors == 0:
            return "Не указано" 
        elif (br_grey == 0 and br_blue == 0) and br_colors4 >= dk_colors4:
            return "Яркая"
        elif (br_grey == 0 and br_blue == 0) and br_colors4 < dk_colors4:
            return "Темная"
        elif ((br_grey != 0 and grey != 0) or (br_blue != 0 and blue != 0 )) and br_colors1 >= dk_colors4:
            return "Яркая"
        elif ((br_grey != 0 and grey != 0) or (br_blue != 0 and blue != 0 )) and br_colors1 < dk_colors4:
            return "Темная"
        elif (br_grey == 0) and br_colors2 >= dk_colors2:
            return "Яркая" 
        elif (br_grey == 0) and br_colors2 < dk_colors2:
            return "Темная" 
        elif (br_blue == 0) and br_colors3 >= dk_colors3:
            return "Яркая"

# %% [markdown]
# # Перейдем к сбору признаков

# %%
for i in my_list:
    my_url = i
    uClient = uReq(my_url)
    page_html = uClient.read()
    uClient.close()
    page_soup = soup(page_html, "html.parser")
    title = page_soup.title
    title1 = str(title)
    html = requests.get(my_url).content
    sel = Selector(text=html)
    containers = page_soup.findAll("div", {"class":"content"})
    contents = page_soup.findAll("div", {"class":"content"})[0].contents
    containers11 = str(containers)
    containers2 = page_soup.findAll("div", {"class":"pagination"})
    containers22 = str(containers2)
    containers8 = page_soup.findAll("div", {"class":"notice"})
    containers88 = str(containers8)
    containers1 = re.split('<span style="font-weight: bold">', containers11)
    containers1
    
    list_photo.append(photo1(containers11))
    list_state1.append(state1(title1))
    list_sex1.append(sex1(title1))
    list_age11.append(age11(title1))
    list_posts.append(posts1(containers22))
    list_hair_color.append(hair_color(contents))
    list_bodytype.append(body_type(contents))
    list_eye.append(eyes_color(contents))
    containers = page_soup.findAll("div", {"class":"content"})
    containers11 = str(containers)
    list_height.append(height(containers11))
    list_help1.append(help1(containers11))
    list_place.append(yebanskii(sel))
    list_color_of_clothes.append(color_cloth(containers11)) # Бабкен вставил

# %%
list_of_lists.append(list_age11)
list_of_lists.append(list_height)
list_of_lists.append(list_help1)
list_of_lists.append(list_photo)
list_of_lists.append(list_posts)
list_of_lists.append(list_sex1)
list_of_lists.append(list_state1)
list_of_lists.append(list_hair_color)
list_of_lists.append(list_bodytype)
list_of_lists.append(list_eye)
list_of_lists.append(list_place)
list_of_lists.append(list_color_of_clothes) # Бабкен вставил

# %%
df1 = pd.DataFrame(columns = ['Возраст', 'Рост', 'Мед. Состояние', 'Фото', 'Посты', 'Гендер', 'Состояние', 'Цвет волос', 'Телосложение', 'Цвет глаз', 'Место', 'Одежда'])

# %%
for i, j in zip(list_of_lists, list(df1.columns)):
    df1[j] = pd.Series(i)

# %% [markdown]
# # Тадаам ! Вот , что мы получили

# %%
df1.head()
# Out:
#           Возраст  Рост Мед. Состояние          Фото Посты   Гендер  \
# 0  Коля объебался  None         здоров   отсутствует     1     sboi
# 1  Коля объебался   160         здоров   отсутствует     1     sboi
# 2  Коля объебался   163         здоров   отсутствует     1     sboi
# 3              14   173         здоров  присутствует     4  женский
# 4              16   176         здоров  присутствует     3  женский
#
#     Состояние  Цвет волос Телосложение    Цвет глаз           Место  \
# 0  Не указано  Не указано   Не указано   Не указано
# 1  Не указано  Не указано   Не указано   Не указано     Ставрополь
# 2  Не указано  Не указано   Не указано   Не указано  г. Ставрополь
# 3       живой       русые  нормального  серозеленые   г.Ставрополь
# 4       живой     светлые     среднего      голубые  г. Ставрополь
#
#        Одежда
# 0  Не указано
# 1      Темная
# 2      Темная
# 3       Яркая
# 4      Темная

# %%
df1
# Out:
#             Возраст     Рост         Мед. Состояние          Фото Посты  \
# 0    Коля объебался     None                 здоров   отсутствует     1
# 1    Коля объебался      160                 здоров   отсутствует     1
# 2    Коля объебался      163                 здоров   отсутствует     1
# 3                14      173                 здоров  присутствует     4
# 4                16      176                 здоров  присутствует     3
# 5                24      120                 здоров  присутствует     2
# 6                80      180                 здоров  присутствует     3
# 7                 8      185                 здоров  присутствует     3
# 8                59      160                 здоров  присутствует     8
# 9    Коля объебался      165                 здоров  присутствует     4
# 10               21     None                 здоров  присутствует    10
# 11               57      160                 здоров  присутствует     6
# 12               24      185                 здоров   отсутствует     1
# 13               84      120                 здоров  присутствует     5
# 14               56      165                 здоров  присутствует     1
# 15                7      175                 здоров  присутствует     4
# 16               82     None                 здоров  присутствует     2
# 17               29      130                 здоров  присутствует     2
# 18               28      170                 здоров  присутствует    37
# 19                8      170                 здоров  присутствует     3
# 20               55      168  требуется мед. помощь  присутствует     2
# 21   Коля объебался     None                 здоров  присутствует     2
# 22               81      170                 здоров   отсутствует     3
# 23               89      170  требуется мед. помощь   отсутствует     2
# 24               86      170  требуется мед. помощь   отсутствует     6
# 25               68      170  требуется мед. помощь   отсутствует     8
# 26               82     None                 здоров   отсутствует     4
# 27               26      165  требуется мед. помощь   отсутствует     3
# 28   Коля объебался      160  требуется мед. помощь   отсутствует     1
# 29               78     None                 здоров   отсутствует     3
# ..              ...      ...                    ...           ...   ...
# 662               2      155                 здоров  присутствует     5
# 663              16      160                 здоров  присутствует     2
# 664              13      190                 здоров  присутствует     7
# 665              91      155                 здоров  присутствует     9
# 666              51      170                 здоров  присутствует     7
# 667              59      168                 здоров  присутствует    11
# 668              84      160                 здоров  присутствует     3
# 669              16      170                 здоров  присутствует     4
# 670              27      160                 здоров  присутствует     3
# 671              71      160                 здоров  присутствует     4
# 672         Mistake      130                 здоров  присутствует     3
# 673              18      170                 здоров  присутствует     9
# 674              10      196                 здоров  присутствует     4
# 675              46      170                 здоров  присутствует     3
# 676              28  Mistake                 здоров   отсутствует    11
# 677              85      170                 здоров  присутствует     3
# 678               2      159                 здоров  присутствует     1
# 679              45      160                 здоров  присутствует     6
# 680              60      186                 здоров  присутствует     8
# 681              78  Mistake                 здоров  присутствует     6
# 682              28      173                 здоров  присутствует     2
# 683         Mistake  Mistake                 здоров  присутствует     1
# 684              67      170                 здоров  присутствует     7
# 685         Mistake      185                 здоров  присутствует     1
# 686              21      178  требуется мед. помощь   отсутствует     3
# 687         Mistake  Mistake                 здоров  присутствует     2
# 688              51      175                 здоров   отсутствует     5
# 689         Mistake      180                 здоров  присутствует     5
# 690              82      NaN                    NaN  присутствует     6
# 691         Mistake      NaN                    NaN   отсутствует     9
#
#                 Гендер   Состояние         Цвет волос          Телосложение  \
# 0                 sboi  Не указано         Не указано            Не указано
# 1                 sboi  Не указано         Не указано            Не указано
# 2                 sboi  Не указано         Не указано            Не указано
# 3              женский       живой              русые           нормального
# 4              женский       живой            светлые              среднего
# 5              женский       живой              русые              среднего
# 6              мужской       живой              лысый            нормальное
# 7              мужской       живой        светлорусые             xудощавое
# 8              мужской       живой         тёмнорусые                полное
# 9              мужской       живой              рыжие            худощавого
# 10             мужской       живой  короткостриженные             xудощавое
# 11             мужской       живой         каштановые            нормальное
# 12                sboi  Не указано         Не указано            Не указано
# 13             мужской       живой              седые            Не указано
# 14             мужской       живой              русые             xудощавое
# 15             мужской       живой              русые             xудощавое
# 16             мужской       живой                  с                     с
# 17                sboi  Не указано         Не указано              обычного
# 18                sboi  Не указано         Не указано            Не указано
# 19             мужской       живой        светлорусые             xудощавое
# 20             мужской       живой              седые            худощавого
# 21   несколько человек       живой             чёрные             xудощавое
# 22             мужской     мертвый              седые            худощавого
# 23                sboi      ищется              седые  рост160158худощавого
# 24             мужской     мертвый         седыеглаза             худощавое
# 25             мужской     мертвый         Не указано               плотное
# 26             мужской       живой              седые               среднее
# 27             женский       живой            светлые            худощавого
# 28                sboi  Не указано         Не указано            Не указано
# 29             мужской       живой              седые                полное
# ..                 ...         ...                ...                   ...
# 662            Mistake       Погиб         Не указано            Не указано
# 663            Mistake        Ищут              русые            худощавого
# 664            Женщина       Живой              русые             xудощавое
# 665            Mistake        Ищут              седые             xудощавое
# 666            Мужчина        Ищут         тёмнорусые             xудощавое
# 667            Мужчина        Ищут          волнистые              плотного
# 668            Женщина       Живой              седые               плотное
# 669            Мужчина       Живой             чёрные              среднего
# 670            Мужчина       Живой           короткие            худощавого
# 671            Мужчина       Живой              седые             xудощавое
# 672            Mistake       Погиб              русые            худощавого
# 673            Мужчина       Живой         Не указано            нормальное
# 674            Мужчина        Ищут              русые           нормального
# 675            Мужчина       Живой         тёмнорусые             xудощавое
# 676            Мужчина       Живой         тёмнорусые             xудощавое
# 677            Mistake       Погиб              седые                полное
# 678            Мужчина       Живой         Не указано            Не указано
# 679            Mistake        Ищут        светлорусые             xудощавое
# 680            Мужчина       Живой              седые            нормальное
# 681            Мужчина       Живой              русые            нормальное
# 682            Mistake        Ищут            светлые            худощавого
# 683            Мужчина       Живой         Не указано            Не указано
# 684            Mistake        Ищут              седые           нормального
# 685            Mistake       Погиб         Не указано            Не указано
# 686            Mistake        Ищут              рыжие          Ты объебался
# 687            Мужчина        Ищут              седые            Не указано
# 688            Мужчина       Живой              русые            нормальное
# 689            Mistake       Погиб         Не указано            Не указано
# 690            Mistake        Ищут              седые       худощавоеволосы
# 691            Мужчина        Ищут             темные               плотное
#
#          Цвет глаз                                              Место  \
# 0       Не указано
# 1       Не указано                                        Ставрополь
# 2       Не указано                                     г. Ставрополь
# 3      серозеленые                                      г.Ставрополь
# 4          голубые                                     г. Ставрополь
# 5      серозеленые                                        Ставрополь
# 6      сероголубые                                        Ставрополь
# 7            серые                               Станица Есентукская
# 8            карие                     Шпаковский район, хутор Ташла
# 9          голубые                                     г. Изобильный
# 10         голубые
# 11           карие                                        Кисловодск
# 12      Не указано  Ставропольский край, Левокумский р-он, с.Левок...
# 13           карие                       Заветное Кочубеевского р-на
# 14         голубые                                      г. Ессентуки
# 15   светлозеленые                                      г.Ставрополь
# 16           карие
# 17             при             г.Михайловск, ул. Советская, д. 196/1
# 18      Не указано                 Шпаковский р-он, с. Сенгилеевское
# 19          растет  Амирзаян Рената (17)+ Захарян Владимир (14), Б...
# 20           карие
# 21           карие
# 22      Не указано
# 23           серые
# 24           карие
# 25           Серые
# 26      Не указано
# 27         голубые                                      г.Ставрополь
# 28      Не указано                                     г. Михайловск
# 29           серые
# ..             ...                                                ...
# 662     Не указано                                         с. Дивное
# 663          карие                                 хутор Средний Лес
# 664    сероголубые   г. Новоалександровск, ул. Мясокомбинатовская 14
# 665        зелёные                              г.Новоалександровск.
# 666          серые                                      Ставрополь .
# 667        голубые                        (2002 г.р.), г. Ставрополь
# 668          карие                                     г. Михайловск
# 669          карие                                год, г. Кисловодск
# 670        зеленые                                     г. Кисловодск
# 671    сероголубые
# 672          карие              Александровский р-он, с. Саблинское.
# 673          карие                                       г.Пятигорск
# 674    серозелёные                                     г. Изобильный
# 675    зелёнокарие              Ставрополь ул. Макарова д.8/2 кв.106
# 676    сероголубые
# 677          карие  (1973 г.р), хутор Красночервонный, Новоалексан...
# 678     Не указано           Григорий Иванович 60 лет, г. Ставрополь
# 679    сероголубые                                 Новоалександровск
# 680        голубые  с. Шведино, Петровский р-он, Ставропольский край
# 681        голубые
# 682    сероголубые  лет, с. Серноводское, Сунженский р-н, Чеченска...
# 683     Не указано
# 684         черные                                   г. Владикавказ.
# 685     Не указано                                          Черкесск
# 686          карие                                       Владикавказ
# 687          карие
# 688        голубые
# 689     Не указано
# 690    карезеленые                                                NaN
# 691    серозеленые                                                NaN
#
#          Одежда
# 0    Не указано
# 1        Темная
# 2        Темная
# 3         Яркая
# 4        Темная
# 5        Темная
# 6    Не указано
# 7        Темная
# 8         Яркая
# 9        Темная
# 10   Не указано
# 11       Темная
# 12       Темная
# 13       Темная
# 14       Темная
# 15   Не указано
# 16   Не указано
# 17       Темная
# 18   Не указано
# 19        Яркая
# 20   Не указано
# 21   Не указано
# 22   Не указано
# 23       Темная
# 24   Не указано
# 25   Не указано
# 26   Не указано
# 27       Темная
# 28   Не указано
# 29   Не указано
# ..          ...
# 662      Темная
# 663      Темная
# 664      Темная
# 665  Не указано
# 666      Темная
# 667      Темная
# 668      Темная
# 669      Темная
# 670      Темная
# 671       Яркая
# 672      Темная
# 673      Темная
# 674      Темная
# 675      Темная
# 676  Не указано
# 677      Темная
# 678  Не указано
# 679      Темная
# 680      Темная
# 681  Не указано
# 682  Не указано
# 683  Не указано
# 684  Не указано
# 685      Темная
# 686  Не указано
# 687  Не указано
# 688  Не указано
# 689  Не указано
# 690         NaN
# 691         NaN
#
# [692 rows x 12 columns]

# %% [markdown]
# Пока дальше не нужно смотреть ( Славе)

# %%
df1.shape

# %%
count = 0
for element in  df1["Телосложение"][:19]:
    if element == "Не указано":
        count += 1
count/len(df1["Телосложение"][:19])

# %% [markdown]
# TRY EXCEL

# %%
filename = "post7.csv"
f = open(filename, "w")
headers = "age1, height, posts\n"
f.write(headers)

# %% [markdown]
# Так, осталось выпарсить (хотя бы ублюдочно):
# 1) время пропажи
# 2) телосложение
# 3) цвет глаз
# 4) волосы
# 5) одежда???
#
# А сейчас PPPPANDA, PPPAND, PPPPPPPANDA:

# %%
# PAAAANDA, PPPPANDA, LADDDNO (c) illumate & obladaet

# %%
# ДЛЯ КОЛИ!!!!!!!!!!!!!!!!!!!!!
html1 = requests.get('https://lizaalert.org/forum/viewforum.php?f=184').content #url='google.com'
sel1 = Selector(text=html1)
course_as11 = sel1.xpath('//a[contains(@class,"forumtitle")]')
print(course_as11)
hrefs11_from_css = course_as11.css('::attr(href)')
print(hrefs11_from_css.extract())
hrefz = list()
#print("\"https://lizaalert.org/forum" + str(hrefs11_from_css.extract()[4])[1:] + "\"")
for i in range(len(hrefs11_from_css.extract())):
    clean_link1 = "\"https://lizaalert.org/forum" + str(hrefs11_from_css.extract()[i])[1:] + "\""
    hrefz.append(clean_link1)
#for i in hrefs11_from_css.extract():
 #   hrefs11_from_css.extract()[i] = "\"https://lizaalert.org/forum" + str(hrefs11_from_css.extract()[i])[1:] + "\""
print(hrefz[0])

# %%
page_soup.findAll("div", {"class":"content"})[0].contents

# %%
body_type(contents)

# %%
contents

# %%
container2
