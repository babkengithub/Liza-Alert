# %%
import bs4
from urllib.request import urlopen as urll
from bs4 import BeautifulSoup as soup
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
my_url = ['https://lizaalert.org/forum/viewforum.php?f=276&sid=77f734cb1fc11635f9faa41851544905',
          'https://lizaalert.org/forum/viewforum.php?f=276&start=25',
          'https://lizaalert.org/forum/viewforum.php?f=276&sid=591c45caaa848f397a0901614cd2c798&start=50',
          'https://lizaalert.org/forum/viewforum.php?f=276&start=75',
          'https://lizaalert.org/forum/viewforum.php?f=276&start=100']
# Out:
# 5

# %%
df = pd.DataFrame({
    'Characteristics' : [],
    'Posts' : [],
    'Views' : [],
    'Lasts': [],
    'Firsts': []
})
df
# Out:
# Empty DataFrame
# Columns: [Characteristics, Posts, Views, Lasts, Firsts]
# Index: []

# %%
for k in range(0,len(my_url)):
    uClient = urll(my_url[h])
    page_html = uClient.read()
    uClient.close()
    page_soup = soup(page_html,"html.parser")
    main = page_soup.find('ul', {'class':'topiclist topics'})
    person = page_soup.findAll('li',class_='row bg1')
    name = page_soup.findAll('a',class_='topictitle')
    post = page_soup.findAll('dd',class_='posts')
    for i in range(1,len(person)):
        Post = person[i].find('dd',class_='posts').text[:2]
        Name = person[i].find('a',class_='topictitle').text.split(' ')[0]
        View = person[i].find('dd',class_='views').text.split(' ')[0]
        Last = person[i].find('dd',class_='lastpost').text.split('\n')[1]
        try:
            sd = person[i].findAll('span', class_='for-desc')[1].text.split(" ")[3:]
        except:
            sd = person[i].find('span', class_='for-desc').text.split(" ")[3:]
        newrow = pd.DataFrame({
            'Characteristics' : [Name],
            'Posts': [Post],
            'Views': [View],
            'Lasts': [Last],
            'Firsts': [sd]
            
            })
        df = df.append(newrow)
        
    person = page_soup.findAll('li',class_='row bg2')   
    for i in range(1,len(person)):
        Post = person[i].find('dd',class_='posts').text[:2]
        Name = person[i].find('a',class_='topictitle').text.split(' ')[0]
        View = person[i].find('dd',class_='views').text.split(' ')[0]
        Last = person[i].find('dd',class_ = 'lastpost').text.split('\n')[1]
        try:
            sd = person[i].findAll('span', class_='for-desc')[1].text.split(' ')[3:]
        except:
            sd = person[i].find('span', class_='for-desc').text.split(" ")[3:]
        #First = person[i].find('span',class_ = 'for-desc').find('a').text
        #print(Name)
        newrow = pd.DataFrame({
            'Characteristics' : [Name],
            'Posts': [Post],
            'Views': [View],
            'Lasts': [Last],
            'Firsts': [sd]
            
            })
        df = df.append(newrow)
        
df
# Out:
#    Characteristics Posts  Views                Lasts  \
# 0              Жив    61   1541   16 апр 2019, 07:27
# 0             Жив,    8    1116   15 апр 2019, 10:42
# 0          Погибла    62   4358   14 апр 2019, 13:37
# 0             Жива    41   2030   13 апр 2019, 23:24
# 0             Жива    27   1507   11 апр 2019, 09:58
# 0              Жив    23   2257   10 апр 2019, 07:12
# 0              Жив    1    1070   04 апр 2019, 12:09
# 0            Жива.    37   6783   05 янв 2019, 06:14
# 0             Живы    6    2868   02 янв 2019, 03:28
#
#                         Firsts
# 0      [15, апр, 2019,, 18:38]
# 0      [15, апр, 2019,, 00:07]
# 0      [11, апр, 2019,, 19:34]
# 0      [12, апр, 2019,, 22:50]
# 0      [10, апр, 2019,, 19:22]
# 0      [10, апр, 2019,, 02:49]
# 0      [04, апр, 2019,, 12:06]
# 0      [03, апр, 2019,, 02:28]
# 0      [02, апр, 2019,, 23:26]
# 0      [02, апр, 2019,, 16:15]
# 0      [31, мар, 2019,, 18:27]
# 0      [16, апр, 2019,, 01:41]
# 0      [14, апр, 2019,, 13:10]
# 0   [», 07, апр, 2019,, 01:45]
# 0      [13, апр, 2019,, 20:21]
# 0      [03, апр, 2019,, 21:17]
# 0      [10, апр, 2019,, 13:11]
# 0      [09, апр, 2019,, 21:37]
# 0      [03, апр, 2019,, 14:02]
# 0      [03, апр, 2019,, 23:54]
# 0      [02, апр, 2019,, 16:53]
# 0      [01, апр, 2019,, 01:43]
# 0      [25, мар, 2019,, 19:53]
# 0      [24, мар, 2019,, 19:18]
# 0      [23, мар, 2019,, 09:55]
# 0      [22, мар, 2019,, 14:10]
# 0      [19, мар, 2019,, 21:20]
# 0      [19, мар, 2019,, 21:30]
# 0      [17, мар, 2019,, 13:19]
# 0      [12, мар, 2019,, 14:22]
# ..                         ...
# 0      [30, янв, 2019,, 00:24]
# 0      [29, янв, 2019,, 01:25]
# 0      [28, янв, 2019,, 01:01]
# 0      [26, янв, 2019,, 02:22]
# 0      [23, янв, 2019,, 07:02]
# 0      [23, янв, 2019,, 03:24]
# 0      [20, янв, 2019,, 18:45]
# 0      [16, янв, 2019,, 19:07]
# 0      [15, янв, 2019,, 13:37]
# 0      [13, янв, 2019,, 22:20]
# 0      [13, янв, 2019,, 03:47]
# 0      [30, янв, 2019,, 20:57]
# 0      [30, янв, 2019,, 00:20]
# 0      [29, янв, 2019,, 17:15]
# 0      [26, янв, 2019,, 21:06]
# 0      [22, янв, 2019,, 19:04]
# 0      [22, янв, 2019,, 20:06]
# 0      [22, янв, 2019,, 00:09]
# 0      [18, янв, 2019,, 23:16]
# 0      [17, янв, 2019,, 02:27]
# 0      [15, янв, 2019,, 21:21]
# 0      [13, янв, 2019,, 00:06]
# 0      [11, янв, 2019,, 18:06]
# 0      [07, янв, 2019,, 19:24]
# 0      [08, янв, 2019,, 00:11]
# 0      [01, янв, 2019,, 12:23]
# 0      [04, янв, 2019,, 18:51]
# 0      [08, янв, 2019,, 00:05]
# 0      [03, янв, 2019,, 17:12]
# 0      [02, янв, 2019,, 01:24]
#
# [99 rows x 5 columns]

# %%
df.to_excel('Slava I did 14.04 .xlsx')
