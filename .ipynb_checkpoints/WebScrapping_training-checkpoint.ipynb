# %% [markdown]
# # Как достать признаки с LizaAlert и оформить это в jupyter

# %% [markdown]
# Сначала импортируем необходимые пакеты из соответствующих библиотек

# %%
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import re
import scrapy
import nltk
import pandas as pd
from datetime import datetime, date, time
from scrapy.selector import Selector
import requests
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /Users/vgodie/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
my_url = 'https://lizaalert.org/forum/viewtopic.php?f=236&t=11986&sid=6d3c03b3cbac6c923d5f43933dc40c36'
#my_url = "https://lizaalert.org/forum/viewtopic.php?f=120&t=2360"
#my_url = "https://lizaalert.org/forum/viewtopic.php?f=276&t=25112"# boy and AK-47
#my_url = "https://lizaalert.org/forum/viewtopic.php?f=276&t=25087" #девочка с необычным лицом
#my_url = "https://lizaalert.org/forum/viewtopic.php?f=276&t=25197" #косоглазый чел
#my_url = "https://lizaalert.org/forum/viewtopic.php?f=276&t=25104" #ded anisimov
#my_url = "https://lizaalert.org/forum/viewtopic.php?f=276&t=25098" #ded Medvedev
#my_url = "https://lizaalert.org/forum/viewtopic.php?f=276&t=25109" #дед Павлов
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=276&t=25083'#boy Sayakbaev
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=276&t=25078' #grandma Leandrova
#my_url = "https://lizaalert.org/forum/viewtopic.php?f=276&t=25077" #girl Kamilla
client = uReq(my_url)  # создаем документ, являющийся сырым кодом сайта

# %%
not_url = requests.get(my_url).content

# %%
sel = Selector(text=not_url)

# %%
page_html = client.read() # функция .read() позволяет вывести на экран все содержимое файла, а если мы это сохраним в переменную, 
                          # то получим объект, который хранит в себе все строки этого файла

# %%
client.close()

# %%
ps = soup(page_html, "html.parser")

# %%
type(ps)
# Out:
# bs4.BeautifulSoup

# %%
english_stops = ['.', ',', ':', ';', "!", "?", "-"]

# %% [markdown]
# Далее, для работы понадобится открыть код страницы, которую мы хотим парсить. Для этого правой кнопки мыши нажимаем на страницу, затем выбираем просмотреть код, который затем должен появиться в правой стороне страницы.

# %%
containers = ps.find_all("div", {"class": "content"})
len(containers)
# Out:
# 4

# %%
main = ps.find('div', {'class':'content'}).text

# %%
main
# Out:
# 'Поферяева Диана Юрьевна, 13 лет, г. Белгород13.04.2016 ушла в школу и до настоящего момента её местонахождение неизвестноПРИМЕТЫ: рост 160см, телосложение нормальное, волосы светло-русые вьющиеся, до плеч, глаза серыеОСОБЫЕ ПРИМЕТЫ: На запястье левой руки царапины, напоминающие разрезы.БЫЛА ОДЕТА: Туника черная до пояса с большим рисунком оранжево-салатовым, лосины черные, туфли женские закрытые черные, водолазка белаяОРИЕНТИРОВКА: Группа поиска: https://vk.com/lizaalert_belgorodИнфорг Дарья +79803934754'

# %%
main1 = sel.xpath('//div[@class="content"]/text()').extract_first()
main1
# Out:
# 'Поферяева Диана Юрьевна, 13 лет, г. Белгород'

# %%
notmain1 = sel.xpath('//div[@class="notice"]/text()').extract()[1]

# %%
notmain1
# Out:
# ' 19 апр 2016, 23:49, всего редактировалось 1 раз.\n\t\t\t\t\t\n\t\t\t\t'

# %%
main1
# Out:
# 'Поферяева Диана Юрьевна, 13 лет, г. Белгород'

# %%
babken = ps.find('p', {'class':'author'}).text

# %%
babken
# Out:
# ' Ennoris » 18 апр 2016, 23:41 '

# %%
juk_slava = sel.xpath('//p[@class="author"]/text()').extract()[-1]

# %%
re.search(r'\d+\s\w+\s\d+',juk_slava)
# Out:
# <re.Match object; span=(3, 14), match='19 апр 2016'>

# %%
posts = ps.find('div', {'class':'pagination'})
posts
re.search(r'\d+', str(posts)).group()
# Out:
# '3'

# %%
re.search(r'\d+', str(posts)).group()
# Out:
# '3'

# %% [markdown]
# Код для возраста

# %%
title = ps.find("title").extract()
title
# Out:
# <title>Найден.Жив.Кирин Владислав Павлович, 8 лет, г.Ставрополь • Форум lizaalert.org</title>

# %%
re.search(r'\d+', str(title)).group()
# Out:
# '8'

# %%
container = containers[0]
containers[0]
# Out:
# <div class="content"><span style="font-size: 140%; line-height: 116%;"><span style="font-weight: bold">Кирин Владислав Павлович 8 лет, Ставрополь </span></span><br/><br/>27 декабря 2018 около 10-00 ушёл из дома и не вернулся<br/><br/><a class="postlink" href="http://www.radikal.ru" rel="nofollow" target="_blank"><img alt="Изображение" src="https://c.radikal.ru/c08/1812/42/da244bfb25d6.jpg"/></a><br/><br/><a class="postlink" href="http://www.radikal.ru" rel="nofollow" target="_blank"><img alt="Изображение" src="https://c.radikal.ru/c36/1812/bb/bc0a69606dbc.jpg"/></a><br/><span style="font-weight: bold">Приметы:</span><br/>Рост: 120  см.<br/>Телосложение: xудощавое<br/>Цвет глаз: серые<br/>Волосы: светло-русые, короткая стрижка<br/><br/><span style="font-weight: bold">Был одет:</span>  серые тёплые брюки , сапоги зимние с белой подошвой, серая куртка с капюшоном, серая шапка с красным подворотом и крупной надписью<br/><br/><span style="font-weight: bold">Особые приметы:</span> рост 120 см, волосы светло-русые, глаза серые, особая примета-веснушки<br/><br/><span style="font-weight: bold"><a href="https://docs.google.com/spreadsheets/d/1xuYK_sypPLYcJia2MlgncKFPGUnIpS984RWh4NWsxGo/edit?usp=sharing" rel="nofollow" target="_blank">Таблица прозвона больниц и ОВД</a></span><br/><br/><span style="font-weight: bold"><a href="http://la-org.ru//images/2018/12/901ad458a7bc5ed171c698c294eabf791.jpg?rnd=24797112" rel="nofollow" target="_blank">Ориентировка на печать</a></span><br/><br/><span style="font-weight: bold"><a href="http://la-org.ru//images/2018/12/901ad458a7bc5ed171c698c294eabf792.jpg?rnd=76125648" rel="nofollow" target="_blank">Ориентировка на репост</a></span><br/><br/>--------------------------------------------------<br/><br/><span style="font-weight: bold">Координатор:</span> Войдан Дмитрий 89620955660 <br/><span style="font-weight: bold">Инфорг:</span> Светлана 89624940466</div>

# %%
container.img["alt"]  # проверили наличие или отсутствие изображения
# Out:
# 'Изображение'

# %%
contents = container.contents
contents
# Out:
# [<span style="font-size: 140%; line-height: 116%;"><span style="font-weight: bold">Кирин Владислав Павлович 8 лет, Ставрополь </span></span>,
#  <br/>,
#  <br/>,
#  '27 декабря 2018 около 10-00 ушёл из дома и не вернулся',
#  <br/>,
#  <br/>,
#  <a class="postlink" href="http://www.radikal.ru" rel="nofollow" target="_blank"><img alt="Изображение" src="https://c.radikal.ru/c08/1812/42/da244bfb25d6.jpg"/></a>,
#  <br/>,
#  <br/>,
#  <a class="postlink" href="http://www.radikal.ru" rel="nofollow" target="_blank"><img alt="Изображение" src="https://c.radikal.ru/c36/1812/bb/bc0a69606dbc.jpg"/></a>,
#  <br/>,
#  <span style="font-weight: bold">Приметы:</span>,
#  <br/>,
#  'Рост: 120  см.',
#  <br/>,
#  'Телосложение: xудощавое',
#  <br/>,
#  'Цвет глаз: серые',
#  <br/>,
#  'Волосы: светло-русые, короткая стрижка',
#  <br/>,
#  <br/>,
#  <span style="font-weight: bold">Был одет:</span>,
#  '  серые тёплые брюки , сапоги зимние с белой подошвой, серая куртка с капюшоном, серая шапка с красным подворотом и крупной надписью',
#  <br/>,
#  <br/>,
#  <span style="font-weight: bold">Особые приметы:</span>,
#  ' рост 120 см, волосы светло-русые, глаза серые, особая примета-веснушки',
#  <br/>,
#  <br/>,
#  <span style="font-weight: bold"><a href="https://docs.google.com/spreadsheets/d/1xuYK_sypPLYcJia2MlgncKFPGUnIpS984RWh4NWsxGo/edit?usp=sharing" rel="nofollow" target="_blank">Таблица прозвона больниц и ОВД</a></span>,
#  <br/>,
#  <br/>,
#  <span style="font-weight: bold"><a href="http://la-org.ru//images/2018/12/901ad458a7bc5ed171c698c294eabf791.jpg?rnd=24797112" rel="nofollow" target="_blank">Ориентировка на печать</a></span>,
#  <br/>,
#  <br/>,
#  <span style="font-weight: bold"><a href="http://la-org.ru//images/2018/12/901ad458a7bc5ed171c698c294eabf792.jpg?rnd=76125648" rel="nofollow" target="_blank">Ориентировка на репост</a></span>,
#  <br/>,
#  <br/>,
#  '--------------------------------------------------',
#  <br/>,
#  <br/>,
#  <span style="font-weight: bold">Координатор:</span>,
#  ' Войдан Дмитрий 89620955660 ',
#  <br/>,
#  <span style="font-weight: bold">Инфорг:</span>,
#  ' Светлана 89624940466']

# %% [markdown]
# Код, чтобы достать телесложение

# %%
for string in contents:
    if "елосложени" in string:
        no_stops_string = ''.join([t for t in string if t not in english_stops])
        tokens = word_tokenize(no_stops_string)
for i in range(len(tokens)):
    if "елосложени" in tokens[i]:
        if tokens[i][-1] == "я":
            body = tokens[i - 1]
        else:
            body = tokens[i + 1]
body.lower()
a = WordNetLemmatizer()
a.lemmatize(body)
# Out:
# 'xудощавое'

# %%
body
# Out:
# 'xудощавое'

# %%
## Нужно доработать код! Или сделать заново
def eyes_color(contents):
    ec = "Не указано"
    for string in contents:
        if "лаз" in string:
            no_stops_string = ''.join([t for t in string if t not in english_stops])
            tokens = word_tokenize(no_stops_string)
            tokens.append("Кто-то объебался")
            for i in range(len(tokens)):
                if "лаз" in tokens[i]:
                    ec = tokens[i + 1]
                if ec == "Кто-то объебался":
                    ec = tokens[i-1]
                    break
    return ec
eyes_color(contents)
# Out:
# 'серые'

# %% [markdown]
# Код, чтобы достать цвет волос

# %%
for string in contents:
    if "олосы" in string:
        no_stops_string_1 = ''.join([t for t in string if t not in english_stops])
        tokens_1 = word_tokenize(no_stops_string_1)
for i in range(len(tokens_1)):
    if "олосы" in tokens_1[i]:
        hair_colour = tokens_1[i + 1]
hair_colour.lower()
b = WordNetLemmatizer()
b.lemmatize(hair_colour)
# Out:
# 'светлорусые'

# %%
def hair_color(contents):
    hc = ''
    for string in contents:
        if "олосы" in string:
            no_stops_string_1 = ''.join([t for t in string if t not in english_stops])
            tokens_1 = word_tokenize(no_stops_string_1)
            for i in range(len(tokens_1)):
                if "олосы" in tokens_1[i]:
                    hc = tokens_1[i + 1]
                    break
    return hc

# %%
hair_color(contents)
# Out:
# 'светлорусые'

# %%
tokens_1
# Out:
# ['рост',
#  '120',
#  'см',
#  'волосы',
#  'светлорусые',
#  'глаза',
#  'серые',
#  'особая',
#  'приметавеснушки']

# %% [markdown]
# Сделаем вспомогательные словари для следующего шага

# %%
months_length = {"янв": 31, "фев": 28, "мар": 31, "апр": 30, "май": 31, "июн": 30, "июл": 31, "авг": 31, "сен": "30",
                "окт": 31, "ноя": 30, "дек": 31}
months_num = {"янв": 1, "фев": 2, "мар": 3,"апр": 4,"мая": 5, "май": 5,"июн": 6,"июл": 7,"авг": 8,"сен": 9,"окт": 10,"ноя": 11,"дек": 12}

# %%
loss_find = {"время пропажи": "", "время нахождения": ""}

# %% [markdown]
# Код, чтобы достать время пропажи

# %%
def lost_timing(x):
    if re.search(r'\d+ \w+ \d{4}|\d{2}.\d{2}.\d{4}', x).group() == None:
        return "Сбой"
    else:
        lost_time = re.search(r'\d+ \w+ \d{4}|\d{2}.\d{2}.\d{4}', x).group()
        if "." in lost_time:
            lost_time = lost_time[:2] + " " + months_num[lost_time[3:5]]
        elif "я" in lost_time or "т" in lost_time:
            return re.search(r'\d+ \w{3}').group()

# %%
main
# Out:
# 'Кирин Владислав Павлович 8 лет, Ставрополь 27 декабря 2018 около 10-00 ушёл из дома и не вернулсяПриметы:Рост: 120  см.Телосложение: xудощавоеЦвет глаз: серыеВолосы: светло-русые, короткая стрижкаБыл одет:  серые тёплые брюки , сапоги зимние с белой подошвой, серая куртка с капюшоном, серая шапка с красным подворотом и крупной надписьюОсобые приметы: рост 120 см, волосы светло-русые, глаза серые, особая примета-веснушкиТаблица прозвона больниц и ОВДОриентировка на печатьОриентировка на репост--------------------------------------------------Координатор: Войдан Дмитрий 89620955660 Инфорг: Светлана 89624940466'

# %%
notmain = ps.find('div', {'class':'notice'}).text

# %% [markdown]
# Код, чтобы достать время нахождения

# %%
postbody = ps.find('div', {"class":"notice"}).text

# %%
postbody
# Out:
# 'Последний раз редактировалось Инфорг СК 27 дек 2018, 21:26, всего редактировалось 1 раз.\n\t\t\t\t\t\n\t\t\t\t'

# %% [markdown]
# # А теперь реализуем то, ради чего были найдены предыдущие два пункта: время поиска

# %%
ml = list(months_length.keys())
lt = re.search(r'\w{3}', loss_find["время пропажи"]).group()
ft = re.search(r'\w{3}', loss_find["время нахождения"]).group()

# %%
if lt == ft:
    search_time = int(re.search(r'\d+', loss_find["время нахождения"]).group()) - int(re,search(r'\d+', loss_find["время пропажи"]).group())
elif ml.index(ft) > ml.index(lt):
    search_time = int(re.search(r'\d+', loss_find["время нахождения"]).group())
    for i in range(ml.index(ft) - 1, ml.index(lt) - 1, -1):
        if ml[i] != lt:
            search_time += months_length[ml[i]]
        else:
            search_time += months_length[ml[i]] - int(re.search(r'\d+', loss_find["время пропажи"]).group())
elif ml.index(ft) < ml.index(lt):
    search_time = int(re.search(r'\d+', loss_find["время нахождения"]).group())
    i = ml.index(ft) - 1
    while i >= 0:
        if ml[i] != lt:
            search_time += months_length[ml[i]]
        i -= 1
    for j in range(len(ml) - 1, ml.index(lt) - 1, -1):
        if ml[j] != lt:
            search_time += months_length[ml[j]]
        else:
            search_time += months_length[ml[j]] - int(re.search(r'\d+', loss_find["время пропажи"]).group())

# %%
search_time

# %%
containers2 = ps.findAll("div", {"class":"content"})[0].contents
containers2

# %%
containers.contents

# %% [markdown]
# Код для доставания возраста

# %%
def lost_timing(x):
    if re.search(r'\d+ \w+ \d{4}|\d{2}.\d{2}.\d{4}', x) == None:
        return "Сбой"
    else:
        lost_time = re.search(r'\d+ \w+ \d{4}|\d{2}.\d{2}.\d{4}', x).group()
        print(lost_time)
        if "я" in lost_time or "т" in lost_time:
            lts = lost_time.split()
            print(lts)
            lts[1] = months_num[lts[1][:3]]
            lts = list(map(int, lts))
            lost_time = date(lts[-1], lts[-2], lts[-3])
            return lost_time
            #lost_time = date(lts[-1], [-2], [-3])
        else:
            lts = lost_time.split('.')
            lts = list(map(int, lts))
            lost_time = date(lts[-1], lts[-2], lts[-3])
            return lost_time

# %%
lost_timing(main)
# Out:
# 27 декабря 2018
# ['27', 'декабря', '2018']
# datetime.date(2018, 12, 27)

# %%
def find_timing(x):
    if re.search(r'\d+ \w+ \d{4}|\d{2}.\d{2}.\d{4}', x) == None:
        return "Сбой"
    else:
        find_time = re.search(r'\d+ \w+ \d{4}|\d{2}.\d{2}.\d{4}', x).group()
        print(find_time)
        fts = find_time.split()
        print(fts)
        fts[1] = months_num[fts[1]]
        fts = list(map(int, fts))
        find_time = date(fts[-1], fts[-2], fts[-3])
        return find_time

# %%
find_timing(notmain)
# Out:
# 27 дек 2018
# ['27', 'дек', '2018']
# datetime.date(2018, 12, 27)

# %%
df1 = pd.read_csv('/Users/vgodie/Documents/GitHub/Liza-Alert/table4slava.csv')
df1
# Out:
#      Unnamed: 0  Готовые  Искатели  Репосты_вк  Репосты_одн         Возраст  \
# 0             0        2         0           0            0  Коля объебался
# 1             1        0         1           0            0              78
# 2             2        0         1           0            0              28
# 3             3        0        12           0            0              14
# 4             4        0         1           0            0              16
# 5             5        0         1           0            0              24
# 6             6        0         3           0            0              80
# 7             7        0        21           0            0               8
# 8             8        0         3         108            0              59
# 9             9        0        15           0            0  Коля объебался
# 10           10        0        15           0            0              21
# 11           11        0         5           0            0              57
# 12           12        0         0           2            0              24
# 13           13        0        20           0            0              84
# 14           14        0         0           0            0              56
# 15           15        0        18           0            0               7
# 16           16        0         1           0            0              82
# 17           17        0         1           0            0              29
# 18           18        1        28           1            0              28
# 19           19        0        14           0            0               8
# 20           20        0         1           0            0              55
# 21           21        0        14           0            0  Коля объебался
# 22           22        0        73          20            0              81
# 23           23        0         4           1            0              89
# 24           24        0        39          51            0              86
# 25           25        0        55          18            0              68
# 26           26        2         0           0            0  Коля объебался
# 27           27        0        19          40            0              82
# 28           28        0         3           1            0              26
# 29           29        0         4           0            0              78
# ..          ...      ...       ...         ...          ...             ...
# 78           78        0         8          43            0              29
# 79           79        0        55          51            0              62
# 80           80        0        19           0            0              80
# 81           81        0         4           0            0               2
# 82           82        0         0           0            0              16
# 83           83        0         8           0            0              91
# 84           84        0         1          36            5              51
# 85           85        0         1         211            0              59
# 86           86        0        33           0            0              84
# 87           87        0         1          48            5              16
# 88           88        0        14           0            0              27
# 89           89        0         1           0            0              71
# 90           90        0         1           0            0              41
# 91           91        0         1           0            0              18
# 92           92        0        19           0            0              10
# 93           93        0        15           0            0              46
# 94           94        0         4          96            5              28
# 95           95        0        45           0            0              85
# 96           96        0         0           1            0               2
# 97           97        0         1           0            0              45
# 98           98        0         3         150            0              60
# 99           99        2         0           0            0  Коля объебался
# 100         100        0        13           0            0              67
# 101         101        2         0           0            0  Коля объебался
# 102         102        0         1           0            0              21
# 103         103        0         1           0            0  Коля объебался
# 104         104        0       123          41           17              51
# 105         105        0         4           2            0  Коля объебался
# 106         106        0        12          49            8              82
# 107         107        0        27          98            9              30
#
#     Рост(Slava)         Мед. Состояние          Фото  Посты  \
# 0            Er                 здоров   отсутствует      1
# 1           160                 здоров  присутствует      6
# 2           186                 здоров  присутствует      2
# 3           160                 здоров  присутствует      4
# 4           163                 здоров  присутствует      3
# 5           173                 здоров  присутствует      2
# 6           176                 здоров  присутствует      3
# 7           120                 здоров  присутствует      3
# 8           180                 здоров  присутствует      8
# 9           185                 здоров  присутствует      4
# 10          160                 здоров  присутствует     10
# 11          165                 здоров  присутствует      6
# 12           Er                 здоров   отсутствует      1
# 13          160                 здоров  присутствует      5
# 14          185                 здоров  присутствует      1
# 15          120                 здоров  присутствует      4
# 16          165                 здоров  присутствует      2
# 17          175                 здоров  присутствует      2
# 18           Er                 здоров  присутствует     37
# 19          130                 здоров  присутствует      3
# 20          170                 здоров  присутствует      2
# 21          170                 здоров  присутствует      2
# 22          168  требуется мед. помощь   отсутствует      3
# 23          160                 здоров   отсутствует      2
# 24          170                 здоров   отсутствует      6
# 25          170  требуется мед. помощь   отсутствует      8
# 26           Er                 здоров   отсутствует      1
# 27          170  требуется мед. помощь   отсутствует      4
# 28          170  требуется мед. помощь   отсутствует      3
# 29          165  требуется мед. помощь   отсутствует      3
# ..          ...                    ...           ...    ...
# 78          170                 здоров  присутствует      4
# 79          175                 здоров  присутствует      6
# 80          154                 здоров  присутствует      9
# 81           Er                 здоров  присутствует      5
# 82          165                 здоров  присутствует      2
# 83          160                 здоров  присутствует      9
# 84          190                 здоров  присутствует      7
# 85          155                 здоров  присутствует     11
# 86          170                 здоров  присутствует      3
# 87          168                 здоров  присутствует      4
# 88          160                 здоров  присутствует      3
# 89          170                 здоров  присутствует      4
# 90          160                 здоров  присутствует      3
# 91          160                 здоров   отсутствует      9
# 92          130                 здоров  присутствует      4
# 93          170                 здоров  присутствует      3
# 94          196                 здоров  присутствует     11
# 95          170                 здоров  присутствует      3
# 96           Er                 здоров  присутствует      1
# 97          170                 здоров  присутствует      6
# 98          159                 здоров  присутствует      8
# 99           Er                 здоров   отсутствует      1
# 100         173                 здоров  присутствует      7
# 101          Er                 здоров   отсутствует      1
# 102         170                 здоров  присутствует      3
# 103         185                 здоров  присутствует      2
# 104         178  требуется мед. помощь   отсутствует      5
# 105          Er                 здоров   отсутствует      5
# 106         175                 здоров  присутствует      6
# 107         180                 здоров  присутствует      9
#
#            ...              Цвет глаз  \
# 0          ...             Не указано
# 1          ...                голубые
# 2          ...            сероголубые
# 3          ...            серозеленые
# 4          ...                голубые
# 5          ...            серозеленые
# 6          ...            сероголубые
# 7          ...                  серые
# 8          ...                  карие
# 9          ...                голубые
# 10         ...                голубые
# 11         ...                  карие
# 12         ...             Не указано
# 13         ...                  карие
# 14         ...                голубые
# 15         ...          светлозеленые
# 16         ...                  карие
# 17         ...                    при
# 18         ...             Не указано
# 19         ...                 растет
# 20         ...                  карие
# 21         ...                  карие
# 22         ...             Не указано
# 23         ...                  серые
# 24         ...                  карие
# 25         ...                  Серые
# 26         ...             Не указано
# 27         ...             Не указано
# 28         ...                голубые
# 29         ...                  серые
# ..         ...                    ...
# 78         ...             Не указано
# 79         ...                голубые
# 80         ...                зелёные
# 81         ...             Не указано
# 82         ...                  карие
# 83         ...                зелёные
# 84         ...                  серые
# 85         ...                голубые
# 86         ...                  карие
# 87         ...                  карие
# 88         ...                зеленые
# 89         ...            сероголубые
# 90         ...                  карие
# 91         ...                  карие
# 92         ...            серозелёные
# 93         ...            зелёнокарие
# 94         ...            сероголубые
# 95         ...                  карие
# 96         ...             Не указано
# 97         ...            сероголубые
# 98         ...                голубые
# 99         ...             Не указано
# 100        ...                 черные
# 101        ...             Не указано
# 102        ...                  карие
# 103        ...                  карие
# 104        ...                голубые
# 105        ...             Не указано
# 106        ...            карезеленые
# 107        ...            серозеленые
#
#                                                    Url  \
# 0    https://lizaalert.org/forum/viewtopic.php?f=17...
# 1    https://lizaalert.org/forum/viewtopic.php?f=17...
# 2    https://lizaalert.org/forum/viewtopic.php?f=17...
# 3    https://lizaalert.org/forum/viewtopic.php?f=17...
# 4    https://lizaalert.org/forum/viewtopic.php?f=17...
# 5    https://lizaalert.org/forum/viewtopic.php?f=17...
# 6    https://lizaalert.org/forum/viewtopic.php?f=17...
# 7    https://lizaalert.org/forum/viewtopic.php?f=17...
# 8    https://lizaalert.org/forum/viewtopic.php?f=17...
# 9    https://lizaalert.org/forum/viewtopic.php?f=17...
# 10   https://lizaalert.org/forum/viewtopic.php?f=17...
# 11   https://lizaalert.org/forum/viewtopic.php?f=17...
# 12   https://lizaalert.org/forum/viewtopic.php?f=17...
# 13   https://lizaalert.org/forum/viewtopic.php?f=17...
# 14   https://lizaalert.org/forum/viewtopic.php?f=17...
# 15   https://lizaalert.org/forum/viewtopic.php?f=17...
# 16   https://lizaalert.org/forum/viewtopic.php?f=17...
# 17   https://lizaalert.org/forum/viewtopic.php?f=17...
# 18   https://lizaalert.org/forum/viewtopic.php?f=17...
# 19   https://lizaalert.org/forum/viewtopic.php?f=17...
# 20   https://lizaalert.org/forum/viewtopic.php?f=17...
# 21   https://lizaalert.org/forum/viewtopic.php?f=17...
# 22   https://lizaalert.org/forum/viewtopic.php?f=17...
# 23   https://lizaalert.org/forum/viewtopic.php?f=17...
# 24   https://lizaalert.org/forum/viewtopic.php?f=17...
# 25   https://lizaalert.org/forum/viewtopic.php?f=17...
# 26   https://lizaalert.org/forum/viewtopic.php?f=17...
# 27   https://lizaalert.org/forum/viewtopic.php?f=17...
# 28   https://lizaalert.org/forum/viewtopic.php?f=17...
# 29   https://lizaalert.org/forum/viewtopic.php?f=17...
# ..                                                 ...
# 78   https://lizaalert.org/forum/viewtopic.php?f=17...
# 79   https://lizaalert.org/forum/viewtopic.php?f=17...
# 80   https://lizaalert.org/forum/viewtopic.php?f=17...
# 81   https://lizaalert.org/forum/viewtopic.php?f=17...
# 82   https://lizaalert.org/forum/viewtopic.php?f=17...
# 83   https://lizaalert.org/forum/viewtopic.php?f=17...
# 84   https://lizaalert.org/forum/viewtopic.php?f=17...
# 85   https://lizaalert.org/forum/viewtopic.php?f=17...
# 86   https://lizaalert.org/forum/viewtopic.php?f=17...
# 87   https://lizaalert.org/forum/viewtopic.php?f=17...
# 88   https://lizaalert.org/forum/viewtopic.php?f=17...
# 89   https://lizaalert.org/forum/viewtopic.php?f=17...
# 90   https://lizaalert.org/forum/viewtopic.php?f=17...
# 91   https://lizaalert.org/forum/viewtopic.php?f=17...
# 92   https://lizaalert.org/forum/viewtopic.php?f=17...
# 93   https://lizaalert.org/forum/viewtopic.php?f=17...
# 94   https://lizaalert.org/forum/viewtopic.php?f=17...
# 95   https://lizaalert.org/forum/viewtopic.php?f=17...
# 96   https://lizaalert.org/forum/viewtopic.php?f=17...
# 97   https://lizaalert.org/forum/viewtopic.php?f=17...
# 98   https://lizaalert.org/forum/viewtopic.php?f=17...
# 99   https://lizaalert.org/forum/viewtopic.php?f=29...
# 100  https://lizaalert.org/forum/viewtopic.php?f=29...
# 101  https://lizaalert.org/forum/viewtopic.php?f=18...
# 102  https://lizaalert.org/forum/viewtopic.php?f=18...
# 103  https://lizaalert.org/forum/viewtopic.php?f=18...
# 104  https://lizaalert.org/forum/viewtopic.php?f=18...
# 105  https://lizaalert.org/forum/viewtopic.php?f=18...
# 106  https://lizaalert.org/forum/viewtopic.php?f=18...
# 107  https://lizaalert.org/forum/viewtopic.php?f=18...
#
#                                                  Место Одежда(яркая)  \
# 0                                                  NaN    Не указано
# 1                                                  NaN        Темная
# 2                                   Новоалександровск         Темная
# 3    с. Шведино, Петровский р-он, Ставропольский край         Темная
# 4                                          Ставрополь         Темная
# 5                                       г. Ставрополь          Яркая
# 6                                        г.Ставрополь         Темная
# 7                                       г. Ставрополь         Темная
# 8                                          Ставрополь     Не указано
# 9                                          Ставрополь         Темная
# 10                                Станица Есентукская          Яркая
# 11                      Шпаковский район, хутор Ташла         Темная
# 12                                      г. Изобильный     Не указано
# 13                                                 NaN        Темная
# 14                                         Кисловодск         Темная
# 15   Ставропольский край, Левокумский р-он, с.Левок...        Темная
# 16                        Заветное Кочубеевского р-на         Темная
# 17                                       г. Ессентуки     Не указано
# 18                                       г.Ставрополь     Не указано
# 19                                                 NaN        Темная
# 20              г.Михайловск, ул. Советская, д. 196/1     Не указано
# 21                  Шпаковский р-он, с. Сенгилеевское          Яркая
# 22   Амирзаян Рената (17)+ Захарян Владимир (14), Б...    Не указано
# 23                                                 NaN    Не указано
# 24                                                 NaN    Не указано
# 25                                                 NaN        Темная
# 26                                                 NaN    Не указано
# 27                                                 NaN    Не указано
# 28                                                 NaN    Не указано
# 29                                                 NaN        Темная
# ..                                                 ...           ...
# 78                                     г. Ставрополь.          Яркая
# 79                        пос. Свободы, г. Пятигорск.         Темная
# 80                                         Ставрополь         Темная
# 81                                    г. Невинномысск         Темная
# 82                                                 NaN         Яркая
# 83                               г. Минеральные воды.         Темная
# 84                                  хутор Средний Лес         Темная
# 85    г. Новоалександровск, ул. Мясокомбинатовская 14     Не указано
# 86                               г.Новоалександровск.         Темная
# 87                                       Ставрополь .         Темная
# 88                         (2002 г.р.), г. Ставрополь         Темная
# 89                                      г. Михайловск         Темная
# 90                                 год, г. Кисловодск         Темная
# 91                                      г. Кисловодск          Яркая
# 92                                                 NaN        Темная
# 93               Александровский р-он, с. Саблинское.         Темная
# 94                                        г.Пятигорск         Темная
# 95                                      г. Изобильный         Темная
# 96               Ставрополь ул. Макарова д.8/2 кв.106     Не указано
# 97                                                 NaN        Темная
# 98   (1973 г.р), хутор Красночервонный, Новоалексан...    Не указано
# 99            Григорий Иванович 60 лет, г. Ставрополь     Не указано
# 100                                                NaN    Не указано
# 101  лет, с. Серноводское, Сунженский р-н, Чеченска...    Не указано
# 102                                                NaN    Не указано
# 103                                   г. Владикавказ.         Темная
# 104                                          Черкесск     Не указано
# 105                                       Владикавказ     Не указано
# 106                                                NaN    Не указано
# 107                                                NaN    Не указано
#
#     Одежда(подробность) Приметы(кол-во) Время поиска Время пропажи  \
# 0            Не указано      Не указано       Ошибка        Ошибка
# 1                     4               0           72    03.11.2018
# 2                     4               4       Ошибка        Ошибка
# 3                     4               4            1    07.01.2019
# 4                     4               4            6    02.01.2019
# 5                     4               4       Ошибка        Ошибка
# 6                     4               0            0    28.12.2018
# 7                     4               4            0    27.12.2018
# 8                     0               4          130    13.08.2018
# 9                     0               4            4    11.12.2018
# 10                    4               4            9    03.12.2018
# 11                    0               0           13    20.11.2018
# 12           Не указано      Не указано       Ошибка        Ошибка
# 13                    4               4            4    13.11.2018
# 14                    0               0       Ошибка        Ошибка
# 15                    4               4            1    12.10.2018
# 16                    4               4            2    04.10.2018
# 17                    0               0            8    28.09.2018
# 18           Не указано      Не указано           -4    30.09.2018
# 19                    4               4            1    02.10.2018
# 20                    4               0            5    28.09.2018
# 21                    0               0            1    31.08.2018
# 22                    4               4          164    30.03.2018
# 23           Не указано      Не указано       Ошибка        Ошибка
# 24                    0               4          144    19.04.2018
# 25                    4               4          102    08.01.2018
# 26           Не указано      Не указано       Ошибка        Ошибка
# 27                    0      Не указано            1    14.03.2018
# 28                    4               0            1    08.02.2018
# 29                    3               0            1    04.01.2018
# ..                  ...             ...          ...           ...
# 78                    4               0            2    28.04.2019
# 79                    4               0            2    26.04.2019
# 80                    4               0           50    26.02.2019
# 81                    4      Не указано       Ошибка        Ошибка
# 82                    4               4            2    13.04.2019
# 83                    4               0           26    14.02.2019
# 84                    0               0       Ошибка        Ошибка
# 85                    0               4            6    28.03.2019
# 86                    4               0            1    30.03.2019
# 87                    4               4            2    20.03.2019
# 88                    4               4            1    11.03.2019
# 89                    4               0            5    25.02.2019
# 90                    4               4           15    14.02.2019
# 91                    4      Не указано       Ошибка        Ошибка
# 92                    0               4            2    21.02.2019
# 93                    4               0            8    07.02.2019
# 94                    0               0          176    23.08.2018
# 95                    4               0            0    14.02.2019
# 96           Не указано      Не указано       Ошибка        Ошибка
# 97                    4               0           81    15.11.2018
# 98                    0               0            2    19.01.2019
# 99           Не указано      Не указано       Ошибка        Ошибка
# 100                   0               0           56    28.12.2018
# 101          Не указано      Не указано       Ошибка        Ошибка
# 102                   0               0       Ошибка        Ошибка
# 103                   4               0       Ошибка        Ошибка
# 104                   0               0           30    30.09.2017
# 105          Не указано      Не указано       Ошибка        Ошибка
# 106          Не указано      Не указано       Ошибка        Ошибка
# 107          Не указано      Не указано       Ошибка        Ошибка
#
#     Время нахождения Координаты пропажи
# 0             Ошибка                NaN
# 1         14.01.2019                NaN
# 2             Ошибка                NaN
# 3         08.01.2019                NaN
# 4         08.01.2019                NaN
# 5             Ошибка                NaN
# 6         28.12.2018                NaN
# 7         27.12.2018                NaN
# 8         21.12.2018                NaN
# 9         15.12.2018                NaN
# 10        12.12.2018                NaN
# 11        03.12.2018                NaN
# 12            Ошибка                NaN
# 13        17.11.2018                NaN
# 14            Ошибка                NaN
# 15        13.10.2018                NaN
# 16        06.10.2018                NaN
# 17        06.10.2018                NaN
# 18        26.09.2018                NaN
# 19        03.10.2018                NaN
# 20        03.10.2018                NaN
# 21        01.09.2018                NaN
# 22        10.09.2018                NaN
# 23            Ошибка                NaN
# 24        10.09.2018                NaN
# 25        20.04.2018                NaN
# 26            Ошибка                NaN
# 27        15.03.2018                NaN
# 28        09.02.2018                NaN
# 29        05.01.2018                NaN
# ..               ...                ...
# 78        30.04.2019                NaN
# 79        28.04.2019                NaN
# 80        17.04.2019                NaN
# 81            Ошибка                NaN
# 82        15.04.2019                NaN
# 83        12.03.2019                NaN
# 84            Ошибка                NaN
# 85        03.04.2019                NaN
# 86        31.03.2019                NaN
# 87        22.03.2019                NaN
# 88        12.03.2019                NaN
# 89        02.03.2019                NaN
# 90        01.03.2019                NaN
# 91            Ошибка                NaN
# 92        23.02.2019                NaN
# 93        15.02.2019                NaN
# 94        15.02.2019                NaN
# 95        14.02.2019                NaN
# 96            Ошибка                NaN
# 97        04.02.2019                NaN
# 98        21.01.2019                NaN
# 99            Ошибка                NaN
# 100       22.02.2019                NaN
# 101           Ошибка                NaN
# 102           Ошибка                NaN
# 103           Ошибка                NaN
# 104       30.10.2017                NaN
# 105           Ошибка                NaN
# 106           Ошибка                NaN
# 107           Ошибка                NaN
#
# [108 rows x 24 columns]

# %%
df1.iloc[5, 'url']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     221             try:
# --> 222                 self._validate_key(k, i)
#     223             except ValueError:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_key(self, key, axis)
#    1970             raise ValueError("Can only index by location with "
# -> 1971                              "a [{types}]".format(types=self._valid_types))
#    1972
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-9e7063220038> in <module>
# ----> 1 df1.iloc[5, 'url']
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    2011     def _getitem_tuple(self, tup):
#    2012
# -> 2013         self._has_valid_tuple(tup)
#    2014         try:
#    2015             return self._getitem_lowerdim(tup)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     224                 raise ValueError("Location based indexing can only have "
#     225                                  "[{types}] types"
# --> 226                                  .format(types=self._valid_types))
#     227
#     228     def _is_nested_tuple_indexer(self, tup):
#
# ValueError: Location based indexing can only have [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array] types

# %%
def lost_timing(x, y):
    if re.search(r'\d+ \w+ \d{4}|\d{2}[.]\d{2}[.]\d{4}', x) == None:
        if re.search(r'\d+\s\w+\s\d+', y) != None:
            lost_time = re.search(r'\d+\s\w+\s\d+', y).group()
            lts = lost_time.split()
            lts[1] = months_num[lts[1][:3]]
            lts = list(map(int, lts))
            lost_time = date(lts[-1], lts[-2], lts[-3])
            return lost_time
        else:
            return "Сбой"
    else:
        lost_time = re.search(r'\d+ \w+ \d{4}|\d{2}[.]\d{2}[.]\d{4}', x).group()
        if "я" in lost_time or "т" in lost_time:
            lts = lost_time.split()
            lts[1] = months_num[lts[1][:3]]
            lts = list(map(int, lts))
            lost_time = date(lts[-1], lts[-2], lts[-3])
            return lost_time
            #lost_time = date(lts[-1], [-2], [-3])
        else:
            lts = lost_time.split('.')
            lts = list(map(int, lts))
            lost_time = date(lts[-1], lts[-2], lts[-3])
            return lost_time

# %%
lost_timing(main, babken)
# Out:
# datetime.date(2019, 5, 25)
