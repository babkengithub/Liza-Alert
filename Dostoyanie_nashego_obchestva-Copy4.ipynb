# %%
import numpy as np
import pandas as pd
import re
import bs4
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
from scrapy import Selector
from nltk import word_tokenize
import nltk
nltk.download('punkt') #winlocker
pd.set_option("display.max_rows", 400)
pd.set_option("display.max_columns", 50)
pd.set_option('display.max_colwidth', -1)
import datetime
from datetime import datetime, time, date
import scrapy
from scrapy.selector import Selector
import requests
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# Данные для поиска силы лис

# %%
names_df = pd.read_excel('names_df.xlsx')

# %%
names_list = list(names_df["Unnamed: 0"])

# %%
#names_list = list(names_df.index)

# %%
messages_list = list(names_df["Количество сообщений"])

# %% [markdown]
# Привязка к tracks10

# %%
df_coor = pd.read_excel("final_coords.xlsx")
list_x_tracks = []
for i in range(len(df_coor["liza"])):
    list_x_tracks.append(float('%.10g' % df_coor["liza"][i]))
list_url = list(df_coor["url"])
list_km = list(df_coor["km"])
list_teams = list(df_coor["teams"])
list_date1 = list(df_coor["date1"])
list_date2 = list(df_coor["date2"])

# %% [markdown]
# Привязка (шаг 0) закончена

# %%
# ДЛЯ КОЛИ!!!!!!!!!!!!!!!!!!!!!
import requests
#ssylka = 'https://lizaalert.org/forum/viewforum.php?f=180'
ssylka = 'https://lizaalert.org/forum/viewforum.php?f=181'
html1 = requests.get(ssylka).content #url='google.com'
sel1 = Selector(text=html1)
course_as11 = sel1.xpath('//a[contains(@class,"forumtitle")]')
hrefs11_from_css = course_as11.css('::attr(href)')


hrefz = list()
for i in range(len(hrefs11_from_css.extract())):
    clean_link1 = "https://lizaalert.org/forum" + str(hrefs11_from_css.extract()[i])[1:]
    hrefz.append(clean_link1)

# %%
hrefzz = []
for i in range(len(hrefz)):
    html = requests.get(hrefz[i]).content #url='google.com'
    selka = Selector(text=html)
    course90 = selka.xpath('//a[contains(@class,"forumtitle")]')
    hrefs90_from_css = course90.css('::attr(href)')
    for i in range(len(hrefs90_from_css.extract())):
        clean_link11 = "https://lizaalert.org/forum" + str(hrefs90_from_css.extract()[i])[1:]
        hrefzz.append(clean_link1)
for i in range(len(hrefz)):
    hrefzz.append(hrefz[i])

# %%
# Import requests
import requests

list_of_all_pages = list()
# Create the string html containing the HTML source
for i in range(len(hrefzz)):
    html = requests.get(hrefzz[i]).content #url='google.com'
    sel = Selector(text=html)

    uClient = uReq(hrefzz[i])
    page_html = uClient.read()
    uClient.close()
    page_soup = soup(page_html, "html.parser")
    containers2 = page_soup.findAll("div", {"class":"pagination"})
    containers22 = str(containers2)

    def page12(containers22):
        page1 = list()
        c = containers22.find("из ")
        page1.append(containers22[c+11])
        page1.append(containers22[c+12])
        if containers22[c+12] == "<":
            page1.pop()
        return page1

    if len(page12(containers22)) == 2:
        page_real = int(page12(containers22)[0] + page12(containers22)[1])
    else:
        page_real = int(page12(containers22)[0])

    # Парсим
    course_as = sel.xpath('//a[contains(@class,"right-box right")]')
    hrefs_from_css = course_as.css('::attr(href)')
    
    if len(str(hrefs_from_css.extract())[1:]) == 1:
        links_to_follow = ssylka
        clean_link = ssylka
    else:
        links_to_follow = "\"https://lizaalert.org/forum" + str(hrefs_from_css.extract()[0])[1:] + "\""
        clean_link = str(hrefs_from_css.extract()[0])[1:len(hrefs_from_css.extract()[0])-2]
    list_links = list()
    for i in range((page_real)-1):
        list_links.append(clean_link)

    #За 500 надо пояснить! Но это вроде несложно
    i=0
    list1 = list()
    for i in range(0,(page_real-1)*25, 25):
        i = i + 25
        list1.append(i)

    result = [str(item) for item in list1]

    for i in range(len(list1)):
        list_links[i] += result[i]

    for i in range(len(list_links)):
        list_links[i] = "https://lizaalert.org/forum" + list_links[i]
    list_of_all_pages.append(list_links)

# %%
print(len(list_of_all_pages))
listSYKA = list()
for i in range(len(list_of_all_pages)):
    for j in range(len(list_of_all_pages[i])):
        listSYKA.append(list_of_all_pages[i][j])

for j in range(len(hrefzz)):
    listSYKA.append(hrefzz[j])
listSYKA.append(ssylka)
# Out:
# 5

# %%
list_full = list()
for i in range(len(listSYKA)):
    #html = requests.get(list_links[i]).content #url='google.com'
    html = requests.get(listSYKA[i]).content #url='google.com'
    sel = Selector(text=html)

    course_as1 = sel.css('a.topictitle')
    hrefs1_from_css = course_as1.css('::attr(href)')

    list0 = list()
    for i in range(0, len(hrefs1_from_css.extract())):
        list0.append("https://lizaalert.org/forum" + str(hrefs1_from_css.extract()[i])[1:])
        list_full.append(list0[i])
#print(list_full)
print(len(list_full))
# Out:
# 1316

# %%
my_list = list_full

# %%
my_list[0]
print(len(list_full))
# Out:
# 1316

# %% [markdown]
# # Здесь соберем все вспомогательные перменные

# %%
list_searchers = []
list_photo = []
list_state1 = []
list_sex1 = []
list_age11 = []
list_posts = []
list_height = []
list_help1 = []
list_hair_color = []
list_bodytype = []
list_eye = []
list_of_lists = []  ## Здесь нужно додумать
list_place = []
list_color_of_clothes = []# Бабкен Вставил
list_of_lists = []  ## Здесь нужно додумать
list_podrobnost = []
list_primeti = []
list_search_time =[]
list_lost_time = []
list_find_time = []
list_of_coor = []
list_x_tracks1 = []
list_url1 = []
list_km1 = []
list_teams1 = []
list_date11 = []
list_date22 = []
list_delta = []
list_of_power = []
list_month = []
list_year = []

# %%
english_stops = ['.', ',', ':', ';', "!", "?", '-', ')', '(']
months_num = {"янв": 1, "фев": 2, "мар": 3,"апр": 4,"мая": 5, "май": 5,"июн": 6,"июл": 7,"авг": 8,"сен": 9,"окт": 10,"ноя": 11,"дек": 12}
match_months = {'01': 'Январь', '02': ' Февраль', '03': 'Март', '04': 'Апрель', '05': 'Май', '06': 'Июнь', '07': 'Июль', '08': 'Август', '09': 'Сентябрь', '10': 'Октябрь', '11': 'Ноябрь', '12': 'Декабрь'}

# %% [markdown]
# # Напишем все функции, которые нам понадобятся в сборе признаков

# %%
def fox_power(containers228, names_list, messages_list):
    sila = 0
    if containers228 == 'ebanyi obychenie':
        sila = 0
    else:
        kerka = containers228.findAll(text=re.compile(r'\w+'))
        for i in range(len(names_list)):
            for j in range(len(kerka)):
                if names_list[i] in kerka[j]:
                    sila += int(messages_list[i])
    return sila

# %%
def searchers(containers228):
    if containers228 == 'ebanyi obychenie':
        searchers = 0
    else:
        kerka = containers228.findAll(text=re.compile(r'\w+'))
        kerka1 = containers228.findAll(text=re.compile(r'На месте|НА МЕСТЕ|Дом|ДОМ|Экипаж|ЭКИПАЖ'))
        searchers = (len(kerka) - len(kerka1))
    return searchers

# %%
def photo1(containers11):
    if containers11.find("Изображение") != -1:
        photo =  'присутствует'
    else:
        photo = 'отсутствует'
    return photo

# %%
def state1(title1):
    if title1.find("Жив") != -1 or title1.find("ЖИВ") != -1 or title1.find("Найден") != -1 or title1.find("НАЙДЕН") != -1:
        state = "живой"
    elif title1.find("Пропал") != -1 or title1.find("ПРОПАЛ") != -1:
        state = 'ищется'
    elif title1.find("Погиб") != -1 or title1.find("ПОГИБ") != -1 or title1.find("Мертв") != -1 or title1.find("МЕРТВ") != -1:
        state = 'мертвый'
    else:
        state = "Не указано"
    return state

# %%
def sex1(title1): # Слава вставил 8 мая 
    sex = re.search(r'[Пп]ропала|[Вв]ышла|[Уу]шла|[Нн]айдена|[Жж]ива|[Ее]ё|[Ее]е|[Ее]го|[Уу]ехала|[Пп]огибла|[Вв]ернулась|не [Вв]ернулась|[Вв]ышел|[Уу]шёл|[Уу]шел|[Пп]ропал|[Нн]айден|[Жж]ив|[Ее]го|[Уу]ехал|[Пп]огиб|[Вв]ернулся|не [Вв]ернулся', title1)
    if sex is None:
        return "Er"
    sex = str(sex.group(0))
    if sex == "вышел" or sex == "Вышел" or sex == "ушел" or sex == "Ушел" or sex == 'ушёл' or sex == 'пропал' or sex == 'Пропал' or sex == 'Найден' or sex == 'найден' or sex == 'ушел'or sex == 'ушёл'or sex == 'пропал'or sex == 'найден'or sex == 'Найден'or sex == 'вышел' or sex == 'Жив'or sex == 'жив' or sex == 'уехал'or sex == 'Погиб'or sex == 'погиб'or sex == 'вернулся':
        sex = "Мужчина"
    else:
        sex = "Женщина"
    return sex

# %%
def age11(title1):
    preage = re.search(r'\d+', str(title1))
    if preage is None:
        return "Коля объебался"
    else:
        age = preage.group()
        if len(age) == 4:
            age = 2019 - int(age)
    return age

# %%
def posts1(containers2):
    posts = re.search(r'\d+', str(containers2)).group()
    return posts

# %%
def data1(containers88):
    d = containers88.find("Инфорг")
    if d == -1:
        data1, data2 = 'не','редактировали'
    else:
        data1 = containers88[d+11] + containers88[d+12] + containers88[d+13] + containers88[d+14] + containers88[d+15] + containers88[d+16] + containers88[d+17] + containers88[d+18] + containers88[d+19] + containers88[d+20] + containers88[d+21]
        data2 = containers88[d+24] + containers88[d+25] + containers88[d+26] + containers88[d+27] + containers88[d+28]
        data = data1 + ' ' + data2
    return data

# %%
def height(containers11): # Вставил Слава 8.05.2019
    high = re.search(r'[Рр]ост \d{3}|[Рр]оста \d{3}|[Рр]оста\d{3}|[Рр]ост: \d{3}|[Рр]ост - \d{3}|рост\d{3}-|Рост:\d{3}| росто \d{3}', containers11 )
    if high is None:
        return "Er"
    high = str(high.group(0))

    height = re.findall(r'\d+',high)
    height = int(" ".join(height))
    return height

# %%
def help1(containers11):
    if containers11.find("В МЕДИЦИНСКОЙ ПОМОЩИ") == -1 and containers11.find("в медицинской помощи") == -1:
        help1 = 'здоров'
    else:
        help1 = 'требуется мед. помощь'
    return help1

# %%
def hair_color(contents):
    hc = 'Не указано'
    for string in contents:
        if "олосы" in string:
            no_stops_string_1 = ''.join([t for t in string if t not in english_stops])
            tokens_1 = word_tokenize(no_stops_string_1)
            for i in range(len(tokens_1)):
                if "олосы" in tokens_1[i]:
                    if i < (len(tokens_1) - 1):
                        hc = tokens_1[i + 1]
                    else:
                        hc = tokens_1[i-1]
    return hc

# %%
## Нужно доработать код! Или сделать заново
def body_type(contents):
    body = "Не указано"
    for string in contents:
        if "елосложени" in string:
            no_stops_string = ''.join([t for t in string if t not in english_stops])
            tokens = word_tokenize(no_stops_string)
            tokens.append("Ты объебался")
            for i in range(len(tokens)):
                if "елосложени" in tokens[i]:
                    if tokens[i][-1] == "я":
                        body = tokens[i - 1]
                        break
                    else:
                        body = tokens[i + 1]
                        break
    return body

# %%
## Нужно доработать код! Или сделать заново
def eyes_color(contents):
    ec = "Не указано"
    for string in contents:
        if "лаз" in string:
            no_stops_string = ''.join([t for t in string if t not in english_stops])
            tokens = word_tokenize(no_stops_string)
            tokens.append("Кто-то объебался")
            for i in range(len(tokens)):
                if "лаз" in tokens[i]:
                    ec = tokens[i + 1]
                if ec == "Кто-то объебался":
                    ec = tokens[i-1]
                    break
    return ec

# %%
def yebanskii(sel):
    p = sel.css("div.content").xpath('./span[@style="font-size: 140%; line-height: 116%;"]/span[@style="font-weight: bold"]/text()').extract()
    a = str(p)
    b = re.split('\s+', a)
    b1 = b[5:]
    t = str(b1)
    p = t.replace("\'", "")
    p1 = p.replace(']', '')
    p2 = p1.replace('[', '')
    p3 = p2.replace('"', '')
    p4 = p3.replace(', ', " ")
    p5 = p4.replace('- ','-')
    return p5

# %%
def color_cloth(containers11):
    containers1 = re.split('<span style="font-weight: bold">', containers11)
    if len(containers1) < 4:
        return "Не указано"
    else:
        containers_new = containers1[3]
        black = len(re.findall(r'черн', containers_new))
        white = len(re.findall(r'бел', containers_new))
        yellow = len(re.findall(r'желт', containers_new))
        orange = len(re.findall(r'оранж', containers_new))
        br_grey = len(re.findall(r'тло-сер', containers_new))
        grey = len(re.findall(r'сер', containers_new))
        beg = len(re.findall(r'бежев', containers_new))
        br_blue = len(re.findall(r'тло-син', containers_new))
        blue = len(re.findall(r'син', containers_new))
        green = len(re.findall(r'зелен', containers_new))
        violent = len(re.findall(r'фиол', containers_new))
        black1 = len(re.findall(r'чёрн', containers_new))
        brown = len(re.findall(r'коричн', containers_new))
        al_colors = black + yellow + orange + grey + beg + blue + green + violent + black1
        br_colors1 = white + yellow + orange + br_grey + beg + br_blue + green + violent
        br_colors2 = white + yellow + orange + beg + br_blue + green + violent
        br_colors3 = white + yellow + orange + br_grey + beg + green + violent
        br_colors4 = white + yellow + orange + beg + green + violent
        dk_colors1 = black + black1 + brown
        dk_colors2 = black + grey + black1 + brown
        dk_colors3 = black + blue + black1 + brown
        dk_colors4 = black + blue + grey + black1 + brown
        if al_colors == 0:
            return "Не указано" 
        elif (br_grey == 0 and br_blue == 0) and br_colors4 >= dk_colors4:
            return "Яркая"
        elif (br_grey == 0 and br_blue == 0) and br_colors4 < dk_colors4:
            return "Темная"
        elif ((br_grey != 0 and grey != 0) or (br_blue != 0 and blue != 0 )) and br_colors1 >= dk_colors4:
            return "Яркая"
        elif ((br_grey != 0 and grey != 0) or (br_blue != 0 and blue != 0 )) and br_colors1 < dk_colors4:
            return "Темная"
        elif (br_grey == 0) and br_colors2 >= dk_colors2:
            return "Яркая" 
        elif (br_grey == 0) and br_colors2 < dk_colors2:
            return "Темная" 
        elif (br_blue == 0) and br_colors3 >= dk_colors3:
            return "Яркая"

# %%
def podrobnost(containers11):
    containers1 = re.split('<span style="font-weight: bold">', containers11)
    if len(containers1) < 4:
        return("Не указано")
    else:
        containers_new = containers1[3]
        containers_new_sep = containers_new.split(',')
        l = len(containers_new_sep)
        if l > 3:
            return 4
        elif 2 <= l < 3:
            return 3
        else:
            return 0

# %%
def primeti(containers11):
    containers1 = re.split('<span style="font-weight: bold">', containers11)
    if len(containers1) < 5:
        return("Не указано")
    else:
        containers_new = containers1[4]
        containers_new_sep = containers_new.split(',')
        l = len(containers_new_sep)
        if l > 3:
            return 4
        elif 2 <= l < 3:
            return 2
        else:
            return 0

# %%
def lost_timing(x, y):
    if re.search(r'\d+ \w+ \d{4}|\d{2}[.]\d{2}[.]\d{4}', x) == None:
        if re.search(r'\d+\s\w+\s\d+', y) != None:
            lost_time = re.search(r'\d+\s\w+\s\d+', y).group()
            lts = lost_time.split()
            lts[1] = months_num[lts[1][:3]]
            lts = list(map(int, lts))
            lost_time = date(lts[-1], lts[-2], lts[-3])
            return lost_time
        else:
            return "Сбой"
    else:
        lost_time = re.search(r'\d+ \w+ \d{4}|\d{2}[.]\d{2}[.]\d{4}', x).group()
        if "я" in lost_time or "т" in lost_time:
            lts = lost_time.split()
            lts[1] = months_num[lts[1][:3]]
            lts = list(map(int, lts))
            lost_time = date(lts[-1], lts[-2], lts[-3])
            return lost_time
        else:
            lts = lost_time.split('.')
            lts = list(map(int, lts))
            lost_time = date(lts[-1], lts[-2], lts[-3])
            return lost_time

# %%
def find_timing(x, y):
    if re.search(r'\d+ \w+ \d{4}|\d{2}[.]\d{2}[.]\d{4}', x) == None:
        if re.search(r'\d+\s\w+\s\d{4}', y) != None:
            find_time = re.search(r'\d+\s\w+\s\d{4}', y).group()
            fts = find_time.split()
            fts[1] = months_num[fts[1]]
            fts = list(map(int, fts))
            find_time = date(fts[-1], fts[-2], fts[-3])
            return find_time
        else:
            return "Сбой"
    else:
        find_time = re.search(r'\d+ \w+ \d{4}|\d{2}[.]\d{2}[.]\d{4}', x).group()
        fts = find_time.split()
        fts[1] = months_num[fts[1]]
        fts = list(map(int, fts))
        find_time = date(fts[-1], fts[-2], fts[-3])
        return find_time

# %%
def search_timing(x, y, babken, slava):
    return (find_timing(y, slava) - lost_timing(x, babken)).days

# %%
def super_format(function, x, y):
    if len(str(function(x, y).day)) == 1:
        day = "0" + str(function(x, y).day)
    else:
        day = str(function(x, y).day)
    if len(str(function(x, y).month)) == 1:
        month = "0" + str(function(x, y).month)
    else:
        month = str(function(x, y).month)
    return day + "." + month + "." + str(function(x, y).year)

# %%
def find_cor(comp):
    for i in range (len(comp)):
        contents = page_soup.findAll("div", {"class":"content"})[i].contents
        kavka = re.search(r'\d+.\d+, \d+.\d+|\d+.\d+,\d+.\d+|\d+.\d+ \d+.\d+', str(contents))
        if kavka is not None:
            kavkaz = kavka.group()
            break
        else:
            kavkaz = 'no cord'
    return kavkaz

# %% [markdown]
# # Перейдем к сбору признаков

# %%
for i in my_list:
    my_url = i
    vanya_url = requests.get(my_url).content
    vanya_selector = Selector(text=vanya_url)
    uClient = uReq(my_url)
    page_html = uClient.read()
    uClient.close()
    page_soup = soup(page_html, "html.parser")
    title = page_soup.title
    title1 = str(title)

    comp = page_soup.findAll("div", {"class":"content"})
    containers = page_soup.findAll("div", {"class":"content"})
    contents = page_soup.findAll("div", {"class":"content"})[0].contents
    containers11 = str(containers)
    containers2 = page_soup.findAll("div", {"class":"pagination"})
    containers22 = str(containers2)
    containers8 = page_soup.findAll("div", {"class":"notice"})
    containers88 = str(containers8) 
    containers1 = re.split('<span style="font-weight: bold">', containers11)
    if len(page_soup.findAll("div", {"class":"content"})) > 1:
        containers228 = page_soup.findAll("div", {"class":"content"})[1]
    else:
        containers228 = 'ebanyi obychenie'
    
    list_searchers.append(searchers(containers228))
    list_photo.append(photo1(containers11))
    list_state1.append(state1(title1))
    list_sex1.append(sex1(title1))
    list_age11.append(age11(title1))
    list_posts.append(posts1(containers22))
    list_hair_color.append(hair_color(contents))
    list_bodytype.append(body_type(contents))
    list_eye.append(eyes_color(contents))
    containers = page_soup.findAll("div", {"class":"content"})
    containers11 = str(containers)
    list_height.append(height(containers11))
    list_help1.append(help1(containers11))
    list_place.append(yebanskii(vanya_selector))
    list_color_of_clothes.append(color_cloth(containers11)) # Бабкен вставил
    list_podrobnost.append(podrobnost(containers11)) # Бабкен вставил еще раз, но уже Ване
    list_primeti.append(primeti(containers11))
    
    
    babken = page_soup.find('p', {'class': 'author'}).text
    if vanya_selector.xpath('//p[@class="author"]/text()').extract_first() != None:
        juk_slava = vanya_selector.xpath('//p[@class="author"]/text()').extract()[-1]
    else:
        juk_slava = 'Сбой'
    if vanya_selector.xpath('//div[@class="content"]/text()').extract_first() != None:
        main = vanya_selector.xpath('//div[@class="content"]/text()').extract_first()
    else:
        main = "Сбой"
    if lost_timing(main, babken) != "Сбой":
        list_lost_time.append(super_format(lost_timing, main, babken))
    else:
        list_lost_time.append("Ошибка")
        
    if vanya_selector.xpath('//div[@class="notice"]/text()').extract_first() != None:
        notmain = vanya_selector.xpath('//div[@class="notice"]/text()').extract()[1]
    else:
        notmain = "Сбой"
    if find_timing(notmain, juk_slava) != "Сбой":
            list_find_time.append(super_format(find_timing, notmain, juk_slava))
    else:
        list_find_time.append("Ошибка")

        
        
    if lost_timing(main, babken) != "Сбой" and find_timing(notmain, juk_slava) != "Сбой":
        list_search_time.append(search_timing(main, notmain, babken, juk_slava))
    else:
        list_search_time.append("Ошибка") 
            
    list_month.append(match_months[super_format(lost_timing, main, babken)[3:5]])
    list_year.append(super_format(lost_timing, main, babken)[-4:])
    list_of_coor.append(find_cor(comp))
    list_x_tracks1.append(0)
    list_url1.append(0)
    list_km1.append(0)
    list_teams1.append(0)
    list_date11.append(0)
    list_date22.append(0)
    list_delta.append(0)
    list_of_power.append(fox_power(containers228, names_list, messages_list))

# %%
for i in range(len(list_of_coor)):
    for j in range(len(list_x_tracks)):
        if str(list_x_tracks[j]) in (list_of_coor[i]):
            list_x_tracks1[i] = str(list_x_tracks[j])
            list_url1[i] = str(list_url[j])
            list_km1[i] = str(list_km[j])
            list_date11[i] = str(list_date1[j])
            list_date22[i] = str(list_date2[j])
            list_teams1[i] = str(list_teams[j])

# %% [markdown]
# Delta dates in processing...

# %%
for i in range(len(list_date22)):
    if re.search('май', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('май', '05')
    if re.search('апр', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('апр', '04')
    if re.search('мар', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('мар', '03')
    if re.search('фев', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('фев', '02')
    if re.search('янв', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('янв', '01')
    if re.search('дек', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('дек', '12')
    if re.search('ноя', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('ноя', '11')
    if re.search('окт', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('окт', '10')
    if re.search('сен', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('сен', '09')
    if re.search('авг', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('авг', '08')
    if re.search('июл', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('июл', '07')
    if re.search('июн', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('июн', '06')

# %%
for i in range(len(list_date11)):
    if re.search('май', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('май', '05')
    if re.search('апр', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('апр', '04')
    if re.search('мар', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('мар', '03')
    if re.search('фев', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('фев', '02')
    if re.search('янв', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('янв', '01')
    if re.search('дек', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('дек', '12')
    if re.search('ноя', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('ноя', '11')
    if re.search('окт', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('окт', '10')
    if re.search('сен', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('сен', '09')
    if re.search('авг', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('авг', '08')
    if re.search('июл', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('июл', '07')
    if re.search('июн', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('июн', '06')

# %%
for i in range(len(list_date11)):
    if str(list_date11[i]) != '0' and str(list_date22[i]) != '0':
        date2k = datetime.strptime(str(list_date22[i]), "%d-%m-%y  %H:%M")
        date1k = datetime.strptime(str(list_date11[i]), "%d-%m-%y  %H:%M")
        delta = (date2k - date1k).seconds/3600
        list_delta[i] = delta

# %% [markdown]
# Парсим посты, копаем вглубь!

# %%
list_of_all_pages1 = list()

for i in my_list:
    URL = i
    
    html = requests.get(URL).content #url='google.com'
    sel = Selector(text=html)

    uClient = uReq(URL)
    page_html = uClient.read()
    uClient.close()
    page_soup = soup(page_html, "html.parser")
    containers2 = page_soup.findAll("div", {"class":"pagination"})
    containers22 = str(containers2)

    def page12(containers22):
        page1 = list()
        c = containers22.find("из ")
        page1.append(containers22[c+11])
        page1.append(containers22[c+12])
        if containers22[c+12] == "<":
            page1.pop()
            return page1

    if page12(containers22) is None:
        page_real = 1
    else:
        if len(page12(containers22)) == 2:
            page_real = int(page12(containers22)[0] + page12(containers22)[1])
        else:
            page_real = int(page12(containers22)[0])

        # Парсим
    course_as = sel.xpath('//a[contains(@class,"right-box right")]')
    hrefs_from_css = course_as.css('::attr(href)')

    if len(str(hrefs_from_css.extract())[1:]) == 1:
        links_to_follow = URL
        clean_link = URL[27:len(URL)]
    else:
        links_to_follow = "\"https://lizaalert.org/forum" + str(hrefs_from_css.extract()[0])[1:] + "\""
        clean_link = str(hrefs_from_css.extract()[0])[1:len(hrefs_from_css.extract()[0])-2]

    list_links = list()
    for i in range((page_real)):
        list_links.append(clean_link)


        #За 500 надо пояснить! Но это вроде несложно
    i=0
    list1 = [0]
    for i in range(0,(page_real-1)*10, 10):
        i = i + 10
        list1.append(i)

    result = [str(item) for item in list1]

    for i in range(len(list1)):
        if list_links[i].find("start") != -1:
            list_links[i] += result[i]
        
    for i in range(len(list_links)):
        list_links[i] = "https://lizaalert.org/forum" + list_links[i]
    
    list_of_all_pages1.append(list_links)

# %%
list_vk_posts = []
list_odn_posts = []
list_ready_posts = []
for j in range(len(list_of_all_pages1)):
    vk_posts = 0
    vk_postes = []
    odn_posts = 0
    odn_postes = []
    odn_post = []
    ready_posts = 0
    ready_postes = []
    for item in range(len(list_of_all_pages1[j])):
        odn_post = []
        ready_post = []
        vk_post = []
        uClient = uReq(list_of_all_pages1[j][item])
        page_html = uClient.read()
        uClient.close()
        page_soup = soup(page_html, "html.parser")
        for p in range(len(page_soup.findAll("div", {"class":"content"}))):
            containers2 = page_soup.findAll("div", {"class":"content"})[p] #ЧТО ЭТО ЗА ХУЙНЯ?????????
            kirka0 = containers2.findAll(text=re.compile("vk.com"))
            vk_post.append(len(kirka0))
            kirka1 = containers2.findAll(text=re.compile(r'odnokl|ok.ru'))
            odn_post.append(len(kirka1))
            kirka2 = containers2.findAll(text=re.compile(r'[Гг]отов'))
            ready_post.append(len(kirka2))
        vk_postes.append(vk_post)
        ready_postes.append(ready_post)
        odn_postes.append(odn_post)
    odn_posts += odn_posts   
    vk_posts += vk_posts
    ready_posts += ready_posts
    for i in range(len(vk_postes)):
        for k in range(len(vk_postes[i])):
            vk_posts += vk_postes[i][k]
    list_vk_posts.append(vk_posts)
    for i in range(len(odn_postes)):
        for k in range(len(odn_postes[i])):
            odn_posts += odn_postes[i][k]
    list_odn_posts.append(odn_posts)
    for i in range(len(ready_postes)):
        for k in range(len(ready_postes[i])):
            ready_posts += ready_postes[i][k]
    list_ready_posts.append(ready_posts)

# %% [markdown]
# Для таблицы

# %%
list_of_lists.append(list_ready_posts)
list_of_lists.append(list_searchers)
list_of_lists.append(list_of_power)
list_of_lists.append(list_vk_posts)
list_of_lists.append(list_odn_posts)
list_of_lists.append(list_age11)
list_of_lists.append(list_height)
list_of_lists.append(list_help1)
list_of_lists.append(list_photo)
list_of_lists.append(list_posts)
list_of_lists.append(list_sex1)
list_of_lists.append(list_state1)
list_of_lists.append(list_hair_color)
list_of_lists.append(list_bodytype)
list_of_lists.append(list_eye)
list_of_lists.append(list_full)
list_of_lists.append(list_place)
list_of_lists.append(list_color_of_clothes) # Бабкен вставил
list_of_lists.append(list_podrobnost) # Бабкен вставил еще раз, но уже себе
list_of_lists.append(list_primeti)
list_of_lists.append(list_search_time)
list_of_lists.append(list_lost_time)
list_of_lists.append(list_find_time)
list_of_lists.append(list_x_tracks1)
list_of_lists.append(list_url1)
list_of_lists.append(list_km1)
list_of_lists.append(list_teams1)
list_of_lists.append(list_date11)
list_of_lists.append(list_date22)
list_of_lists.append(list_delta)
list_of_lists.append(list_month)
list_of_lists.append(list_year)
# Бабкен вставил снова, только Коле в пердачело

# %%
df1 = pd.DataFrame(columns = ['Готовые', 'Искатели', 'Сила искателей', 'Репосты_вк', 'Репосты_одн', 'Возраст', 'Рост', 'Мед. Состояние', 'Фото', 'Посты', 'Гендер', 'Состояние', 'Цвет волос', 'Телосложение', 'Цвет глаз', 'Url','Место', 'Одежда_ярк', 'Одежда_колво', 'Приметы_колво', 'Время поиска', "Время пропажи", "Время нахождения", "Координаты пропажи", 'url_tracks', 'km', 'teams','date1', 'date2', 'delta_dates', 'Месяц', 'Год'])

# %%
for i, j in zip(list_of_lists, list(df1.columns)):
    df1[j] = pd.Series(i)

# %% [markdown]
# # Тадаам ! Вот , что мы получили

# %%
df1
# Out:
#       Готовые  Искатели  Сила искателей  Репосты_вк  Репосты_одн  \
# 0     2        0         0               0           0
# 1     0        2         0               1           0
# 2     0        31        3               11          0
# 3     1        15        16              0           0
# 4     0        0         0               0           0
# 5     0        2         0               0           0
# 6     0        2         0               1           0
# 7     0        4         0               0           0
# 8     0        2         0               0           0
# 9     0        2         0               0           0
# 10    0        0         0               0           0
# 11    0        2         0               0           0
# 12    0        2         0               0           0
# 13    0        2         0               0           0
# 14    0        2         0               0           0
# 15    0        2         0               1           0
# 16    0        2         0               0           0
# 17    0        2         0               0           0
# 18    0        2         0               1           0
# 19    0        2         0               1           0
# 20    0        2         0               0           0
# 21    0        2         0               0           0
# 22    0        2         0               0           0
# 23    0        2         0               0           0
# 24    0        1         0               0           0
# 25    0        2         0               0           0
# 26    2        0         0               0           0
# 27    0        2         0               0           0
# 28    0        2         0               0           0
# 29    0        2         0               0           0
# 30    0        1         0               0           0
# 31    0        0         0               0           0
# 32    0        1         0               0           0
# 33    0        1         598             0           0
# 34    0        1         0               0           0
# 35    0        1         0               0           0
# 36    0        1         0               0           0
# 37    0        2         0               0           0
# 38    0        0         0               2           0
# 39    0        2         0               0           0
# 40    0        2         0               0           0
# 41    0        2         0               1           0
# 42    2        0         774             0           0
# 43    0        1         0               0           0
# 44    2        0         0               0           0
# 45    0        1         0               0           0
# 46    0        41        654             0           0
# 47    0        1         0               0           0
# 48    0        1         0               0           0
# 49    0        1         0               0           0
# 50    0        1         11              0           0
# 51    0        8         4               0           0
# 52    0        0         0               0           0
# 53    0        1         0               0           0
# 54    0        22        690             0           0
# 55    0        1         0               0           0
# 56    0        2         0               0           0
# 57    0        1         0               0           0
# 58    0        1         0               0           0
# 59    0        0         0               0           0
# 60    0        1         0               0           0
# 61    0        6         33              0           0
# 62    0        1         0               0           0
# 63    0        1         0               0           0
# 64    0        1         0               0           0
# 65    0        1         0               0           0
# 66    0        1         0               0           0
# 67    0        1         0               0           0
# 68    0        1         0               0           0
# 69    0        25        29790           0           0
# 70    2        0         0               0           0
# 71    0        56        1052            0           0
# 72    0        1         0               0           0
# 73    0        1         0               0           0
# 74    0        1         0               0           0
# 75    0        1         0               0           0
# 76    0        1         0               0           0
# 77    0        1         0               0           0
# 78    0        1         0               0           0
# 79    0        1         0               0           0
# 80    0        0         0               0           0
# 81    0        46        2265            0           0
# 82    0        1         0               0           0
# 83    0        1         0               0           0
# 84    0        1         0               0           0
# 85    0        6         6               0           0
# 86    0        1         0               0           0
# 87    0        1         0               0           0
# 88    0        1         0               0           0
# 89    0        1         0               0           0
# 90    0        1         0               0           0
# 91    0        1         0               0           0
# 92    0        1         0               0           0
# 93    0        1         0               0           0
# 94    0        1         0               0           0
# 95    0        1         0               0           0
# 96    2        0         0               0           0
# 97    0        1         0               0           0
# 98    0        1         0               0           0
# 99    0        1         0               0           0
# 100   0        1         0               0           0
# 101   0        1         0               0           0
# 102   0        1         0               0           0
# 103   0        1         0               0           0
# 104   0        35        885             0           0
# 105   0        1         0               0           0
# 106   0        33        99              0           0
# 107   0        1         0               0           0
# 108   0        13        78              0           0
# 109   0        1         0               0           0
# 110   0        9         74              0           0
# 111   0        1         0               0           0
# 112   0        1         0               0           0
# 113   0        1         0               0           0
# 114   0        1         0               0           0
# 115   0        30        29497           0           0
# 116   0        1         0               0           0
# 117   0        1         0               0           0
# 118   0        1         0               0           0
# 119   0        1         0               0           0
# 120   0        1         0               0           0
# 121   0        31        1273            0           0
# 122   2        0         0               0           0
# 123   0        0         0               1           0
# 124   0        1         0               0           0
# 125   0        1         0               0           0
# 126   0        1         0               0           0
# 127   0        1         0               0           0
# 128   0        1         0               0           0
# 129   0        1         0               0           0
# 130   0        52        30111           0           0
# 131   0        1         0               0           0
# 132   0        1         0               0           0
# 133   0        2         0               0           0
# 134   0        1         0               0           0
# 135   0        2         0               0           0
# 136   0        1         0               0           0
# 137   0        1         0               0           0
# 138   0        1         0               0           0
# 139   0        1         0               0           0
# 140   0        1         0               0           0
# 141   0        1         0               0           0
# 142   0        1         0               0           0
# 143   0        1         0               0           0
# 144   0        1         0               0           0
# 145   0        1         0               0           0
# 146   0        1         0               0           0
# 147   0        0         0               0           0
# 148   2        0         0               0           0
# 149   0        1         0               0           0
# 150   1        2         4               0           0
# 151   0        1         0               0           0
# 152   0        1         0               0           0
# 153   0        1         0               0           0
# 154   0        1         0               0           0
# 155   0        1         0               0           0
# 156   0        1         0               0           0
# 157   0        1         0               1           0
# 158   0        2         29418           0           0
# 159   0        1         0               0           0
# 160   0        1         0               0           0
# 161   0        1         0               0           0
# 162   0        1         0               0           0
# 163   0        86        61877           0           0
# 164   0        1         0               0           0
# 165   0        1         0               0           0
# 166   0        76        30927           0           0
# 167   0        1         0               0           0
# 168   0        1         0               0           0
# 169   0        11        60              0           0
# 170   1        1         0               0           0
# 171   1        22        108             0           0
# 172   0        42        29537           0           0
# 173   0        1         0               0           0
# 174   2        0         0               0           0
# 175   0        1         0               0           0
# 176   0        1         0               0           0
# 177   0        1         0               0           0
# 178   0        1         0               0           0
# 179   0        1         0               0           0
# 180   0        1         0               0           0
# 181   0        1         0               0           0
# 182   0        31        1396            0           0
# 183   0        1         0               0           0
# 184   0        1         0               0           0
# 185   0        1         0               0           0
# 186   0        1         0               0           0
# 187   0        1         0               0           0
# 188   0        1         0               0           0
# 189   0        37        29885           0           0
# 190   0        1         0               0           0
# 191   0        1         0               0           0
# 192   0        1         0               0           0
# 193   0        65        62439           0           0
# 194   0        40        117             0           0
# 195   0        1         0               0           0
# 196   0        3         2               0           0
# 197   0        1         0               0           0
# 198   0        0         0               0           0
# 199   0        1         0               0           0
# ...  ..       ..        ..              ..          ..
# 1116  0        1         1               0           0
# 1117  0        1         0               0           0
# 1118  0        1         0               0           0
# 1119  0        1         0               0           0
# 1120  0        1         0               1           0
# 1121  0        2         0               2           0
# 1122  0        1         0               1           0
# 1123  0        2         0               1           0
# 1124  0        1         0               2           0
# 1125  0        35        71              1           0
# 1126  10       2         0               0           0
# 1127  0        0         0               1           0
# 1128  0        2         24              27          0
# 1129  0        0         0               1           0
# 1130  0        6         26              0           0
# 1131  0        1         0               0           0
# 1132  0        1         0               0           0
# 1133  0        3         1               0           0
# 1134  0        1         0               0           0
# 1135  3        5         13              2           0
# 1136  2        0         0               0           0
# 1137  0        1         0               1           0
# 1138  1        1         0               0           0
# 1139  1        1         0               0           0
# 1140  0        1         0               1           0
# 1141  0        1         611             1           0
# 1142  0        2         0               0           0
# 1143  0        1         0               0           0
# 1144  1        1         0               0           0
# 1145  0        1         0               0           0
# 1146  0        1         0               0           0
# 1147  0        0         0               0           0
# 1148  0        1         0               0           0
# 1149  0        1         8               0           0
# 1150  0        1         0               1           0
# 1151  1        1         0               0           0
# 1152  2        4         8               2           0
# 1153  0        3         12              0           12
# 1154  1        3         0               0           0
# 1155  0        0         0               2           0
# 1156  0        4         39              0           0
# 1157  0        2         1               1           0
# 1158  1        1         23              0           0
# 1159  0        1         29354           0           0
# 1160  0        3         0               1           0
# 1161  0        6         4               2           0
# 1162  2        0         0               0           0
# 1163  0        3         0               0           0
# 1164  1        1         12              1           0
# 1165  0        0         0               1           0
# 1166  0        0         0               1           0
# 1167  0        4         16              0           0
# 1168  2        6         19              0           0
# 1169  3        5         45              4           0
# 1170  0        4         0               0           0
# 1171  0        1         12              0           0
# 1172  0        1         0               0           0
# 1173  0        2         62              1           0
# 1174  0        28        55              0           0
# 1175  0        1         2               0           0
# 1176  0        4         0               0           0
# 1177  0        10        30              0           0
# 1178  0        7         4               0           0
# 1179  0        1         63              1           0
# 1180  0        2         0               0           0
# 1181  0        18        0               1           0
# 1182  2        22        36              2           0
# 1183  0        7         144             0           0
# 1184  0        4         9               0           0
# 1185  0        0         0               0           0
# 1186  0        2         34              0           0
# 1187  0        0         0               0           0
# 1188  2        0         0               0           0
# 1189  3        1         0               0           0
# 1190  2        0         0               0           0
# 1191  0        1         0               0           0
# 1192  0        1         0               0           0
# 1193  0        1         0               0           0
# 1194  0        1         0               4           0
# 1195  0        1         0               0           0
# 1196  0        28        6               9           0
# 1197  1        4         479             0           0
# 1198  2        11        1290            0           0
# 1199  0        2         0               0           0
# 1200  0        1         0               0           0
# 1201  0        2         0               0           0
# 1202  0        5         37              0           0
# 1203  0        4         0               1           0
# 1204  1        5         0               4           0
# 1205  0        0         0               0           0
# 1206  0        1         0               0           0
# 1207  3        9         376             0           0
# 1208  0        94        10              31          0
# 1209  6        1         0               0           0
# 1210  0        0         0               1           0
# 1211  0        1         0               0           0
# 1212  2        0         0               0           0
# 1213  0        30        954             0           0
# 1214  0        2         12              0           0
# 1215  2        36        18              44          4
# 1216  2        0         0               0           0
# 1217  0        2         0               1           0
# 1218  0        1         0               0           0
# 1219  2        7         1               2           0
# 1220  0        1         24              0           0
# 1221  0        1         1               0           0
# 1222  0        1         0               1           0
# 1223  1        1         0               0           0
# 1224  0        7         70              1           0
# 1225  0        1         0               1           0
# 1226  1        74        55              12          0
# 1227  0        54        35              16          0
# 1228  0        1         0               18          0
# 1229  0        22        4               7           0
# 1230  0        13        0               5           0
# 1231  0        1         0               0           0
# 1232  0        11        83              1           0
# 1233  0        31        12              10          0
# 1234  0        2         6               11          0
# 1235  0        7         1               16          1
# 1236  0        1         0               1           0
# 1237  0        64        46              35          0
# 1238  0        17        0               5           0
# 1239  0        2         0               1           0
# 1240  0        1         12              0           0
# 1241  0        2         0               0           0
# 1242  2        0         0               0           0
# 1243  0        1         0               0           0
# 1244  0        185       284             241         0
# 1245  0        0         0               0           0
# 1246  0        1         0               0           0
# 1247  0        1         0               0           0
# 1248  0        1         0               0           0
# 1249  1        33        29427           0           0
# 1250  0        0         0               0           0
# 1251  0        0         0               0           0
# 1252  0        1         0               0           0
# 1253  0        1         0               0           0
# 1254  0        1         0               0           0
# 1255  0        1         0               0           0
# 1256  0        1         0               0           0
# 1257  0        26        90              0           0
# 1258  0        1         0               0           0
# 1259  0        1         0               0           0
# 1260  0        38        2857            0           0
# 1261  0        1         0               0           0
# 1262  0        1         0               0           0
# 1263  0        8         52              0           0
# 1264  0        1         0               0           0
# 1265  0        47        813             0           0
# 1266  0        21        20              0           0
# 1267  0        1         0               0           0
# 1268  2        0         0               0           0
# 1269  0        1         0               0           0
# 1270  0        1         0               0           0
# 1271  0        1         0               0           0
# 1272  1        1         0               0           0
# 1273  0        1         0               0           0
# 1274  0        1         0               0           0
# 1275  0        1         0               0           0
# 1276  0        1         0               0           0
# 1277  0        1         0               0           0
# 1278  0        1         0               0           0
# 1279  0        1         0               0           0
# 1280  0        1         0               0           0
# 1281  0        1         0               0           0
# 1282  0        1         0               0           0
# 1283  0        1         0               0           0
# 1284  0        1         0               0           0
# 1285  0        1         0               0           0
# 1286  0        1         0               0           0
# 1287  0        1         0               0           0
# 1288  0        1         0               0           0
# 1289  0        1         0               0           0
# 1290  0        1         0               0           0
# 1291  0        1         0               0           0
# 1292  0        1         0               0           0
# 1293  0        1         0               0           0
# 1294  2        0         0               0           0
# 1295  0        34        40              1           0
# 1296  4        4         0               0           0
# 1297  2        0         0               0           0
# 1298  0        1         0               0           0
# 1299  0        1         0               0           0
# 1300  0        1         0               0           0
# 1301  0        2         0               0           0
# 1302  0        2         0               0           0
# 1303  0        1         0               0           0
# 1304  0        1         0               0           0
# 1305  0        1         0               1           0
# 1306  0        1         0               0           0
# 1307  0        1         0               0           0
# 1308  0        0         0               1           0
# 1309  0        13        16              1           0
# 1310  0        20        0               6           0
# 1311  0        1         0               0           0
# 1312  0        1         0               0           0
# 1313  0        0         0               0           0
# 1314  0        0         0               0           0
# 1315  0        7         13              0           0
#
#              Возраст Рост         Мед. Состояние          Фото Посты   Гендер  \
# 0     Коля объебался  Er   здоров                 отсутствует   1     Er
# 1     11              160  здоров                 отсутствует   2     Женщина
# 2     32              175  здоров                 отсутствует   3     Мужчина
# 3     83              157  здоров                 отсутствует   4     Женщина
# 4     60              170  здоров                 отсутствует   1     Мужчина
# 5     83              Er   здоров                 отсутствует   2     Мужчина
# 6     14              157  здоров                 отсутствует   2     Er
# 7     24              174  здоров                 отсутствует   3     Мужчина
# 8     37              186  здоров                 присутствует  2     Женщина
# 9     35              170  здоров                 отсутствует   2     Er
# 10    23              170  здоров                 отсутствует   1     Мужчина
# 11    20              165  здоров                 отсутствует   2     Er
# 12    35              170  здоров                 отсутствует   2     Er
# 13    14              150  здоров                 отсутствует   2     Er
# 14    16              155  здоров                 присутствует  2     Er
# 15    89              150  здоров                 присутствует  2     Женщина
# 16    57              175  здоров                 отсутствует   2     Er
# 17    61              165  здоров                 присутствует  2     Мужчина
# 18    23              180  здоров                 отсутствует   2     Мужчина
# 19    35              Er   здоров                 отсутствует   2     Мужчина
# 20    31              180  здоров                 присутствует  2     Мужчина
# 21    38              180  здоров                 присутствует  2     Мужчина
# 22    88              165  здоров                 отсутствует   2     Er
# 23    49              173  здоров                 отсутствует   2     Мужчина
# 24    Коля объебался  Er   здоров                 отсутствует   2     Женщина
# 25    12              156  здоров                 присутствует  2     Er
# 26    Коля объебался  Er   здоров                 отсутствует   1     Er
# 27    20              183  здоров                 отсутствует   2     Мужчина
# 28    45              182  здоров                 присутствует  2     Мужчина
# 29    25              Er   здоров                 отсутствует   2     Мужчина
# 30    87              160  здоров                 отсутствует   2     Er
# 31    61              150  здоров                 отсутствует   1     Мужчина
# 32    70              156  здоров                 отсутствует   2     Er
# 33    49              172  здоров                 отсутствует   2     Мужчина
# 34    6               120  здоров                 отсутствует   2     Мужчина
# 35    32              Er   здоров                 отсутствует   2     Женщина
# 36    55              170  здоров                 отсутствует   2     Er
# 37    48              160  здоров                 присутствует  2     Женщина
# 38    33              182  здоров                 отсутствует   1     Мужчина
# 39    77              140  здоров                 присутствует  2     Женщина
# 40    39              167  здоров                 отсутствует   2     Мужчина
# 41    42              163  здоров                 присутствует  2     Женщина
# 42    26              Er   здоров                 отсутствует   6     Er
# 43    37              178  здоров                 отсутствует   2     Женщина
# 44    Коля объебался  Er   здоров                 отсутствует   1     Er
# 45    17              178  здоров                 присутствует  2     Мужчина
# 46    81              157  требуется мед. помощь  присутствует  29    Женщина
# 47    68              176  требуется мед. помощь  присутствует  2     Мужчина
# 48    15              158  здоров                 присутствует  2     Женщина
# 49    48              175  здоров                 присутствует  2     Мужчина
# 50    35              173  здоров                 присутствует  2     Женщина
# 51    69              165  требуется мед. помощь  присутствует  7     Мужчина
# 52    Коля объебался  Er   здоров                 присутствует  1     Er
# 53    80              170  здоров                 присутствует  16    Мужчина
# 54    16              180  здоров                 присутствует  14    Мужчина
# 55    67              170  требуется мед. помощь  присутствует  2     Женщина
# 56    64              160  здоров                 присутствует  2     Мужчина
# 57    34              180  здоров                 присутствует  2     Мужчина
# 58    68              165  здоров                 присутствует  2     Мужчина
# 59    72              168  здоров                 присутствует  1     Мужчина
# 60    63              175  здоров                 присутствует  2     Женщина
# 61    9               140  здоров                 присутствует  21    Женщина
# 62    32              178  здоров                 присутствует  2     Мужчина
# 63    17              186  здоров                 присутствует  2     Мужчина
# 64    63              165  здоров                 присутствует  2     Женщина
# 65    39              170  здоров                 присутствует  2     Мужчина
# 66    35              176  здоров                 присутствует  2     Мужчина
# 67    30              182  здоров                 присутствует  2     Мужчина
# 68    66              200  здоров                 присутствует  2     Мужчина
# 69    Коля объебался  185  здоров                 присутствует  28    Мужчина
# 70    Коля объебался  Er   здоров                 отсутствует   1     Er
# 71    10              156  здоров                 присутствует  42    Мужчина
# 72    31              163  здоров                 присутствует  2     Женщина
# 73    83              160  здоров                 присутствует  2     Женщина
# 74    18              Er   здоров                 присутствует  2     Мужчина
# 75    27              183  здоров                 отсутствует   2     Мужчина
# 76    36              186  здоров                 присутствует  2     Мужчина
# 77    41              174  здоров                 присутствует  2     Женщина
# 78    61              165  здоров                 присутствует  2     Мужчина
# 79    48              180  здоров                 присутствует  2     Мужчина
# 80    77              160  здоров                 присутствует  1     Женщина
# 81    11              140  здоров                 присутствует  39    Мужчина
# 82    84              170  здоров                 присутствует  9     Женщина
# 83    17              170  здоров                 присутствует  2     Мужчина
# 84    24              170  здоров                 присутствует  2     Женщина
# 85    55              170  здоров                 присутствует  23    Мужчина
# 86    19              182  здоров                 отсутствует   2     Мужчина
# 87    25              192  здоров                 присутствует  2     Мужчина
# 88    73              160  здоров                 присутствует  2     Женщина
# 89    68              173  здоров                 присутствует  2     Мужчина
# 90    44              167  здоров                 присутствует  2     Женщина
# 91    65              170  требуется мед. помощь  присутствует  2     Мужчина
# 92    79              165  требуется мед. помощь  присутствует  2     Женщина
# 93    28              170  здоров                 присутствует  2     Мужчина
# 94    40              145  здоров                 присутствует  2     Женщина
# 95    33              165  здоров                 присутствует  3     Мужчина
# 96    Коля объебался  Er   здоров                 отсутствует   1     Er
# 97    27              186  здоров                 присутствует  2     Мужчина
# 98    60              165  требуется мед. помощь  присутствует  2     Мужчина
# 99    45              170  здоров                 присутствует  2     Мужчина
# 100   47              180  здоров                 присутствует  2     Мужчина
# 101   30              186  здоров                 присутствует  3     Мужчина
# 102   26              168  здоров                 присутствует  2     Мужчина
# 103   40              180  здоров                 присутствует  2     Мужчина
# 104   12              167  здоров                 присутствует  47    Мужчина
# 105   45              172  здоров                 присутствует  2     Мужчина
# 106   40              175  здоров                 присутствует  43    Мужчина
# 107   29              176  здоров                 присутствует  2     Мужчина
# 108   69              175  здоров                 присутствует  19    Мужчина
# 109   37              175  здоров                 присутствует  2     Мужчина
# 110   80              170  здоров                 присутствует  13    Мужчина
# 111   29              173  здоров                 присутствует  2     Женщина
# 112   31              170  здоров                 присутствует  2     Мужчина
# 113   29              185  здоров                 присутствует  2     Мужчина
# 114   27              165  здоров                 присутствует  2     Женщина
# 115   62              164  здоров                 присутствует  31    Женщина
# 116   42              168  требуется мед. помощь  присутствует  2     Женщина
# 117   80              160  здоров                 присутствует  2     Женщина
# 118   50              175  здоров                 присутствует  2     Мужчина
# 119   26              186  здоров                 присутствует  2     Мужчина
# 120   29              173  здоров                 отсутствует   2     Мужчина
# 121   58              170  здоров                 присутствует  36    Мужчина
# 122   Коля объебался  Er   здоров                 отсутствует   1     Er
# 123   36              176  здоров                 присутствует  1     Мужчина
# 124   32              170  требуется мед. помощь  присутствует  2     Мужчина
# 125   15              164  здоров                 присутствует  2     Женщина
# 126   24              175  здоров                 присутствует  2     Мужчина
# 127   15              160  здоров                 отсутствует   2     Мужчина
# 128   33              170  здоров                 присутствует  2     Мужчина
# 129   Коля объебался  165  требуется мед. помощь  присутствует  2     Мужчина
# 130   11              148  здоров                 присутствует  49    Женщина
# 131   60              165  здоров                 присутствует  2     Мужчина
# 132   52              174  здоров                 присутствует  2     Мужчина
# 133   40              170  здоров                 присутствует  2     Мужчина
# 134   34              170  здоров                 присутствует  2     Er
# 135   42              165  здоров                 присутствует  2     Женщина
# 136   34              167  здоров                 присутствует  2     Мужчина
# 137   16              165  здоров                 присутствует  2     Женщина
# 138   31              187  требуется мед. помощь  присутствует  2     Мужчина
# 139   26              174  здоров                 присутствует  2     Мужчина
# 140   82              177  здоров                 присутствует  2     Мужчина
# 141   16              180  здоров                 присутствует  2     Мужчина
# 142   9               130  здоров                 присутствует  40    Мужчина
# 143   39              175  здоров                 присутствует  2     Мужчина
# 144   41              175  здоров                 присутствует  2     Мужчина
# 145   62              174  здоров                 присутствует  3     Мужчина
# 146   17              165  здоров                 присутствует  2     Женщина
# 147   35              175  здоров                 присутствует  1     Мужчина
# 148   Коля объебался  Er   здоров                 отсутствует   1     Er
# 149   19              180  здоров                 присутствует  2     Мужчина
# 150   83              176  требуется мед. помощь  присутствует  27    Мужчина
# 151   16              175  здоров                 присутствует  2     Мужчина
# 152   15              170  здоров                 присутствует  3     Мужчина
# 153   47              175  здоров                 присутствует  2     Мужчина
# 154   51              170  здоров                 присутствует  2     Мужчина
# 155   46              175  здоров                 присутствует  2     Мужчина
# 156   40              182  здоров                 присутствует  3     Мужчина
# 157   19              176  здоров                 присутствует  4     Мужчина
# 158   Коля объебался  170  требуется мед. помощь  отсутствует   44    Мужчина
# 159   16              182  здоров                 присутствует  2     Мужчина
# 160   33              187  здоров                 присутствует  2     Мужчина
# 161   54              177  требуется мед. помощь  присутствует  2     Мужчина
# 162   54              170  здоров                 присутствует  2     Мужчина
# 163   30              174  здоров                 присутствует  87    Мужчина
# 164   11              155  здоров                 присутствует  15    Мужчина
# 165   37              170  здоров                 отсутствует   2     Мужчина
# 166   9               140  здоров                 присутствует  64    Мужчина
# 167   16              170  здоров                 присутствует  2     Мужчина
# 168   48              170  здоров                 отсутствует   2     Мужчина
# 169   9               150  здоров                 присутствует  43    Мужчина
# 170   10              140  здоров                 присутствует  13    Мужчина
# 171   48              170  здоров                 отсутствует   21    Мужчина
# 172   82              170  здоров                 присутствует  49    Мужчина
# 173   17              175  здоров                 присутствует  2     Мужчина
# 174   Коля объебался  Er   здоров                 отсутствует   1     Er
# 175   30              170  здоров                 присутствует  2     Мужчина
# 176   36              178  здоров                 присутствует  2     Мужчина
# 177   31              183  здоров                 присутствует  2     Мужчина
# 178   31              175  требуется мед. помощь  отсутствует   2     Мужчина
# 179   20              153  требуется мед. помощь  присутствует  2     Женщина
# 180   22              180  здоров                 присутствует  2     Мужчина
# 181   66              160  здоров                 присутствует  2     Женщина
# 182   76              175  здоров                 присутствует  27    Мужчина
# 183   16              163  здоров                 присутствует  2     Женщина
# 184   73              180  требуется мед. помощь  присутствует  2     Мужчина
# 185   16              170  требуется мед. помощь  присутствует  7     Мужчина
# 186   67              176  требуется мед. помощь  присутствует  2     Мужчина
# 187   77              175  здоров                 присутствует  2     Мужчина
# 188   24              184  здоров                 присутствует  2     Мужчина
# 189   67              164  требуется мед. помощь  присутствует  43    Женщина
# 190   62              165  здоров                 отсутствует   2     Мужчина
# 191   31              173  здоров                 присутствует  2     Женщина
# 192   21              Er   здоров                 присутствует  2     Мужчина
# 193   11              130  здоров                 присутствует  50    Мужчина
# 194   73              178  требуется мед. помощь  присутствует  42    Мужчина
# 195   35              185  здоров                 отсутствует   2     Мужчина
# 196   80              155  здоров                 присутствует  5     Женщина
# 197   22              170  здоров                 присутствует  2     Женщина
# 198   32              172  здоров                 присутствует  1     Мужчина
# 199   34              173  здоров                 отсутствует   2     Мужчина
# ...   ..              ...     ...                         ...  ..         ...
# 1116  17              180  здоров                 присутствует  4     Мужчина
# 1117  40              162  здоров                 отсутствует   3     Er
# 1118  12              163  здоров                 присутствует  6     Мужчина
# 1119  39              170  здоров                 присутствует  4     Мужчина
# 1120  Коля объебался  173  здоров                 отсутствует   2     Женщина
# 1121  Коля объебался  188  здоров                 отсутствует   2     Мужчина
# 1122  Коля объебался  165  требуется мед. помощь  отсутствует   4     Er
# 1123  Коля объебался  150  здоров                 отсутствует   2     Женщина
# 1124  Коля объебался  175  здоров                 присутствует  2     Мужчина
# 1125  Коля объебался  180  требуется мед. помощь  присутствует  7     Мужчина
# 1126  Коля объебался  Er   здоров                 отсутствует   53    Er
# 1127  35              170  здоров                 отсутствует   1     Женщина
# 1128  23              170  здоров                 отсутствует   12    Er
# 1129  50              193  здоров                 отсутствует   1     Мужчина
# 1130  Коля объебался  177  здоров                 присутствует  10    Мужчина
# 1131  5               Er   здоров                 присутствует  2     Мужчина
# 1132  Коля объебался  Er   здоров                 отсутствует   31    Er
# 1133  82              175  здоров                 отсутствует   3     Мужчина
# 1134  90              160  здоров                 присутствует  2     Мужчина
# 1135  86              160  здоров                 отсутствует   7     Женщина
# 1136  Коля объебался  Er   здоров                 отсутствует   1     Er
# 1137  26              167  здоров                 отсутствует   2     Женщина
# 1138  33              163  здоров                 отсутствует   7     Женщина
# 1139  69              160  здоров                 отсутствует   4     Женщина
# 1140  1               170  здоров                 отсутствует   2     Женщина
# 1141  35              180  здоров                 отсутствует   4     Мужчина
# 1142  54              Er   здоров                 отсутствует   2     Женщина
# 1143  15              Er   здоров                 отсутствует   2     Женщина
# 1144  06              176  здоров                 присутствует  3     Женщина
# 1145  27              Er   здоров                 присутствует  2     Мужчина
# 1146  13              Er   здоров                 присутствует  2     Мужчина
# 1147  35              182  здоров                 отсутствует   1     Мужчина
# 1148  78              170  здоров                 присутствует  2     Er
# 1149  31              175  здоров                 присутствует  4     Мужчина
# 1150  14              174  здоров                 отсутствует   2     Мужчина
# 1151  32              173  здоров                 отсутствует   2     Женщина
# 1152  Коля объебался  165  здоров                 присутствует  7     Er
# 1153  39              176  здоров                 отсутствует   4     Мужчина
# 1154  31              176  здоров                 отсутствует   10    Er
# 1155  19              Er   здоров                 отсутствует   1     Er
# 1156  11              152  здоров                 отсутствует   2     Мужчина
# 1157  10              150  здоров                 отсутствует   2     Женщина
# 1158  21              182  здоров                 присутствует  3     Мужчина
# 1159  Коля объебался  165  здоров                 отсутствует   2     Женщина
# 1160  9               140  здоров                 отсутствует   9     Мужчина
# 1161  Коля объебался  Er   здоров                 отсутствует   3     Er
# 1162  Коля объебался  Er   здоров                 отсутствует   1     Er
# 1163  73              158  здоров                 отсутствует   17    Женщина
# 1164  Коля объебался  Er   здоров                 отсутствует   9     Er
# 1165  28              188  здоров                 отсутствует   1     Мужчина
# 1166  34              178  здоров                 отсутствует   1     Мужчина
# 1167  56              168  здоров                 отсутствует   5     Мужчина
# 1168  40              170  здоров                 отсутствует   28    Er
# ...
# 173   0                0                0.000000      Февраль  2019
# 174   0                0                0.000000     Март      2016
# 175   0                0                0.000000     Январь    2019
# 176   0                0                0.000000      Февраль  2019
# 177   0                0                0.000000      Февраль  2019
# 178   0                0                0.000000      Февраль  2019
# 179   0                0                0.000000      Февраль  2019
# 180   0                0                0.000000      Февраль  2019
# 181   0                0                0.000000      Февраль  2019
# 182   0                0                0.000000      Февраль  2019
# 183   0                0                0.000000      Февраль  2019
# 184   0                0                0.000000      Февраль  2019
# 185   0                0                0.000000      Февраль  2019
# 186   0                0                0.000000     Январь    2019
# 187   0                0                0.000000      Февраль  2019
# 188   0                0                0.000000      Февраль  2019
# 189   0                0                0.000000      Февраль  2019
# 190   0                0                0.000000      Февраль  2019
# 191   0                0                0.000000      Февраль  2019
# 192   0                0                0.000000     Январь    2019
# 193   0                0                0.000000      Февраль  2019
# 194   0                0                0.000000      Февраль  2019
# 195   0                0                0.000000      Февраль  2019
# 196   0                0                0.000000      Февраль  2019
# 197   0                0                0.000000     Ноябрь    2018
# 198   0                0                0.000000      Февраль  2019
# 199   0                0                0.000000      Февраль  2019
# ...  ..               ..                     ...          ...   ...
# 1116  0                0                0.000000     Ноябрь    2014
# 1117  0                0                0.000000     Ноябрь    2014
# 1118  0                0                0.000000     Июнь      2014
# 1119  0                0                0.000000     Апрель    2014
# 1120  0                0                0.000000     Апрель    2014
# 1121  0                0                0.000000     Апрель    2014
# 1122  0                0                0.000000     Апрель    2014
# 1123  0                0                0.000000     Октябрь   1992
# 1124  0                0                0.000000     Апрель    2014
# 1125  0                0                0.000000      Февраль  2014
# 1126  0                0                0.000000     Ноябрь    2010
# 1127  0                0                0.000000     Ноябрь    2013
# 1128  0                0                0.000000     Ноябрь    2013
# 1129  0                0                0.000000     Ноябрь    2013
# 1130  0                0                0.000000     Июль      2013
# 1131  0                0                0.000000     Сентябрь  2013
# 1132  0                0                0.000000     Июль      2013
# 1133  0                0                0.000000     Июль      2013
# 1134  0                0                0.000000     Июнь      2013
# 1135  0                0                0.000000     Июнь      2013
# 1136  0                0                0.000000     Март      2016
# 1137  0                0                0.000000     Июнь      2013
# 1138  0                0                0.000000      Февраль  2013
# 1139  0                0                0.000000     Май       2013
# 1140  0                0                0.000000     Июнь      2013
# 1141  0                0                0.000000     Январь    2013
# 1142  0                0                0.000000     Апрель    2013
# 1143  0                0                0.000000      Февраль  2013
# 1144  0                0                0.000000     Октябрь   1972
# 1145  0                0                0.000000     Январь    2013
# 1146  0                0                0.000000     Март      2013
# 1147  0                0                0.000000     Март      1984
# 1148  0                0                0.000000     Март      2013
# 1149  0                0                0.000000     Январь    2013
# 1150  0                0                0.000000     Январь    2013
# 1151  0                0                0.000000     Январь    2013
# 1152  0                0                0.000000     Январь    2013
# 1153  0                0                0.000000     Январь    2013
# 1154  0                0                0.000000     Декабрь   2012
# 1155  0                0                0.000000     Январь    2013
# 1156  0                0                0.000000     Январь    2013
# 1157  0                0                0.000000     Январь    2013
# 1158  0                0                0.000000     Январь    2013
# 1159  0                0                0.000000     Декабрь   2012
# 1160  0                0                0.000000     Ноябрь    2012
# 1161  0                0                0.000000     Декабрь   2012
# 1162  0                0                0.000000     Март      2016
# 1163  0                0                0.000000     Октябрь   2012
# 1164  0                0                0.000000     Ноябрь    2011
# 1165  0                0                0.000000     Декабрь   2012
# 1166  0                0                0.000000     Ноябрь    2012
# 1167  0                0                0.000000     Ноябрь    2012
# 1168  0                0                0.000000     Октябрь   2012
# 1169  0                0                0.000000     Сентябрь  2012
# 1170  0                0                0.000000     Ноябрь    2012
# 1171  0                0                0.000000     Ноябрь    2012
# 1172  0                0                0.000000     Ноябрь    2012
# 1173  0                0                0.000000     Ноябрь    2012
# 1174  0                0                0.000000     Ноябрь    2012
# 1175  0                0                0.000000     Сентябрь  2012
# 1176  0                0                0.000000     Сентябрь  2012
# 1177  0                0                0.000000     Сентябрь  2012
# 1178  0                0                0.000000     Сентябрь  2012
# 1179  0                0                0.000000     Сентябрь  2012
# 1180  0                0                0.000000     Июль      2012
# 1181  0                0                0.000000      Февраль  2012
# 1182  0                0                0.000000     Март      2012
# 1183  0                0                0.000000      Февраль  2012
# 1184  0                0                0.000000      Февраль  2012
# 1185  0                0                0.000000     Январь    2012
# 1186  0                0                0.000000     Октябрь   2011
# 1187  0                0                0.000000     Декабрь   2011
# 1188  0                0                0.000000     Март      2016
# 1189  0                0                0.000000     Октябрь   2011
# 1190  0                0                0.000000     Март      2016
# 1191  0                0                0.000000     Сентябрь  2017
# 1192  0                0                0.000000     Январь    2017
# 1193  0                0                0.000000     Январь    2017
# 1194  0                0                0.000000     Май       2015
# 1195  0                0                0.000000     Октябрь   2014
# 1196  0                0                0.000000     Октябрь   2014
# 1197  0                0                0.000000     Август    2014
# 1198  0                0                0.000000     Сентябрь  2014
# 1199  0                0                0.000000     Октябрь   2014
# 1200  0                0                0.000000     Октябрь   2014
# 1201  0                0                0.000000     Август    2014
# 1202  0                0                0.000000     Август    2014
# 1203  0                0                0.000000     Июль      2014
# 1204  0                0                0.000000     Июль      2014
# 1205  0                0                0.000000     Июль      2014
# 1206  0                0                0.000000     Июль      2014
# 1207  0                0                0.000000     Январь    1962
# 1208  0                0                0.000000     Октябрь   2012
# 1209  0                0                0.000000     Июнь      2014
# 1210  0                0                0.000000     Декабрь   2013
# 1211  0                0                0.000000     Октябрь   2012
# 1212  0                0                0.000000     Март      2016
# 1213  0                0                0.000000     Декабрь   2018
# 1214  0                0                0.000000      Февраль  2012
# 1215  0                0                0.000000     Март      2013
# 1216  0                0                0.000000     Март      2016
# 1217  0                0                0.000000     Май       2019
# 1218  0                0                0.000000     Май       2019
# 1219  0                0                0.000000     Май       2019
# 1220  0                0                0.000000     Апрель    2018
# 1221  0                0                0.000000     Август    2017
# 1222  0                0                0.000000     Июль      2017
# 1223  0                0                0.000000     Апрель    2019
# 1224  0                0                0.000000     Июнь      2018
# 1225  0                0                0.000000     Март      2019
# 1226  0                0                0.000000     Март      2019
# 1227  0                0                0.000000     Март      2019
# 1228  0                0                0.000000     Сентябрь  2018
# 1229  0                0                0.000000     Март      2019
# 1230  0                0                0.000000      Февраль  2019
# 1231  0                0                0.000000     Январь    2019
# 1232  0                0                0.000000     Декабрь   2018
# 1233  0                0                0.000000     Ноябрь    2018
# 1234  0                0                0.000000     Ноябрь    2018
# 1235  0                0                0.000000     Ноябрь    2018
# 1236  0                0                0.000000     Ноябрь    2018
# 1237  0                0                0.000000     Октябрь   2018
# 1238  0                0                0.000000     Июль      2018
# 1239  0                0                0.000000     Май       2018
# 1240  0                0                0.000000     Июнь      2018
# 1241  0                0                0.000000     Сентябрь  2018
# 1242  0                0                0.000000     Март      2016
# 1243  0                0                0.000000     Май       2019
# 1244  0                0                0.000000     Декабрь   2018
# 1245  0                0                0.000000     Май       2019
# 1246  0                0                0.000000     Май       2019
# 1247  0                0                0.000000     Май       2019
# 1248  0                0                0.000000     Май       2019
# 1249  0                0                0.000000     Май       2019
# 1250  0                0                0.000000     Апрель    2019
# 1251  0                0                0.000000     Май       2019
# 1252  0                0                0.000000     Май       2019
# 1253  0                0                0.000000     Май       2019
# 1254  0                0                0.000000     Май       2019
# 1255  0                0                0.000000     Май       2019
# 1256  0                0                0.000000     Апрель    2019
# 1257  0                0                0.000000     Май       2019
# 1258  0                0                0.000000     Май       2019
# 1259  0                0                0.000000     Май       2019
# 1260  0                0                0.000000     Май       2019
# 1261  0                0                0.000000     Май       2019
# 1262  0                0                0.000000     Май       2019
# 1263  0                0                0.000000     Май       2019
# 1264  0                0                0.000000     Май       2019
# 1265  0                0                0.000000     Май       2019
# 1266  0                0                0.000000     Май       2019
# 1267  0                0                0.000000     Май       2019
# 1268  0                0                0.000000     Март      2016
# 1269  0                0                0.000000     Апрель    2019
# 1270  0                0                0.000000     Декабрь   2018
# 1271  0                0                0.000000     Декабрь   2018
# 1272  0                0                0.000000     Ноябрь    2018
# 1273  0                0                0.000000     Ноябрь    2018
# 1274  0                0                0.000000     Ноябрь    2018
# 1275  0                0                0.000000     Ноябрь    2018
# 1276  0                0                0.000000     Октябрь   2018
# 1277  0                0                0.000000     Октябрь   2018
# 1278  0                0                0.000000     Октябрь   2018
# 1279  0                0                0.000000     Октябрь   2018
# 1280  0                0                0.000000     Октябрь   2018
# 1281  0                0                0.000000     Сентябрь  2018
# 1282  0                0                0.000000     Август    2018
# 1283  0                0                0.000000     Август    2018
# 1284  0                0                0.000000     Август    2018
# 1285  0                0                0.000000     Январь    2018
# 1286  0                0                0.000000     Декабрь   2017
# 1287  0                0                0.000000     Декабрь   2017
# 1288  0                0                0.000000     Июль      2017
# 1289  0                0                0.000000     Ноябрь    2017
# 1290  0                0                0.000000     Ноябрь    2017
# 1291  0                0                0.000000     Ноябрь    2017
# 1292  0                0                0.000000     Октябрь   2017
# 1293  0                0                0.000000     Октябрь   2017
# 1294  0                0                0.000000     Март      2016
# 1295  0                0                0.000000     Январь    2014
# 1296  0                0                0.000000      Февраль  2014
# 1297  0                0                0.000000     Март      2016
# 1298  0                0                0.000000     Апрель    2019
# 1299  0                0                0.000000     Октябрь   2018
# 1300  0                0                0.000000     Октябрь   2018
# 1301  0                0                0.000000     Сентябрь  2018
# 1302  0                0                0.000000     Сентябрь  2018
# 1303  0                0                0.000000     Май       2018
# 1304  0                0                0.000000     Июнь      2018
# 1305  0                0                0.000000      Февраль  2018
# 1306  0                0                0.000000     Август    2017
# 1307  0                0                0.000000     Сентябрь  2017
# 1308  0                0                0.000000     Июль      2015
# 1309  0                0                0.000000     Август    2015
# 1310  0                0                0.000000     Июль      2014
# 1311  0                0                0.000000     Июль      2013
# 1312  0                0                0.000000     Ноябрь    2012
# 1313  0                0                0.000000     Сентябрь  2012
# 1314  0                0                0.000000     Сентябрь  2012
# 1315  0                0                0.000000      Февраль  1991
#
# [1316 rows x 32 columns]

# %%
df1.to_excel("NorthWest.xlsx")
