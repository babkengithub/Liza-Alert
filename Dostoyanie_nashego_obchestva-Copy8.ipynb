# %%
import numpy as np
import pandas as pd
import re
import bs4
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
from scrapy import Selector
from nltk import word_tokenize
import nltk
nltk.download('punkt') #winlocker
pd.set_option("display.max_rows", 400)
pd.set_option("display.max_columns", 50)
pd.set_option('display.max_colwidth', -1)
import datetime
from datetime import datetime, time, date
import scrapy
from scrapy.selector import Selector
import requests
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# Данные для поиска силы лис

# %%
names_df = pd.read_excel('names_df.xlsx')

# %%
names_list = list(names_df["Unnamed: 0"])

# %%
#names_list = list(names_df.index)

# %%
messages_list = list(names_df["Количество сообщений"])

# %% [markdown]
# Привязка к tracks10

# %%
df_coor = pd.read_excel("final_coords.xlsx")
list_x_tracks = []
for i in range(len(df_coor["liza"])):
    list_x_tracks.append(float('%.10g' % df_coor["liza"][i]))
list_url = list(df_coor["url"])
list_km = list(df_coor["km"])
list_teams = list(df_coor["teams"])
list_date1 = list(df_coor["date1"])
list_date2 = list(df_coor["date2"])

# %% [markdown]
# Привязка (шаг 0) закончена

# %%
# ДЛЯ КОЛИ!!!!!!!!!!!!!!!!!!!!!
import requests
#ssylka = 'https://lizaalert.org/forum/viewforum.php?f=180'
ssylka = 'https://lizaalert.org/forum/viewforum.php?f=183'
html1 = requests.get(ssylka).content #url='google.com'
sel1 = Selector(text=html1)
course_as11 = sel1.xpath('//a[contains(@class,"forumtitle")]')
hrefs11_from_css = course_as11.css('::attr(href)')


hrefz = list()
for i in range(len(hrefs11_from_css.extract())):
    clean_link1 = "https://lizaalert.org/forum" + str(hrefs11_from_css.extract()[i])[1:]
    hrefz.append(clean_link1)

# %%
hrefzz = []
for i in range(len(hrefz)):
    html = requests.get(hrefz[i]).content #url='google.com'
    selka = Selector(text=html)
    course90 = selka.xpath('//a[contains(@class,"forumtitle")]')
    hrefs90_from_css = course90.css('::attr(href)')
    for i in range(len(hrefs90_from_css.extract())):
        clean_link11 = "https://lizaalert.org/forum" + str(hrefs90_from_css.extract()[i])[1:]
        hrefzz.append(clean_link1)
for i in range(len(hrefz)):
    hrefzz.append(hrefz[i])

# %%
# Import requests
import requests

list_of_all_pages = list()
# Create the string html containing the HTML source
for i in range(len(hrefzz)):
    html = requests.get(hrefzz[i]).content #url='google.com'
    sel = Selector(text=html)

    uClient = uReq(hrefzz[i])
    page_html = uClient.read()
    uClient.close()
    page_soup = soup(page_html, "html.parser")
    containers2 = page_soup.findAll("div", {"class":"pagination"})
    containers22 = str(containers2)

    def page12(containers22):
        page1 = list()
        c = containers22.find("из ")
        page1.append(containers22[c+11])
        page1.append(containers22[c+12])
        if containers22[c+12] == "<":
            page1.pop()
        return page1

    if len(page12(containers22)) == 2:
        page_real = int(page12(containers22)[0] + page12(containers22)[1])
    else:
        page_real = int(page12(containers22)[0])

    # Парсим
    course_as = sel.xpath('//a[contains(@class,"right-box right")]')
    hrefs_from_css = course_as.css('::attr(href)')
    
    if len(str(hrefs_from_css.extract())[1:]) == 1:
        links_to_follow = ssylka
        clean_link = ssylka
    else:
        links_to_follow = "\"https://lizaalert.org/forum" + str(hrefs_from_css.extract()[0])[1:] + "\""
        clean_link = str(hrefs_from_css.extract()[0])[1:len(hrefs_from_css.extract()[0])-2]
    list_links = list()
    for i in range((page_real)-1):
        list_links.append(clean_link)

    #За 500 надо пояснить! Но это вроде несложно
    i=0
    list1 = list()
    for i in range(0,(page_real-1)*25, 25):
        i = i + 25
        list1.append(i)

    result = [str(item) for item in list1]

    for i in range(len(list1)):
        list_links[i] += result[i]

    for i in range(len(list_links)):
        list_links[i] = "https://lizaalert.org/forum" + list_links[i]
    list_of_all_pages.append(list_links)

# %%
print(len(list_of_all_pages))
listSYKA = list()
for i in range(len(list_of_all_pages)):
    for j in range(len(list_of_all_pages[i])):
        listSYKA.append(list_of_all_pages[i][j])

for j in range(len(hrefzz)):
    listSYKA.append(hrefzz[j])
listSYKA.append(ssylka)
# Out:
# 23

# %%
list_full = list()
for i in range(len(listSYKA)):
    #html = requests.get(list_links[i]).content #url='google.com'
    html = requests.get(listSYKA[i]).content #url='google.com'
    sel = Selector(text=html)

    course_as1 = sel.css('a.topictitle')
    hrefs1_from_css = course_as1.css('::attr(href)')

    list0 = list()
    for i in range(0, len(hrefs1_from_css.extract())):
        list0.append("https://lizaalert.org/forum" + str(hrefs1_from_css.extract()[i])[1:])
        list_full.append(list0[i])
#print(list_full)
print(len(list_full))
# Out:
# 3082

# %%
my_list = list_full

# %%
my_list[0]
print(len(list_full))
# Out:
# 3082

# %% [markdown]
# # Здесь соберем все вспомогательные перменные

# %%
list_searchers = []
list_photo = []
list_state1 = []
list_sex1 = []
list_age11 = []
list_posts = []
list_height = []
list_help1 = []
list_hair_color = []
list_bodytype = []
list_eye = []
list_of_lists = []  ## Здесь нужно додумать
list_place = []
list_color_of_clothes = []# Бабкен Вставил
list_of_lists = []  ## Здесь нужно додумать
list_podrobnost = []
list_primeti = []
list_search_time =[]
list_lost_time = []
list_find_time = []
list_of_coor = []
list_x_tracks1 = []
list_url1 = []
list_km1 = []
list_teams1 = []
list_date11 = []
list_date22 = []
list_delta = []
list_of_power = []
list_month = []
list_year = []

# %%
english_stops = ['.', ',', ':', ';', "!", "?", '-', ')', '(']
months_num = {"янв": 1, "фев": 2, "мар": 3,"апр": 4,"мая": 5, "май": 5,"июн": 6,"июл": 7,"авг": 8,"сен": 9,"окт": 10,"ноя": 11,"дек": 12,"Янв": 1, "Фев": 2, "Мар": 3,"Апр": 4,"Март": 5, "Май": 5,"Июн": 6,"Июл": 7,"Авг": 8,"Сен": 9,"Окт": 10,"Ноя": 11,"Дек": 12}
match_months = {'01': 'Январь', '02': ' Февраль', '03': 'Март', '04': 'Апрель', '05': 'Май', '06': 'Июнь', '07': 'Июль', '08': 'Август', '09': 'Сентябрь', '10': 'Октябрь', '11': 'Ноябрь', '12': 'Декабрь'}

# %% [markdown]
# # Напишем все функции, которые нам понадобятся в сборе признаков

# %%
def fox_power(containers228, names_list, messages_list):
    sila = 0
    if containers228 == 'ebanyi obychenie':
        sila = 0
    else:
        kerka = containers228.findAll(text=re.compile(r'\w+'))
        for i in range(len(names_list)):
            for j in range(len(kerka)):
                if names_list[i] in kerka[j]:
                    sila += int(messages_list[i])
    return sila

# %%
def searchers(containers228):
    if containers228 == 'ebanyi obychenie':
        searchers = 0
    else:
        kerka = containers228.findAll(text=re.compile(r'\w+'))
        kerka1 = containers228.findAll(text=re.compile(r'На месте|НА МЕСТЕ|Дом|ДОМ|Экипаж|ЭКИПАЖ'))
        searchers = (len(kerka) - len(kerka1))
    return searchers

# %%
def photo1(containers11):
    if containers11.find("Изображение") != -1:
        photo =  'присутствует'
    else:
        photo = 'отсутствует'
    return photo

# %%
def state1(title1):
    if title1.find("Жив") != -1 or title1.find("ЖИВ") != -1 or title1.find("Найден") != -1 or title1.find("НАЙДЕН") != -1:
        state = "живой"
    elif title1.find("Пропал") != -1 or title1.find("ПРОПАЛ") != -1:
        state = 'ищется'
    elif title1.find("Погиб") != -1 or title1.find("ПОГИБ") != -1 or title1.find("Мертв") != -1 or title1.find("МЕРТВ") != -1:
        state = 'мертвый'
    else:
        state = "Не указано"
    return state

# %%
def sex1(title1): # Слава вставил 8 мая 
    sex = re.search(r'[Пп]ропала|[Вв]ышла|[Уу]шла|[Нн]айдена|[Жж]ива|[Ее]ё|[Ее]е|[Ее]го|[Уу]ехала|[Пп]огибла|[Вв]ернулась|не [Вв]ернулась|[Вв]ышел|[Уу]шёл|[Уу]шел|[Пп]ропал|[Нн]айден|[Жж]ив|[Ее]го|[Уу]ехал|[Пп]огиб|[Вв]ернулся|не [Вв]ернулся', title1)
    if sex is None:
        return "Er"
    sex = str(sex.group(0))
    if sex == "вышел" or sex == "Вышел" or sex == "ушел" or sex == "Ушел" or sex == 'ушёл' or sex == 'пропал' or sex == 'Пропал' or sex == 'Найден' or sex == 'найден' or sex == 'ушел'or sex == 'ушёл'or sex == 'пропал'or sex == 'найден'or sex == 'Найден'or sex == 'вышел' or sex == 'Жив'or sex == 'жив' or sex == 'уехал'or sex == 'Погиб'or sex == 'погиб'or sex == 'вернулся':
        sex = "Мужчина"
    else:
        sex = "Женщина"
    return sex

# %%
def age11(title1):
    preage = re.search(r'\d+', str(title1))
    if preage is None:
        return "Коля объебался"
    else:
        age = preage.group()
        if len(age) == 4:
            age = 2019 - int(age)
    return age

# %%
def posts1(containers2):
    posts = re.search(r'\d+', str(containers2)).group()
    return posts

# %%
def data1(containers88):
    d = containers88.find("Инфорг")
    if d == -1:
        data1, data2 = 'не','редактировали'
    else:
        data1 = containers88[d+11] + containers88[d+12] + containers88[d+13] + containers88[d+14] + containers88[d+15] + containers88[d+16] + containers88[d+17] + containers88[d+18] + containers88[d+19] + containers88[d+20] + containers88[d+21]
        data2 = containers88[d+24] + containers88[d+25] + containers88[d+26] + containers88[d+27] + containers88[d+28]
        data = data1 + ' ' + data2
    return data

# %%
def height(containers11): # Вставил Слава 8.05.2019
    high = re.search(r'[Рр]ост \d{3}|[Рр]оста \d{3}|[Рр]оста\d{3}|[Рр]ост: \d{3}|[Рр]ост - \d{3}|рост\d{3}-|Рост:\d{3}| росто \d{3}', containers11 )
    if high is None:
        return "Er"
    high = str(high.group(0))

    height = re.findall(r'\d+',high)
    height = int(" ".join(height))
    return height

# %%
def help1(containers11):
    if containers11.find("В МЕДИЦИНСКОЙ ПОМОЩИ") == -1 and containers11.find("в медицинской помощи") == -1:
        help1 = 'здоров'
    else:
        help1 = 'требуется мед. помощь'
    return help1

# %%
def hair_color(contents):
    hc = 'Не указано'
    for string in contents:
        if "олосы" in string:
            no_stops_string_1 = ''.join([t for t in string if t not in english_stops])
            tokens_1 = word_tokenize(no_stops_string_1)
            for i in range(len(tokens_1)):
                if "олосы" in tokens_1[i]:
                    if i < (len(tokens_1) - 1):
                        hc = tokens_1[i + 1]
                    else:
                        hc = tokens_1[i-1]
    return hc

# %%
## Нужно доработать код! Или сделать заново
def body_type(contents):
    body = "Не указано"
    for string in contents:
        if "елосложени" in string:
            no_stops_string = ''.join([t for t in string if t not in english_stops])
            tokens = word_tokenize(no_stops_string)
            tokens.append("Ты объебался")
            for i in range(len(tokens)):
                if "елосложени" in tokens[i]:
                    if tokens[i][-1] == "я":
                        body = tokens[i - 1]
                        break
                    else:
                        body = tokens[i + 1]
                        break
    return body

# %%
## Нужно доработать код! Или сделать заново
def eyes_color(contents):
    ec = "Не указано"
    for string in contents:
        if "лаз" in string:
            no_stops_string = ''.join([t for t in string if t not in english_stops])
            tokens = word_tokenize(no_stops_string)
            tokens.append("Кто-то объебался")
            for i in range(len(tokens)):
                if "лаз" in tokens[i]:
                    ec = tokens[i + 1]
                if ec == "Кто-то объебался":
                    ec = tokens[i-1]
                    break
    return ec

# %%
def yebanskii(sel):
    p = sel.css("div.content").xpath('./span[@style="font-size: 140%; line-height: 116%;"]/span[@style="font-weight: bold"]/text()').extract()
    a = str(p)
    b = re.split('\s+', a)
    b1 = b[5:]
    t = str(b1)
    p = t.replace("\'", "")
    p1 = p.replace(']', '')
    p2 = p1.replace('[', '')
    p3 = p2.replace('"', '')
    p4 = p3.replace(', ', " ")
    p5 = p4.replace('- ','-')
    return p5

# %%
def color_cloth(containers11):
    containers1 = re.split('<span style="font-weight: bold">', containers11)
    if len(containers1) < 4:
        return "Не указано"
    else:
        containers_new = containers1[3]
        black = len(re.findall(r'черн', containers_new))
        white = len(re.findall(r'бел', containers_new))
        yellow = len(re.findall(r'желт', containers_new))
        orange = len(re.findall(r'оранж', containers_new))
        br_grey = len(re.findall(r'тло-сер', containers_new))
        grey = len(re.findall(r'сер', containers_new))
        beg = len(re.findall(r'бежев', containers_new))
        br_blue = len(re.findall(r'тло-син', containers_new))
        blue = len(re.findall(r'син', containers_new))
        green = len(re.findall(r'зелен', containers_new))
        violent = len(re.findall(r'фиол', containers_new))
        black1 = len(re.findall(r'чёрн', containers_new))
        brown = len(re.findall(r'коричн', containers_new))
        al_colors = black + yellow + orange + grey + beg + blue + green + violent + black1
        br_colors1 = white + yellow + orange + br_grey + beg + br_blue + green + violent
        br_colors2 = white + yellow + orange + beg + br_blue + green + violent
        br_colors3 = white + yellow + orange + br_grey + beg + green + violent
        br_colors4 = white + yellow + orange + beg + green + violent
        dk_colors1 = black + black1 + brown
        dk_colors2 = black + grey + black1 + brown
        dk_colors3 = black + blue + black1 + brown
        dk_colors4 = black + blue + grey + black1 + brown
        if al_colors == 0:
            return "Не указано" 
        elif (br_grey == 0 and br_blue == 0) and br_colors4 >= dk_colors4:
            return "Яркая"
        elif (br_grey == 0 and br_blue == 0) and br_colors4 < dk_colors4:
            return "Темная"
        elif ((br_grey != 0 and grey != 0) or (br_blue != 0 and blue != 0 )) and br_colors1 >= dk_colors4:
            return "Яркая"
        elif ((br_grey != 0 and grey != 0) or (br_blue != 0 and blue != 0 )) and br_colors1 < dk_colors4:
            return "Темная"
        elif (br_grey == 0) and br_colors2 >= dk_colors2:
            return "Яркая" 
        elif (br_grey == 0) and br_colors2 < dk_colors2:
            return "Темная" 
        elif (br_blue == 0) and br_colors3 >= dk_colors3:
            return "Яркая"

# %%
def podrobnost(containers11):
    containers1 = re.split('<span style="font-weight: bold">', containers11)
    if len(containers1) < 4:
        return("Не указано")
    else:
        containers_new = containers1[3]
        containers_new_sep = containers_new.split(',')
        l = len(containers_new_sep)
        if l > 3:
            return 4
        elif 2 <= l < 3:
            return 3
        else:
            return 0

# %%
def primeti(containers11):
    containers1 = re.split('<span style="font-weight: bold">', containers11)
    if len(containers1) < 5:
        return("Не указано")
    else:
        containers_new = containers1[4]
        containers_new_sep = containers_new.split(',')
        l = len(containers_new_sep)
        if l > 3:
            return 4
        elif 2 <= l < 3:
            return 2
        else:
            return 0

# %%
def lost_timing(x, y):
    if re.search(r'\d+ \w+ \d{4}|\d{2}[.]\d{2}[.]\d{4}', x) == None:
        if re.search(r'\d+\s\w+\s\d+', y) != None:
            lost_time = re.search(r'\d+\s\w+\s\d+', y).group()
            lts = lost_time.split()
            lts[1] = months_num[lts[1][:3]]
            lts = list(map(int, lts))
            lost_time = date(lts[-1], lts[-2], lts[-3])
            return lost_time
        else:
            return "Сбой"
    else:
        lost_time = re.search(r'\d+ \w+ \d{4}|\d{2}[.]\d{2}[.]\d{4}', x).group()
        if "я" in lost_time or "т" in lost_time:
            lts = lost_time.split()
            lts[1] = months_num[lts[1][:3]]
            lts = list(map(int, lts))
            lost_time = date(lts[-1], lts[-2], lts[-3])
            return lost_time
        else:
            lts = lost_time.split('.')
            lts = list(map(int, lts))
            lost_time = date(lts[-1], lts[-2], lts[-3])
            return lost_time

# %%
def find_timing(x, y):
    if re.search(r'\d+ \w+ \d{4}|\d{2}[.]\d{2}[.]\d{4}', x) == None:
        if re.search(r'\d+\s\w+\s\d{4}', y) != None:
            find_time = re.search(r'\d+\s\w+\s\d{4}', y).group()
            fts = find_time.split()
            fts[1] = months_num[fts[1]]
            fts = list(map(int, fts))
            find_time = date(fts[-1], fts[-2], fts[-3])
            return find_time
        else:
            return "Сбой"
    else:
        find_time = re.search(r'\d+ \w+ \d{4}|\d{2}[.]\d{2}[.]\d{4}', x).group()
        fts = find_time.split()
        fts[1] = months_num[fts[1]]
        fts = list(map(int, fts))
        find_time = date(fts[-1], fts[-2], fts[-3])
        return find_time

# %%
def search_timing(x, y, babken, slava):
    return (find_timing(y, slava) - lost_timing(x, babken)).days

# %%
def super_format(function, x, y):
    if len(str(function(x, y).day)) == 1:
        day = "0" + str(function(x, y).day)
    else:
        day = str(function(x, y).day)
    if len(str(function(x, y).month)) == 1:
        month = "0" + str(function(x, y).month)
    else:
        month = str(function(x, y).month)
    return day + "." + month + "." + str(function(x, y).year)

# %%
def find_cor(comp):
    for i in range (len(comp)):
        contents = page_soup.findAll("div", {"class":"content"})[i].contents
        kavka = re.search(r'\d+.\d+, \d+.\d+|\d+.\d+,\d+.\d+|\d+.\d+ \d+.\d+', str(contents))
        if kavka is not None:
            kavkaz = kavka.group()
            break
        else:
            kavkaz = 'no cord'
    return kavkaz

# %% [markdown]
# # Перейдем к сбору признаков

# %%
for i in my_list:
    my_url = i
    vanya_url = requests.get(my_url).content
    vanya_selector = Selector(text=vanya_url)
    uClient = uReq(my_url)
    page_html = uClient.read()
    uClient.close()
    page_soup = soup(page_html, "html.parser")
    title = page_soup.title
    title1 = str(title)

    comp = page_soup.findAll("div", {"class":"content"})
    containers = page_soup.findAll("div", {"class":"content"})
    contents = page_soup.findAll("div", {"class":"content"})[0].contents
    containers11 = str(containers)
    containers2 = page_soup.findAll("div", {"class":"pagination"})
    containers22 = str(containers2)
    containers8 = page_soup.findAll("div", {"class":"notice"})
    containers88 = str(containers8) 
    containers1 = re.split('<span style="font-weight: bold">', containers11)
    if len(page_soup.findAll("div", {"class":"content"})) > 1:
        containers228 = page_soup.findAll("div", {"class":"content"})[1]
    else:
        containers228 = 'ebanyi obychenie'
    
    list_searchers.append(searchers(containers228))
    list_photo.append(photo1(containers11))
    list_state1.append(state1(title1))
    list_sex1.append(sex1(title1))
    list_age11.append(age11(title1))
    list_posts.append(posts1(containers22))
    list_hair_color.append(hair_color(contents))
    list_bodytype.append(body_type(contents))
    list_eye.append(eyes_color(contents))
    containers = page_soup.findAll("div", {"class":"content"})
    containers11 = str(containers)
    list_height.append(height(containers11))
    list_help1.append(help1(containers11))
    list_place.append(yebanskii(vanya_selector))
    list_color_of_clothes.append(color_cloth(containers11)) # Бабкен вставил
    list_podrobnost.append(podrobnost(containers11)) # Бабкен вставил еще раз, но уже Ване
    list_primeti.append(primeti(containers11))
    
    
    babken = page_soup.find('p', {'class': 'author'}).text
    if vanya_selector.xpath('//p[@class="author"]/text()').extract_first() != None:
        juk_slava = vanya_selector.xpath('//p[@class="author"]/text()').extract()[-1]
    else:
        juk_slava = 'Сбой'
    if vanya_selector.xpath('//div[@class="content"]/text()').extract_first() != None:
        main = vanya_selector.xpath('//div[@class="content"]/text()').extract_first()
    else:
        main = "Сбой"
    if lost_timing(main, babken) != "Сбой":
        list_lost_time.append(super_format(lost_timing, main, babken))
    else:
        list_lost_time.append("Ошибка")
        
    if vanya_selector.xpath('//div[@class="notice"]/text()').extract_first() != None:
        notmain = vanya_selector.xpath('//div[@class="notice"]/text()').extract()[1]
    else:
        notmain = "Сбой"
    if find_timing(notmain, juk_slava) != "Сбой":
            list_find_time.append(super_format(find_timing, notmain, juk_slava))
    else:
        list_find_time.append("Ошибка")

        
        
    if lost_timing(main, babken) != "Сбой" and find_timing(notmain, juk_slava) != "Сбой":
        list_search_time.append(search_timing(main, notmain, babken, juk_slava))
    else:
        list_search_time.append("Ошибка") 
            
    list_month.append(match_months[super_format(lost_timing, main, babken)[3:5]])
    list_year.append(super_format(lost_timing, main, babken)[-4:])
    list_of_coor.append(find_cor(comp))
    list_x_tracks1.append(0)
    list_url1.append(0)
    list_km1.append(0)
    list_teams1.append(0)
    list_date11.append(0)
    list_date22.append(0)
    list_delta.append(0)
    list_of_power.append(fox_power(containers228, names_list, messages_list))

# %%
for i in range(len(list_of_coor)):
    for j in range(len(list_x_tracks)):
        if str(list_x_tracks[j]) in (list_of_coor[i]):
            list_x_tracks1[i] = str(list_x_tracks[j])
            list_url1[i] = str(list_url[j])
            list_km1[i] = str(list_km[j])
            list_date11[i] = str(list_date1[j])
            list_date22[i] = str(list_date2[j])
            list_teams1[i] = str(list_teams[j])

# %% [markdown]
# Delta dates in processing...

# %%
for i in range(len(list_date22)):
    if re.search('май', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('май', '05')
    if re.search('апр', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('апр', '04')
    if re.search('мар', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('мар', '03')
    if re.search('фев', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('фев', '02')
    if re.search('янв', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('янв', '01')
    if re.search('дек', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('дек', '12')
    if re.search('ноя', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('ноя', '11')
    if re.search('окт', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('окт', '10')
    if re.search('сен', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('сен', '09')
    if re.search('авг', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('авг', '08')
    if re.search('июл', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('июл', '07')
    if re.search('июн', str(list_date22[i])) is not None:
        list_date22[i] = str(list_date22[i]).replace('июн', '06')

# %%
for i in range(len(list_date11)):
    if re.search('май', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('май', '05')
    if re.search('апр', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('апр', '04')
    if re.search('мар', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('мар', '03')
    if re.search('фев', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('фев', '02')
    if re.search('янв', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('янв', '01')
    if re.search('дек', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('дек', '12')
    if re.search('ноя', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('ноя', '11')
    if re.search('окт', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('окт', '10')
    if re.search('сен', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('сен', '09')
    if re.search('авг', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('авг', '08')
    if re.search('июл', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('июл', '07')
    if re.search('июн', str(list_date11[i])) is not None:
        list_date11[i] = str(list_date11[i]).replace('июн', '06')

# %%
for i in range(len(list_date11)):
    if str(list_date11[i]) != '0' and str(list_date22[i]) != '0':
        date2k = datetime.strptime(str(list_date22[i]), "%d-%m-%y  %H:%M")
        date1k = datetime.strptime(str(list_date11[i]), "%d-%m-%y  %H:%M")
        delta = (date2k - date1k).seconds/3600
        list_delta[i] = delta

# %% [markdown]
# Парсим посты, копаем вглубь!

# %%
list_of_all_pages1 = list()

for i in my_list:
    URL = i
    
    html = requests.get(URL).content #url='google.com'
    sel = Selector(text=html)

    uClient = uReq(URL)
    page_html = uClient.read()
    uClient.close()
    page_soup = soup(page_html, "html.parser")
    containers2 = page_soup.findAll("div", {"class":"pagination"})
    containers22 = str(containers2)

    def page12(containers22):
        page1 = list()
        c = containers22.find("из ")
        page1.append(containers22[c+11])
        page1.append(containers22[c+12])
        if containers22[c+12] == "<":
            page1.pop()
            return page1

    if page12(containers22) is None:
        page_real = 1
    else:
        if len(page12(containers22)) == 2:
            page_real = int(page12(containers22)[0] + page12(containers22)[1])
        else:
            page_real = int(page12(containers22)[0])

        # Парсим
    course_as = sel.xpath('//a[contains(@class,"right-box right")]')
    hrefs_from_css = course_as.css('::attr(href)')

    if len(str(hrefs_from_css.extract())[1:]) == 1:
        links_to_follow = URL
        clean_link = URL[27:len(URL)]
    else:
        links_to_follow = "\"https://lizaalert.org/forum" + str(hrefs_from_css.extract()[0])[1:] + "\""
        clean_link = str(hrefs_from_css.extract()[0])[1:len(hrefs_from_css.extract()[0])-2]

    list_links = list()
    for i in range((page_real)):
        list_links.append(clean_link)


        #За 500 надо пояснить! Но это вроде несложно
    i=0
    list1 = [0]
    for i in range(0,(page_real-1)*10, 10):
        i = i + 10
        list1.append(i)

    result = [str(item) for item in list1]

    for i in range(len(list1)):
        if list_links[i].find("start") != -1:
            list_links[i] += result[i]
        
    for i in range(len(list_links)):
        list_links[i] = "https://lizaalert.org/forum" + list_links[i]
    
    list_of_all_pages1.append(list_links)

# %%
list_vk_posts = []
list_odn_posts = []
list_ready_posts = []
for j in range(len(list_of_all_pages1)):
    vk_posts = 0
    vk_postes = []
    odn_posts = 0
    odn_postes = []
    odn_post = []
    ready_posts = 0
    ready_postes = []
    for item in range(len(list_of_all_pages1[j])):
        odn_post = []
        ready_post = []
        vk_post = []
        uClient = uReq(list_of_all_pages1[j][item])
        page_html = uClient.read()
        uClient.close()
        page_soup = soup(page_html, "html.parser")
        for p in range(len(page_soup.findAll("div", {"class":"content"}))):
            containers2 = page_soup.findAll("div", {"class":"content"})[p] #ЧТО ЭТО ЗА ХУЙНЯ?????????
            kirka0 = containers2.findAll(text=re.compile("vk.com"))
            vk_post.append(len(kirka0))
            kirka1 = containers2.findAll(text=re.compile(r'odnokl|ok.ru'))
            odn_post.append(len(kirka1))
            kirka2 = containers2.findAll(text=re.compile(r'[Гг]отов'))
            ready_post.append(len(kirka2))
        vk_postes.append(vk_post)
        ready_postes.append(ready_post)
        odn_postes.append(odn_post)
    odn_posts += odn_posts   
    vk_posts += vk_posts
    ready_posts += ready_posts
    for i in range(len(vk_postes)):
        for k in range(len(vk_postes[i])):
            vk_posts += vk_postes[i][k]
    list_vk_posts.append(vk_posts)
    for i in range(len(odn_postes)):
        for k in range(len(odn_postes[i])):
            odn_posts += odn_postes[i][k]
    list_odn_posts.append(odn_posts)
    for i in range(len(ready_postes)):
        for k in range(len(ready_postes[i])):
            ready_posts += ready_postes[i][k]
    list_ready_posts.append(ready_posts)

# %% [markdown]
# Для таблицы

# %%
list_of_lists.append(list_ready_posts)
list_of_lists.append(list_searchers)
list_of_lists.append(list_of_power)
list_of_lists.append(list_vk_posts)
list_of_lists.append(list_odn_posts)
list_of_lists.append(list_age11)
list_of_lists.append(list_height)
list_of_lists.append(list_help1)
list_of_lists.append(list_photo)
list_of_lists.append(list_posts)
list_of_lists.append(list_sex1)
list_of_lists.append(list_state1)
list_of_lists.append(list_hair_color)
list_of_lists.append(list_bodytype)
list_of_lists.append(list_eye)
list_of_lists.append(list_full)
list_of_lists.append(list_place)
list_of_lists.append(list_color_of_clothes) # Бабкен вставил
list_of_lists.append(list_podrobnost) # Бабкен вставил еще раз, но уже себе
list_of_lists.append(list_primeti)
list_of_lists.append(list_search_time)
list_of_lists.append(list_lost_time)
list_of_lists.append(list_find_time)
list_of_lists.append(list_x_tracks1)
list_of_lists.append(list_url1)
list_of_lists.append(list_km1)
list_of_lists.append(list_teams1)
list_of_lists.append(list_date11)
list_of_lists.append(list_date22)
list_of_lists.append(list_delta)
list_of_lists.append(list_month)
list_of_lists.append(list_year)
# Бабкен вставил снова, только Коле в пердачело

# %%
df1 = pd.DataFrame(columns = ['Готовые', 'Искатели', 'Сила искателей', 'Репосты_вк', 'Репосты_одн', 'Возраст', 'Рост', 'Мед. Состояние', 'Фото', 'Посты', 'Гендер', 'Состояние', 'Цвет волос', 'Телосложение', 'Цвет глаз', 'Url','Место', 'Одежда_ярк', 'Одежда_колво', 'Приметы_колво', 'Время поиска', "Время пропажи", "Время нахождения", "Координаты пропажи", 'url_tracks', 'km', 'teams','date1', 'date2', 'delta_dates', 'Месяц', 'Год'])

# %%
for i, j in zip(list_of_lists, list(df1.columns)):
    df1[j] = pd.Series(i)

# %% [markdown]
# # Тадаам ! Вот , что мы получили

# %%
df1
# Out:
#       Готовые  Искатели  Сила искателей  Репосты_вк  Репосты_одн  \
# 0     2        0         0               0           0
# 1     0        1         0               15          0
# 2     0        1         0               0           0
# 3     0        1         10              0           0
# 4     0        3         0               15          0
# 5     0        2         0               0           0
# 6     0        1         0               0           0
# 7     0        1         0               0           0
# 8     0        1         3               0           0
# 9     0        1         0               0           0
# 10    0        2         0               0           0
# 11    0        3         3               0           0
# 12    0        3         0               0           0
# 13    0        3         0               0           0
# 14    0        0         0               0           0
# 15    0        3         0               0           0
# 16    0        4         346             0           0
# 17    0        1         0               0           0
# 18    0        1         0               0           0
# 19    0        1         0               0           0
# 20    0        1         0               0           0
# 21    0        1         0               0           0
# 22    0        3         0               0           0
# 23    0        1         0               0           0
# 24    0        1         167             0           0
# 25    0        2         0               0           0
# 26    2        0         0               0           0
# 27    0        1         0               0           0
# 28    0        1         0               0           0
# 29    0        1         0               0           0
# 30    0        1         0               0           0
# 31    0        5         208             0           0
# 32    0        6         29              0           0
# 33    0        2         0               0           0
# 34    0        4         0               0           0
# 35    0        2         510             0           0
# 36    0        2         0               0           0
# 37    0        3         4               0           0
# 38    0        150       307             53          0
# 39    0        4         1               0           0
# 40    0        1         0               34          0
# 41    0        1         0               0           0
# 42    0        1         0               0           0
# 43    0        1         0               0           0
# 44    0        1         0               0           0
# 45    0        1         164             0           0
# 46    0        1         0               0           0
# 47    0        2         50              0           0
# 48    0        2         0               0           0
# 49    0        3         0               0           0
# 50    0        1         0               0           0
# 51    0        2         12              0           0
# 52    2        0         0               0           0
# 53    0        4         14              0           0
# 54    0        1         0               0           0
# 55    0        1         1               71          0
# 56    0        1         0               0           0
# 57    0        1         3               48          0
# 58    0        5         12              42          0
# 59    0        1         0               0           0
# 60    0        1         0               0           0
# 61    0        0         0               0           0
# 62    0        2         0               0           0
# 63    0        1         0               0           0
# 64    0        7         1               25          0
# 65    0        1         0               0           0
# 66    0        2         0               0           0
# 67    0        1         0               0           0
# 68    0        2         9               0           0
# 69    0        2         0               0           0
# 70    1        1         0               0           0
# 71    0        1         0               174         0
# 72    0        2         0               0           0
# 73    0        1         0               0           0
# 74    0        1         0               0           0
# 75    0        1         0               0           0
# 76    0        1         0               0           0
# 77    0        5         549             0           0
# 78    2        0         0               0           0
# 79    0        7         500             0           0
# 80    0        1         0               0           0
# 81    0        1         0               0           0
# 82    0        1         0               0           0
# 83    0        4         318             0           0
# 84    0        1         0               0           0
# 85    0        1         0               0           0
# 86    0        14        1285            0           0
# 87    0        1         0               0           0
# 88    0        1         0               0           0
# 89    0        2         7               0           0
# 90    0        3         10              0           0
# 91    0        3         1               0           0
# 92    1        1         0               30          0
# 93    0        3         2               0           0
# 94    0        1         0               0           0
# 95    0        1         0               0           0
# 96    0        1         0               42          0
# 97    0        1         0               88          0
# 98    0        1         0               22          0
# 99    0        16        769             20          0
# 100   0        4         125             0           0
# 101   0        1         1225            91          0
# 102   0        1         0               0           0
# 103   0        1         0               0           0
# 104   2        0         0               0           0
# 105   0        1         0               0           0
# 106   0        1         0               0           0
# 107   0        1         0               0           0
# 108   0        1         0               0           0
# 109   0        3         4               20          0
# 110   0        9         860             26          0
# 111   0        1         0               10          0
# 112   0        16        8               0           0
# 113   0        22        430             547         0
# 114   0        2         237             0           0
# 115   0        1         0               40          0
# 116   0        1         0               56          0
# 117   0        11        2               0           0
# 118   0        2         0               0           0
# 119   0        1         0               0           0
# 120   0        1         0               19          0
# 121   0        1         0               96          0
# 122   0        11        3               146         0
# 123   0        1         0               30          0
# 124   0        13        24              1           2
# 125   0        23        255             18          0
# 126   0        1         0               0           0
# 127   2        0         0               0           0
# 128   0        1         0               15          0
# 129   0        1         0               0           0
# 130   0        1         10              0           0
# 131   0        3         0               15          0
# 132   0        2         0               0           0
# 133   0        1         0               0           0
# 134   0        1         0               0           0
# 135   0        1         3               0           0
# 136   0        1         0               0           0
# 137   0        2         0               0           0
# 138   0        3         3               0           0
# 139   0        3         0               0           0
# 140   0        3         0               0           0
# 141   0        0         0               0           0
# 142   0        3         0               0           0
# 143   0        4         346             0           0
# 144   0        1         0               0           0
# 145   0        1         0               0           0
# 146   0        1         0               0           0
# 147   0        1         0               0           0
# 148   0        1         0               0           0
# 149   0        3         0               0           0
# 150   0        1         0               0           0
# 151   0        1         167             0           0
# 152   0        2         0               0           0
# 153   2        0         0               0           0
# 154   0        1         0               0           0
# 155   0        1         0               0           0
# 156   0        1         0               0           0
# 157   0        1         0               0           0
# 158   0        5         208             0           0
# 159   0        6         29              0           0
# 160   0        2         0               0           0
# 161   0        4         0               0           0
# 162   0        2         510             0           0
# 163   0        2         0               0           0
# 164   0        3         4               0           0
# 165   0        150       307             53          0
# 166   0        4         1               0           0
# 167   0        1         0               34          0
# 168   0        1         0               0           0
# 169   0        1         0               0           0
# 170   0        1         0               0           0
# 171   0        1         0               0           0
# 172   0        1         164             0           0
# 173   0        1         0               0           0
# 174   0        2         50              0           0
# 175   0        2         0               0           0
# 176   0        3         0               0           0
# 177   0        1         0               0           0
# 178   0        2         12              0           0
# 179   2        0         0               0           0
# 180   0        4         14              0           0
# 181   0        1         0               0           0
# 182   0        1         1               71          0
# 183   0        1         0               0           0
# 184   0        1         3               48          0
# 185   0        5         12              42          0
# 186   0        1         0               0           0
# 187   0        1         0               0           0
# 188   0        0         0               0           0
# 189   0        2         0               0           0
# 190   0        1         0               0           0
# 191   0        7         1               25          0
# 192   0        1         0               0           0
# 193   0        2         0               0           0
# 194   0        1         0               0           0
# 195   0        2         9               0           0
# 196   0        2         0               0           0
# 197   1        1         0               0           0
# 198   0        1         0               174         0
# 199   0        2         0               0           0
# ...  ..       ..        ..              ..          ..
# 2882  0        1         0               0           0
# 2883  0        5         774             0           0
# 2884  3        754       1017693         0           0
# 2885  0        1         0               0           0
# 2886  0        0         0               0           0
# 2887  0        1         0               0           0
# 2888  0        0         0               0           0
# 2889  0        0         0               0           0
# 2890  0        1         0               0           0
# 2891  2        0         0               0           0
# 2892  0        0         0               0           0
# 2893  0        19        1797            0           0
# 2894  0        1         0               0           0
# 2895  4        36        3293            0           0
# 2896  0        0         0               0           0
# 2897  0        1         0               0           0
# 2898  1        38        867             0           0
# 2899  1        45        1141            0           0
# 2900  0        1         0               0           0
# 2901  0        15        1672            1           0
# 2902  0        16        440             0           0
# 2903  0        1         0               0           0
# 2904  1        25        1025            0           0
# 2905  0        1         0               0           0
# 2906  0        8         39              0           0
# 2907  2        1         0               0           0
# 2908  1        9         29690           0           0
# 2909  0        1         0               0           0
# 2910  0        64        28              58          0
# 2911  2        1         0               1           0
# 2912  1        14        752             0           0
# 2913  2        10        1030            0           0
# 2914  0        22        409             0           0
# 2915  0        8         109             0           0
# 2916  1        6         359             0           0
# 2917  2        0         0               0           0
# 2918  0        1         0               0           0
# 2919  0        1         12              0           0
# 2920  0        1         0               0           0
# 2921  0        1         0               0           0
# 2922  0        1         0               0           0
# 2923  0        4         2714            0           0
# 2924  0        1         0               0           0
# 2925  0        1         0               0           0
# 2926  0        3         6               0           0
# 2927  0        1         0               0           0
# 2928  0        1         0               0           0
# 2929  0        1         0               0           0
# 2930  0        1         0               0           0
# 2931  0        2         29464           0           0
# 2932  0        1         0               0           0
# 2933  0        1         0               0           0
# 2934  0        26        247             0           0
# 2935  0        0         0               0           0
# 2936  0        1         0               0           0
# 2937  0        1         0               0           0
# 2938  0        1         0               0           0
# 2939  0        1         0               0           0
# 2940  0        1         0               0           0
# 2941  1        1         0               0           0
# 2942  0        1         0               0           0
# 2943  2        0         0               0           0
# 2944  0        98        210             24          0
# 2945  0        134       208             42          0
# 2946  0        86        16              23          0
# 2947  0        29        8               33          0
# 2948  0        94        16              31          0
# 2949  1        1         0               24          0
# 2950  0        138       48              60          0
# 2951  0        1         0               0           0
# 2952  0        29        0               18          0
# 2953  0        38        0               31          0
# 2954  0        131       31              30          0
# 2955  0        54        16              27          0
# 2956  0        54        16              27          0
# 2957  0        98        14              33          0
# 2958  0        59        288             14          0
# 2959  0        160       58              39          0
# 2960  0        185       1696            227         15
# 2961  0        76        16              18          0
# 2962  0        0         0               0           0
# 2963  1        58        1632            18          0
# 2964  0        1         17              0           0
# 2965  0        57        26              14          0
# 2966  0        62        1662            15          0
# 2967  0        60        16              36          0
# 2968  1        12        649             39          0
# 2969  2        0         0               0           0
# 2970  0        3         0               0           0
# 2971  0        3         0               0           0
# 2972  0        3         0               0           0
# 2973  0        2         0               0           0
# 2974  0        145       202             48          0
# 2975  0        72        6               61          0
# 2976  0        93        10              30          0
# 2977  0        0         0               0           0
# 2978  0        0         0               0           0
# 2979  0        20        31858           68          0
# 2980  0        1         0               0           0
# 2981  0        1         0               15          0
# 2982  0        2         12              0           0
# 2983  0        1         0               0           0
# 2984  0        92        23              52          0
# 2985  0        90        10              37          0
# 2986  0        6         749             0           0
# 2987  0        1         0               0           0
# 2988  0        147       45              200         0
# 2989  0        1         0               0           0
# 2990  0        41        26              86          0
# 2991  0        1         0               0           0
# 2992  0        92        5               74          0
# 2993  0        86        20              28          0
# 2994  0        89        1677            57          0
# 2995  2        0         0               0           0
# 2996  0        1         0               58          0
# 2997  0        1         0               44          0
# 2998  0        1         0               81          0
# 2999  0        1         0               69          0
# 3000  0        1         0               372         0
# 3001  0        14        507             0           0
# 3002  0        1         0               32          0
# 3003  0        1         0               372         0
# 3004  0        1         0               24          0
# 3005  0        4         0               41          0
# 3006  0        1         0               6           0
# 3007  0        1         0               20          0
# 3008  0        5         0               37          0
# 3009  0        3         0               24          0
# 3010  0        8         14              14          0
# 3011  1        17        12              19          0
# 3012  0        1         0               8           0
# 3013  0        35        29394           97          0
# 3014  0        8         15              29          0
# 3015  0        1         0               45          0
# 3016  1        101       65329           23          0
# 3017  0        4         0               45          0
# 3018  0        4         1               0           0
# 3019  0        30        34              0           0
# 3020  0        1         17              0           0
# 3021  2        0         0               0           0
# 3022  1        1         0               1           0
# 3023  0        1         0               51          0
# 3024  0        1         0               93          0
# 3025  0        4         0               62          0
# 3026  0        0         0               0           0
# 3027  2        0         0               0           0
# 3028  0        1         113             10          0
# 3029  0        201       1976            84          0
# 3030  0        1         14              70          0
# 3031  0        148       583             71          0
# 3032  0        0         0               0           0
# 3033  0        65        326             16          0
# 3034  0        200       4               159         0
# 3035  0        3         4               88          0
# 3036  0        41        1653            143         0
# 3037  0        201       1972            80          0
# 3038  0        201       1968            102         0
# 3039  0        1         0               62          0
# 3040  0        107       303             78          0
# 3041  0        81        1679            20          0
# 3042  0        29        292             37          0
# 3043  0        115       3337            45          0
# 3044  0        77        1687            49          0
# 3045  1        5         12              36          0
# 3046  0        1         0               0           0
# 3047  0        3         12              36          0
# 3048  0        1         0               0           0
# 3049  0        69        5               96          0
# 3050  0        173       1682            66          0
# 3051  0        30        10              74          0
# 3052  0        121       16              238         0
# 3053  2        0         0               0           0
# 3054  0        23        99              0           0
# 3055  0        2         0               0           0
# 3056  0        3         0               0           0
# 3057  0        5         0               0           0
# 3058  0        1         0               0           0
# 3059  0        7         6               0           0
# 3060  0        1         0               0           0
# 3061  0        7         3               12          0
# 3062  0        1         0               0           0
# 3063  0        3         0               0           0
# 3064  0        1         0               0           0
# 3065  0        1         0               0           0
# 3066  0        1         0               0           0
# 3067  0        1         3               0           0
# 3068  0        2         96              0           0
# 3069  0        1         0               0           0
# 3070  0        1         0               0           0
# 3071  0        1         0               0           0
# 3072  0        1         0               0           0
# 3073  0        1         0               0           0
# 3074  0        2         0               0           0
# 3075  0        3         5               0           0
# 3076  0        4         96              0           0
# 3077  0        8         0               0           0
# 3078  0        6         173             6           0
# 3079  2        0         0               0           0
# 3080  0        16        14              2           1
# 3081  0        1         0               0           0
#
#              Возраст Рост         Мед. Состояние          Фото Посты   Гендер  \
# 0     Коля объебался  Er   здоров                 отсутствует   1     Er
# 1     80              160  здоров                 присутствует  6     Женщина
# 2     69              177  здоров                 отсутствует   3     Мужчина
# 3     86              170  здоров                 отсутствует   3     Мужчина
# 4     42              165  здоров                 отсутствует   6     Женщина
# 5     63              160  здоров                 присутствует  3     Мужчина
# 6     60              150  здоров                 присутствует  5     Мужчина
# 7     7               130  здоров                 отсутствует   4     Мужчина
# 8     71              157  здоров                 присутствует  4     Женщина
# 9     52              165  здоров                 присутствует  3     Мужчина
# 10    40              160  здоров                 присутствует  2     Мужчина
# 11    71              175  здоров                 присутствует  3     Мужчина
# 12    34              180  здоров                 присутствует  2     Мужчина
# 13    22              175  здоров                 присутствует  2     Мужчина
# 14    38              170  здоров                 присутствует  5     Мужчина
# 15    14              165  здоров                 присутствует  2     Женщина
# 16    13              140  здоров                 присутствует  4     Мужчина
# 17    26              185  здоров                 отсутствует   3     Мужчина
# 18    53              185  здоров                 присутствует  3     Мужчина
# 19    30              160  здоров                 присутствует  4     Женщина
# 20    57              175  здоров                 присутствует  4     Мужчина
# 21    50              185  здоров                 присутствует  4     Мужчина
# 22    80              150  здоров                 присутствует  2     Мужчина
# 23    39              168  здоров                 отсутствует   4     Женщина
# 24    79              168  здоров                 присутствует  3     Женщина
# 25    Коля объебался  170  здоров                 присутствует  2     Er
# 26    Коля объебался  Er   здоров                 отсутствует   1     Er
# 27    44              165  здоров                 присутствует  3     Мужчина
# 28    12              160  здоров                 отсутствует   3     Мужчина
# 29    77              155  здоров                 присутствует  3     Мужчина
# 30    71              175  здоров                 отсутствует   3     Мужчина
# 31    65              175  здоров                 присутствует  3     Мужчина
# 32    56              160  здоров                 присутствует  4     Мужчина
# 33    81              150  здоров                 присутствует  3     Женщина
# 34    60              165  здоров                 отсутствует   3     Женщина
# 35    Коля объебался  165  здоров                 присутствует  3     Мужчина
# 36    Коля объебался  160  здоров                 отсутствует   2     Мужчина
# 37    1               Er   здоров                 присутствует  3     Мужчина
# 38    53              165  здоров                 отсутствует   4     Мужчина
# 39    56              Er   здоров                 присутствует  5     Мужчина
# 40    26              175  здоров                 отсутствует   4     Мужчина
# 41    61              172  здоров                 присутствует  3     Мужчина
# 42    42              175  здоров                 присутствует  3     Мужчина
# 43    38              170  здоров                 присутствует  4     Er
# 44    58              170  здоров                 присутствует  4     Мужчина
# 45    38              160  здоров                 отсутствует   3     Женщина
# 46    13              155  здоров                 присутствует  3     Женщина
# 47    33              170  здоров                 присутствует  3     Мужчина
# 48    30              170  здоров                 присутствует  2     Er
# 49    11              155  здоров                 присутствует  3     Мужчина
# 50    52              170  здоров                 присутствует  2     Мужчина
# 51    55              170  здоров                 отсутствует   3     Мужчина
# 52    Коля объебался  Er   здоров                 отсутствует   1     Er
# 53    76              155  здоров                 присутствует  3     Женщина
# 54    Коля объебался  165  здоров                 отсутствует   2     Er
# 55    33              160  здоров                 присутствует  7     Женщина
# 56    45              160  здоров                 отсутствует   2     Мужчина
# 57    85              160  здоров                 отсутствует   5     Мужчина
# 58    64              165  требуется мед. помощь  присутствует  4     Мужчина
# 59    37              Er   требуется мед. помощь  присутствует  7     Мужчина
# 60    55              160  здоров                 присутствует  3     Женщина
# 61    40              160  здоров                 отсутствует   1     Мужчина
# 62    50              160  здоров                 отсутствует   2     Мужчина
# 63    80              160  здоров                 присутствует  3     Женщина
# 64    78              158  здоров                 отсутствует   5     Женщина
# 65    60              Er   здоров                 отсутствует   3     Er
# 66    32              Er   здоров                 отсутствует   2     Er
# 67    47              170  здоров                 присутствует  2     Мужчина
# 68    42              168  здоров                 отсутствует   4     Мужчина
# 69    71              160  здоров                 отсутствует   2     Женщина
# 70    69              Er   здоров                 отсутствует   6     Мужчина
# 71    84              160  здоров                 отсутствует   8     Мужчина
# 72    44              164  здоров                 отсутствует   2     Мужчина
# 73    22              178  здоров                 отсутствует   3     Мужчина
# 74    34              183  здоров                 отсутствует   2     Мужчина
# 75    82              168  здоров                 отсутствует   4     Мужчина
# 76    33              180  здоров                 отсутствует   4     Мужчина
# 77    82              165  здоров                 отсутствует   3     Женщина
# 78    Коля объебался  Er   здоров                 отсутствует   1     Er
# 79    75              Er   здоров                 отсутствует   5     Мужчина
# 80    8               Er   здоров                 отсутствует   2     Мужчина
# 81    86              160  здоров                 отсутствует   3     Женщина
# 82    Коля объебался  155  здоров                 отсутствует   2     Мужчина
# 83    83              Er   здоров                 отсутствует   3     Женщина
# 84    76              Er   здоров                 отсутствует   2     Женщина
# 85    20              Er   здоров                 отсутствует   3     Женщина
# 86    21              Er   здоров                 отсутствует   3     Мужчина
# 87    14              168  здоров                 отсутствует   3     Женщина
# 88    31              173  здоров                 отсутствует   3     Мужчина
# 89    69              150  здоров                 отсутствует   3     Женщина
# 90    13              165  здоров                 отсутствует   3     Женщина
# 91    31              182  здоров                 отсутствует   3     Мужчина
# 92    56              175  здоров                 отсутствует   5     Мужчина
# 93    26              168  здоров                 отсутствует   3     Женщина
# 94    41              165  здоров                 присутствует  3     Женщина
# 95    52              152  здоров                 отсутствует   2     Женщина
# 96    17              180  здоров                 отсутствует   4     Мужчина
# 97    32              176  здоров                 отсутствует   6     Мужчина
# 98    77              170  здоров                 присутствует  3     Мужчина
# 99    28              173  здоров                 отсутствует   4     Мужчина
# 100   33              170  здоров                 отсутствует   2     Мужчина
# 101   51              165  здоров                 отсутствует   5     Женщина
# 102   66              168  здоров                 отсутствует   3     Мужчина
# 103   62              164  здоров                 отсутствует   3     Мужчина
# 104   Коля объебался  Er   здоров                 отсутствует   1     Er
# 105   84              162  здоров                 отсутствует   3     Женщина
# 106   18              178  здоров                 отсутствует   3     Мужчина
# 107   35              170  здоров                 отсутствует   3     Мужчина
# 108   58              165  здоров                 отсутствует   3     Женщина
# 109   80              170  здоров                 отсутствует   4     Мужчина
# 110   16              Er   здоров                 отсутствует   4     Мужчина
# 111   78              155  здоров                 отсутствует   4     Мужчина
# 112   63              165  здоров                 отсутствует   3     Женщина
# 113   11              140  здоров                 отсутствует   22    Женщина
# 114   48              178  здоров                 отсутствует   3     Мужчина
# 115   37              155  здоров                 отсутствует   4     Женщина
# 116   60              162  здоров                 отсутствует   4     Женщина
# 117   57              175  здоров                 отсутствует   3     Мужчина
# 118   60              160  здоров                 отсутствует   3     Мужчина
# 119   32              190  здоров                 отсутствует   3     Мужчина
# 120   39              189  требуется мед. помощь  отсутствует   4     Мужчина
# 121   30              180  здоров                 отсутствует   6     Мужчина
# 122   28              175  здоров                 отсутствует   6     Мужчина
# 123   82              153  здоров                 отсутствует   4     Женщина
# 124   55              156  здоров                 отсутствует   5     Женщина
# 125   57              165  здоров                 отсутствует   4     Мужчина
# 126   30              160  здоров                 отсутствует   3     Женщина
# 127   Коля объебался  Er   здоров                 отсутствует   1     Er
# 128   80              160  здоров                 присутствует  6     Женщина
# 129   69              177  здоров                 отсутствует   3     Мужчина
# 130   86              170  здоров                 отсутствует   3     Мужчина
# 131   42              165  здоров                 отсутствует   6     Женщина
# 132   63              160  здоров                 присутствует  3     Мужчина
# 133   60              150  здоров                 присутствует  5     Мужчина
# 134   7               130  здоров                 отсутствует   4     Мужчина
# 135   71              157  здоров                 присутствует  4     Женщина
# 136   52              165  здоров                 присутствует  3     Мужчина
# 137   40              160  здоров                 присутствует  2     Мужчина
# 138   71              175  здоров                 присутствует  3     Мужчина
# 139   34              180  здоров                 присутствует  2     Мужчина
# 140   22              175  здоров                 присутствует  2     Мужчина
# 141   38              170  здоров                 присутствует  5     Мужчина
# 142   14              165  здоров                 присутствует  2     Женщина
# 143   13              140  здоров                 присутствует  4     Мужчина
# 144   26              185  здоров                 отсутствует   3     Мужчина
# 145   53              185  здоров                 присутствует  3     Мужчина
# 146   30              160  здоров                 присутствует  4     Женщина
# 147   57              175  здоров                 присутствует  4     Мужчина
# 148   50              185  здоров                 присутствует  4     Мужчина
# 149   80              150  здоров                 присутствует  2     Мужчина
# 150   39              168  здоров                 отсутствует   4     Женщина
# 151   79              168  здоров                 присутствует  3     Женщина
# 152   Коля объебался  170  здоров                 присутствует  2     Er
# 153   Коля объебался  Er   здоров                 отсутствует   1     Er
# 154   44              165  здоров                 присутствует  3     Мужчина
# 155   12              160  здоров                 отсутствует   3     Мужчина
# 156   77              155  здоров                 присутствует  3     Мужчина
# 157   71              175  здоров                 отсутствует   3     Мужчина
# 158   65              175  здоров                 присутствует  3     Мужчина
# 159   56              160  здоров                 присутствует  4     Мужчина
# 160   81              150  здоров                 присутствует  3     Женщина
# 161   60              165  здоров                 отсутствует   3     Женщина
# 162   Коля объебался  165  здоров                 присутствует  3     Мужчина
# 163   Коля объебался  160  здоров                 отсутствует   2     Мужчина
# 164   1               Er   здоров                 присутствует  3     Мужчина
# 165   53              165  здоров                 отсутствует   4     Мужчина
# 166   56              Er   здоров                 присутствует  5     Мужчина
# 167   26              175  здоров                 отсутствует   4     Мужчина
# 168   61              172  здоров                 присутствует  3     Мужчина
# 169   42              175  здоров                 присутствует  3     Мужчина
# 170   38              170  здоров                 присутствует  4     Er
# 171   58              170  здоров                 присутствует  4     Мужчина
# 172   38              160  здоров                 отсутствует   3     Женщина
# 173   13              155  здоров                 присутствует  3     Женщина
# 174   33              170  здоров                 присутствует  3     Мужчина
# 175   30              170  здоров                 присутствует  2     Er
# 176   11              155  здоров                 присутствует  3     Мужчина
# 177   52              170  здоров                 присутствует  2     Мужчина
# 178   55              170  здоров                 отсутствует   3     Мужчина
# 179   Коля объебался  Er   здоров                 отсутствует   1     Er
# 180   76              155  здоров                 присутствует  3     Женщина
# 181   Коля объебался  165  здоров                 отсутствует   2     Er
# 182   33              160  здоров                 присутствует  7     Женщина
# 183   45              160  здоров                 отсутствует   2     Мужчина
# 184   85              160  здоров                 отсутствует   5     Мужчина
# 185   64              165  требуется мед. помощь  присутствует  4     Мужчина
# 186   37              Er   требуется мед. помощь  присутствует  7     Мужчина
# 187   55              160  здоров                 присутствует  3     Женщина
# 188   40              160  здоров                 отсутствует   1     Мужчина
# 189   50              160  здоров                 отсутствует   2     Мужчина
# 190   80              160  здоров                 присутствует  3     Женщина
# 191   78              158  здоров                 отсутствует   5     Женщина
# 192   60              Er   здоров                 отсутствует   3     Er
# 193   32              Er   здоров                 отсутствует   2     Er
# 194   47              170  здоров                 присутствует  2     Мужчина
# 195   42              168  здоров                 отсутствует   4     Мужчина
# 196   71              160  здоров                 отсутствует   2     Женщина
# 197   69              Er   здоров                 отсутствует   6     Мужчина
# 198   84              160  здоров                 отсутствует   8     Мужчина
# 199   44              164  здоров                 отсутствует   2     Мужчина
# ...   ..              ...     ...                         ...  ..         ...
# 2882  17              175  здоров                 присутствует  2     Женщина
# 2883  36              165  здоров                 присутствует  3     Мужчина
# 2884  9               130  здоров                 присутствует  40    Женщина
# 2885  48              175  здоров                 присутствует  2     Мужчина
# 2886  84              160  здоров                 присутствует  1     Мужчина
# 2887  21              140  здоров                 присутствует  2     Женщина
# 2888  58              182  здоров                 присутствует  1     Мужчина
# 2889  26              170  здоров                 отсутствует   1     Мужчина
# 2890  63              165  здоров                 отсутствует   5     Женщина
# 2891  Коля объебался  Er   здоров                 отсутствует   1     Er
# 2892  84              160  здоров                 присутствует  4     Женщина
# 2893  15              195  здоров                 присутствует  3     Мужчина
# 2894  50              167  здоров                 присутствует  4     Мужчина
# 2895  77              175  здоров                 присутствует  25    Мужчина
# 2896  20              175  здоров                 присутствует  1     Мужчина
# 2897  63              163  здоров                 присутствует  2     Женщина
# 2898  78              158  здоров                 присутствует  13    Женщина
# 2899  80              165  здоров                 присутствует  14    Мужчина
# 2900  23              180  здоров                 присутствует  2     Мужчина
# 2901  Коля объебался  Er   здоров                 присутствует  2     Er
# 2902  91              168  здоров                 присутствует  3     Женщина
# 2903  16              170  здоров                 присутствует  3     Мужчина
# 2904  72              160  здоров                 присутствует  6     Женщина
# 2905  81              160  здоров                 присутствует  5     Женщина
# 2906  55              Er   здоров                 присутствует  3     Мужчина
# 2907  38              180  здоров                 присутствует  7     Мужчина
# 2908  21              175  здоров                 присутствует  8     Мужчина
# 2909  40              176  здоров                 присутствует  3     Женщина
# 2910  83              155  здоров                 присутствует  7     Женщина
# 2911  40              172  здоров                 присутствует  11    Мужчина
# 2912  77              173  здоров                 присутствует  4     Мужчина
# 2913  66              174  здоров                 присутствует  5     Мужчина
# 2914  21              175  здоров                 присутствует  5     Мужчина
# 2915  39              170  здоров                 присутствует  5     Мужчина
# 2916  29              170  здоров                 присутствует  5     Мужчина
# 2917  Коля объебался  Er   здоров                 отсутствует   1     Er
# 2918  63              183  здоров                 присутствует  3     Мужчина
# 2919  11              140  здоров                 присутствует  4     Женщина
# 2920  40              174  здоров                 присутствует  3     Мужчина
# 2921  64              155  здоров                 присутствует  6     Женщина
# 2922  24              180  здоров                 присутствует  4     Мужчина
# 2923  85              156  здоров                 присутствует  4     Женщина
# 2924  65              Er   здоров                 присутствует  5     Мужчина
# 2925  26              180  здоров                 присутствует  3     Мужчина
# 2926  20              190  здоров                 присутствует  4     Мужчина
# 2927  78              170  требуется мед. помощь  присутствует  4     Мужчина
# 2928  52              167  здоров                 присутствует  7     Мужчина
# 2929  28              162  здоров                 присутствует  3     Женщина
# 2930  78              Er   здоров                 присутствует  3     Женщина
# 2931  70              180  здоров                 присутствует  5     Мужчина
# 2932  11              134  здоров                 присутствует  3     Женщина
# 2933  Коля объебался  175  здоров                 присутствует  5     Er
# 2934  11              158  здоров                 присутствует  3     Er
# ...
# 170   0                0               0.000000     Август    2018
# 171   0                0               0.000000     Август    2018
# 172   0                0               0.000000     Август    2018
# 173   0                0               0.000000     Август    2018
# 174   0                0               0.000000     Август    2018
# 175   0                0               0.000000     Август    2018
# 176   0                0               0.000000     Август    2018
# 177   0                0               0.000000     Август    2018
# 178   0                0               0.000000     Август    2018
# 179   0                0               0.000000     Март      2016
# 180   0                0               0.000000     Июль      2018
# 181   0                0               0.000000     Июль      2018
# 182   0                0               0.000000     Июль      2018
# 183   0                0               0.000000     Июль      2018
# 184   0                0               0.000000     Июль      2018
# 185   0                0               0.000000     Июль      2018
# 186   0                0               0.000000     Июнь      2018
# 187   0                0               0.000000     Июнь      2018
# 188   0                0               0.000000     Июль      2018
# 189   0                0               0.000000     Июнь      2018
# 190   0                0               0.000000     Июнь      2018
# 191   0                0               0.000000      Февраль  2018
# 192   0                0               0.000000     Июнь      2018
# 193   0                0               0.000000     Июнь      2018
# 194   0                0               0.000000     Июнь      2018
# 195   0                0               0.000000     Июнь      2018
# 196   0                0               0.000000     Июнь      2018
# 197   0                0               0.000000     Май       2018
# 198   0                0               0.000000     Май       2018
# 199   0                0               0.000000     Апрель    2018
# ...  ..               ..                    ...        ...     ...
# 2882  0                0               0.000000     Сентябрь  2018
# 2883  0                0               0.000000     Сентябрь  2018
# 2884  29-08-18  20:14  30-08-18 01:19  5.083333     Август    2018
# 2885  0                0               0.000000     Август    2018
# 2886  0                0               0.000000     Июль      2015
# 2887  0                0               0.000000     Март      2009
# 2888  0                0               0.000000     Июнь      2013
# 2889  0                0               0.000000     Ноябрь    2012
# 2890  0                0               0.000000     Апрель    2012
# 2891  0                0               0.000000     Март      2016
# 2892  0                0               0.000000     Май       2019
# 2893  0                0               0.000000     Май       2019
# 2894  0                0               0.000000     Май       2019
# 2895  0                0               0.000000     Май       2019
# 2896  0                0               0.000000     Декабрь   2018
# 2897  0                0               0.000000     Май       2019
# 2898  0                0               0.000000     Май       2019
# 2899  0                0               0.000000     Апрель    2019
# 2900  0                0               0.000000     Апрель    2019
# 2901  0                0               0.000000     Апрель    2019
# 2902  0                0               0.000000     Апрель    2019
# 2903  0                0               0.000000     Апрель    2019
# 2904  0                0               0.000000     Апрель    2019
# 2905  0                0               0.000000     Июнь      2018
# 2906  0                0               0.000000     Апрель    2019
# 2907  0                0               0.000000     Декабрь   2018
# 2908  0                0               0.000000      Февраль  2019
# 2909  0                0               0.000000     Декабрь   2018
# 2910  0                0               0.000000     Октябрь   2018
# 2911  0                0               0.000000     Май       2018
# 2912  0                0               0.000000     Апрель    2019
# 2913  0                0               0.000000     Апрель    2019
# 2914  0                0               0.000000     Март      2019
# 2915  0                0               0.000000     Март      2019
# 2916  0                0               0.000000     Январь    2019
# 2917  0                0               0.000000     Март      2016
# 2918  0                0               0.000000     Апрель    2019
# 2919  0                0               0.000000     Май       2019
# 2920  0                0               0.000000     Апрель    2019
# 2921  0                0               0.000000     Октябрь   2018
# 2922  0                0               0.000000     Март      2019
# 2923  0                0               0.000000     Апрель    2019
# 2924  0                0               0.000000     Январь    2019
# 2925  0                0               0.000000     Март      2019
# 2926  0                0               0.000000     Март      2019
# 2927  0                0               0.000000      Февраль  2019
# 2928  0                0               0.000000     Июнь      2018
# 2929  0                0               0.000000     Декабрь   2018
# 2930  0                0               0.000000      Февраль  2019
# 2931  0                0               0.000000     Январь    2019
# 2932  0                0               0.000000     Декабрь   2018
# 2933  0                0               0.000000     Апрель    2018
# 2934  0                0               0.000000     Октябрь   2018
# 2935  0                0               0.000000     Август    2018
# 2936  0                0               0.000000     Июль      2018
# 2937  0                0               0.000000     Май       2018
# 2938  0                0               0.000000     Март      2018
# 2939  0                0               0.000000     Апрель    2018
# 2940  0                0               0.000000      Февраль  2018
# 2941  0                0               0.000000      Февраль  2018
# 2942  0                0               0.000000     Март      2017
# 2943  0                0               0.000000     Март      2016
# 2944  0                0               0.000000     Май       2019
# 2945  0                0               0.000000     Май       2019
# 2946  0                0               0.000000     Май       2019
# 2947  0                0               0.000000     Май       2019
# 2948  0                0               0.000000     Май       2019
# 2949  0                0               0.000000     Май       2019
# 2950  0                0               0.000000     Май       2019
# 2951  0                0               0.000000     Май       2019
# 2952  0                0               0.000000     Май       2019
# 2953  0                0               0.000000     Май       2019
# 2954  0                0               0.000000     Май       2019
# 2955  0                0               0.000000     Май       2019
# 2956  0                0               0.000000     Май       2019
# 2957  0                0               0.000000     Март      2019
# 2958  0                0               0.000000     Май       2019
# 2959  0                0               0.000000     Апрель    2019
# 2960  0                0               0.000000     Январь    2019
# 2961  0                0               0.000000     Май       2019
# 2962  0                0               0.000000     Май       2019
# 2963  0                0               0.000000     Май       2019
# 2964  0                0               0.000000     Май       2019
# 2965  0                0               0.000000     Май       2019
# 2966  0                0               0.000000     Май       2019
# 2967  0                0               0.000000     Апрель    2019
# 2968  0                0               0.000000     Май       2019
# 2969  0                0               0.000000     Март      2016
# 2970  0                0               0.000000     Май       2019
# 2971  0                0               0.000000     Май       2019
# 2972  0                0               0.000000     Сентябрь  2018
# 2973  0                0               0.000000     Май       2019
# 2974  0                0               0.000000     Май       2019
# 2975  0                0               0.000000     Август    2018
# 2976  0                0               0.000000     Май       2019
# 2977  0                0               0.000000     Май       2019
# 2978  0                0               0.000000     Май       2019
# 2979  0                0               0.000000     Май       2019
# 2980  0                0               0.000000     Май       2019
# 2981  0                0               0.000000     Апрель    2019
# 2982  0                0               0.000000     Апрель    2019
# 2983  0                0               0.000000     Апрель    2019
# 2984  0                0               0.000000     Апрель    2019
# 2985  0                0               0.000000     Апрель    2019
# 2986  0                0               0.000000     Декабрь   2018
# 2987  0                0               0.000000     Март      2017
# 2988  0                0               0.000000     Апрель    2019
# 2989  0                0               0.000000     Март      2019
# 2990  0                0               0.000000      Февраль  2019
# 2991  0                0               0.000000     Март      2019
# 2992  0                0               0.000000     Март      2019
# 2993  0                0               0.000000     Март      2019
# 2994  0                0               0.000000     Март      2019
# 2995  0                0               0.000000     Март      2016
# 2996  0                0               0.000000     Май       2019
# 2997  0                0               0.000000     Май       2019
# 2998  0                0               0.000000     Май       2019
# 2999  0                0               0.000000     Ноябрь    2018
# 3000  0                0               0.000000     Май       2019
# 3001  0                0               0.000000     Май       2019
# 3002  0                0               0.000000     Апрель    2019
# 3003  0                0               0.000000     Апрель    2019
# 3004  0                0               0.000000     Декабрь   2018
# 3005  0                0               0.000000     Декабрь   2018
# 3006  0                0               0.000000     Декабрь   2018
# 3007  0                0               0.000000     Ноябрь    2018
# 3008  0                0               0.000000     Ноябрь    2018
# 3009  0                0               0.000000     Август    2018
# 3010  0                0               0.000000     Август    2018
# 3011  0                0               0.000000     Июль      2018
# 3012  0                0               0.000000     Декабрь   2017
# 3013  0                0               0.000000     Сентябрь  2017
# 3014  0                0               0.000000     Август    2017
# 3015  0                0               0.000000     Июнь      2017
# 3016  0                0               0.000000     Сентябрь  2016
# 3017  0                0               0.000000      Февраль  2017
# 3018  0                0               0.000000     Июль      2016
# 3019  0                0               0.000000     Май       2016
# 3020  0                0               0.000000     Март      2016
# 3021  0                0               0.000000     Март      2016
# 3022  0                0               0.000000      Февраль  2019
# 3023  0                0               0.000000     Июнь      2018
# 3024  0                0               0.000000     Июнь      2017
# 3025  0                0               0.000000     Апрель    2016
# 3026  0                0               0.000000     Ноябрь    2012
# 3027  0                0               0.000000     Март      2016
# 3028  0                0               0.000000     Май       2019
# 3029  0                0               0.000000     Май       2019
# 3030  0                0               0.000000     Май       2019
# 3031  0                0               0.000000     Май       2019
# 3032  0                0               0.000000     Май       2019
# 3033  0                0               0.000000     Май       2019
# 3034  0                0               0.000000     Май       2019
# 3035  0                0               0.000000     Апрель    2019
# 3036  0                0               0.000000     Апрель    2019
# 3037  0                0               0.000000     Апрель    2019
# 3038  0                0               0.000000     Апрель    2019
# 3039  0                0               0.000000     Март      2019
# 3040  0                0               0.000000     Март      2019
# 3041  0                0               0.000000      Февраль  2019
# 3042  0                0               0.000000     Март      2019
# 3043  0                0               0.000000     Январь    2019
# 3044  0                0               0.000000     Январь    2019
# 3045  0                0               0.000000     Январь    2019
# 3046  0                0               0.000000     Январь    2019
# 3047  0                0               0.000000     Январь    2019
# 3048  0                0               0.000000     Ноябрь    2018
# 3049  0                0               0.000000     Ноябрь    2018
# 3050  0                0               0.000000     Ноябрь    2018
# 3051  0                0               0.000000     Октябрь   2018
# 3052  0                0               0.000000     Октябрь   2018
# 3053  0                0               0.000000     Март      2016
# 3054  0                0               0.000000     Май       2019
# 3055  0                0               0.000000     Май       2019
# 3056  0                0               0.000000     Май       2019
# 3057  0                0               0.000000     Апрель    2019
# 3058  0                0               0.000000     Март      2019
# 3059  0                0               0.000000     Апрель    2019
# 3060  0                0               0.000000     Апрель    2019
# 3061  0                0               0.000000     Январь    2019
# 3062  0                0               0.000000     Апрель    2019
# 3063  0                0               0.000000     Апрель    2019
# 3064  0                0               0.000000     Октябрь   2018
# 3065  0                0               0.000000     Январь    2019
# 3066  0                0               0.000000     Декабрь   2018
# 3067  0                0               0.000000     Апрель    2019
# 3068  0                0               0.000000     Апрель    2019
# 3069  0                0               0.000000     Апрель    2019
# 3070  0                0               0.000000     Март      2019
# 3071  0                0               0.000000     Март      2019
# 3072  0                0               0.000000     Март      2019
# 3073  0                0               0.000000     Март      2019
# 3074  0                0               0.000000     Март      2019
# 3075  0                0               0.000000     Март      2019
# 3076  0                0               0.000000      Февраль  2019
# 3077  0                0               0.000000      Февраль  2019
# 3078  0                0               0.000000     Ноябрь    2018
# 3079  0                0               0.000000     Март      2016
# 3080  0                0               0.000000     Ноябрь    2018
# 3081  0                0               0.000000     Ноябрь    2011
#
# [3082 rows x 32 columns]

# %%
df1.to_excel("Volga.xlsx")
