# %%
import re
import bs4
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

my_url = 'https://lizaalert.org/forum/viewtopic.php?f=278&t=17946'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=278&t=16803'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=278&t=16825'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=278&t=15587'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=278&t=13990'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=278&t=15023'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=278&t=15418'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=278&t=14037'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=278&t=14031'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=278&t=14139'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=120&t=25101'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=120&t=23673'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=120&t=23928'!!!
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=120&t=25066'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=120&t=25139'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=189&t=4292' 
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=189&t=23654'
#!my_url = 'https://lizaalert.org/forum/viewtopic.php?f=187&t=8495'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=187&t=18999'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=187&t=18845'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=123&t=23194'
#my_url = 'https://lizaalert.org/forum/viewtopic.php?f=287&t=23834'

uClient = uReq(my_url)
page_html = uClient.read()
uClient.close()

page_soup = soup(page_html, "html.parser")
title = page_soup.title
print(title)
title1 = str(title)

if title1.find("Жив") != -1 or title1.find("ЖИВ") != -1:
    print("ЖИВОЙ")
else:
    print("ПОГИБ")
    
if title1.find("Жив ") != -1 or title1.find("Жив,") != -1 or title1.find("ЖИВ ") != -1 or title1.find("жив ") != -1 or title1.find("Погиб ") != -1 or title1.find("ПОГИБ ") != -1:
    print("МУЖСКОЙ ПОЛ")
elif title1.find("Жива") != -1 or title1.find("ЖИВА") != -1 or title1.find("Погибла") != -1 or title1.find("ПОГИБЛА") != -1:
    print("ЖЕНСКИЙ ПОЛ")
elif title1.find("Живы") != -1 or title1.find("ЖИВЫ") != -1 or title1.find("Погибли") != -1 or title1.find("ПОГИБЛИ") != -1:
    print("НЕСКОЛЬКО ЧЕЛОВЕК")
else:
    print("СБОЙ")

c = title1.find("лет")
if title1.find("лет") == -1:
    c = title1.find("года")
    if title1.find("года") == -1:
        c = title1.find("год")
print(title1[c])
if title1[c-1] ==' ':
    print(title1[c-3], title1[c-2], sep='')
else:
    print(title1[c-2], title1[c-1], sep='')

filename = "post6.csv"
f = open(filename, "w")
headers = "title1", "title2\n"
title2 = "hallo"
f.write("title1, title2\n")

containers7 = page_soup.findAll("div", {"class":"topictitle"})
print((containers7), "ЗДЕСЯЯЯ")

containers8 = page_soup.findAll("div", {"class":"notice"})
print(containers8)
containers88 = str(containers8)
d = containers88.find("Инфорг")
print(containers88[d+11], containers88[d+12], containers88[d+13], containers88[d+14], containers88[d+15], containers88[d+16], containers88[d+17], containers88[d+18], containers88[d+19], containers88[d+20], containers88[d+21], sep='')
print(containers88[d+24], containers88[d+25], containers88[d+26], containers88[d+27], containers88[d+28], sep='')

containers = page_soup.findAll("div", {"class":"content"})
print(type(containers))
containers11 = str(containers)
print(containers11)
b = containers11.find("Рост")
if containers11.find("Рост") == -1:
   b = containers11.find("рост") 
print(b)
print(containers11[b])
    
if containers11[b+4] == ":":
        print(containers11[b+6],containers11[b+7],containers11[b+8], sep ='')
else:
        print(containers11[b+5],containers11[b+6],containers11[b+7], sep ='')
containers111 = containers11[0]

if containers11.find("Изображение") == -1:
    print('ФОТО ОТСУТСТВУЕТ')
else:
    print('ФОТО ПРИСУТСТВУЕТ')

containers2 = page_soup.findAll("div", {"class":"pagination"})
containers22 = str(containers2)
print(containers22)
a = containers22.find("Сообщений")
print(containers22[a+11], containers22[a+12], sep ='')

#if re.search(r'\bрост\b', 'рост'):
 #print("Привет")
    
s = 'hi my name is ryan, and i am new to python and would like to learn more'
m = re.search('name\s\w+\s(\w+)',s)
m.group(1)

f.write(title1 + title2 + "\n")
f.close()

#print(containers2)
#print(containers)
# Out:
# <title>Жива Рыбакова (Лаврентьева) Лидия Григорьевна 79 лет, р-н • Форум lizaalert.org</title>
# ЖИВОЙ
# ЖЕНСКИЙ ПОЛ
# л
# 79
# [] ЗДЕСЯЯЯ
# [<div class="notice">Последний раз редактировалось <a class="username-coloured" href="./memberlist.php?mode=viewprofile&amp;u=5735&amp;sid=bdb4fed1a68dc40261fbf4dbfa96f3e3" style="color: #3300CC;">Инфорг</a> 06 дек 2017, 02:23, всего редактировалось 7 раз(а).
#
# 				</div>, <div class="notice">Последний раз редактировалось <a class="username-coloured" href="./memberlist.php?mode=viewprofile&amp;u=5735&amp;sid=bdb4fed1a68dc40261fbf4dbfa96f3e3" style="color: #3300CC;">Инфорг</a> 06 дек 2017, 13:23, всего редактировалось 32 раз(а).
#
# 				</div>, <div class="notice">Последний раз редактировалось <a href="./memberlist.php?mode=viewprofile&amp;u=15935&amp;sid=bdb4fed1a68dc40261fbf4dbfa96f3e3">Natashik</a> 05 дек 2017, 23:05, всего редактировалось 1 раз.
#
# 				</div>]
# 06 дек 2017
# 02:23
# <class 'bs4.element.ResultSet'>
# [<div class="content"><span style="font-size: 140%; line-height: 116%;"><span style="font-weight: bold">Найдена, жива! Рыбакова (Лаврентьева) Лидия Григорьевна 79 лет, р-н Кузьминки, ул. Юных ленинцев д.72 </span></span><br/><br/>4 декабря 2017 в 9:30 ушла из дома и не вернулась<br/><br/><span style="font-weight: bold"><span style="color: #0000FF">ДЕЗОРИЕНТИРОВАНА!<br/>НУЖДАЕТСЯ В МЕДИЦИНСКОЙ ПОМОЩИ!</span></span><br/><br/><img alt="Изображение" src="http://info-la.ru/photo/18894_7563272427.jpg"/><br/><img alt="Изображение" src="http://info-la.ru/photo/18894_3497635185.jpg"/><br/><br/><span style="font-weight: bold">Приметы:</span><br/>Рост 160<br/>Худощавого телосложения<br/>Немного сутулится<br/>Волосы седые до плеч<br/>Серые глаза<br/><br/><span style="font-weight: bold">Была одета:</span> Была одета: вязанная белая шапка, бежевая куртка до середины бедра, термостойкие темные штаны, светло-синие тряпочные ботинки на шнуровке.<br/><br/><span style="font-weight: bold">С собой:</span> С собой: темная тряпочная сумка 40/30<br/><br/><br/><br/><span style="font-weight: bold"><span style="color: #0000FF"><span style="text-decoration: line-through;">ВНИМАНИЕ! ВЫЕЗД СЕЙЧАС!<br/>Сбор в 23:30 по адресу р-н Кузьминки,  ул.Юных ленинцев д.72, с торца дома.</span><br/><br/><span style="text-decoration: line-through;">Стоп! Проверка информации!</span><br/><br/>Найдена, жива!<br/><br/><br/><br/><br/></span></span><br/><br/><span style="font-weight: bold"><a href="https://docs.google.com/spreadsheets/d/1H-TG0ZtTuH02WLtisoFoSbHCMcyBHrsfEwJsKXzlI9g/edit#gid=8" rel="nofollow" target="_blank">Таблица прозвона больниц и ОВД</a></span><br/><span style="font-weight: bold"><a href="http://la-org.ru/images/2017/12/c797abeb7c3bd122e5ed2c0f1d554dad1.jpg" rel="nofollow" target="_blank">Ориентировка на печать</a></span><br/><span style="font-weight: bold"><a href="http://la-org.ru/images/2017/12/c797abeb7c3bd122e5ed2c0f1d554dad2.jpg" rel="nofollow" target="_blank">Ориентировка на репост</a></span><br/><br/>--------------------------------------------------<br/><br/><span style="font-weight: bold">Координатор:</span> ОТЕЦ ОЛЕГ<br/><span style="font-weight: bold">Инфорг:</span> Вишня 89099601973</div>, <div class="content"><span style="font-weight: bold"><span style="color: #0000FF">Дома:</span></span><br/>Анна1801<br/>Лока<br/>Genka<br/>Natashik<br/>Карась<br/>Волёна<br/>Дежурнаямашина<br/>Ромео<br/>Отец Олег<br/>Акари<br/>ЛенаР<br/><br/><br/><br/><br/><span style="font-weight: bold"><span style="color: #0000FF">Пешие:</span></span><br/>Ливия + собака, после 00, м. Владыкино, 89853911713<br/>Листик, Раменское, 89672574244</div>, <div class="content"><span style="font-weight: bold"><span style="color: #0000FF">Ориентировки печатает Лока, спасибо огромное!</span></span></div>, <div class="content">Авто , три места, Люберцы, выезд по окончанию печати ориентировок, примерно в 23:00<br/>89262354534</div>, <div class="content">В 22-30 выезжаю из Бибирево. Заберу пеших от метро Бибирево, Медведково, Новогиреево. Звоните 910-409-08-59 Владислав.</div>, <div class="content">В 22.50 выезжаю от м.Университет. Места есть.</div>, <div class="content">Выезд в 23.15. Авто</div>, <div class="content"><span style="font-weight: bold"><span style="color: #0000FF">Очень-очень нужна помощь! Очень нужны люди на поиск! </span></span></div>, <div class="content">Готова при наличии экипажа. Раменское.</div>, <div class="content">Пешая , готова из Южного Бутово в 24:00  тел 89091581050</div>]
# 644
# Р
# 160
# ФОТО ПРИСУТСТВУЕТ
# [<div class="pagination">
# 			Сообщений: 25
# 			 • <a href="#" onclick="jumpto(); return false;" title="Перейти на страницу…">Страница <strong>1</strong> из <strong>3</strong></a> • <span><strong>1</strong><span class="page-sep">, </span><a href="./viewtopic.php?f=278&amp;t=17946&amp;sid=bdb4fed1a68dc40261fbf4dbfa96f3e3&amp;start=10">2</a><span class="page-sep">, </span><a href="./viewtopic.php?f=278&amp;t=17946&amp;sid=bdb4fed1a68dc40261fbf4dbfa96f3e3&amp;start=20">3</a></span>
# </div>, <div class="pagination">
# 			Сообщений: 25
# 			 • <a href="#" onclick="jumpto(); return false;" title="Перейти на страницу…">Страница <strong>1</strong> из <strong>3</strong></a> • <span><strong>1</strong><span class="page-sep">, </span><a href="./viewtopic.php?f=278&amp;t=17946&amp;sid=bdb4fed1a68dc40261fbf4dbfa96f3e3&amp;start=10">2</a><span class="page-sep">, </span><a href="./viewtopic.php?f=278&amp;t=17946&amp;sid=bdb4fed1a68dc40261fbf4dbfa96f3e3&amp;start=20">3</a></span>
# </div>]
# 25
