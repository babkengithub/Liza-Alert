# %%
import numpy as np
import pandas as pd
import re
import bs4
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
from scrapy import Selector

# Import requests
import requests

# Create the string html containing the HTML source
html = requests.get('https://lizaalert.org/forum/viewforum.php?f=213').content #url='google.com'

# Create the Selector object sel from html
sel = Selector(text=html)


uClient = uReq('https://lizaalert.org/forum/viewforum.php?f=213')
page_html = uClient.read()
uClient.close()
page_soup = soup(page_html, "html.parser")
containers2 = page_soup.findAll("div", {"class":"pagination"})
containers22 = str(containers2)
#print(containers22)

def page12(containers22):
    page1 = list()
    c = containers22.find("из ")
    page1.append(containers22[c+11])
    page1.append(containers22[c+12])
    if containers22[c+12] == "<":
        page1.pop()
    return page1

print('ALOOOOOOOOOOOO', page12(containers22))
if len(page12(containers22)) == 2:
    page_real = int(page12(containers22)[0] + page12(containers22)[1])
else:
    page_real = int(page12(containers22)[0])
print(page_real)

# Парсим
course_as = sel.xpath('//a[contains(@class,"right-box right")]')
print(course_as)
hrefs_from_css = course_as.css('::attr(href)')
print(str(hrefs_from_css)[1:])
next1 = "https://lizaalert.org/forum" + str(hrefs_from_css.extract()[0])[1:]
print("ссылка=", next1)
links_to_follow = "\"https://lizaalert.org/forum" + str(hrefs_from_css.extract()[0])[1:] + "\""
print(links_to_follow)

clean_link = str(hrefs_from_css.extract()[0])[1:len(hrefs_from_css.extract()[0])-2]
print(clean_link)
list_links = list()
for i in range((page_real)-1):
    list_links.append(clean_link)
print(list_links)

#За 500 надо пояснить! Но это вроде несложно
i=0
list1 = list()
for i in range(0,(page_real-1)*25, 25):
    i = i + 25
    list1.append(i)
print(list1)

result = [str(item) for item in list1]

#print(type(result[2]))

for i in range(len(list1)):
    list_links[i] += result[i]
#print(list_links)

for i in range(len(list_links)):
    list_links[i] = "https://lizaalert.org/forum" + list_links[i]
#print(list_links[10])
print(list_links)
# Out:
# ALOOOOOOOOOOOO ['2', '2']
# 22
# [<Selector xpath='//a[contains(@class,"right-box right")]' data='<a href="./viewforum.php?f=213&amp;sid=f'>]
# <Selector xpath='descendant-or-self::*/@href' data='./viewforum.php?f=213&sid=febb2793057cb9'>]
# ссылка= https://lizaalert.org/forum/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=25
# "https://lizaalert.org/forum/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=25"
# /viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=
# ['/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=', '/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=', '/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=', '/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=', '/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=', '/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=', '/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=', '/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=', '/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=', '/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=', '/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=', '/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=', '/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=', '/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=', '/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=', '/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=', '/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=', '/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=', '/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=', '/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=', '/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=']
# [25, 50, 75, 100, 125, 150, 175, 200, 225, 250, 275, 300, 325, 350, 375, 400, 425, 450, 475, 500, 525]
# ['https://lizaalert.org/forum/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=25', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=50', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=75', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=100', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=125', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=150', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=175', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=200', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=225', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=250', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=275', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=300', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=325', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=350', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=375', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=400', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=425', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=450', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=475', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=500', 'https://lizaalert.org/forum/viewforum.php?f=213&sid=febb2793057cb9e096206a247377d8e1&start=525']

# %%
list_full = list()
#url = "'" + list_links[5] + "'"
#url1 = list_links[7]
for i in range((page_real)-1):
    html = requests.get(list_links[i]).content #url='google.com'
    sel = Selector(text=html)

    course_as1 = sel.css('a.topictitle')
    hrefs1_from_css = course_as1.css('::attr(href)')
#syka
    list0 = list()
    for i in range(0, len(hrefs1_from_css.extract())):
        list0.append("https://lizaalert.org/forum" + str(hrefs1_from_css.extract()[i])[1:])
        list_full.append(list0[i])
print(list_full)
print(len(list_full))
# Out:
# ['https://lizaalert.org/forum/viewtopic.php?f=213&t=11738&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=24782&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=24833&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=19833&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=24424&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=24504&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=24561&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=24705&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=24609&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=24586&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=22989&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=24500&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=24434&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=24414&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=24361&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=24341&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=24246&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=24171&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=16238&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=24204&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=24169&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=24150&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=24166&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=24163&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=23934&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=24070&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=11738&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=23857&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=23909&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=23890&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=23821&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=23800&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=23638&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=23767&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=23735&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=23729&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=23694&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=22246&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=23372&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=23623&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=23495&sid=febb2793057cb9e096206a247377d8e1', 'https://lizaalert.org/forum/viewtopic.php?f=213&t=23559&sid=fe ...
# 533
